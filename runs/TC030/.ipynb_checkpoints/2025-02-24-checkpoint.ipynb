# %%
import os 
from datetime import date
from matplotlib import pyplot as plt
import numpy as np

# we need to set the current path to the directory
# containing the suite3d repository, this hack should
# do the trick
os.chdir(os.path.dirname(os.path.abspath("")))

from suite3d.job import Job
from suite3d import io
from suite3d import plot_utils as plot
from suite3d import file_utils as flu

# %%
subjects_dir =   '/mnt/zenneth-subjects/'
expt_info = { 
    'subject':         'TC030',
    'date' :          '2025-02-24',
    'expnum' :         [3],}
n_planes = 9
tifs, si_params, exp_str = flu.find_exp(subjects_dir, **expt_info, verbose=False, get_si_params=False)

data_dir = '/mnt/md0/data/' + exp_str

os.makedirs(data_dir, exist_ok=True)

# %%
# Set the mandatory parameters
params = {
    # volume rate
    'fs': io.get_vol_rate(tifs[0]) / 9,
    
    # planes to analyze. 0 is typically the flyback, so we exclude it here
    'planes' : np.array([1,2,3,4,5,6,7,8]), 
    # number of planes recorded by scanimage, including the flyback
    'n_ch_tif' : 9,
    
    # Decay time of the Ca indicator in seconds. 1.3 for GCaMP6s. This example is for GCamP8m
    'tau' : 1.3,
    'lbm' : False, 
    'num_colors' : 2, # how many color channels were recorded by scanimage
    'functional_color_channel' : 0, # which color channel is the functional one
     # voxel size in z,y,x in microns
    'voxel_size_um' : (20, 1.5, 1.5),

    # number of files to use for the initial pass
    # usually, ~500 frames is a good rule of thumb
    # we will just use 200 here for speed
    'n_init_files' :  4,

    # 3D GPU registration - fast! 
    '3d_reg' : True,
    'gpu_reg' : True,
    
    # note : 3D CPU is not supported yet
    'subtract_crosstalk' : False, # turn off some lbm-only features
    'fuse_strips' : False, # turn off some lbm-only features

    
}

# %%
# Create the job
job = Job(r'/mnt/md0/runs','demo-std', tifs = tifs,
          params=params, create=True, overwrite=True, verbosity = 3)
# Out:
# Job directory /mnt/md0/runs/s3d-demo-std already exists
# Loading job directory for demo-std in /mnt/md0/runs
#    Loading dirs
#       Found dir registered_fused_data
#       Found dir summary
#       Found dir iters
#    Loading default params
#       Updating param fs
#       Updating param planes
#       Updating param n_ch_tif
#       Updating param tau
#       Updating param lbm
#       Updating param num_colors
#       Updating param functional_color_channel
#       Updating param voxel_size_um
#       Updating param n_init_files
#       Updating param 3d_reg
#       Updating param gpu_reg
#       Updating param subtract_crosstalk
#       Updating param fuse_strips
#    Updated main params file

# %%
job.run_init_pass()
# Out:
#    Saved a copy of params at /mnt/md0/runs/s3d-demo-std/summary
#    Updated main params file
# Launching initial pass
# Saving summary to /mnt/md0/runs/s3d-demo-std/summary/summary.npy
#    Loading init tifs with 9 channels
#       Loading tiff 1/4: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00005.tif
#       Loading tiff 2/4: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00010.tif
#       Loading tiff 3/4: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00015.tif
#       Loading tiff 4/4: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00020.tif
#    Loaded 4 files, total 3.91 GB
#    Selecting 500 random frames from the init tif files
#    Loaded movie with 500 frames and shape 9, 512, 512
#       Enforcing positivity in mean image
#    No crosstalk estimation or subtraction
#    Using 3d registration
#    Computing plane alignment shifts
#    Applying plane alignment shifts
#    Launching 3D GPU reference image calculation
#       Seeding reference image with most active frames
#       Completed iter 1 out of 8 in  4.35s using  68/490 frames
#       Completed iter 2 out of 8 in  4.58s using  121/490 frames
#       Completed iter 3 out of 8 in  4.89s using  174/490 frames
#       Completed iter 4 out of 8 in  5.19s using  227/490 frames
#       Completed iter 5 out of 8 in  5.51s using  280/490 frames
#       Completed iter 6 out of 8 in  5.80s using  333/490 frames
#       Completed iter 7 out of 8 in  6.12s using  386/490 frames
#       Completed iter 8 out of 8 in  3.90s using  440/490 frames
#       Used 440 frames to make the reference image
#    Saved init mov to /mnt/md0/runs/s3d-demo-std/summary/init_mov.npy
#    Saving summary to /mnt/md0/runs/s3d-demo-std/summary/summary.npy
#    Initial pass complete. See /mnt/md0/runs/s3d-demo-std/summary for details

# %%
# If you have large tiffs, split the large tiffs into files of size 100 after registration
job.params['split_tif_size'] = 100

# %%
# OPTIONAL: load and take a look at the reference image
summary = job.load_summary()
ref_img = summary['ref_img_3d']

# # view 1 plane at a time
# plot.show_img(ref_img[3], figsize=(3,4))

# # interactive 3D viewer
# plot.VolumeViewer(ref_img)

# %%
job.register()
# Out:
#       Found dir /mnt/md0/runs/s3d-demo-std/registered_fused_data
#       Updating self.dirs tag registered_fused_data
#    Saved a copy of params at /mnt/md0/runs/s3d-demo-std/registered_fused_data
#    Updated main params file
#    Starting registration: 3D: True, GPU: True
#    Not clipping frames for registration
# Will analyze 24 tifs in 24 batches
#    Enforcing positivity
#    Launching IO thread
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00001.tif
#          Memory at batch 0.  Total Used: 109.244 GB, Virtual Available: 409.637 GB, Virtual Used: 093.558 GB, Swap Used: 015.685 GB
# Loading Batch 0 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 0 IO thread joined
#          Memory after IO thread joinTotal Used: 110.228 GB, Virtual Available: 408.653 GB, Virtual Used: 094.543 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 111.199 GB, Virtual Available: 407.682 GB, Virtual Used: 095.514 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 110.219 GB, Virtual Available: 408.662 GB, Virtual Used: 094.534 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 110.219 GB, Virtual Available: 408.662 GB, Virtual Used: 094.534 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00002.tif
#    Completed rigid reg on batch in :2.9801523685455322s
#    Shifted the mov in: 0.6783409118652344s
#          After all GPU Batches:Total Used: 114.186 GB, Virtual Available: 404.695 GB, Virtual Used: 098.501 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0000.npy
#          Saved in 0.77 sec
#       Computing quality metrics and saving
# /home/ali/packages/s2p-lbm/suite3d/quality_metrics.py:41: RuntimeWarning: invalid value encountered in divide
#   dff = df / fs.mean(axis=1,keepdims=True)
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0001.npy
#          Saved in 0.70 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0002.npy
#          Saved in 0.17 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.555 GB, Virtual Available: 404.326 GB, Virtual Used: 098.870 GB, Swap Used: 015.685 GB
#          Memory at batch 1.  Total Used: 114.558 GB, Virtual Available: 404.323 GB, Virtual Used: 098.873 GB, Swap Used: 015.685 GB
# Loading Batch 1 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 1 IO thread joined
#          Memory after IO thread joinTotal Used: 114.187 GB, Virtual Available: 404.694 GB, Virtual Used: 098.502 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.188 GB, Virtual Available: 405.693 GB, Virtual Used: 097.503 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.205 GB, Virtual Available: 406.676 GB, Virtual Used: 096.520 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.205 GB, Virtual Available: 406.676 GB, Virtual Used: 096.520 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00003.tif
#    Completed rigid reg on batch in :2.864246368408203s
#    Shifted the mov in: 0.6728165149688721s
#          After all GPU Batches:Total Used: 118.146 GB, Virtual Available: 400.735 GB, Virtual Used: 102.461 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0003.npy
#          Saved in 0.75 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0004.npy
#          Saved in 0.70 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0005.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.328 GB, Virtual Available: 404.553 GB, Virtual Used: 098.642 GB, Swap Used: 015.685 GB
#          Memory at batch 2.  Total Used: 114.329 GB, Virtual Available: 404.552 GB, Virtual Used: 098.643 GB, Swap Used: 015.685 GB
# Loading Batch 2 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 2 IO thread joined
#          Memory after IO thread joinTotal Used: 114.253 GB, Virtual Available: 404.628 GB, Virtual Used: 098.568 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.264 GB, Virtual Available: 405.617 GB, Virtual Used: 097.578 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.282 GB, Virtual Available: 406.599 GB, Virtual Used: 096.596 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.282 GB, Virtual Available: 406.599 GB, Virtual Used: 096.596 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00004.tif
#    Completed rigid reg on batch in :2.897475242614746s
#    Shifted the mov in: 0.6740286350250244s
#          After all GPU Batches:Total Used: 117.798 GB, Virtual Available: 401.083 GB, Virtual Used: 102.112 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0006.npy
#          Saved in 0.68 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0007.npy
#          Saved in 0.68 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0008.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.217 GB, Virtual Available: 404.664 GB, Virtual Used: 098.531 GB, Swap Used: 015.685 GB
#          Memory at batch 3.  Total Used: 114.217 GB, Virtual Available: 404.664 GB, Virtual Used: 098.531 GB, Swap Used: 015.685 GB
# Loading Batch 3 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 3 IO thread joined
#          Memory after IO thread joinTotal Used: 114.223 GB, Virtual Available: 404.658 GB, Virtual Used: 098.538 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.224 GB, Virtual Available: 405.657 GB, Virtual Used: 097.539 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.247 GB, Virtual Available: 406.634 GB, Virtual Used: 096.562 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.247 GB, Virtual Available: 406.634 GB, Virtual Used: 096.562 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00005.tif
#    Completed rigid reg on batch in :2.8860604763031006s
#    Shifted the mov in: 0.6650059223175049s
#          After all GPU Batches:Total Used: 118.089 GB, Virtual Available: 400.792 GB, Virtual Used: 102.404 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0009.npy
#          Saved in 0.72 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0010.npy
#          Saved in 0.70 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0011.npy
#          Saved in 0.17 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.473 GB, Virtual Available: 404.408 GB, Virtual Used: 098.787 GB, Swap Used: 015.685 GB
#          Memory at batch 4.  Total Used: 114.474 GB, Virtual Available: 404.407 GB, Virtual Used: 098.788 GB, Swap Used: 015.685 GB
# Loading Batch 4 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 4 IO thread joined
#          Memory after IO thread joinTotal Used: 114.271 GB, Virtual Available: 404.610 GB, Virtual Used: 098.586 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.285 GB, Virtual Available: 405.596 GB, Virtual Used: 097.600 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.302 GB, Virtual Available: 406.579 GB, Virtual Used: 096.617 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.302 GB, Virtual Available: 406.579 GB, Virtual Used: 096.617 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 223, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00006.tif
#    Completed rigid reg on batch in :2.8338143825531006s
#    Shifted the mov in: 0.7738254070281982s
#          After all GPU Batches:Total Used: 116.961 GB, Virtual Available: 401.920 GB, Virtual Used: 101.275 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0012.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0013.npy
#          Saved in 0.68 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 23, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0014.npy
#          Saved in 0.17 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.228 GB, Virtual Available: 404.653 GB, Virtual Used: 098.542 GB, Swap Used: 015.685 GB
#          Memory at batch 5.  Total Used: 114.230 GB, Virtual Available: 404.651 GB, Virtual Used: 098.545 GB, Swap Used: 015.685 GB
# Loading Batch 5 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 5 IO thread joined
#          Memory after IO thread joinTotal Used: 114.224 GB, Virtual Available: 404.657 GB, Virtual Used: 098.538 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.214 GB, Virtual Available: 405.667 GB, Virtual Used: 097.529 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.233 GB, Virtual Available: 406.648 GB, Virtual Used: 096.547 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.233 GB, Virtual Available: 406.648 GB, Virtual Used: 096.547 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00007.tif
#    Completed rigid reg on batch in :2.8189890384674072s
#    Shifted the mov in: 0.773360013961792s
#          After all GPU Batches:Total Used: 117.049 GB, Virtual Available: 401.832 GB, Virtual Used: 101.363 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0015.npy
#          Saved in 0.66 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0016.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0017.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.252 GB, Virtual Available: 404.629 GB, Virtual Used: 098.567 GB, Swap Used: 015.685 GB
#          Memory at batch 6.  Total Used: 114.252 GB, Virtual Available: 404.629 GB, Virtual Used: 098.567 GB, Swap Used: 015.685 GB
# Loading Batch 6 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 6 IO thread joined
#          Memory after IO thread joinTotal Used: 114.253 GB, Virtual Available: 404.628 GB, Virtual Used: 098.568 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.263 GB, Virtual Available: 405.618 GB, Virtual Used: 097.577 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.281 GB, Virtual Available: 406.600 GB, Virtual Used: 096.595 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.281 GB, Virtual Available: 406.600 GB, Virtual Used: 096.595 GB, Swap Used: 015.685 GB
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00008.tif
#       Loaded batch of size (9, 222, 512, 512)
#    Completed rigid reg on batch in :2.846147060394287s
#    Shifted the mov in: 0.7147529125213623s
#          After all GPU Batches:Total Used: 116.199 GB, Virtual Available: 402.682 GB, Virtual Used: 100.513 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0018.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0019.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0020.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.411 GB, Virtual Available: 404.470 GB, Virtual Used: 098.726 GB, Swap Used: 015.685 GB
#          Memory at batch 7.  Total Used: 114.413 GB, Virtual Available: 404.468 GB, Virtual Used: 098.728 GB, Swap Used: 015.685 GB
# Loading Batch 7 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 7 IO thread joined
#          Memory after IO thread joinTotal Used: 114.235 GB, Virtual Available: 404.646 GB, Virtual Used: 098.550 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.236 GB, Virtual Available: 405.645 GB, Virtual Used: 097.551 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.259 GB, Virtual Available: 406.622 GB, Virtual Used: 096.574 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.259 GB, Virtual Available: 406.622 GB, Virtual Used: 096.574 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00009.tif
#    Completed rigid reg on batch in :2.861464500427246s
#    Shifted the mov in: 0.6887192726135254s
#          After all GPU Batches:Total Used: 116.261 GB, Virtual Available: 402.620 GB, Virtual Used: 100.575 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0021.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0022.npy
#          Saved in 0.69 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0023.npy
#          Saved in 0.17 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.797 GB, Virtual Available: 404.084 GB, Virtual Used: 099.111 GB, Swap Used: 015.685 GB
#          Memory at batch 8.  Total Used: 114.798 GB, Virtual Available: 404.083 GB, Virtual Used: 099.112 GB, Swap Used: 015.685 GB
# Loading Batch 8 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 8 IO thread joined
#          Memory after IO thread joinTotal Used: 114.281 GB, Virtual Available: 404.600 GB, Virtual Used: 098.595 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.295 GB, Virtual Available: 405.586 GB, Virtual Used: 097.610 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.310 GB, Virtual Available: 406.571 GB, Virtual Used: 096.624 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.310 GB, Virtual Available: 406.571 GB, Virtual Used: 096.624 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 223, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00010.tif
#    Completed rigid reg on batch in :2.8601596355438232s
#    Shifted the mov in: 0.6874845027923584s
#          After all GPU Batches:Total Used: 116.583 GB, Virtual Available: 402.298 GB, Virtual Used: 100.898 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0024.npy
#    Loaded 1 files, total 0.98 GB
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0025.npy
#          Saved in 0.64 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 23, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0026.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.277 GB, Virtual Available: 404.604 GB, Virtual Used: 098.592 GB, Swap Used: 015.685 GB
#          Memory at batch 9.  Total Used: 114.277 GB, Virtual Available: 404.604 GB, Virtual Used: 098.592 GB, Swap Used: 015.685 GB
# Loading Batch 9 of 23
#    Batch 9 IO thread joined
#          Memory after IO thread joinTotal Used: 114.277 GB, Virtual Available: 404.604 GB, Virtual Used: 098.592 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.270 GB, Virtual Available: 405.611 GB, Virtual Used: 097.585 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.287 GB, Virtual Available: 406.594 GB, Virtual Used: 096.602 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.287 GB, Virtual Available: 406.594 GB, Virtual Used: 096.602 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00011.tif
#    Completed rigid reg on batch in :2.8326656818389893s
#    Shifted the mov in: 0.8276534080505371s
#          After all GPU Batches:Total Used: 117.352 GB, Virtual Available: 401.529 GB, Virtual Used: 101.666 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0027.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0028.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0029.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.319 GB, Virtual Available: 404.562 GB, Virtual Used: 098.634 GB, Swap Used: 015.685 GB
#          Memory at batch 10. Total Used: 114.319 GB, Virtual Available: 404.562 GB, Virtual Used: 098.634 GB, Swap Used: 015.685 GB
# Loading Batch 10 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 10 IO thread joined
#          Memory after IO thread joinTotal Used: 114.320 GB, Virtual Available: 404.561 GB, Virtual Used: 098.635 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.331 GB, Virtual Available: 405.550 GB, Virtual Used: 097.646 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.352 GB, Virtual Available: 406.529 GB, Virtual Used: 096.667 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.352 GB, Virtual Available: 406.529 GB, Virtual Used: 096.667 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00012.tif
#    Completed rigid reg on batch in :2.819821357727051s
#    Shifted the mov in: 0.7560009956359863s
#          After all GPU Batches:Total Used: 117.468 GB, Virtual Available: 401.413 GB, Virtual Used: 101.782 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0030.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0031.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0032.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.272 GB, Virtual Available: 404.609 GB, Virtual Used: 098.586 GB, Swap Used: 015.685 GB
#          Memory at batch 11. Total Used: 114.272 GB, Virtual Available: 404.609 GB, Virtual Used: 098.586 GB, Swap Used: 015.685 GB
# Loading Batch 11 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 11 IO thread joined
#          Memory after IO thread joinTotal Used: 114.277 GB, Virtual Available: 404.604 GB, Virtual Used: 098.592 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.278 GB, Virtual Available: 405.603 GB, Virtual Used: 097.593 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.303 GB, Virtual Available: 406.578 GB, Virtual Used: 096.618 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00013.tif
#          After IO thread launch:Total Used: 112.303 GB, Virtual Available: 406.578 GB, Virtual Used: 096.618 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#    Completed rigid reg on batch in :2.825953483581543s
#    Shifted the mov in: 0.7485635280609131s
#          After all GPU Batches:Total Used: 117.630 GB, Virtual Available: 401.251 GB, Virtual Used: 101.945 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0033.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0034.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0035.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.446 GB, Virtual Available: 404.435 GB, Virtual Used: 098.761 GB, Swap Used: 015.685 GB
#          Memory at batch 12. Total Used: 114.446 GB, Virtual Available: 404.435 GB, Virtual Used: 098.761 GB, Swap Used: 015.685 GB
# Loading Batch 12 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 12 IO thread joined
#          Memory after IO thread joinTotal Used: 114.451 GB, Virtual Available: 404.430 GB, Virtual Used: 098.766 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.458 GB, Virtual Available: 405.423 GB, Virtual Used: 097.772 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.477 GB, Virtual Available: 406.404 GB, Virtual Used: 096.792 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.477 GB, Virtual Available: 406.404 GB, Virtual Used: 096.792 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00014.tif
#    Completed rigid reg on batch in :2.845726490020752s
#    Shifted the mov in: 0.7283527851104736s
#          After all GPU Batches:Total Used: 116.371 GB, Virtual Available: 402.510 GB, Virtual Used: 100.686 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0036.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0037.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0038.npy
#          Saved in 0.16 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.647 GB, Virtual Available: 404.234 GB, Virtual Used: 098.962 GB, Swap Used: 015.685 GB
#          Memory at batch 13. Total Used: 114.649 GB, Virtual Available: 404.232 GB, Virtual Used: 098.964 GB, Swap Used: 015.685 GB
# Loading Batch 13 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 13 IO thread joined
#          Memory after IO thread joinTotal Used: 114.404 GB, Virtual Available: 404.477 GB, Virtual Used: 098.719 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.418 GB, Virtual Available: 405.463 GB, Virtual Used: 097.733 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.433 GB, Virtual Available: 406.448 GB, Virtual Used: 096.748 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.433 GB, Virtual Available: 406.448 GB, Virtual Used: 096.748 GB, Swap Used: 015.685 GB
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00015.tif
#       Loaded batch of size (9, 223, 512, 512)
#    Completed rigid reg on batch in :2.8518683910369873s
#    Shifted the mov in: 0.7323927879333496s
#          After all GPU Batches:Total Used: 116.440 GB, Virtual Available: 402.441 GB, Virtual Used: 100.754 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0039.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0040.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 23, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0041.npy
#          Saved in 0.15 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.640 GB, Virtual Available: 404.241 GB, Virtual Used: 098.955 GB, Swap Used: 015.685 GB
#          Memory at batch 14. Total Used: 114.641 GB, Virtual Available: 404.240 GB, Virtual Used: 098.955 GB, Swap Used: 015.685 GB
# Loading Batch 14 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 14 IO thread joined
#          Memory after IO thread joinTotal Used: 114.471 GB, Virtual Available: 404.410 GB, Virtual Used: 098.785 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.473 GB, Virtual Available: 405.408 GB, Virtual Used: 097.787 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.495 GB, Virtual Available: 406.386 GB, Virtual Used: 096.810 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.495 GB, Virtual Available: 406.386 GB, Virtual Used: 096.810 GB, Swap Used: 015.685 GB
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00016.tif
#       Loaded batch of size (9, 222, 512, 512)
#    Completed rigid reg on batch in :2.851855516433716s
#    Shifted the mov in: 0.6916370391845703s
#          After all GPU Batches:Total Used: 116.403 GB, Virtual Available: 402.478 GB, Virtual Used: 100.718 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0042.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0043.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0044.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.451 GB, Virtual Available: 404.430 GB, Virtual Used: 098.766 GB, Swap Used: 015.685 GB
#          Memory at batch 15. Total Used: 114.453 GB, Virtual Available: 404.428 GB, Virtual Used: 098.768 GB, Swap Used: 015.685 GB
# Loading Batch 15 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 15 IO thread joined
#          Memory after IO thread joinTotal Used: 114.419 GB, Virtual Available: 404.462 GB, Virtual Used: 098.734 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.420 GB, Virtual Available: 405.461 GB, Virtual Used: 097.735 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.437 GB, Virtual Available: 406.444 GB, Virtual Used: 096.752 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.437 GB, Virtual Available: 406.444 GB, Virtual Used: 096.752 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00017.tif
#    Completed rigid reg on batch in :2.8514134883880615s
#    Shifted the mov in: 0.680368185043335s
#          After all GPU Batches:Total Used: 116.451 GB, Virtual Available: 402.430 GB, Virtual Used: 100.766 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0045.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0046.npy
#          Saved in 0.66 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0047.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.849 GB, Virtual Available: 404.033 GB, Virtual Used: 099.163 GB, Swap Used: 015.685 GB
#          Memory at batch 16. Total Used: 114.852 GB, Virtual Available: 404.029 GB, Virtual Used: 099.166 GB, Swap Used: 015.685 GB
# Loading Batch 16 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 16 IO thread joined
#          Memory after IO thread joinTotal Used: 114.482 GB, Virtual Available: 404.399 GB, Virtual Used: 098.797 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.485 GB, Virtual Available: 405.396 GB, Virtual Used: 097.800 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.502 GB, Virtual Available: 406.379 GB, Virtual Used: 096.817 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.502 GB, Virtual Available: 406.379 GB, Virtual Used: 096.817 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00018.tif
#    Completed rigid reg on batch in :2.9401278495788574s
#    Shifted the mov in: 0.7447125911712646s
#          After all GPU Batches:Total Used: 118.215 GB, Virtual Available: 400.666 GB, Virtual Used: 102.530 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0048.npy
#          Saved in 0.71 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0049.npy
#          Saved in 0.70 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0050.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.594 GB, Virtual Available: 404.287 GB, Virtual Used: 098.908 GB, Swap Used: 015.685 GB
#          Memory at batch 17. Total Used: 114.596 GB, Virtual Available: 404.285 GB, Virtual Used: 098.911 GB, Swap Used: 015.685 GB
# Loading Batch 17 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 17 IO thread joined
#          Memory after IO thread joinTotal Used: 114.423 GB, Virtual Available: 404.458 GB, Virtual Used: 098.738 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.437 GB, Virtual Available: 405.444 GB, Virtual Used: 097.751 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.454 GB, Virtual Available: 406.427 GB, Virtual Used: 096.768 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.454 GB, Virtual Available: 406.427 GB, Virtual Used: 096.768 GB, Swap Used: 015.685 GB
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00019.tif
#       Loaded batch of size (9, 223, 512, 512)
#    Completed rigid reg on batch in :2.946038007736206s
#    Shifted the mov in: 0.7139103412628174s
#          After all GPU Batches:Total Used: 117.148 GB, Virtual Available: 401.733 GB, Virtual Used: 101.463 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0051.npy
#    Loaded 1 files, total 0.98 GB
#          Saved in 0.63 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0052.npy
#          Saved in 0.62 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 23, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0053.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.518 GB, Virtual Available: 404.363 GB, Virtual Used: 098.833 GB, Swap Used: 015.685 GB
#          Memory at batch 18. Total Used: 114.518 GB, Virtual Available: 404.363 GB, Virtual Used: 098.833 GB, Swap Used: 015.685 GB
# Loading Batch 18 of 23
#    Batch 18 IO thread joined
#          Memory after IO thread joinTotal Used: 114.518 GB, Virtual Available: 404.363 GB, Virtual Used: 098.833 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.521 GB, Virtual Available: 405.360 GB, Virtual Used: 097.835 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.540 GB, Virtual Available: 406.341 GB, Virtual Used: 096.855 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.540 GB, Virtual Available: 406.341 GB, Virtual Used: 096.855 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00020.tif
#    Completed rigid reg on batch in :2.94661545753479s
#    Shifted the mov in: 0.726346492767334s
#          After all GPU Batches:Total Used: 116.428 GB, Virtual Available: 402.453 GB, Virtual Used: 100.742 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0054.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0055.npy
#          Saved in 0.64 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0056.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.446 GB, Virtual Available: 404.436 GB, Virtual Used: 098.760 GB, Swap Used: 015.685 GB
#          Memory at batch 19. Total Used: 114.446 GB, Virtual Available: 404.436 GB, Virtual Used: 098.760 GB, Swap Used: 015.685 GB
# Loading Batch 19 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 19 IO thread joined
#          Memory after IO thread joinTotal Used: 114.445 GB, Virtual Available: 404.437 GB, Virtual Used: 098.759 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.445 GB, Virtual Available: 405.436 GB, Virtual Used: 097.760 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.473 GB, Virtual Available: 406.408 GB, Virtual Used: 096.788 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.473 GB, Virtual Available: 406.408 GB, Virtual Used: 096.788 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00021.tif
#    Completed rigid reg on batch in :2.9062061309814453s
#    Shifted the mov in: 0.8564400672912598s
#          After all GPU Batches:Total Used: 117.509 GB, Virtual Available: 401.372 GB, Virtual Used: 101.824 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0057.npy
#          Saved in 0.64 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0058.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0059.npy
#          Saved in 0.15 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.514 GB, Virtual Available: 404.367 GB, Virtual Used: 098.829 GB, Swap Used: 015.685 GB
#          Memory at batch 20. Total Used: 114.514 GB, Virtual Available: 404.367 GB, Virtual Used: 098.829 GB, Swap Used: 015.685 GB
# Loading Batch 20 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 20 IO thread joined
#          Memory after IO thread joinTotal Used: 114.512 GB, Virtual Available: 404.369 GB, Virtual Used: 098.826 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.518 GB, Virtual Available: 405.363 GB, Virtual Used: 097.833 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.537 GB, Virtual Available: 406.344 GB, Virtual Used: 096.852 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.537 GB, Virtual Available: 406.344 GB, Virtual Used: 096.852 GB, Swap Used: 015.685 GB
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00022.tif
#       Loaded batch of size (9, 222, 512, 512)
#    Completed rigid reg on batch in :2.8974406719207764s
#    Shifted the mov in: 0.8101825714111328s
#          After all GPU Batches:Total Used: 117.590 GB, Virtual Available: 401.291 GB, Virtual Used: 101.904 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0060.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0061.npy
#          Saved in 0.65 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0062.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.469 GB, Virtual Available: 404.412 GB, Virtual Used: 098.783 GB, Swap Used: 015.685 GB
#          Memory at batch 21. Total Used: 114.469 GB, Virtual Available: 404.412 GB, Virtual Used: 098.783 GB, Swap Used: 015.685 GB
# Loading Batch 21 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 21 IO thread joined
#          Memory after IO thread joinTotal Used: 114.457 GB, Virtual Available: 404.424 GB, Virtual Used: 098.771 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.460 GB, Virtual Available: 405.421 GB, Virtual Used: 097.775 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.477 GB, Virtual Available: 406.404 GB, Virtual Used: 096.792 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.477 GB, Virtual Available: 406.404 GB, Virtual Used: 096.792 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 222, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00023.tif
#    Completed rigid reg on batch in :2.9038193225860596s
#    Shifted the mov in: 0.8554699420928955s
#          After all GPU Batches:Total Used: 117.519 GB, Virtual Available: 401.362 GB, Virtual Used: 101.834 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0063.npy
#          Saved in 0.66 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0064.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 22, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0065.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.504 GB, Virtual Available: 404.377 GB, Virtual Used: 098.819 GB, Swap Used: 015.685 GB
#          Memory at batch 22. Total Used: 114.504 GB, Virtual Available: 404.377 GB, Virtual Used: 098.819 GB, Swap Used: 015.685 GB
# Loading Batch 22 of 23
#    Loaded 1 files, total 0.98 GB
#    Batch 22 IO thread joined
#          Memory after IO thread joinTotal Used: 114.507 GB, Virtual Available: 404.374 GB, Virtual Used: 098.821 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 113.518 GB, Virtual Available: 405.363 GB, Virtual Used: 097.832 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 112.534 GB, Virtual Available: 406.347 GB, Virtual Used: 096.849 GB, Swap Used: 015.685 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.534 GB, Virtual Available: 406.347 GB, Virtual Used: 096.849 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 223, 512, 512)
#       Loading tiff 1/1: /mnt/zenneth-subjects/TC030/2025-02-24/3/2025-02-24_3_TC030_2P_00001_00024.tif
#    Completed rigid reg on batch in :2.931872606277466s
#    Loaded 1 files, total 0.05 GB
#    Shifted the mov in: 0.7537930011749268s
#          After all GPU Batches:Total Used: 115.524 GB, Virtual Available: 403.357 GB, Virtual Used: 099.839 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0066.npy
#          Saved in 0.63 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 100, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0067.npy
#          Saved in 0.62 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (9, 23, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0068.npy
#          Saved in 0.14 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 113.545 GB, Virtual Available: 405.336 GB, Virtual Used: 097.859 GB, Swap Used: 015.685 GB
#          Memory at batch 23. Total Used: 113.545 GB, Virtual Available: 405.336 GB, Virtual Used: 097.859 GB, Swap Used: 015.685 GB
# Loading Batch 23 of 23
#    Batch 23 IO thread joined
#          Memory after IO thread joinTotal Used: 113.545 GB, Virtual Available: 405.336 GB, Virtual Used: 097.859 GB, Swap Used: 015.685 GB
#          Memory after movie copied from threadTotal Used: 111.614 GB, Virtual Available: 407.267 GB, Virtual Used: 095.929 GB, Swap Used: 015.685 GB
#          Memory after thread memory clearedTotal Used: 111.565 GB, Virtual Available: 407.316 GB, Virtual Used: 095.879 GB, Swap Used: 015.685 GB
#       Loaded batch of size (9, 12, 512, 512)
#    Completed rigid reg on batch in :0.16793084144592285s
#    Shifted the mov in: 0.03715920448303223s
#          After all GPU Batches:Total Used: 111.727 GB, Virtual Available: 407.154 GB, Virtual Used: 096.042 GB, Swap Used: 015.685 GB
#       Saving fused, registered file of shape (9, 12, 517, 512) to /mnt/md0/runs/s3d-demo-std/registered_fused_data/fused_reg_data0069.npy
#          Saved in 0.07 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 109.740 GB, Virtual Available: 409.141 GB, Virtual Used: 094.055 GB, Swap Used: 015.685 GB

# %%
corr_map = job.calculate_corr_map()
# Out:
#       Found dir /mnt/md0/runs/s3d-demo-std/corrmap
#       Updating self.dirs tag corrmap
#       Found dir /mnt/md0/runs/s3d-demo-std/mov_sub
#       Updating self.dirs tag mov_sub
#    Updated detection_timebin to 23 based on framerate and tau
#    Saved a copy of params at /mnt/md0/runs/s3d-demo-std/corrmap
#    Updated main params file
#    Computing correlation map of movie with 5123 frames, volume shape: 9, 517, 512
#       Running batch 1 of 7
#       Binning with timebin of size 23
#          Timer batch_timebin completed in 0.001 sec
# /tmp/ipykernel_655056/472069948.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   corr_map = job.calculate_corr_map()
#          Timer prep completed in 1.279 sec
#          Timer batch_setup completed in 0.078 sec
#          Timer batch_edgecrop completed in 0.014 sec
#          Timer accum_meanmeax completed in 0.086 sec
#          Timer batch_rolling_mean_filt completed in 0.062 sec
#          Timer batch_accum_sdmov completed in 0.191 sec
#          Timer batch_norm_sdmov completed in 0.034 sec
#          Loading movie of size (34, 9, 517, 512) into shared memory
#          Timer dtu_shmem completed in 0.277 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 1.820 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.077 sec
#          Timer dtu_cleanup completed in 0.128 sec
#          Timer batch_filt_reduce completed in 2.304 sec
#          Timer batch_accum_vmap completed in 0.009 sec
#          Timer batch completed in 2.980 sec
#          Timer save completed in 0.242 sec
#       Running batch 2 of 7
#       Binning with timebin of size 23
#          Timer batch_timebin completed in 0.002 sec
# /tmp/ipykernel_655056/472069948.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   corr_map = job.calculate_corr_map()
#          Timer prep completed in 1.392 sec
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 2 leaked shared_memory objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/resource_tracker.py:229: UserWarning: resource_tracker: '/psm_93c6087b': [Errno 2] No such file or directory: '/psm_93c6087b'
#   warnings.warn('resource_tracker: %r: %s' % (name, e))
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/resource_tracker.py:229: UserWarning: resource_tracker: '/psm_616594e5': [Errno 2] No such file or directory: '/psm_616594e5'
#   warnings.warn('resource_tracker: %r: %s' % (name, e))
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 2 leaked shared_memory objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/resource_tracker.py:229: UserWarning: resource_tracker: '/psm_616594e5': [Errno 2] No such file or directory: '/psm_616594e5'
#   warnings.warn('resource_tracker: %r: %s' % (name, e))
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/resource_tracker.py:229: UserWarning: resource_tracker: '/psm_93c6087b': [Errno 2] No such file or directory: '/psm_93c6087b'
#   warnings.warn('resource_tracker: %r: %s' % (name, e))
#          Timer batch_setup completed in 0.079 sec
#          Timer batch_edgecrop completed in 0.007 sec
#          Timer accum_meanmeax completed in 0.097 sec
#          Timer batch_rolling_mean_filt completed in 0.061 sec
#          Timer batch_accum_sdmov completed in 0.190 sec
#          Timer batch_norm_sdmov completed in 0.034 sec
#          Loading movie of size (34, 9, 517, 512) into shared memory
#          Timer dtu_shmem completed in 0.245 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 1.796 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.074 sec
#          Timer dtu_cleanup completed in 0.122 sec
#          Timer batch_filt_reduce completed in 2.238 sec
#          Timer batch_accum_vmap completed in 0.009 sec
#          Timer batch completed in 2.958 sec
#          Timer save completed in 0.251 sec
#       Running batch 3 of 7
#       Binning with timebin of size 23
#          Timer batch_timebin completed in 0.002 sec
# /tmp/ipykernel_655056/472069948.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   corr_map = job.calculate_corr_map()
#          Timer prep completed in 1.272 sec
#          Timer batch_setup completed in 0.079 sec
#          Timer batch_edgecrop completed in 0.014 sec
#          Timer accum_meanmeax completed in 0.094 sec
#          Timer batch_rolling_mean_filt completed in 0.061 sec
#          Timer batch_accum_sdmov completed in 0.189 sec
#          Timer batch_norm_sdmov completed in 0.035 sec
#          Loading movie of size (34, 9, 517, 512) into shared memory
#          Timer dtu_shmem completed in 0.242 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 1.851 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.076 sec
#          Timer dtu_cleanup completed in 0.125 sec
#          Timer batch_filt_reduce completed in 2.296 sec
#          Timer batch_accum_vmap completed in 0.011 sec
#          Timer batch completed in 3.038 sec
#          Timer save completed in 0.250 sec
#       Running batch 4 of 7
#       Binning with timebin of size 23
#          Timer batch_timebin completed in 0.002 sec
# /tmp/ipykernel_655056/472069948.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   corr_map = job.calculate_corr_map()
#          Timer prep completed in 1.358 sec
#          Timer batch_setup completed in 0.080 sec
#          Timer batch_edgecrop completed in 0.014 sec
#          Timer accum_meanmeax completed in 0.093 sec
#          Timer batch_rolling_mean_filt completed in 0.062 sec
#          Timer batch_accum_sdmov completed in 0.190 sec
#          Timer batch_norm_sdmov completed in 0.034 sec
#          Loading movie of size (34, 9, 517, 512) into shared memory
#          Timer dtu_shmem completed in 0.245 sec
#          Subtracting neuropil and applying cell filters
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-58:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-49:
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#
# KeyboardInterrupt
#
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ali/packages/s2p-lbm/suite3d/detection3d.py", line 537, in np_sub_and_conv3d_split_shmem_w
#     mov_filt[idx] = conv_filt_size[-1] * conv_filt(
# KeyboardInterrupt
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/scipy/ndimage/_filters.py", line 342, in gaussian_filter
#     gaussian_filter1d(input, sigma, axis, order, output,
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/scipy/ndimage/_filters.py", line 261, in gaussian_filter1d
#     return correlate1d(input, weights, axis, output, mode, cval, 0)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/scipy/ndimage/_filters.py", line 133, in correlate1d
#     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# KeyboardInterrupt
# Process ForkPoolWorker-50:
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/ali/packages/s2p-lbm/suite3d/detection3d.py", line 537, in np_sub_and_conv3d_split_shmem_w
#     mov_filt[idx] = conv_filt_size[-1] * conv_filt(
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/scipy/ndimage/_filters.py", line 342, in gaussian_filter
#     gaussian_filter1d(input, sigma, axis, order, output,
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/scipy/ndimage/_filters.py", line 261, in gaussian_filter1d
#     return correlate1d(input, weights, axis, output, mode, cval, 0)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/scipy/ndimage/_filters.py", line 133, in correlate1d
#     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# KeyboardInterrupt
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7ff4985b8640>>
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/ipykernel/iostream.py", line 609, in flush
#     if not evt.wait(self.flush_timeout):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt:
# Process ForkPoolWorker-66:
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7ff4985b8640>>
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/ipykernel/iostream.py", line 609, in flush
#     if not evt.wait(self.flush_timeout):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt:
# Process ForkPoolWorker-65:
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7ff4985b8640>>
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/ipykernel/iostream.py", line 609, in flush
#     if not evt.wait(self.flush_timeout):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/threading.py", line 558, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/threading.py", line 306, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt:
# Process ForkPoolWorker-67:
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt

# %%
res = job.load_corr_map_results()
vmap = res['vmap']

# %%
job.params['patch_size_xy'] = (550, 550)
# for speed, only segment a single patch
job.segment_rois()

# %%
job.compute_npil_masks()
traces = job.extract_and_deconvolve()

# %%
job.export_results('path/to/output',result_dir_name='rois')
# Out:
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.

# %% [markdown]
# To take a look at the outputs in napari, navigate to the suite3d directory in a command shell and run the following:
# ```
# python curation.py curation --output_dir /path/to/output/rois
# ```
