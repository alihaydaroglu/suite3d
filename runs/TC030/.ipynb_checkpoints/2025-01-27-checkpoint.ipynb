# %%
# %load_ext autoreload
# %autoreload 2

import os 
import shutil
import numpy as n
from datetime import date
from matplotlib import pyplot as plt
import time
import napari

# %%
os.chdir('/home/ali/packages/s2p-lbm/')

from suite3d.job import Job
from suite3d import lbmio, utils, ui
from suite3d import tiff_utils as tfu
from suite3d import file_utils as flu
from suite3d import nbtools as nbui
from suite3d import extension as ext
# Out:
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/paramiko/pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/paramiko/transport.py:258: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
subjects_dir =   '/mnt/zortex-subjects/'
expt_info = { 
    'subject':         'TC030',
    'date' :          '2025-01-27',
    'expnum' :         [3,4],}
n_planes = 9
original_tifs, si_params, exp_str = flu.find_exp(subjects_dir, **expt_info, verbose=False, get_si_params=False)

data_dir = '/mnt/md0/data/' + exp_str

os.makedirs(data_dir, exist_ok=True)

# %%
original_tifs
# Out:
# ['/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00001.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00002.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00003.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00004.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00005.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00006.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00007.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00008.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00009.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00001.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00002.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00003.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00004.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00005.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00006.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00007.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00008.tif',
#  '/mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00009.tif']

# %%
dir_idx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dir_idx
#
# NameError: name 'dir_idx' is not defined

# %%
import tifffile

# %%
n_leftover_planes = 0
tifs = []
leftover_planes = None
dir_idx_old = -1
for tif_idx, tif in enumerate(original_tifs):
    dir_idx = tif.split('/')[-2]
    if dir_idx_old != dir_idx:
        n_leftover_planes = 0
        dir_idx_old = dir_idx
    save_dir = os.path.join(data_dir, dir_idx)
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir,f"{tif_idx:05d}.tiff")
    tf = tifffile.TiffFile(tif)
    n_planes_tif = len(tf.pages)
    n_first_planes = (n_planes - n_leftover_planes) % n_planes
    
    
    n_full_frames = (n_planes_tif - n_first_planes) // n_planes
    n_new_leftovers = (n_planes_tif - n_first_planes) % n_planes

    all_frames = tf.asarray()

    if n_leftover_planes > 0:
        all_frames = n.concatenate([leftover_planes, all_frames],axis=0)

    full_frames = all_frames[:n_planes_tif+n_leftover_planes-n_new_leftovers]
    leftover_planes = all_frames[n_planes_tif+n_leftover_planes-n_new_leftovers:]

    print(f"Tif {tif_idx:03d} has {n_planes_tif} planes. Path: {tif}")
    print(f"First {n_first_planes} planes complete the {n_leftover_planes} from the previous tif to form a full frame")
    
    n_leftover_planes = n_new_leftovers
    print(f"Of the remaining {n_planes_tif - n_first_planes}, we complete {n_full_frames} frames with {n_full_frames * n_planes} planes")
    print(f"This leaves {n_leftover_planes} planes to be completed by the next tif")
    mov = full_frames.reshape(-1, *full_frames.shape[1:])
    print(f"Saving movie of shape {mov.shape} to {save_path}")
    tifffile.imsave(save_path, mov, dtype=mov.dtype)
    tifs.append(save_path)
# Out:
# Tif 000 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00001.tif
# First 0 planes complete the 0 from the previous tif to form a full frame
# Of the remaining 2000, we complete 222 frames with 1998 planes
# This leaves 2 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00000.tiff
# Tif 001 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00002.tif
# First 7 planes complete the 2 from the previous tif to form a full frame
# Of the remaining 1993, we complete 221 frames with 1989 planes
# This leaves 4 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00001.tiff
# Tif 002 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00003.tif
# First 5 planes complete the 4 from the previous tif to form a full frame
# Of the remaining 1995, we complete 221 frames with 1989 planes
# This leaves 6 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00002.tiff
# Tif 003 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00004.tif
# First 3 planes complete the 6 from the previous tif to form a full frame
# Of the remaining 1997, we complete 221 frames with 1989 planes
# This leaves 8 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00003.tiff
# Tif 004 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00005.tif
# First 1 planes complete the 8 from the previous tif to form a full frame
# Of the remaining 1999, we complete 222 frames with 1998 planes
# This leaves 1 planes to be completed by the next tif
# Saving movie of shape (2007, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00004.tiff
# Tif 005 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00006.tif
# First 8 planes complete the 1 from the previous tif to form a full frame
# Of the remaining 1992, we complete 221 frames with 1989 planes
# This leaves 3 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00005.tiff
# Tif 006 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00007.tif
# First 6 planes complete the 3 from the previous tif to form a full frame
# Of the remaining 1994, we complete 221 frames with 1989 planes
# This leaves 5 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00006.tiff
# Tif 007 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00008.tif
# First 4 planes complete the 5 from the previous tif to form a full frame
# Of the remaining 1996, we complete 221 frames with 1989 planes
# This leaves 7 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00007.tiff
# Tif 008 has 136 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/3/2025-01-27_3_TC030_2P_00001_00009.tif
# First 2 planes complete the 7 from the previous tif to form a full frame
# Of the remaining 134, we complete 14 frames with 126 planes
# This leaves 8 planes to be completed by the next tif
# Saving movie of shape (135, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/3/00008.tiff
# Tif 009 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00001.tif
# First 0 planes complete the 0 from the previous tif to form a full frame
# Of the remaining 2000, we complete 222 frames with 1998 planes
# This leaves 2 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00009.tiff
# Tif 010 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00002.tif
# First 7 planes complete the 2 from the previous tif to form a full frame
# Of the remaining 1993, we complete 221 frames with 1989 planes
# This leaves 4 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00010.tiff
# Tif 011 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00003.tif
# First 5 planes complete the 4 from the previous tif to form a full frame
# Of the remaining 1995, we complete 221 frames with 1989 planes
# This leaves 6 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00011.tiff
# Tif 012 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00004.tif
# First 3 planes complete the 6 from the previous tif to form a full frame
# Of the remaining 1997, we complete 221 frames with 1989 planes
# This leaves 8 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00012.tiff
# Tif 013 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00005.tif
# First 1 planes complete the 8 from the previous tif to form a full frame
# Of the remaining 1999, we complete 222 frames with 1998 planes
# This leaves 1 planes to be completed by the next tif
# Saving movie of shape (2007, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00013.tiff
# Tif 014 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00006.tif
# First 8 planes complete the 1 from the previous tif to form a full frame
# Of the remaining 1992, we complete 221 frames with 1989 planes
# This leaves 3 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00014.tiff
# Tif 015 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00007.tif
# First 6 planes complete the 3 from the previous tif to form a full frame
# Of the remaining 1994, we complete 221 frames with 1989 planes
# This leaves 5 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00015.tiff
# Tif 016 has 2000 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00008.tif
# First 4 planes complete the 5 from the previous tif to form a full frame
# Of the remaining 1996, we complete 221 frames with 1989 planes
# This leaves 7 planes to be completed by the next tif
# Saving movie of shape (1998, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00016.tiff
# Tif 017 has 59 planes. Path: /mnt/zortex-subjects/TC030/2025-01-27/4/2025-01-27_4_TC030_2P_00001_00009.tif
# First 2 planes complete the 7 from the previous tif to form a full frame
# Of the remaining 57, we complete 6 frames with 54 planes
# This leaves 3 planes to be completed by the next tif
# Saving movie of shape (63, 512, 512) to /mnt/md0/data/TC030_2025-01-27_3-4/4/00017.tiff

# %%
vol_rate = 30 / 9

job_params = {   
    'lbm' : False,
    # number of channels recorded in the tiff file, typically 30
    'n_ch_tif' : 9,
    # convert from the Scanimage channel ordering to deep-to-shallow ordering
    # in our case, ScanImage channel numbers are in temporal order. 
    'planes' : n.arange(n_planes),
    'multiplane_2p_use_planes' : n.array([2,3,4,5,6, 7, 8]),
    # number of files to use for the initial pass
    'n_init_files' :   3,
    'init_file_pool' : [(0, 6)],

    # volume rate in acquisition
    'fs' : vol_rate,
    'lbm' : False,
    'subtract_crosstalk' : False,
    'fuse_strips' : False,
    
    # 3D GPU registration - fast! 
    # for now, 3D + GPU are well-tested, other options might have minor bugs
    # if you run into them, let us know! we'll fix them
    '3d_reg' : True,
    'gpu_reg' : True,
}


savedir = os.path.join('/mnt/md0/runs', expt_info['subject'], expt_info['date'])
os.makedirs(savedir, exist_ok=True)

# Create the job
job = Job('/mnt/md0/runs',exp_str, tifs = tifs,
          params=job_params, create=True, overwrite=True, verbosity = 3)
# Out:
# Job directory /mnt/md0/runs/s3d-TC030_2025-01-27_3-4 already exists
# Loading job directory for TC030_2025-01-27_3-4 in /mnt/md0/runs
#    Loading dirs
#       Found dir registered_fused_data
#       Found dir summary
#       Found dir iters
#    Loading default params
#       Updating param lbm
#       Updating param n_ch_tif
#       Updating param planes
#       Updating param multiplane_2p_use_planes
#       Updating param n_init_files
#       Updating param init_file_pool
#       Updating param fs
#       Updating param subtract_crosstalk
#       Updating param fuse_strips
#       Updating param 3d_reg
#       Updating param gpu_reg
#    Updated main params file

# %%
job.run_init_pass()
# Out:
#    Saved a copy of params at /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/summary
#    Updated main params file
# Launching initial pass
# Saving summary to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/summary/summary.npy
#    Loading init tifs with 9 channels
#       Loading tiff 1/3: /mnt/md0/data/TC030_2025-01-27_3-4/3/00001.tiff
#       Loading tiff 2/3: /mnt/md0/data/TC030_2025-01-27_3-4/3/00003.tiff
#       Loading tiff 3/3: /mnt/md0/data/TC030_2025-01-27_3-4/3/00004.tiff
#    Loaded 3 files, total 2.28 GB
#    Loaded movie with 667 frames and shape 7, 512, 512
#       Enforcing positivity in mean image
#    No crosstalk estimation or subtraction
#    Using 3d registration
#    Computing plane alignment shifts
#    Applying plane alignment shifts
#    Launching 3D GPU reference image calculation
#       Seeding reference image with most active frames
#       Completed iter 1 out of 8 in  5.94s using  85/667 frames
#       Completed iter 2 out of 8 in  5.58s using  159/667 frames
#       Completed iter 3 out of 8 in  5.03s using  232/667 frames
#       Completed iter 4 out of 8 in  5.36s using  305/667 frames
#       Completed iter 5 out of 8 in  5.66s using  379/667 frames
#       Completed iter 6 out of 8 in  6.05s using  452/667 frames
#       Completed iter 7 out of 8 in  6.37s using  525/667 frames
#       Completed iter 8 out of 8 in  3.95s using  599/667 frames
#       Used 599 frames to make the reference image
#    Saved init mov to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/summary/init_mov.npy
#    Saving summary to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/summary/summary.npy
#    Initial pass complete. See /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/summary for details

# %%
sum = job.load_summary()

# %%
job.register()
# Out:
#       Found dir /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data
#       Updating self.dirs tag registered_fused_data
#    Saved a copy of params at /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data
#    Updated main params file
#    Starting registration: 3D: True, GPU: True
#    Not clipping frames for registration
# Will analyze 18 tifs in 18 batches
#    Enforcing positivity
#    Launching IO thread
#          Memory at batch 0.  Total Used: 096.357 GB, Virtual Available: 407.230 GB, Virtual Used: 095.966 GB, Swap Used: 000.391 GB
# Loading Batch 0 of 17
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00000.tiff
#    Loaded 1 files, total 0.76 GB
#    Batch 0 IO thread joined
#          Memory after IO thread joinTotal Used: 100.673 GB, Virtual Available: 402.942 GB, Virtual Used: 100.254 GB, Swap Used: 000.420 GB
#          Memory after movie copied from threadTotal Used: 102.300 GB, Virtual Available: 401.315 GB, Virtual Used: 101.881 GB, Swap Used: 000.420 GB
#          Memory after thread memory clearedTotal Used: 091.768 GB, Virtual Available: 411.847 GB, Virtual Used: 091.349 GB, Swap Used: 000.420 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 091.772 GB, Virtual Available: 411.843 GB, Virtual Used: 091.353 GB, Swap Used: 000.420 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00001.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :3.791398286819458s
#    Shifted the mov in: 0.649583101272583s
#          After all GPU Batches:Total Used: 102.504 GB, Virtual Available: 401.114 GB, Virtual Used: 102.082 GB, Swap Used: 000.422 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0000.npy
#          Saved in 1.24 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0001.npy
#          Saved in 1.15 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0002.npy
#          Saved in 0.24 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 105.223 GB, Virtual Available: 398.395 GB, Virtual Used: 104.801 GB, Swap Used: 000.422 GB
#          Memory at batch 1.  Total Used: 105.224 GB, Virtual Available: 398.394 GB, Virtual Used: 104.802 GB, Swap Used: 000.422 GB
# Loading Batch 1 of 17
#    Batch 1 IO thread joined
#          Memory after IO thread joinTotal Used: 105.224 GB, Virtual Available: 398.394 GB, Virtual Used: 104.802 GB, Swap Used: 000.422 GB
#          Memory after movie copied from threadTotal Used: 105.330 GB, Virtual Available: 398.287 GB, Virtual Used: 104.908 GB, Swap Used: 000.422 GB
#          Memory after thread memory clearedTotal Used: 105.031 GB, Virtual Available: 398.587 GB, Virtual Used: 104.609 GB, Swap Used: 000.422 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 105.031 GB, Virtual Available: 398.587 GB, Virtual Used: 104.609 GB, Swap Used: 000.422 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00002.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :3.16119647026062s
#    Shifted the mov in: 0.5954024791717529s
#          After all GPU Batches:Total Used: 081.151 GB, Virtual Available: 422.505 GB, Virtual Used: 080.691 GB, Swap Used: 000.460 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0003.npy
#          Saved in 0.53 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0004.npy
#          Saved in 0.52 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0005.npy
#          Saved in 0.11 sec
#       Computing quality metrics and saving
# /home/ali/packages/s2p-lbm/suite3d/quality_metrics.py:41: RuntimeWarning: invalid value encountered in divide
#   dff = df / fs.mean(axis=1,keepdims=True)
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#          After full batch saving:Total Used: 083.144 GB, Virtual Available: 420.512 GB, Virtual Used: 082.684 GB, Swap Used: 000.460 GB
#          Memory at batch 2.  Total Used: 083.145 GB, Virtual Available: 420.511 GB, Virtual Used: 082.684 GB, Swap Used: 000.460 GB
# Loading Batch 2 of 17
#    Batch 2 IO thread joined
#          Memory after IO thread joinTotal Used: 083.145 GB, Virtual Available: 420.511 GB, Virtual Used: 082.685 GB, Swap Used: 000.460 GB
#          Memory after movie copied from threadTotal Used: 082.903 GB, Virtual Available: 420.753 GB, Virtual Used: 082.443 GB, Swap Used: 000.460 GB
#          Memory after thread memory clearedTotal Used: 082.462 GB, Virtual Available: 421.194 GB, Virtual Used: 082.001 GB, Swap Used: 000.460 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 082.462 GB, Virtual Available: 421.193 GB, Virtual Used: 082.002 GB, Swap Used: 000.460 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00003.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.221766471862793s
#    Shifted the mov in: 0.5855119228363037s
#          After all GPU Batches:Total Used: 090.759 GB, Virtual Available: 412.897 GB, Virtual Used: 090.299 GB, Swap Used: 000.460 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0006.npy
#          Saved in 0.52 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0007.npy
#          Saved in 0.51 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0008.npy
#          Saved in 0.11 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 092.724 GB, Virtual Available: 410.932 GB, Virtual Used: 092.264 GB, Swap Used: 000.460 GB
#          Memory at batch 3.  Total Used: 092.725 GB, Virtual Available: 410.931 GB, Virtual Used: 092.265 GB, Swap Used: 000.460 GB
# Loading Batch 3 of 17
#    Batch 3 IO thread joined
#          Memory after IO thread joinTotal Used: 092.725 GB, Virtual Available: 410.931 GB, Virtual Used: 092.265 GB, Swap Used: 000.460 GB
#          Memory after movie copied from threadTotal Used: 092.600 GB, Virtual Available: 411.056 GB, Virtual Used: 092.140 GB, Swap Used: 000.460 GB
#          Memory after thread memory clearedTotal Used: 092.318 GB, Virtual Available: 411.338 GB, Virtual Used: 091.858 GB, Swap Used: 000.460 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 092.320 GB, Virtual Available: 411.336 GB, Virtual Used: 091.860 GB, Swap Used: 000.460 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00004.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.163316249847412s
#    Shifted the mov in: 0.591609001159668s
#          After all GPU Batches:Total Used: 103.524 GB, Virtual Available: 400.132 GB, Virtual Used: 103.064 GB, Swap Used: 000.460 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0009.npy
#          Saved in 0.52 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0010.npy
#          Saved in 0.53 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0011.npy
#          Saved in 0.11 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 107.115 GB, Virtual Available: 396.541 GB, Virtual Used: 106.654 GB, Swap Used: 000.460 GB
#          Memory at batch 4.  Total Used: 107.114 GB, Virtual Available: 396.542 GB, Virtual Used: 106.654 GB, Swap Used: 000.460 GB
# Loading Batch 4 of 17
#    Batch 4 IO thread joined
#          Memory after IO thread joinTotal Used: 107.115 GB, Virtual Available: 396.541 GB, Virtual Used: 106.655 GB, Swap Used: 000.460 GB
#          Memory after movie copied from threadTotal Used: 106.480 GB, Virtual Available: 397.176 GB, Virtual Used: 106.020 GB, Swap Used: 000.460 GB
#          Memory after thread memory clearedTotal Used: 105.674 GB, Virtual Available: 397.982 GB, Virtual Used: 105.214 GB, Swap Used: 000.460 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 105.674 GB, Virtual Available: 397.982 GB, Virtual Used: 105.213 GB, Swap Used: 000.460 GB
#       Loaded batch of size (7, 223, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00005.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.1934292316436768s
#    Shifted the mov in: 0.6397418975830078s
#          After all GPU Batches:Total Used: 111.186 GB, Virtual Available: 392.470 GB, Virtual Used: 110.725 GB, Swap Used: 000.460 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0012.npy
#          Saved in 5.23 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0013.npy
#          Saved in 0.69 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 23, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0014.npy
#          Saved in 0.15 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 113.217 GB, Virtual Available: 390.439 GB, Virtual Used: 112.757 GB, Swap Used: 000.460 GB
#          Memory at batch 5.  Total Used: 113.222 GB, Virtual Available: 390.434 GB, Virtual Used: 112.762 GB, Swap Used: 000.460 GB
# Loading Batch 5 of 17
#    Batch 5 IO thread joined
#          Memory after IO thread joinTotal Used: 113.228 GB, Virtual Available: 390.428 GB, Virtual Used: 112.768 GB, Swap Used: 000.460 GB
#          Memory after movie copied from threadTotal Used: 112.714 GB, Virtual Available: 390.942 GB, Virtual Used: 112.254 GB, Swap Used: 000.460 GB
#          Memory after thread memory clearedTotal Used: 112.026 GB, Virtual Available: 391.630 GB, Virtual Used: 111.566 GB, Swap Used: 000.460 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 112.027 GB, Virtual Available: 391.629 GB, Virtual Used: 111.567 GB, Swap Used: 000.460 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00006.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :3.167264461517334s
#    Shifted the mov in: 0.725653886795044s
#          After all GPU Batches:Total Used: 116.466 GB, Virtual Available: 387.233 GB, Virtual Used: 115.963 GB, Swap Used: 000.503 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0015.npy
#          Saved in 0.67 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0016.npy
#          Saved in 0.68 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0017.npy
#          Saved in 0.15 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 114.307 GB, Virtual Available: 389.391 GB, Virtual Used: 113.804 GB, Swap Used: 000.503 GB
#          Memory at batch 6.  Total Used: 114.309 GB, Virtual Available: 389.389 GB, Virtual Used: 113.806 GB, Swap Used: 000.503 GB
# Loading Batch 6 of 17
#    Batch 6 IO thread joined
#          Memory after IO thread joinTotal Used: 114.310 GB, Virtual Available: 389.388 GB, Virtual Used: 113.807 GB, Swap Used: 000.503 GB
#          Memory after movie copied from threadTotal Used: 112.677 GB, Virtual Available: 391.022 GB, Virtual Used: 112.174 GB, Swap Used: 000.503 GB
#          Memory after thread memory clearedTotal Used: 111.559 GB, Virtual Available: 392.140 GB, Virtual Used: 111.056 GB, Swap Used: 000.503 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 111.561 GB, Virtual Available: 392.138 GB, Virtual Used: 111.058 GB, Swap Used: 000.503 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00007.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.2846744060516357s
#    Shifted the mov in: 0.600714921951294s
#          After all GPU Batches:Total Used: 111.498 GB, Virtual Available: 392.200 GB, Virtual Used: 110.995 GB, Swap Used: 000.503 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0018.npy
#          Saved in 0.52 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0019.npy
#          Saved in 0.55 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0020.npy
#          Saved in 0.11 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 106.905 GB, Virtual Available: 396.794 GB, Virtual Used: 106.402 GB, Swap Used: 000.503 GB
#          Memory at batch 7.  Total Used: 106.904 GB, Virtual Available: 396.794 GB, Virtual Used: 106.401 GB, Swap Used: 000.503 GB
# Loading Batch 7 of 17
#    Batch 7 IO thread joined
#          Memory after IO thread joinTotal Used: 106.905 GB, Virtual Available: 396.794 GB, Virtual Used: 106.402 GB, Swap Used: 000.503 GB
#          Memory after movie copied from threadTotal Used: 106.138 GB, Virtual Available: 397.561 GB, Virtual Used: 105.635 GB, Swap Used: 000.503 GB
#          Memory after thread memory clearedTotal Used: 105.378 GB, Virtual Available: 398.321 GB, Virtual Used: 104.875 GB, Swap Used: 000.503 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 105.379 GB, Virtual Available: 398.320 GB, Virtual Used: 104.875 GB, Swap Used: 000.503 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/3/00008.tiff
#    Loaded 1 files, total 0.05 GB
#    Completed rigid reg on batch in :2.175468683242798s
#    Shifted the mov in: 0.5829367637634277s
#          After all GPU Batches:Total Used: 107.856 GB, Virtual Available: 395.842 GB, Virtual Used: 107.353 GB, Swap Used: 000.503 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0021.npy
#          Saved in 0.55 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0022.npy
#          Saved in 0.53 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0023.npy
#          Saved in 0.12 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 095.297 GB, Virtual Available: 408.401 GB, Virtual Used: 094.794 GB, Swap Used: 000.503 GB
#          Memory at batch 8.  Total Used: 095.297 GB, Virtual Available: 408.401 GB, Virtual Used: 094.794 GB, Swap Used: 000.503 GB
# Loading Batch 8 of 17
#    Batch 8 IO thread joined
#          Memory after IO thread joinTotal Used: 095.297 GB, Virtual Available: 408.401 GB, Virtual Used: 094.794 GB, Swap Used: 000.503 GB
#          Memory after movie copied from threadTotal Used: 094.009 GB, Virtual Available: 409.690 GB, Virtual Used: 093.506 GB, Swap Used: 000.503 GB
#          Memory after thread memory clearedTotal Used: 094.601 GB, Virtual Available: 409.097 GB, Virtual Used: 094.098 GB, Swap Used: 000.503 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 094.605 GB, Virtual Available: 409.093 GB, Virtual Used: 094.102 GB, Swap Used: 000.503 GB
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00009.tiff
#       Loaded batch of size (7, 15, 512, 512)
#    Completed rigid reg on batch in :0.18500065803527832s
#    Shifted the mov in: 0.04413461685180664s
#          After all GPU Batches:Total Used: 095.572 GB, Virtual Available: 408.137 GB, Virtual Used: 095.059 GB, Swap Used: 000.513 GB
#       Saving fused, registered file of shape (7, 15, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0024.npy
#          Saved in 0.08 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 094.430 GB, Virtual Available: 409.293 GB, Virtual Used: 093.902 GB, Swap Used: 000.528 GB
#          Memory at batch 9.  Total Used: 094.429 GB, Virtual Available: 409.294 GB, Virtual Used: 093.901 GB, Swap Used: 000.528 GB
# Loading Batch 9 of 17
#    Loaded 1 files, total 0.76 GB
#    Batch 9 IO thread joined
#          Memory after IO thread joinTotal Used: 097.552 GB, Virtual Available: 406.191 GB, Virtual Used: 097.005 GB, Swap Used: 000.547 GB
#          Memory after movie copied from threadTotal Used: 099.011 GB, Virtual Available: 404.732 GB, Virtual Used: 098.464 GB, Swap Used: 000.547 GB
#          Memory after thread memory clearedTotal Used: 098.961 GB, Virtual Available: 404.781 GB, Virtual Used: 098.414 GB, Swap Used: 000.547 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 098.965 GB, Virtual Available: 404.777 GB, Virtual Used: 098.418 GB, Swap Used: 000.547 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00010.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :4.55528712272644s
#    Shifted the mov in: 0.6258988380432129s
#          After all GPU Batches:Total Used: 106.968 GB, Virtual Available: 396.909 GB, Virtual Used: 106.287 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0025.npy
#          Saved in 0.54 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0026.npy
#          Saved in 0.53 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0027.npy
#          Saved in 0.11 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 065.699 GB, Virtual Available: 438.178 GB, Virtual Used: 065.017 GB, Swap Used: 000.681 GB
#          Memory at batch 10. Total Used: 065.699 GB, Virtual Available: 438.178 GB, Virtual Used: 065.017 GB, Swap Used: 000.681 GB
# Loading Batch 10 of 17
#    Batch 10 IO thread joined
#          Memory after IO thread joinTotal Used: 065.699 GB, Virtual Available: 438.178 GB, Virtual Used: 065.017 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 065.210 GB, Virtual Available: 438.667 GB, Virtual Used: 064.529 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 064.617 GB, Virtual Available: 439.260 GB, Virtual Used: 063.935 GB, Swap Used: 000.681 GB
#    Launching IO thread for next batch
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00011.tiff
#          After IO thread launch:Total Used: 064.617 GB, Virtual Available: 439.260 GB, Virtual Used: 063.936 GB, Swap Used: 000.681 GB
#       Loaded batch of size (7, 222, 512, 512)
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.194176197052002s
#    Shifted the mov in: 0.5785655975341797s
#          After all GPU Batches:Total Used: 070.332 GB, Virtual Available: 433.545 GB, Virtual Used: 069.651 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0028.npy
#          Saved in 0.52 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0029.npy
#          Saved in 0.52 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0030.npy
#          Saved in 0.12 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 070.617 GB, Virtual Available: 433.260 GB, Virtual Used: 069.935 GB, Swap Used: 000.681 GB
#          Memory at batch 11. Total Used: 070.617 GB, Virtual Available: 433.260 GB, Virtual Used: 069.935 GB, Swap Used: 000.681 GB
# Loading Batch 11 of 17
#    Batch 11 IO thread joined
#          Memory after IO thread joinTotal Used: 070.617 GB, Virtual Available: 433.260 GB, Virtual Used: 069.935 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 070.091 GB, Virtual Available: 433.786 GB, Virtual Used: 069.410 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 069.494 GB, Virtual Available: 434.383 GB, Virtual Used: 068.812 GB, Swap Used: 000.681 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 069.493 GB, Virtual Available: 434.384 GB, Virtual Used: 068.812 GB, Swap Used: 000.681 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00012.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.232407808303833s
#    Shifted the mov in: 0.5880649089813232s
#          After all GPU Batches:Total Used: 073.616 GB, Virtual Available: 430.261 GB, Virtual Used: 072.935 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0031.npy
#          Saved in 0.55 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0032.npy
#          Saved in 0.54 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0033.npy
#          Saved in 0.12 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 058.623 GB, Virtual Available: 445.254 GB, Virtual Used: 057.941 GB, Swap Used: 000.681 GB
#          Memory at batch 12. Total Used: 058.466 GB, Virtual Available: 445.411 GB, Virtual Used: 057.785 GB, Swap Used: 000.681 GB
# Loading Batch 12 of 17
#    Batch 12 IO thread joined
#          Memory after IO thread joinTotal Used: 058.261 GB, Virtual Available: 445.616 GB, Virtual Used: 057.580 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 051.370 GB, Virtual Available: 452.507 GB, Virtual Used: 050.688 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 051.221 GB, Virtual Available: 452.656 GB, Virtual Used: 050.540 GB, Swap Used: 000.681 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 051.225 GB, Virtual Available: 452.652 GB, Virtual Used: 050.544 GB, Swap Used: 000.681 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00013.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.2015132904052734s
#    Shifted the mov in: 0.5686094760894775s
#          After all GPU Batches:Total Used: 063.658 GB, Virtual Available: 440.219 GB, Virtual Used: 062.977 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0034.npy
#          Saved in 0.52 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0035.npy
#          Saved in 0.51 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0036.npy
#          Saved in 0.11 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 068.377 GB, Virtual Available: 435.500 GB, Virtual Used: 067.696 GB, Swap Used: 000.681 GB
#          Memory at batch 13. Total Used: 068.377 GB, Virtual Available: 435.499 GB, Virtual Used: 067.696 GB, Swap Used: 000.681 GB
# Loading Batch 13 of 17
#    Batch 13 IO thread joined
#          Memory after IO thread joinTotal Used: 068.377 GB, Virtual Available: 435.499 GB, Virtual Used: 067.696 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 068.544 GB, Virtual Available: 435.333 GB, Virtual Used: 067.863 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 068.448 GB, Virtual Available: 435.428 GB, Virtual Used: 067.767 GB, Swap Used: 000.681 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 068.453 GB, Virtual Available: 435.424 GB, Virtual Used: 067.771 GB, Swap Used: 000.681 GB
#       Loaded batch of size (7, 223, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00014.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.2222611904144287s
#    Shifted the mov in: 0.5910341739654541s
#          After all GPU Batches:Total Used: 068.213 GB, Virtual Available: 435.664 GB, Virtual Used: 067.532 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0037.npy
#          Saved in 0.51 sec
#       Computing quality metrics and saving
# /home/ali/packages/s2p-lbm/suite3d/quality_metrics.py:41: RuntimeWarning: divide by zero encountered in divide
#   dff = df / fs.mean(axis=1,keepdims=True)
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/numpy/lib/function_base.py:1448: RuntimeWarning: invalid value encountered in subtract
#   a = op(a[slice1], a[slice2])
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0038.npy
#          Saved in 0.51 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 23, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0039.npy
#          Saved in 0.13 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 073.077 GB, Virtual Available: 430.800 GB, Virtual Used: 072.396 GB, Swap Used: 000.681 GB
#          Memory at batch 14. Total Used: 073.081 GB, Virtual Available: 430.796 GB, Virtual Used: 072.400 GB, Swap Used: 000.681 GB
# Loading Batch 14 of 17
#    Batch 14 IO thread joined
#          Memory after IO thread joinTotal Used: 073.081 GB, Virtual Available: 430.796 GB, Virtual Used: 072.400 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 073.232 GB, Virtual Available: 430.645 GB, Virtual Used: 072.551 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 073.144 GB, Virtual Available: 430.733 GB, Virtual Used: 072.463 GB, Swap Used: 000.681 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 073.148 GB, Virtual Available: 430.729 GB, Virtual Used: 072.467 GB, Swap Used: 000.681 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00015.tiff
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.1704628467559814s
#    Shifted the mov in: 0.5687024593353271s
#          After all GPU Batches:Total Used: 072.219 GB, Virtual Available: 431.658 GB, Virtual Used: 071.537 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0040.npy
#          Saved in 0.53 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0041.npy
#          Saved in 0.56 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0042.npy
#          Saved in 0.12 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 078.046 GB, Virtual Available: 425.831 GB, Virtual Used: 077.365 GB, Swap Used: 000.681 GB
#          Memory at batch 15. Total Used: 078.050 GB, Virtual Available: 425.827 GB, Virtual Used: 077.369 GB, Swap Used: 000.681 GB
# Loading Batch 15 of 17
#    Batch 15 IO thread joined
#          Memory after IO thread joinTotal Used: 078.050 GB, Virtual Available: 425.827 GB, Virtual Used: 077.369 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 078.155 GB, Virtual Available: 425.722 GB, Virtual Used: 077.473 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 077.558 GB, Virtual Available: 426.319 GB, Virtual Used: 076.877 GB, Swap Used: 000.681 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 077.558 GB, Virtual Available: 426.319 GB, Virtual Used: 076.877 GB, Swap Used: 000.681 GB
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00016.tiff
#       Loaded batch of size (7, 222, 512, 512)
#    Loaded 1 files, total 0.76 GB
#    Completed rigid reg on batch in :2.1884398460388184s
#    Shifted the mov in: 0.5722987651824951s
#          After all GPU Batches:Total Used: 080.712 GB, Virtual Available: 423.165 GB, Virtual Used: 080.031 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0043.npy
#          Saved in 0.53 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0044.npy
#          Saved in 0.54 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0045.npy
#          Saved in 0.11 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 079.190 GB, Virtual Available: 424.687 GB, Virtual Used: 078.509 GB, Swap Used: 000.681 GB
#          Memory at batch 16. Total Used: 079.190 GB, Virtual Available: 424.687 GB, Virtual Used: 078.508 GB, Swap Used: 000.681 GB
# Loading Batch 16 of 17
#    Batch 16 IO thread joined
#          Memory after IO thread joinTotal Used: 079.190 GB, Virtual Available: 424.687 GB, Virtual Used: 078.509 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 078.418 GB, Virtual Available: 425.459 GB, Virtual Used: 077.737 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 077.659 GB, Virtual Available: 426.218 GB, Virtual Used: 076.977 GB, Swap Used: 000.681 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 077.659 GB, Virtual Available: 426.218 GB, Virtual Used: 076.977 GB, Swap Used: 000.681 GB
#       Loaded batch of size (7, 222, 512, 512)
#       Loading tiff 1/1: /mnt/md0/data/TC030_2025-01-27_3-4/4/00017.tiff
#    Loaded 1 files, total 0.02 GB
#    Completed rigid reg on batch in :2.1871745586395264s
#    Shifted the mov in: 0.5750625133514404s
#          After all GPU Batches:Total Used: 081.865 GB, Virtual Available: 422.012 GB, Virtual Used: 081.183 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0046.npy
#          Saved in 0.54 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 100, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0047.npy
#          Saved in 0.58 sec
#       Computing quality metrics and saving
#       Saving fused, registered file of shape (7, 22, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0048.npy
#          Saved in 0.13 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 086.507 GB, Virtual Available: 417.370 GB, Virtual Used: 085.825 GB, Swap Used: 000.681 GB
#          Memory at batch 17. Total Used: 086.507 GB, Virtual Available: 417.370 GB, Virtual Used: 085.825 GB, Swap Used: 000.681 GB
# Loading Batch 17 of 17
#    Batch 17 IO thread joined
#          Memory after IO thread joinTotal Used: 086.510 GB, Virtual Available: 417.367 GB, Virtual Used: 085.829 GB, Swap Used: 000.681 GB
#          Memory after movie copied from threadTotal Used: 085.171 GB, Virtual Available: 418.706 GB, Virtual Used: 084.489 GB, Swap Used: 000.681 GB
#          Memory after thread memory clearedTotal Used: 085.841 GB, Virtual Available: 418.036 GB, Virtual Used: 085.160 GB, Swap Used: 000.681 GB
#       Loaded batch of size (7, 7, 512, 512)
#    Completed rigid reg on batch in :0.06228756904602051s
#    Shifted the mov in: 0.00795435905456543s
#          After all GPU Batches:Total Used: 086.063 GB, Virtual Available: 417.814 GB, Virtual Used: 085.382 GB, Swap Used: 000.681 GB
#       Saving fused, registered file of shape (7, 7, 512, 516) to /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/registered_fused_data/fused_reg_data0049.npy
#          Saved in 0.03 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 084.941 GB, Virtual Available: 418.936 GB, Virtual Used: 084.259 GB, Swap Used: 000.681 GB

# %%
reg = job.load_registration_results()

# %%
intshift = n.concatenate(reg['int_shift'])
float_shift = n.concatenate(reg['sub_pixel_shifts'])

# %%
plt.plot(float_shift[:,0])

# %%
tz = [
    -100, 1350.4,
    7, 1350.4,
    8, 1351.4,
    9, 1355.0,
    10, 1355.1,
    11, 1355.4,
    12, 1355.8,
    13, 1356.9, 
    14, 1358.2,
    15, 1358.1, 
    16, 1358.1, 
    17, 1358.2, 
    18, 1360.1,
    19, 1360.6,
    20, 1360.6,
    21, 1360.6,
    23, 1360.5,
    27, 1360.0,
    28, 1358.8,
    29, 1358.8,
    30, 1358.9,
    31, 1358.9,
    32, 1358.1,
    33, 1357.9,
    34, 1358.0,
    35, 1357.9,
    36, 1357.8,
    37, 1357.8,
    38, 1357.2,
    39, 1356.2,
    40, 1356.2,
    41, 1356.1,
    42, 1355.2,
    43, 1353.4,
    44, 1353.1, 
    45, 1353.0,
    46, 1353.0,
    47, 1352.5,
    48, 1352.5,
    49, 1350.8,
    50, 1350.8,
    51, 1350.8,
    52, 1350.3, 
    53, 1349.9,
    54, 1349.9,
    55, 1349.9,
    58, 1349.9,
    59, 1349.5,
    60, 1347.6,
    61, 1347.6,
    62, 1346.8,
    63, 1346.7,
    64, 1346.7,
    65, 1345.8,
    66, 1345.2,
    67, 1345.3, 
    68, 1345.2, 
    69, 1345.1, 
    70, 1344.6,
    71, 1344.7, 
    72, 1344.6,
    73, 1344.6,
    74, 1343.9,
    75, 1343.4,
    76, 1343.4, 
    78, 1343.4,
    79, 1343.1,
    80, 1342.9,
    81, 1341.6,
    82, 1341.3,
    83, 1341.3,
    84, 1340.6, 
    85, 1340.5,
    86, 1339.8,
    87, 1339.8,
    89, 1339.8,
    90,1340.8,
    91, 1342.2,
    92, 1342.2,
    93, 1342.2,
    94, 1342.7,
    95, 1343.2,
    96, 1343.2,
    97, 1343.1,
    98, 1343.7,
    99, 1345.2,
    100,1345.2,
    101, 1345.2,
    102, 1345.2,
    103, 1345.2,
    104, 1345.7, 
    105, 1346.8, 
    106, 1347.3, 
    107, 1347.3,
    108, 1347.3,
    109, 1348.4,
    110, 1348.8,
    111, 1348.8,
    112, 1348.8,
    113, 1349.4,
    114, 1349.7,
    115, 1349.9,
    116, 1349.9,
    117, 1350.2,
    128, 1350.2, 
    129, 1350.6,
    130, 1352.5, 
    131, 1353.5,
    132, 1353.6,
    133, 1353.8,
    134, 1355.0,
    135, 1355.9,
    136, 1357.0, 
    137, 1357.0,
    138, 1357.1,
    139, 1357.4,
    140, 1359.4,
    141, 1360.5,
    142, 1361.6,
    143, 1361.6,
    144, 1361.6,
    145, 1361.7,
    146, 1364.7,
    147, 1364.6,
    148, 1364.6,
    149, 1367.0,
    150, 1367.9,
    151, 1369.3, 
    152, 1370.3,
    153, 1370.3,
    155, 1370.3,
    157, 1370.3,
    158, 1369.2,
    159, 1369.2,
    160, 1368.0,
    161, 1367.4,
    162, 1367.3,
    163, 1366.1,
    164, 1365.4,
    165, 1364.2,
    166, 1363.6,
    167, 1362.6,
    168, 1362.6,
    169, 1362.6,
    170, 1361.1,
    171, 1360.5,
    172, 1360.5,
    173, 1360.5,
    174, 1359.9,
    175, 1359.7,
    176, 1359.8,
    177, 1359.2,
    178, 1357.5,
    179, 1356.9, 
    180, 1355.7,
    181, 1354.7,
    182, 1354.3,
    183, 1351.9, 
    184, 1350.9,
    185, 1350.9,
    186, 1351.0,
    187, 1350.6,
    188, 1349.9,
    189, 1349.8,
    193, 1349.9,
    194, 1349.7,
    195, 1348.0, 
    196, 1345.2,
    197, 1345.2,
    198, 1345.1,
    199, 1343.9,
    200, 1343.7,
    201, 1343.4,
    202, 1342.7,
    203, 1342.4,
    204, 1342.3,
    205, 1342.3,
    206, 1341.7,
    207, 1341.2,
    208, 1340.6,
    209, 1340.7,
    210, 1340.0,
    211, 1339.2,
    212, 1338.7,
    213, 1338.0,
    214, 1336.9,
    215, 1336.3,
    216, 1336.4,
    217, 1335.7,
    218, 1334.6,
    219, 1334.5,
    220, 1334.1,
    201, 1333.8,
    202, 1332.3,
    203, 1331.9,
    204, 1330.4, 
    205, 1330.3,
    206, 1330.3,
    207, 1330.3,
    208, 1330.3,
    213, 1330.3,
    214, 1331.2, 
    215, 1333.2,
    216, 1335.6,
    217, 1336.8, 
    218, 1336.8,
    219, 1336.8,
    220, 1339.0,
    221, 1341.1,
    222, 1341.1,
    223, 1341.1,
    224, 1343.9,
    225, 1344.0,
    226, 1344.0,
    227, 1345.1,
    228, 1345.9,
    229, 1345.9,
    230, 1345.9,
    231, 1345.9,
    232, 1346.9,
    233, 1346.9,
    234, 1347.3,
    235, 1347.2,
    236, 1347.2,
    237, 1348.2,
    238, 1348.6,
    239, 1350.0,
    240, 1350.5,
    241, 1350.6,
        
    
    
    
]
tz = n.array(tz)

tz = tz.reshape(-1,2)

# %%
nt = float_shift.shape[0]

# %%
ts = n.arange(nt) / job.params['fs']

# %%
plt.plot(ts, float_shift[:,0] * 10)
plt.plot(tz[:,0] + 580, tz[:,1] - tz[0,1])
plt.xlim(500,1299)
# Out:
# (500.0, 1299.0)

# %%
job.params['intensity_thresh'] = 1

# %%
cmap = job.calculate_corr_map()
# Out:
#       Found dir /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/corrmap
#       Updating self.dirs tag corrmap
#       Found dir /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/mov_sub
#       Updating self.dirs tag mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-TC030_2025-01-27_3-4/corrmap
#    Updated main params file
#    Computing correlation map of movie with 3576 frames, volume shape: 7, 512, 516
#       Running batch 1 of 18
#          Timer prep completed in 1.135 sec
#          Timer batch_setup completed in 0.359 sec
#          Timer batch_edgecrop completed in 0.026 sec
#          Timer accum_meanmeax completed in 0.300 sec
#          Timer batch_rolling_mean_filt completed in 0.288 sec
#          Timer batch_accum_sdmov completed in 0.893 sec
#          Timer batch_norm_sdmov completed in 0.148 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.225 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.152 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.338 sec
#          Timer dtu_cleanup completed in 0.667 sec
#          Timer batch_filt_reduce completed in 5.383 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.20506030321121216, mean 0.4843372404575348, type float32
#          Timer batch completed in 7.409 sec
#          Timer save completed in 1.163 sec
#       Running batch 2 of 18
#          Timer prep completed in 1.106 sec
#          Timer batch_setup completed in 0.354 sec
#          Timer batch_edgecrop completed in 0.054 sec
#          Timer accum_meanmeax completed in 0.296 sec
#          Timer batch_rolling_mean_filt completed in 0.274 sec
#          Timer batch_accum_sdmov completed in 0.841 sec
#          Timer batch_norm_sdmov completed in 0.137 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.215 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.117 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.346 sec
#          Timer dtu_cleanup completed in 0.619 sec
#          Timer batch_filt_reduce completed in 5.299 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.18887901306152344, mean 0.47467201948165894, type float32
#          Timer batch completed in 7.272 sec
#          Timer save completed in 1.153 sec
#       Running batch 3 of 18
#          Timer prep completed in 1.141 sec
#          Timer batch_setup completed in 0.355 sec
#          Timer batch_edgecrop completed in 0.024 sec
#          Timer accum_meanmeax completed in 0.292 sec
#          Timer batch_rolling_mean_filt completed in 0.275 sec
#          Timer batch_accum_sdmov completed in 0.858 sec
#          Timer batch_norm_sdmov completed in 0.138 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.179 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.066 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.342 sec
#          Timer dtu_cleanup completed in 0.614 sec
#          Timer batch_filt_reduce completed in 5.203 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.16314637660980225, mean 0.44566810131073, type float32
#          Timer batch completed in 7.162 sec
#          Timer save completed in 1.176 sec
#       Running batch 4 of 18
#          Timer prep completed in 1.207 sec
#          Timer batch_setup completed in 1.579 sec
#          Timer batch_edgecrop completed in 0.024 sec
#          Timer accum_meanmeax completed in 0.299 sec
#          Timer batch_rolling_mean_filt completed in 0.279 sec
#          Timer batch_accum_sdmov completed in 2.136 sec
#          Timer batch_norm_sdmov completed in 0.143 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.349 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.186 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.344 sec
#          Timer dtu_cleanup completed in 0.706 sec
#          Timer batch_filt_reduce completed in 5.587 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.14772580564022064, mean 0.4325142800807953, type float32
#          Timer batch completed in 10.065 sec
#          Timer save completed in 1.177 sec
#       Running batch 5 of 18
#          Timer prep completed in 1.172 sec
#          Timer batch_setup completed in 0.356 sec
#          Timer batch_edgecrop completed in 0.024 sec
#          Timer accum_meanmeax completed in 0.294 sec
#          Timer batch_rolling_mean_filt completed in 0.272 sec
#          Timer batch_accum_sdmov completed in 0.855 sec
#          Timer batch_norm_sdmov completed in 0.138 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.185 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.926 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.357 sec
#          Timer dtu_cleanup completed in 0.587 sec
#          Timer batch_filt_reduce completed in 5.057 sec
#          Timer batch_accum_vmap completed in 0.006 sec
#    VMAP std 0.15733247995376587, mean 0.4515111744403839, type float32
#          Timer batch completed in 7.013 sec
#          Timer save completed in 1.078 sec
#       Running batch 6 of 18
#          Timer prep completed in 1.131 sec
#          Timer batch_setup completed in 0.354 sec
#          Timer batch_edgecrop completed in 0.024 sec
#          Timer accum_meanmeax completed in 0.292 sec
#          Timer batch_rolling_mean_filt completed in 0.275 sec
#          Timer batch_accum_sdmov completed in 0.856 sec
#          Timer batch_norm_sdmov completed in 0.139 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.191 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.315 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.416 sec
#          Timer dtu_cleanup completed in 0.645 sec
#          Timer batch_filt_reduce completed in 5.570 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.15543538331985474, mean 0.4529041051864624, type float32
#          Timer batch completed in 7.528 sec
#          Timer save completed in 1.289 sec
#       Running batch 7 of 18
#          Timer prep completed in 1.309 sec
#          Timer batch_setup completed in 0.380 sec
#          Timer batch_edgecrop completed in 0.058 sec
#          Timer accum_meanmeax completed in 0.318 sec
#          Timer batch_rolling_mean_filt completed in 0.292 sec
#          Timer batch_accum_sdmov completed in 0.964 sec
#          Timer batch_norm_sdmov completed in 0.152 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.377 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.182 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.349 sec
#          Timer dtu_cleanup completed in 0.642 sec
#          Timer batch_filt_reduce completed in 5.552 sec
#          Timer batch_accum_vmap completed in 0.006 sec
#    VMAP std 0.15032042562961578, mean 0.44731906056404114, type float32
#          Timer batch completed in 7.733 sec
#          Timer save completed in 1.102 sec
#       Running batch 8 of 18
#          Timer prep completed in 1.287 sec
#          Timer batch_setup completed in 0.360 sec
#          Timer batch_edgecrop completed in 0.056 sec
#          Timer accum_meanmeax completed in 0.291 sec
#          Timer batch_rolling_mean_filt completed in 0.275 sec
#          Timer batch_accum_sdmov completed in 0.845 sec
#          Timer batch_norm_sdmov completed in 0.138 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.177 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.113 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.345 sec
#          Timer dtu_cleanup completed in 1.359 sec
#          Timer batch_filt_reduce completed in 5.995 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.14620047807693481, mean 0.44458457827568054, type float32
#          Timer batch completed in 7.980 sec
#          Timer save completed in 1.273 sec
#       Running batch 9 of 18
#          Timer prep completed in 2.832 sec
#          Timer batch_setup completed in 0.366 sec
#          Timer batch_edgecrop completed in 0.058 sec
#          Timer accum_meanmeax completed in 0.296 sec
#          Timer batch_rolling_mean_filt completed in 0.278 sec
#          Timer batch_accum_sdmov completed in 0.870 sec
#          Timer batch_norm_sdmov completed in 0.139 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.283 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.967 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.335 sec
#          Timer dtu_cleanup completed in 0.699 sec
#          Timer batch_filt_reduce completed in 5.285 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.14790724217891693, mean 0.4456455707550049, type float32
#          Timer batch completed in 7.308 sec
#          Timer save completed in 1.156 sec
#       Running batch 10 of 18
#          Timer prep completed in 1.163 sec
#          Timer batch_setup completed in 0.357 sec
#          Timer batch_edgecrop completed in 0.058 sec
#          Timer accum_meanmeax completed in 0.300 sec
#          Timer batch_rolling_mean_filt completed in 0.278 sec
#          Timer batch_accum_sdmov completed in 0.880 sec
#          Timer batch_norm_sdmov completed in 0.142 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.235 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.367 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.344 sec
#          Timer dtu_cleanup completed in 0.629 sec
#          Timer batch_filt_reduce completed in 5.577 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.16286760568618774, mean 0.4652990400791168, type float32
#          Timer batch completed in 7.608 sec
#          Timer save completed in 1.085 sec
#       Running batch 11 of 18
#          Timer prep completed in 1.149 sec
#          Timer batch_setup completed in 0.355 sec
#          Timer batch_edgecrop completed in 0.055 sec
#          Timer accum_meanmeax completed in 0.292 sec
#          Timer batch_rolling_mean_filt completed in 0.276 sec
#          Timer batch_accum_sdmov completed in 0.870 sec
#          Timer batch_norm_sdmov completed in 0.140 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.186 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.068 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.342 sec
#          Timer dtu_cleanup completed in 0.574 sec
#          Timer batch_filt_reduce completed in 5.173 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.1684442162513733, mean 0.4727625846862793, type float32
#          Timer batch completed in 7.179 sec
#          Timer save completed in 1.133 sec
#       Running batch 12 of 18
#          Timer prep completed in 1.169 sec
#          Timer batch_setup completed in 0.357 sec
#          Timer batch_edgecrop completed in 0.056 sec
#          Timer accum_meanmeax completed in 0.294 sec
#          Timer batch_rolling_mean_filt completed in 0.280 sec
#          Timer batch_accum_sdmov completed in 0.878 sec
#          Timer batch_norm_sdmov completed in 0.140 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.174 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.081 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.339 sec
#          Timer dtu_cleanup completed in 0.588 sec
#          Timer batch_filt_reduce completed in 5.185 sec
#          Timer batch_accum_vmap completed in 0.008 sec
#    VMAP std 0.16952510178089142, mean 0.4744971990585327, type float32
#          Timer batch completed in 7.208 sec
#          Timer save completed in 1.138 sec
#       Running batch 13 of 18
#          Timer prep completed in 1.197 sec
#          Timer batch_setup completed in 0.399 sec
#          Timer batch_edgecrop completed in 0.055 sec
#          Timer accum_meanmeax completed in 0.288 sec
#          Timer batch_rolling_mean_filt completed in 0.272 sec
#          Timer batch_accum_sdmov completed in 0.856 sec
#          Timer batch_norm_sdmov completed in 0.138 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.264 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.819 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.784 sec
#          Timer dtu_cleanup completed in 4.467 sec
#          Timer batch_filt_reduce completed in 10.338 sec
#          Timer batch_accum_vmap completed in 0.006 sec
#    VMAP std 0.16813325881958008, mean 0.4737130105495453, type float32
#          Timer batch completed in 12.362 sec
#          Timer save completed in 1.293 sec
#       Running batch 14 of 18
#          Timer prep completed in 6.073 sec
#          Timer batch_setup completed in 1.452 sec
#          Timer batch_edgecrop completed in 0.056 sec
#          Timer accum_meanmeax completed in 0.291 sec
#          Timer batch_rolling_mean_filt completed in 0.279 sec
#          Timer batch_accum_sdmov completed in 0.868 sec
#          Timer batch_norm_sdmov completed in 0.141 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.217 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.251 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.358 sec
#          Timer dtu_cleanup completed in 0.699 sec
#          Timer batch_filt_reduce completed in 5.527 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.16440919041633606, mean 0.46886202692985535, type float32
#          Timer batch completed in 8.635 sec
#          Timer save completed in 1.151 sec
#       Running batch 15 of 18
#          Timer prep completed in 1.142 sec
#          Timer batch_setup completed in 0.357 sec
#          Timer batch_edgecrop completed in 0.057 sec
#          Timer accum_meanmeax completed in 0.295 sec
#          Timer batch_rolling_mean_filt completed in 0.280 sec
#          Timer batch_accum_sdmov completed in 0.871 sec
#          Timer batch_norm_sdmov completed in 0.140 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.204 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.117 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.356 sec
#          Timer dtu_cleanup completed in 0.571 sec
#          Timer batch_filt_reduce completed in 5.249 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.16550470888614655, mean 0.47453898191452026, type float32
#          Timer batch completed in 7.267 sec
#          Timer save completed in 1.139 sec
#       Running batch 16 of 18
#          Timer prep completed in 1.172 sec
#          Timer batch_setup completed in 0.360 sec
#          Timer batch_edgecrop completed in 0.057 sec
#          Timer accum_meanmeax completed in 0.296 sec
#          Timer batch_rolling_mean_filt completed in 0.286 sec
#          Timer batch_accum_sdmov completed in 2.288 sec
#          Timer batch_norm_sdmov completed in 0.153 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.413 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.704 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.396 sec
#          Timer dtu_cleanup completed in 1.411 sec
#          Timer batch_filt_reduce completed in 6.927 sec
#          Timer batch_accum_vmap completed in 0.009 sec
#    VMAP std 0.16374516487121582, mean 0.4726945757865906, type float32
#          Timer batch completed in 10.387 sec
#          Timer save completed in 1.398 sec
#       Running batch 17 of 18
#          Timer prep completed in 1.303 sec
#          Timer batch_setup completed in 0.365 sec
#          Timer batch_edgecrop completed in 0.026 sec
#          Timer accum_meanmeax completed in 0.309 sec
#          Timer batch_rolling_mean_filt completed in 0.291 sec
#          Timer batch_accum_sdmov completed in 1.119 sec
#          Timer batch_norm_sdmov completed in 0.146 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.281 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.128 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.336 sec
#          Timer dtu_cleanup completed in 0.654 sec
#          Timer batch_filt_reduce completed in 5.402 sec
#          Timer batch_accum_vmap completed in 0.006 sec
#    VMAP std 0.16599850356578827, mean 0.4774293601512909, type float32
#          Timer batch completed in 7.674 sec
#          Timer save completed in 1.077 sec
#       Running batch 18 of 18
#          Timer prep completed in 1.102 sec
#          Timer batch_setup completed in 0.307 sec
#          Timer batch_edgecrop completed in 0.048 sec
#          Timer accum_meanmeax completed in 0.255 sec
#          Timer batch_rolling_mean_filt completed in 0.244 sec
#          Timer batch_accum_sdmov completed in 2.296 sec
#          Timer batch_norm_sdmov completed in 0.121 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.119 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 3.271 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.315 sec
#          Timer dtu_cleanup completed in 1.456 sec
#          Timer batch_filt_reduce completed in 6.162 sec
#          Timer batch_accum_vmap completed in 0.007 sec
#    VMAP std 0.16821987926959991, mean 0.48134082555770874, type float32
#          Timer batch completed in 9.452 sec
#          Timer save completed in 1.008 sec

# %%
corr_map_thresh = ext.thresh_mask_corr_map(cmap, thresh_window_size_pix = 51, corrmap_thresh_pct = 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 corr_map_thresh = ext.thresh_mask_corr_map(corr_map, thresh_window_size_pix = 51, corrmap_thresh_pct = 50)
#
# NameError: name 'corr_map' is not defined

# %%
# most important parameter - any value of the corrmap
# above this will be considered a peak for a possible ROI,
# and will be used as a "seed" to grow an ROI around it
# bigger number: fewer ROIs, only bright ones
# smaller number: many ROIs, increasingly worse quality
job.params['peak_thresh'] = 0.00

# optionally, bin the movie in time to speed up detection
# probably a good idea if you have high framerate (>5 Hz?)
job.params['detection_timebin'] = 1 

# when extending an ROI, compare its activity to its neighboring pixels
# in frames where the fluorescence is above this percentile
job.params['percentile'] : 99.9
job.params['activity_thresh'] = 5
job.params['extend_thresh'] = 0.015
job.params['max_iter'] = 5000
job.params['n_proc_detect'] = 16


job.segment_rois(vmap = corr_map_thresh)
