# %%
# %load_ext autoreload
# %autoreload 2

import os 
import shutil
import numpy as n
from datetime import date
from matplotlib import pyplot as plt
import time
import napari

# %%
## !! CHANGE ME !! ##
from suite2p.io import lbm as lbmio
from suite2p.suite3d import utils
from suite2p.suite3d.job import Job
from suite2p.suite3d import ui


os.chdir('/home/ali/packages/s2p-lbm/')
from utils import tiff_utils as tfu

# %%
job_params = {
    'planes' :         n.arange(0,30),
    
    'notch_filt' :     None, #{'f0' : 200, 'Q' : 1},
    
    'n_init_files' :   3,
    'init_file_pool' : None,
    'init_file_sample_method': 'random',
    
    'subtract_crosstalk' : True,
    'override_crosstalk' : None,
    'crosstalk_n_planes' : 10, 
    
    'nonrigid' : True,
    'smooth_sigma' : 1.15,
    'maxregshift' : 0.15,
    'reg_filter_pcorr' : 1,
    'generate_sample_registered_bins' : False,

    'dtype' : n.float32,
    'tif_batch_size' : 1,
}

# %%
from utils import file_utils as flu

# %%
tifs = tfu.get_tif_paths('/mnt/md0/data/example-007-0328-5')

# %%
# Set the mandatory parameters
params = {
    # volume rate
    'fs': tfu.get_vol_rate(tifs[0]),
    # planes to analyze. 0 is deepest, 30 is shallowest (corrected for ScanImage channel IDs)
    'planes' : n.arange(30),
    # Decay time of the Ca indicator in seconds. 1.3 for GCaMP6s. This example is for GCamP8m
    'tau' : 0.1
}

# %%
# Create the job
job = Job('/mnt/md0/runs','AH007-03-28_5-sample', tifs = tifs,
          params=params, create=True, overwrite=True, verbosity = 3)
# Out:
# Job directory /mnt/md0/runs/s3d-AH007-03-28_5-sample already exists
# Loading job directory for AH007-03-28_5-sample in /mnt/md0/runs
#    Loading dirs
#       Found dir registered_data
#       Found dir summary
#       Found dir iters
#    Loading default params
#       Updating param fs
#       Updating param planes
#       Updating param tau
#    Updated main params file

# %%
# optional parameters for initialization
# load 1 file to initialize, and select 200 frames randomly to do initalization on
job.params['n_init_files'] = 3
job.params['init_n_frames'] = None

# %%
# %%time
# summary = job.run_init_pass()
# Out:
# CPU times: user 0 ns, sys: 1 µs, total: 1 µs
# Wall time: 3.34 µs

# %%
job.show_summary_plots()

# %%
# split the large tiffs into files of size 100 after registration
job.params['split_tif_size'] = 100
# FUSING: fuse the strips from the FOV into one image
# this is the number of pixels to skip between pixels, 13 makes it look relatively smooth
job.params['n_skip'] = 13
# should only fuse files where the plane_shifts look good, otherwise you might get an error
job.params['fuse_crop'] = ((0,20), (0,1202), (0,1015))

# %%
# %%time
# job.register()
# Out:
# CPU times: user 3 µs, sys: 4 µs, total: 7 µs
# Wall time: 5.01 µs

# %%
# job.fuse_registered_movie()

# %%
mov_full = job.get_registered_movie('registered_fused_data', 'fused')
im_full = mov_full[:,:1000].mean(axis=1).compute()

# %%
job.params['n_svd_comp'] = 800
job.params['svd_crop'] = ((0,20), (0,1202), (0, 1015))
job.params['svd_block_shape'] = (4,200,200)
job.params['svd_block_overlaps'] = (2,100,100)
svd_dir_tag = 'svd_cropped_2'

# %%
# %%time
# job.make_new_dir(svd_dir_tag)
# svd_info = job.svd_decompose_movie(svd_dir_tag, run_svd=True)

# %%
svd_info = n.load(os.path.join(job.dirs[svd_dir_tag], 'svd_info.npy'),allow_pickle=True).item()

# %%
job.params['t_batch_size'] = 400
job.params['n_proc_corr'] = 32
job.params['intensity_thresh'] = 0.25
job.params['conv_filt_xy'] = 1.0

params_to_sweep = {
#     'intensity_thresh' : (0.25, 0.4),
    'n_svd_comp' : (200,400),
    'npil_filt_xy' : (4.0,5.0),
#     'conv_filt_xy' : (0.75, 1.0)
}

# %%
# sweep_summary = job.sweep_params(params_to_sweep, svd_info,testing_dir_tag='sweep-01',
#                            do_vmap=True, all_combinations=True, n_test_iters = 1)
# v = job.vis_vmap_sweep(sweep_summary)

# %%
sweep_summary = n.load(os.path.join(job.dirs['sweep-01'], 'sweep_summary.npy'),allow_pickle=True).item()

# %%
job.params['intensity_thresh'] = 0.4
job.params['n_svd_comps'] = 300
job.params['t_batch_size'] = 300

# %%
vmap, mean_img, max_img = job.calculate_corr_map(svd_info)
# Out:
#    Updated main params file
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\mov_sub with tag mov_sub
#    Saving mov_sub to Y:\runs\Coconut\s3d-Coconut-Demo\mov_sub
#    Using conv_filt: gaussian, 0.75, 1.00
#    Using np_filt: gaussian, 1.00, 5.00
#    Will reconstruct SVD movie on-the-fly from Y:\runs\Coconut\s3d-Coconut-Demo\svd_cropped_2 with 300 components
#    Created files and dirs for 33 batches
#       Running batch 1 of 33
#          Reconstructing from svd
#          Reconstructed in 109.59 seconds
#       Loaded and swapped, idx 0 to 300
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0000
#       Running batch 2 of 33
#          Reconstructing from svd
#          Reconstructed in 110.77 seconds
#       Loaded and swapped, idx 300 to 600
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0001
#       Running batch 3 of 33
#          Reconstructing from svd
#          Reconstructed in 118.73 seconds
#       Loaded and swapped, idx 600 to 900
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0002
#       Running batch 4 of 33
#          Reconstructing from svd
#          Reconstructed in 136.74 seconds
#       Loaded and swapped, idx 900 to 1200
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0003
#       Running batch 5 of 33
#          Reconstructing from svd
#          Reconstructed in 142.26 seconds
#       Loaded and swapped, idx 1200 to 1500
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0004
#       Running batch 6 of 33
#          Reconstructing from svd
#          Reconstructed in 139.00 seconds
#       Loaded and swapped, idx 1500 to 1800
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0005
#       Running batch 7 of 33
#          Reconstructing from svd
#          Reconstructed in 141.86 seconds
#       Loaded and swapped, idx 1800 to 2100
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0006
#       Running batch 8 of 33
#          Reconstructing from svd
#          Reconstructed in 140.58 seconds
#       Loaded and swapped, idx 2100 to 2400
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0007
#       Running batch 9 of 33
#          Reconstructing from svd
#          Reconstructed in 132.27 seconds
#       Loaded and swapped, idx 2400 to 2700
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0008
#       Running batch 10 of 33
#          Reconstructing from svd
#          Reconstructed in 119.65 seconds
#       Loaded and swapped, idx 2700 to 3000
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0009
#       Running batch 11 of 33
#          Reconstructing from svd
#          Reconstructed in 114.93 seconds
#       Loaded and swapped, idx 3000 to 3300
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0010
#       Running batch 12 of 33
#          Reconstructing from svd
#          Reconstructed in 114.39 seconds
#       Loaded and swapped, idx 3300 to 3600
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0011
#       Running batch 13 of 33
#          Reconstructing from svd
#          Reconstructed in 115.13 seconds
#       Loaded and swapped, idx 3600 to 3900
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0012
#       Running batch 14 of 33
#          Reconstructing from svd
#          Reconstructed in 113.28 seconds
#       Loaded and swapped, idx 3900 to 4200
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0013
#       Running batch 15 of 33
#          Reconstructing from svd
#          Reconstructed in 111.94 seconds
#       Loaded and swapped, idx 4200 to 4500
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0014
#       Running batch 16 of 33
#          Reconstructing from svd
#          Reconstructed in 112.42 seconds
#       Loaded and swapped, idx 4500 to 4800
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0015
#       Running batch 17 of 33
#          Reconstructing from svd
#          Reconstructed in 113.78 seconds
#       Loaded and swapped, idx 4800 to 5100
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0016
#       Running batch 18 of 33
#          Reconstructing from svd
#          Reconstructed in 114.65 seconds
#       Loaded and swapped, idx 5100 to 5400
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0017
#       Running batch 19 of 33
#          Reconstructing from svd
#          Reconstructed in 113.84 seconds
#       Loaded and swapped, idx 5400 to 5700
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0018
#       Running batch 20 of 33
#          Reconstructing from svd
#          Reconstructed in 116.19 seconds
#       Loaded and swapped, idx 5700 to 6000
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0019
#       Running batch 21 of 33
#          Reconstructing from svd
#          Reconstructed in 108.86 seconds
#       Loaded and swapped, idx 6000 to 6300
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0020
#       Running batch 22 of 33
#          Reconstructing from svd
#          Reconstructed in 108.62 seconds
#       Loaded and swapped, idx 6300 to 6600
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0021
#       Running batch 23 of 33
#          Reconstructing from svd
#          Reconstructed in 132.96 seconds
#       Loaded and swapped, idx 6600 to 6900
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0022
#       Running batch 24 of 33
#          Reconstructing from svd
#          Reconstructed in 110.40 seconds
#       Loaded and swapped, idx 6900 to 7200
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0023
#       Running batch 25 of 33
#          Reconstructing from svd
#          Reconstructed in 116.26 seconds
#       Loaded and swapped, idx 7200 to 7500
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0024
#       Running batch 26 of 33
#          Reconstructing from svd
#          Reconstructed in 114.38 seconds
#       Loaded and swapped, idx 7500 to 7800
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0025
#       Running batch 27 of 33
#          Reconstructing from svd
#          Reconstructed in 114.16 seconds
#       Loaded and swapped, idx 7800 to 8100
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0026
#       Running batch 28 of 33
#          Reconstructing from svd
#          Reconstructed in 113.88 seconds
#       Loaded and swapped, idx 8100 to 8400
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0027
#       Running batch 29 of 33
#          Reconstructing from svd
#          Reconstructed in 115.35 seconds
#       Loaded and swapped, idx 8400 to 8700
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0028
#       Running batch 30 of 33
#          Reconstructing from svd
#          Reconstructed in 114.76 seconds
#       Loaded and swapped, idx 8700 to 9000
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0029
#       Running batch 31 of 33
#          Reconstructing from svd
#          Reconstructed in 112.50 seconds
#       Loaded and swapped, idx 9000 to 9300
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0030
#       Running batch 32 of 33
#          Reconstructing from svd
#          Reconstructed in 114.01 seconds
#       Loaded and swapped, idx 9300 to 9600
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0031
#       Running batch 33 of 33
#          Reconstructing from svd
#          Reconstructed in 132.16 seconds
#       Loaded and swapped, idx 9600 to 9860
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#       Saving to Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0032

# %%
v = napari.view_image(vmap)
v.add_image(mean_img)
# Out:
# <Image layer 'mean_img' at 0x1d3abf26f10>

# %%
job.params['detection_timebin'] = 1 
job.params['detection_time_crop'] = (None,None)
job.params['max_pix'] = 250
job.params['peak_thresh'] = 5.8
job.params['percentile'] = 99.0
job.params['max_iter'] = 10000 # maximum number of ROIs detected in given patch
combined_dir = job.patch_and_detect(combined_name='combined-full')
# Out:
#    Loading from Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0032
# 30 blocks with overlap (20 without, 1.50x increase)
# 30 blocks with overlap (20 without, 1.50x increase)
#    Detecting from patch: 0/30
#    Updated main params file
#    Created dir Y:\runs\Coconut\s3d-Coconut-Demo\detection with tag detection
#    Created dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0000 with tag patch-0000
#    Running cell detection on patch 0000 at Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0000, max 10000 iters
#    Patch bounds are [ 0 22], [  0 120], [  0 120]
#    Cell center bounds are [ 0 22], [  0 100], [  0 102]
#    Time bounds are (None, None)
# mov_sub
#    Loading 15.48 GB movie to memory
#    Loaded
#    Loading from Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0032
#       Movie shape: (13120, 22, 120, 120)
#    Saving cell stats and info to Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0000
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 5.800 and Th2: 4.000
#    Iter 0000: running 08 ROIs in parallel
#       Added cell 1 at 16, 080, 040, peak: 21.704, thresh: 3.537, 1376 frames, 127 pixels
#       Added cell 2 at 17, 077, 027, peak: 21.250, thresh: 3.780, 619 frames, 69 pixels
#       Added cell 3 at 16, 092, 090, peak: 16.126, thresh: 3.738, 335 frames, 45 pixels
#       Added cell 4 at 16, 037, 063, peak: 15.726, thresh: 3.902, 254 frames, 25 pixels
#       Added cell 5 at 18, 057, 031, peak: 15.297, thresh: 3.215, 517 frames, 55 pixels
#       Added cell 6 at 17, 081, 089, peak: 15.163, thresh: 3.401, 390 frames, 33 pixels
#       Added cell 7 at 16, 006, 054, peak: 13.878, thresh: 3.487, 511 frames, 43 pixels
#       Added cell 8 at 16, 091, 033, peak: 13.283, thresh: 2.975, 646 frames, 63 pixels
#    Iter 0001: running 08 ROIs in parallel
#       Added cell 9 at 16, 053, 029, peak: 12.903, thresh: 3.176, 201 frames, 15 pixels
#       Added cell 10 at 11, 062, 029, peak: 12.566, thresh: 2.855, 374 frames, 30 pixels
#       Added cell 11 at 16, 088, 023, peak: 12.200, thresh: 3.095, 243 frames, 22 pixels
#       Added cell 12 at 18, 068, 058, peak: 12.085, thresh: 3.177, 329 frames, 28 pixels
#       Added cell 13 at 12, 010, 082, peak: 11.884, thresh: 2.877, 443 frames, 45 pixels
#       Added cell 14 at 16, 031, 016, peak: 11.467, thresh: 2.756, 433 frames, 29 pixels
#       Added cell 15 at 19, 060, 093, peak: 11.414, thresh: 3.136, 168 frames, 13 pixels
#       Added cell 16 at 17, 085, 075, peak: 11.246, thresh: 2.947, 842 frames, 79 pixels
#    Iter 0002: running 08 ROIs in parallel
#       Added cell 17 at 19, 005, 023, peak: 11.077, thresh: 2.879, 267 frames, 20 pixels
#       Added cell 18 at 06, 056, 097, peak: 11.052, thresh: 3.382, 317 frames, 19 pixels
#       Added cell 19 at 17, 099, 095, peak: 11.029, thresh: 2.874, 741 frames, 28 pixels
#       Added cell 20 at 16, 067, 085, peak: 10.998, thresh: 2.863, 1212 frames, 125 pixels
#       Added cell 21 at 12, 045, 064, peak: 10.883, thresh: 2.923, 225 frames, 22 pixels
#       Added cell 22 at 19, 035, 052, peak: 10.841, thresh: 2.784, 468 frames, 46 pixels
#       Added cell 23 at 20, 011, 097, peak: 10.583, thresh: 3.083, 226 frames, 19 pixels
#       Added cell 24 at 16, 084, 100, peak: 10.519, thresh: 2.956, 241 frames, 21 pixels
#    Iter 0003: running 08 ROIs in parallel
#       Added cell 25 at 18, 089, 054, peak: 10.309, thresh: 2.819, 442 frames, 44 pixels
#       Added cell 26 at 17, 075, 080, peak: 10.108, thresh: 2.814, 563 frames, 51 pixels
#       Added cell 27 at 13, 099, 037, peak: 9.988, thresh: 2.994, 421 frames, 47 pixels
#       Added cell 28 at 20, 051, 087, peak: 9.778, thresh: 2.701, 1236 frames, 137 pixels
#       Added cell 29 at 16, 078, 067, peak: 9.768, thresh: 2.648, 1447 frames, 161 pixels
#       Added cell 30 at 09, 010, 062, peak: 9.740, thresh: 2.669, 293 frames, 30 pixels
#       Added cell 31 at 17, 044, 020, peak: 9.730, thresh: 2.768, 677 frames, 53 pixels
#       Added cell 32 at 16, 051, 075, peak: 9.622, thresh: 2.771, 415 frames, 40 pixels
#    Iter 0004: running 08 ROIs in parallel
#       Added cell 33 at 12, 007, 008, peak: 9.605, thresh: 2.768, 226 frames, 23 pixels
#       Added cell 34 at 12, 044, 091, peak: 9.568, thresh: 2.740, 188 frames, 13 pixels
#       Added cell 35 at 13, 022, 036, peak: 9.547, thresh: 2.881, 312 frames, 28 pixels
#       Added cell 36 at 20, 046, 057, peak: 9.442, thresh: 2.666, 335 frames, 32 pixels
#       Added cell 37 at 12, 016, 023, peak: 9.310, thresh: 2.601, 311 frames, 27 pixels
#       Added cell 38 at 12, 048, 039, peak: 9.113, thresh: 2.578, 313 frames, 29 pixels
#       Added cell 39 at 17, 070, 010, peak: 9.068, thresh: 2.859, 191 frames, 16 pixels
#       Added cell 40 at 11, 023, 021, peak: 9.055, thresh: 2.508, 249 frames, 18 pixels
#    Iter 0005: running 08 ROIs in parallel
#       Added cell 41 at 16, 066, 059, peak: 9.010, thresh: 2.816, 536 frames, 58 pixels
#       Added cell 42 at 06, 090, 055, peak: 8.941, thresh: 2.521, 293 frames, 22 pixels
#       Added cell 43 at 16, 098, 016, peak: 8.906, thresh: 2.693, 698 frames, 80 pixels
#       Added cell 44 at 11, 043, 087, peak: 8.862, thresh: 2.711, 306 frames, 28 pixels
#       Added cell 45 at 09, 090, 051, peak: 8.851, thresh: 2.442, 460 frames, 42 pixels
#       Added cell 46 at 16, 085, 082, peak: 8.838, thresh: 2.741, 225 frames, 21 pixels
#       Added cell 47 at 17, 073, 043, peak: 8.811, thresh: 2.642, 489 frames, 51 pixels
#       Added cell 48 at 16, 026, 042, peak: 8.799, thresh: 2.844, 478 frames, 41 pixels
#    Iter 0006: running 08 ROIs in parallel
#       Added cell 49 at 16, 033, 011, peak: 8.793, thresh: 2.794, 350 frames, 40 pixels
#       Added cell 50 at 16, 048, 097, peak: 8.656, thresh: 2.617, 295 frames, 23 pixels
#       Added cell 51 at 17, 068, 094, peak: 8.605, thresh: 2.597, 426 frames, 43 pixels
#       Added cell 52 at 17, 055, 033, peak: 8.603, thresh: 2.482, 604 frames, 50 pixels
#       Added cell 53 at 09, 094, 058, peak: 8.574, thresh: 2.504, 186 frames, 12 pixels
#       Added cell 54 at 20, 069, 101, peak: 8.519, thresh: 2.577, 215 frames, 17 pixels
#       Added cell 55 at 12, 088, 069, peak: 8.479, thresh: 2.897, 264 frames, 25 pixels
#       Added cell 56 at 09, 024, 084, peak: 8.337, thresh: 2.590, 280 frames, 26 pixels
#    Iter 0007: running 08 ROIs in parallel
#       Added cell 57 at 18, 086, 096, peak: 8.292, thresh: 2.609, 189 frames, 22 pixels
#       Added cell 58 at 12, 082, 053, peak: 8.277, thresh: 2.504, 363 frames, 37 pixels
#       Added cell 59 at 09, 068, 070, peak: 8.245, thresh: 2.499, 233 frames, 18 pixels
#       Added cell 60 at 12, 037, 017, peak: 8.229, thresh: 2.406, 261 frames, 22 pixels
#       Added cell 61 at 16, 093, 056, peak: 8.193, thresh: 2.679, 457 frames, 34 pixels
#       Added cell 62 at 13, 079, 039, peak: 8.094, thresh: 2.804, 476 frames, 44 pixels
#       Added cell 63 at 17, 006, 040, peak: 8.081, thresh: 2.767, 196 frames, 14 pixels
#       Added cell 64 at 16, 027, 035, peak: 8.060, thresh: 2.630, 295 frames, 25 pixels
#    Iter 0008: running 08 ROIs in parallel
#       Added cell 65 at 18, 017, 092, peak: 8.059, thresh: 2.652, 222 frames, 18 pixels
#       Added cell 66 at 16, 049, 056, peak: 8.055, thresh: 2.753, 323 frames, 23 pixels
#       Added cell 67 at 16, 083, 049, peak: 7.961, thresh: 2.603, 313 frames, 27 pixels
#       Added cell 68 at 12, 095, 013, peak: 7.902, thresh: 2.400, 319 frames, 26 pixels
#       Added cell 69 at 16, 075, 100, peak: 7.836, thresh: 2.439, 761 frames, 65 pixels
#       Added cell 70 at 12, 090, 086, peak: 7.803, thresh: 2.430, 292 frames, 28 pixels
#       Added cell 71 at 19, 090, 043, peak: 7.773, thresh: 2.580, 236 frames, 15 pixels
#       Added cell 72 at 12, 099, 079, peak: 7.747, thresh: 2.473, 241 frames, 22 pixels
#    Iter 0009: running 08 ROIs in parallel
#       Added cell 73 at 16, 051, 051, peak: 8.041, thresh: 2.534, 224 frames, 18 pixels
#       Added cell 74 at 12, 093, 025, peak: 7.738, thresh: 2.393, 284 frames, 27 pixels
#       Added cell 75 at 09, 037, 101, peak: 7.698, thresh: 2.648, 231 frames, 16 pixels
#       Added cell 76 at 16, 068, 019, peak: 7.688, thresh: 2.546, 273 frames, 19 pixels
#       Added cell 77 at 19, 057, 063, peak: 7.686, thresh: 2.681, 191 frames, 16 pixels
#       Added cell 78 at 16, 016, 051, peak: 7.677, thresh: 2.481, 272 frames, 22 pixels
#       Added cell 79 at 17, 051, 064, peak: 7.666, thresh: 2.658, 363 frames, 38 pixels
#       Added cell 80 at 17, 041, 049, peak: 7.654, thresh: 2.458, 285 frames, 25 pixels
#    Iter 0010: running 08 ROIs in parallel
#       Added cell 81 at 16, 067, 076, peak: 7.618, thresh: 2.756, 343 frames, 30 pixels
#       Added cell 82 at 13, 055, 073, peak: 7.617, thresh: 2.700, 392 frames, 28 pixels
#       Added cell 83 at 12, 069, 067, peak: 7.574, thresh: 2.409, 337 frames, 34 pixels
#       Added cell 84 at 12, 052, 016, peak: 7.571, thresh: 2.353, 284 frames, 22 pixels
#       Added cell 85 at 03, 020, 099, peak: 7.568, thresh: 2.445, 160 frames, 11 pixels
#       Added cell 86 at 12, 063, 027, peak: 7.538, thresh: 2.383, 561 frames, 50 pixels
#       Added cell 87 at 08, 005, 041, peak: 7.513, thresh: 2.468, 242 frames, 19 pixels
#       Added cell 88 at 11, 010, 077, peak: 7.509, thresh: 2.608, 176 frames, 12 pixels
#    Iter 0011: running 08 ROIs in parallel
#       Added cell 89 at 19, 034, 026, peak: 7.497, thresh: 2.539, 238 frames, 19 pixels
#       Added cell 90 at 11, 098, 076, peak: 7.492, thresh: 2.573, 214 frames, 19 pixels
#       Added cell 91 at 16, 042, 078, peak: 7.487, thresh: 2.679, 253 frames, 20 pixels
#       Added cell 92 at 09, 062, 031, peak: 7.438, thresh: 2.379, 278 frames, 24 pixels
#       Added cell 93 at 05, 036, 015, peak: 7.432, thresh: 2.429, 217 frames, 18 pixels
#       Added cell 94 at 09, 080, 034, peak: 7.431, thresh: 2.351, 221 frames, 21 pixels
#       Added cell 95 at 06, 010, 088, peak: 7.378, thresh: 2.577, 184 frames, 12 pixels
#       Added cell 96 at 16, 032, 048, peak: 7.335, thresh: 2.571, 658 frames, 52 pixels
#    Iter 0012: running 08 ROIs in parallel
#       Added cell 97 at 16, 079, 007, peak: 7.329, thresh: 2.388, 290 frames, 26 pixels
#       Added cell 98 at 10, 045, 085, peak: 7.325, thresh: 2.590, 252 frames, 22 pixels
#       Added cell 99 at 06, 024, 045, peak: 7.294, thresh: 2.485, 199 frames, 16 pixels
#       Added cell 100 at 12, 064, 079, peak: 7.294, thresh: 2.447, 374 frames, 38 pixels
#       Added cell 101 at 16, 014, 036, peak: 7.255, thresh: 2.469, 239 frames, 22 pixels
#       Added cell 102 at 12, 028, 065, peak: 7.242, thresh: 2.404, 191 frames, 16 pixels
#       Added cell 103 at 12, 085, 004, peak: 7.215, thresh: 2.363, 303 frames, 23 pixels
#       Added cell 104 at 05, 055, 094, peak: 7.213, thresh: 2.532, 228 frames, 18 pixels
#    Iter 0013: running 08 ROIs in parallel
#       Added cell 105 at 05, 055, 055, peak: 7.207, thresh: 2.497, 164 frames, 11 pixels
#       Added cell 106 at 17, 096, 043, peak: 7.185, thresh: 2.530, 177 frames, 14 pixels
#       Added cell 107 at 12, 039, 082, peak: 7.177, thresh: 2.547, 208 frames, 15 pixels
#       Added cell 108 at 12, 061, 014, peak: 7.176, thresh: 2.437, 180 frames, 13 pixels
#       Added cell 109 at 12, 042, 053, peak: 7.167, thresh: 2.392, 173 frames, 12 pixels
#       Added cell 110 at 16, 041, 040, peak: 7.166, thresh: 2.739, 173 frames, 9 pixels
#       Added cell 111 at 07, 088, 068, peak: 7.154, thresh: 2.439, 191 frames, 15 pixels
#       Added cell 112 at 10, 093, 051, peak: 7.150, thresh: 2.422, 363 frames, 29 pixels
#    Iter 0014: running 08 ROIs in parallel
#       Added cell 113 at 20, 039, 040, peak: 7.138, thresh: 2.599, 248 frames, 18 pixels
#       Added cell 114 at 12, 011, 092, peak: 7.131, thresh: 2.386, 178 frames, 12 pixels
#       Added cell 115 at 18, 080, 057, peak: 7.128, thresh: 2.412, 731 frames, 55 pixels
#       Added cell 116 at 12, 059, 083, peak: 7.122, thresh: 2.355, 221 frames, 22 pixels
#       Added cell 117 at 11, 085, 067, peak: 7.118, thresh: 2.394, 232 frames, 18 pixels
#       Added cell 118 at 19, 041, 007, peak: 7.114, thresh: 2.493, 249 frames, 23 pixels
#       Added cell 119 at 05, 004, 020, peak: 7.098, thresh: 2.395, 157 frames, 11 pixels
#       Added cell 120 at 06, 008, 037, peak: 7.093, thresh: 2.419, 230 frames, 21 pixels
#    Iter 0015: running 08 ROIs in parallel
#       Added cell 121 at 13, 087, 073, peak: 7.091, thresh: 2.654, 330 frames, 27 pixels
#       Added cell 122 at 16, 088, 000, peak: 7.090, thresh: 2.547, 254 frames, 17 pixels
#       Added cell 123 at 16, 036, 022, peak: 7.082, thresh: 2.504, 260 frames, 17 pixels
#       Added cell 124 at 10, 066, 071, peak: 7.077, thresh: 2.470, 225 frames, 17 pixels
#       Added cell 125 at 12, 062, 053, peak: 7.076, thresh: 2.348, 412 frames, 40 pixels
#       Added cell 126 at 12, 084, 011, peak: 7.065, thresh: 2.392, 227 frames, 22 pixels
#       Added cell 127 at 04, 097, 027, peak: 7.036, thresh: 2.590, 218 frames, 14 pixels
#       Added cell 128 at 08, 059, 074, peak: 7.036, thresh: 2.623, 184 frames, 14 pixels
#    Iter 0016: running 08 ROIs in parallel
#       Added cell 129 at 12, 093, 042, peak: 7.009, thresh: 2.426, 189 frames, 17 pixels
#       Added cell 130 at 04, 020, 101, peak: 7.005, thresh: 2.637, 201 frames, 13 pixels
#       Added cell 131 at 17, 045, 083, peak: 6.982, thresh: 2.454, 249 frames, 26 pixels
#       Added cell 132 at 19, 081, 040, peak: 6.979, thresh: 2.362, 389 frames, 37 pixels
#       Added cell 133 at 07, 058, 072, peak: 6.969, thresh: 2.580, 151 frames, 10 pixels
#       Added cell 134 at 11, 009, 080, peak: 6.969, thresh: 2.441, 262 frames, 18 pixels
#       Added cell 135 at 06, 051, 069, peak: 6.967, thresh: 2.440, 193 frames, 13 pixels
#       Added cell 136 at 10, 095, 060, peak: 6.964, thresh: 2.505, 237 frames, 17 pixels
#    Iter 0017: running 08 ROIs in parallel
#       Added cell 137 at 20, 021, 047, peak: 6.938, thresh: 2.637, 188 frames, 16 pixels
#       Added cell 138 at 16, 020, 101, peak: 6.923, thresh: 2.502, 249 frames, 18 pixels
#       Added cell 139 at 07, 077, 081, peak: 6.891, thresh: 2.474, 190 frames, 15 pixels
#       Added cell 140 at 20, 086, 017, peak: 6.844, thresh: 2.510, 299 frames, 19 pixels
#       Added cell 141 at 16, 053, 016, peak: 6.835, thresh: 2.424, 352 frames, 34 pixels
#       Added cell 142 at 12, 021, 058, peak: 6.831, thresh: 2.297, 254 frames, 20 pixels
#       Added cell 143 at 16, 014, 029, peak: 6.828, thresh: 2.524, 263 frames, 22 pixels
#       Added cell 144 at 17, 066, 051, peak: 6.807, thresh: 2.681, 243 frames, 21 pixels
#    Iter 0018: running 08 ROIs in parallel
#       Added cell 145 at 12, 043, 002, peak: 6.805, thresh: 2.292, 344 frames, 19 pixels
#       Added cell 146 at 20, 088, 056, peak: 6.795, thresh: 2.358, 254 frames, 19 pixels
#       Added cell 147 at 17, 095, 057, peak: 6.794, thresh: 2.488, 277 frames, 16 pixels
#       Added cell 148 at 12, 039, 100, peak: 6.764, thresh: 2.442, 201 frames, 19 pixels
#       Added cell 149 at 16, 040, 057, peak: 6.761, thresh: 2.475, 993 frames, 68 pixels
#       Added cell 150 at 17, 096, 071, peak: 6.752, thresh: 2.586, 312 frames, 21 pixels
#       Added cell 151 at 12, 050, 099, peak: 6.738, thresh: 2.389, 187 frames, 15 pixels
#       Added cell 152 at 09, 079, 048, peak: 6.720, thresh: 2.359, 205 frames, 18 pixels
#    Iter 0019: running 08 ROIs in parallel
#       Added cell 153 at 10, 044, 062, peak: 6.719, thresh: 2.261, 281 frames, 23 pixels
#       Added cell 154 at 16, 012, 081, peak: 6.711, thresh: 2.328, 279 frames, 26 pixels
#       Added cell 155 at 10, 082, 035, peak: 6.699, thresh: 2.317, 201 frames, 18 pixels
#       Added cell 156 at 16, 056, 038, peak: 6.647, thresh: 2.451, 243 frames, 21 pixels
#       Added cell 157 at 14, 085, 047, peak: 6.631, thresh: 2.365, 2312 frames, 279 pixels
#       Added cell 158 at 16, 050, 045, peak: 6.608, thresh: 2.443, 295 frames, 23 pixels
#       Added cell 159 at 10, 025, 087, peak: 6.595, thresh: 2.496, 183 frames, 13 pixels
#       Added cell 160 at 17, 080, 031, peak: 6.586, thresh: 2.331, 175 frames, 14 pixels
#    Iter 0020: running 08 ROIs in parallel
#       Added cell 161 at 12, 054, 034, peak: 6.583, thresh: 2.316, 187 frames, 17 pixels
#       Added cell 162 at 06, 089, 011, peak: 6.580, thresh: 2.439, 159 frames, 11 pixels
#       Added cell 163 at 17, 023, 037, peak: 6.578, thresh: 2.476, 223 frames, 22 pixels
#       Added cell 164 at 12, 016, 015, peak: 6.558, thresh: 2.268, 201 frames, 17 pixels
#       Added cell 165 at 12, 026, 085, peak: 6.550, thresh: 2.288, 200 frames, 16 pixels
#       Added cell 166 at 04, 084, 062, peak: 6.524, thresh: 2.454, 182 frames, 15 pixels
#       Added cell 167 at 11, 036, 019, peak: 6.515, thresh: 2.299, 251 frames, 17 pixels
#       Added cell 168 at 12, 052, 044, peak: 6.502, thresh: 2.304, 197 frames, 16 pixels
#    Iter 0021: running 08 ROIs in parallel
#       Added cell 169 at 10, 033, 023, peak: 6.513, thresh: 2.420, 202 frames, 18 pixels
#       Added cell 170 at 12, 046, 030, peak: 6.489, thresh: 2.361, 179 frames, 14 pixels
#       Added cell 171 at 21, 067, 054, peak: 6.475, thresh: 2.313, 186 frames, 15 pixels
#       Added cell 172 at 12, 075, 039, peak: 6.466, thresh: 2.331, 231 frames, 18 pixels
#       Added cell 173 at 05, 023, 087, peak: 6.455, thresh: 2.425, 187 frames, 14 pixels
#       Added cell 174 at 13, 085, 079, peak: 6.453, thresh: 2.504, 283 frames, 22 pixels
#       Added cell 175 at 08, 085, 071, peak: 6.446, thresh: 2.266, 317 frames, 26 pixels
#       Added cell 176 at 16, 063, 003, peak: 6.439, thresh: 2.484, 281 frames, 19 pixels
#    Iter 0022: running 08 ROIs in parallel
#       Added cell 177 at 17, 098, 051, peak: 6.439, thresh: 2.329, 310 frames, 29 pixels
#       Added cell 178 at 09, 089, 068, peak: 6.436, thresh: 2.381, 206 frames, 21 pixels
#       Added cell 179 at 03, 094, 079, peak: 6.430, thresh: 2.408, 173 frames, 16 pixels
#       Added cell 180 at 12, 021, 022, peak: 6.417, thresh: 2.319, 267 frames, 27 pixels
#       Added cell 181 at 15, 038, 076, peak: 6.412, thresh: 2.466, 229 frames, 20 pixels
#       Added cell 182 at 16, 019, 004, peak: 6.405, thresh: 2.318, 262 frames, 23 pixels
#       Added cell 183 at 12, 072, 098, peak: 6.403, thresh: 2.232, 192 frames, 14 pixels
#       Added cell 184 at 09, 046, 080, peak: 6.403, thresh: 2.302, 212 frames, 21 pixels
#    Iter 0023: running 08 ROIs in parallel
#       Added cell 185 at 10, 090, 042, peak: 6.393, thresh: 2.240, 263 frames, 20 pixels
#       Added cell 186 at 12, 078, 005, peak: 6.389, thresh: 2.274, 256 frames, 17 pixels
#       Added cell 187 at 10, 074, 086, peak: 6.386, thresh: 2.413, 248 frames, 18 pixels
#       Added cell 188 at 20, 010, 091, peak: 6.384, thresh: 2.499, 696 frames, 58 pixels
#       Added cell 189 at 19, 078, 026, peak: 6.384, thresh: 2.331, 274 frames, 27 pixels
#       Added cell 190 at 12, 087, 096, peak: 6.384, thresh: 2.268, 263 frames, 22 pixels
#       Added cell 191 at 08, 061, 029, peak: 6.382, thresh: 2.272, 284 frames, 24 pixels
#       Added cell 192 at 18, 037, 077, peak: 6.379, thresh: 2.468, 248 frames, 22 pixels
#    Iter 0024: running 08 ROIs in parallel
#       Added cell 193 at 08, 098, 072, peak: 6.376, thresh: 2.309, 187 frames, 16 pixels
#       Added cell 194 at 04, 020, 024, peak: 6.376, thresh: 2.334, 212 frames, 18 pixels
#       Added cell 195 at 13, 087, 022, peak: 6.373, thresh: 2.732, 204 frames, 16 pixels
#       Added cell 196 at 06, 080, 048, peak: 6.363, thresh: 2.355, 203 frames, 18 pixels
#       Added cell 197 at 20, 064, 004, peak: 6.362, thresh: 2.616, 178 frames, 15 pixels
#       Added cell 198 at 16, 071, 069, peak: 6.362, thresh: 2.462, 176 frames, 11 pixels
#       Added cell 199 at 17, 083, 027, peak: 6.360, thresh: 2.375, 160 frames, 10 pixels
#       Added cell 200 at 10, 098, 073, peak: 6.350, thresh: 2.392, 225 frames, 14 pixels
#    Iter 0025: running 08 ROIs in parallel
#       Added cell 201 at 16, 024, 092, peak: 6.349, thresh: 2.418, 265 frames, 22 pixels
#       Added cell 202 at 07, 019, 083, peak: 6.342, thresh: 2.395, 178 frames, 11 pixels
#       Added cell 203 at 20, 036, 086, peak: 6.332, thresh: 2.504, 241 frames, 19 pixels
#       Added cell 204 at 12, 076, 067, peak: 6.329, thresh: 2.384, 272 frames, 23 pixels
#       Added cell 205 at 08, 079, 089, peak: 6.327, thresh: 2.601, 204 frames, 17 pixels
#       Added cell 206 at 02, 085, 064, peak: 6.325, thresh: 2.242, 207 frames, 20 pixels
#       Added cell 207 at 13, 093, 098, peak: 6.316, thresh: 2.508, 193 frames, 19 pixels
#       Added cell 208 at 10, 063, 027, peak: 6.308, thresh: 2.281, 326 frames, 25 pixels
#    Iter 0026: running 08 ROIs in parallel
#       Added cell 209 at 11, 083, 033, peak: 6.306, thresh: 2.280, 212 frames, 18 pixels
#       Added cell 210 at 18, 025, 086, peak: 6.299, thresh: 2.330, 202 frames, 16 pixels
#       Added cell 211 at 02, 057, 048, peak: 6.296, thresh: 2.265, 188 frames, 13 pixels
#       Added cell 212 at 06, 092, 099, peak: 6.289, thresh: 2.379, 149 frames, 11 pixels
#       Added cell 213 at 12, 040, 042, peak: 6.287, thresh: 2.329, 284 frames, 28 pixels
#       Added cell 214 at 12, 088, 042, peak: 6.286, thresh: 2.444, 178 frames, 15 pixels
#       Added cell 215 at 09, 048, 097, peak: 6.286, thresh: 2.428, 176 frames, 16 pixels
#       Added cell 216 at 07, 065, 072, peak: 6.286, thresh: 2.550, 176 frames, 14 pixels
#    Iter 0027: running 08 ROIs in parallel
#       Added cell 217 at 04, 026, 013, peak: 6.285, thresh: 2.362, 209 frames, 17 pixels
#       Added cell 218 at 10, 047, 015, peak: 6.285, thresh: 2.337, 276 frames, 20 pixels
#       Added cell 219 at 00, 042, 065, peak: 6.275, thresh: 2.207, 162 frames, 11 pixels
#       Added cell 220 at 10, 070, 072, peak: 6.271, thresh: 2.448, 184 frames, 17 pixels
#       Added cell 221 at 13, 074, 101, peak: 6.267, thresh: 2.473, 391 frames, 33 pixels
#       Added cell 222 at 12, 088, 006, peak: 6.266, thresh: 2.342, 215 frames, 18 pixels
#       Added cell 223 at 04, 068, 096, peak: 6.265, thresh: 2.433, 177 frames, 13 pixels
#       Added cell 224 at 08, 094, 045, peak: 6.264, thresh: 2.305, 177 frames, 16 pixels
#    Iter 0028: running 08 ROIs in parallel
#       Added cell 225 at 08, 007, 062, peak: 6.260, thresh: 2.352, 212 frames, 21 pixels
#       Added cell 226 at 12, 075, 052, peak: 6.256, thresh: 2.271, 247 frames, 24 pixels
#       Added cell 227 at 00, 019, 065, peak: 6.249, thresh: 2.275, 202 frames, 13 pixels
#       Added cell 228 at 13, 075, 022, peak: 6.248, thresh: 2.460, 268 frames, 23 pixels
#       Added cell 229 at 18, 084, 031, peak: 6.243, thresh: 2.340, 248 frames, 24 pixels
#       Added cell 230 at 12, 071, 032, peak: 6.242, thresh: 2.298, 215 frames, 23 pixels
#       Added cell 231 at 04, 031, 014, peak: 6.235, thresh: 2.422, 150 frames, 10 pixels
#       Added cell 232 at 12, 030, 101, peak: 6.233, thresh: 2.311, 190 frames, 15 pixels
#    Iter 0029: running 08 ROIs in parallel
#       Added cell 233 at 09, 061, 054, peak: 6.233, thresh: 2.197, 268 frames, 21 pixels
#       Added cell 234 at 13, 026, 088, peak: 6.230, thresh: 2.447, 252 frames, 21 pixels
#       Added cell 235 at 09, 042, 078, peak: 6.224, thresh: 2.408, 197 frames, 17 pixels
#       Added cell 236 at 13, 091, 052, peak: 6.223, thresh: 2.489, 266 frames, 22 pixels
#       Added cell 237 at 17, 085, 015, peak: 6.223, thresh: 2.470, 185 frames, 14 pixels
#       Added cell 238 at 12, 065, 038, peak: 6.219, thresh: 2.352, 183 frames, 16 pixels
#       Added cell 239 at 04, 056, 048, peak: 6.210, thresh: 2.447, 150 frames, 15 pixels
#       Added cell 240 at 18, 071, 082, peak: 6.207, thresh: 2.416, 247 frames, 20 pixels
#    Iter 0030: running 08 ROIs in parallel
#       Added cell 241 at 10, 055, 024, peak: 6.206, thresh: 2.288, 185 frames, 15 pixels
#       Added cell 242 at 06, 011, 094, peak: 6.205, thresh: 2.362, 151 frames, 10 pixels
#       Added cell 243 at 13, 098, 082, peak: 6.203, thresh: 2.401, 242 frames, 19 pixels
#       Added cell 244 at 13, 095, 060, peak: 6.199, thresh: 2.568, 193 frames, 15 pixels
#       Added cell 245 at 11, 058, 053, peak: 6.188, thresh: 2.257, 215 frames, 15 pixels
#       Added cell 246 at 08, 075, 101, peak: 6.187, thresh: 2.284, 226 frames, 19 pixels
#       Added cell 247 at 07, 079, 020, peak: 6.180, thresh: 2.250, 224 frames, 16 pixels
#       Added cell 248 at 10, 063, 075, peak: 6.177, thresh: 2.413, 167 frames, 16 pixels
#    Iter 0031: running 08 ROIs in parallel
#       Added cell 249 at 21, 071, 101, peak: 6.170, thresh: 2.237, 197 frames, 14 pixels
#       Added cell 250 at 16, 091, 050, peak: 6.165, thresh: 2.356, 233 frames, 14 pixels
#       Added cell 251 at 04, 063, 000, peak: 6.160, thresh: 2.336, 196 frames, 12 pixels
#       Added cell 252 at 16, 022, 068, peak: 6.158, thresh: 2.455, 197 frames, 12 pixels
#       Added cell 253 at 17, 010, 016, peak: 6.152, thresh: 2.292, 196 frames, 15 pixels
#       Added cell 254 at 12, 048, 096, peak: 6.144, thresh: 2.275, 187 frames, 14 pixels
#       Added cell 255 at 12, 081, 033, peak: 6.139, thresh: 2.373, 192 frames, 17 pixels
#       Added cell 256 at 12, 079, 057, peak: 6.139, thresh: 2.301, 284 frames, 27 pixels
#    Iter 0032: running 08 ROIs in parallel
#       Added cell 257 at 18, 036, 019, peak: 6.135, thresh: 2.352, 215 frames, 20 pixels
#       Added cell 258 at 04, 062, 093, peak: 6.127, thresh: 2.365, 159 frames, 11 pixels
#       Added cell 259 at 19, 081, 036, peak: 6.125, thresh: 2.338, 210 frames, 14 pixels
#       Added cell 260 at 14, 074, 032, peak: 6.109, thresh: 2.384, 508 frames, 49 pixels
#       Added cell 261 at 12, 096, 051, peak: 6.085, thresh: 2.314, 173 frames, 13 pixels
#       Added cell 262 at 18, 063, 042, peak: 6.082, thresh: 2.203, 279 frames, 22 pixels
#       Added cell 263 at 17, 052, 004, peak: 6.081, thresh: 2.454, 201 frames, 16 pixels
#       Added cell 264 at 13, 044, 093, peak: 6.073, thresh: 2.343, 432 frames, 31 pixels
#    Iter 0033: running 08 ROIs in parallel
#       Added cell 265 at 00, 037, 056, peak: 6.071, thresh: 2.205, 192 frames, 15 pixels
#       Added cell 266 at 16, 006, 014, peak: 6.071, thresh: 2.509, 255 frames, 25 pixels
#       Added cell 267 at 13, 044, 012, peak: 6.071, thresh: 2.495, 257 frames, 27 pixels
#       Added cell 268 at 16, 060, 053, peak: 6.056, thresh: 2.329, 352 frames, 31 pixels
#       Added cell 269 at 11, 032, 036, peak: 6.054, thresh: 2.329, 179 frames, 15 pixels
#       Added cell 270 at 12, 057, 051, peak: 6.054, thresh: 2.318, 222 frames, 20 pixels
#       Added cell 271 at 12, 020, 037, peak: 6.050, thresh: 2.291, 209 frames, 17 pixels
#       Added cell 272 at 10, 061, 048, peak: 6.048, thresh: 2.252, 207 frames, 15 pixels
#    Iter 0034: running 08 ROIs in parallel
#       Added cell 273 at 00, 066, 093, peak: 6.047, thresh: 2.254, 175 frames, 13 pixels
#       Added cell 274 at 08, 080, 036, peak: 6.031, thresh: 2.293, 240 frames, 17 pixels
#       Added cell 275 at 14, 072, 021, peak: 6.030, thresh: 2.385, 318 frames, 31 pixels
#       Added cell 276 at 06, 050, 056, peak: 6.027, thresh: 2.420, 155 frames, 13 pixels
#       Added cell 277 at 08, 076, 083, peak: 6.025, thresh: 2.316, 329 frames, 23 pixels
#       Added cell 278 at 12, 098, 027, peak: 5.995, thresh: 2.279, 224 frames, 18 pixels
#       Added cell 279 at 17, 030, 079, peak: 5.992, thresh: 2.416, 217 frames, 16 pixels
#       Added cell 280 at 16, 088, 040, peak: 5.991, thresh: 2.316, 256 frames, 18 pixels
#    Iter 0035: running 08 ROIs in parallel
#       Added cell 281 at 05, 073, 015, peak: 5.991, thresh: 2.216, 172 frames, 12 pixels
#       Added cell 282 at 06, 025, 094, peak: 5.989, thresh: 2.416, 190 frames, 16 pixels
#       Added cell 283 at 16, 055, 072, peak: 5.986, thresh: 2.244, 377 frames, 25 pixels
#       Added cell 284 at 12, 044, 047, peak: 5.983, thresh: 2.412, 188 frames, 16 pixels
#       Added cell 285 at 17, 045, 070, peak: 5.980, thresh: 2.597, 227 frames, 21 pixels
#       Added cell 286 at 09, 072, 084, peak: 5.976, thresh: 2.305, 193 frames, 14 pixels
#       Added cell 287 at 15, 046, 054, peak: 5.972, thresh: 2.205, 205 frames, 17 pixels
#       Added cell 288 at 07, 040, 073, peak: 5.962, thresh: 2.184, 179 frames, 11 pixels
#    Iter 0036: running 08 ROIs in parallel
#       Added cell 289 at 08, 061, 033, peak: 5.959, thresh: 2.271, 198 frames, 16 pixels
#       Added cell 290 at 13, 068, 070, peak: 5.958, thresh: 2.531, 217 frames, 18 pixels
#       Added cell 291 at 12, 026, 020, peak: 5.957, thresh: 2.265, 199 frames, 15 pixels
#       Added cell 292 at 06, 032, 071, peak: 5.956, thresh: 2.375, 168 frames, 16 pixels
#       Added cell 293 at 00, 074, 016, peak: 5.954, thresh: 2.245, 183 frames, 12 pixels
#       Added cell 294 at 11, 045, 050, peak: 5.952, thresh: 2.206, 192 frames, 14 pixels
#       Added cell 295 at 13, 028, 085, peak: 5.948, thresh: 2.427, 282 frames, 24 pixels
#       Added cell 296 at 17, 083, 081, peak: 5.947, thresh: 2.363, 188 frames, 14 pixels
#    Iter 0037: running 08 ROIs in parallel
#       Added cell 297 at 04, 068, 032, peak: 5.947, thresh: 2.387, 206 frames, 20 pixels
#       Added cell 298 at 07, 029, 011, peak: 5.945, thresh: 2.314, 174 frames, 15 pixels
#       Added cell 299 at 06, 097, 101, peak: 5.943, thresh: 2.345, 149 frames, 10 pixels
#       Added cell 300 at 12, 081, 016, peak: 5.938, thresh: 2.304, 184 frames, 16 pixels
#       Added cell 301 at 09, 033, 100, peak: 5.937, thresh: 2.290, 188 frames, 15 pixels
#       Added cell 302 at 17, 092, 023, peak: 5.937, thresh: 2.284, 170 frames, 13 pixels
#       Added cell 303 at 11, 038, 077, peak: 5.937, thresh: 2.451, 158 frames, 10 pixels
#       Added cell 304 at 11, 075, 095, peak: 5.932, thresh: 2.238, 255 frames, 20 pixels
#    Iter 0038: running 08 ROIs in parallel
#       Added cell 305 at 00, 048, 036, peak: 5.931, thresh: 2.209, 217 frames, 15 pixels
#       Added cell 306 at 12, 060, 067, peak: 5.926, thresh: 2.318, 180 frames, 15 pixels
#       Added cell 307 at 07, 098, 091, peak: 5.924, thresh: 2.286, 169 frames, 15 pixels
#       Added cell 308 at 21, 089, 040, peak: 5.923, thresh: 2.248, 153 frames, 10 pixels
#       Added cell 309 at 09, 042, 074, peak: 5.922, thresh: 2.303, 172 frames, 12 pixels
#       Added cell 310 at 07, 035, 030, peak: 5.919, thresh: 2.355, 163 frames, 13 pixels
#       Added cell 311 at 21, 054, 021, peak: 5.912, thresh: 2.290, 178 frames, 20 pixels
#       Added cell 312 at 06, 064, 032, peak: 5.911, thresh: 2.297, 218 frames, 18 pixels
#    Iter 0039: running 08 ROIs in parallel
#       Added cell 313 at 16, 094, 016, peak: 5.908, thresh: 2.368, 205 frames, 17 pixels
#       Added cell 314 at 07, 058, 049, peak: 5.907, thresh: 2.223, 206 frames, 13 pixels
#       Added cell 315 at 12, 026, 033, peak: 5.906, thresh: 2.252, 174 frames, 12 pixels
#       Added cell 316 at 04, 096, 022, peak: 5.905, thresh: 2.275, 147 frames, 9 pixels
#       Added cell 317 at 02, 059, 099, peak: 5.904, thresh: 2.212, 180 frames, 12 pixels
#       Added cell 318 at 13, 080, 075, peak: 5.900, thresh: 2.466, 218 frames, 23 pixels
#       Added cell 319 at 06, 021, 023, peak: 5.900, thresh: 2.399, 161 frames, 12 pixels
#       Added cell 320 at 12, 097, 016, peak: 5.899, thresh: 2.321, 172 frames, 12 pixels
#    Iter 0040: running 08 ROIs in parallel
#       Added cell 321 at 12, 028, 060, peak: 5.898, thresh: 2.330, 189 frames, 15 pixels
#       Added cell 322 at 00, 040, 018, peak: 5.896, thresh: 2.271, 176 frames, 14 pixels
#       Added cell 323 at 09, 097, 056, peak: 5.895, thresh: 2.158, 188 frames, 15 pixels
#       Added cell 324 at 12, 002, 056, peak: 5.886, thresh: 2.323, 199 frames, 13 pixels
#       Added cell 325 at 12, 009, 033, peak: 5.881, thresh: 2.260, 173 frames, 12 pixels
#       Added cell 326 at 12, 071, 080, peak: 5.874, thresh: 2.237, 192 frames, 16 pixels
#       Added cell 327 at 01, 069, 044, peak: 5.873, thresh: 2.184, 185 frames, 12 pixels
#       Added cell 328 at 05, 093, 096, peak: 5.872, thresh: 2.215, 168 frames, 12 pixels
#    Iter 0041: running 08 ROIs in parallel
#       Added cell 329 at 05, 046, 027, peak: 5.872, thresh: 2.266, 187 frames, 16 pixels
#       Added cell 330 at 12, 077, 060, peak: 5.870, thresh: 2.217, 223 frames, 21 pixels
#       Added cell 331 at 12, 035, 024, peak: 5.868, thresh: 2.441, 181 frames, 14 pixels
#       Added cell 332 at 12, 067, 063, peak: 5.858, thresh: 2.304, 205 frames, 20 pixels
#       Added cell 333 at 10, 094, 015, peak: 5.858, thresh: 2.282, 185 frames, 14 pixels
#       Added cell 334 at 12, 038, 045, peak: 5.857, thresh: 2.203, 241 frames, 27 pixels
#       Added cell 335 at 10, 083, 066, peak: 5.853, thresh: 2.244, 188 frames, 13 pixels
#       Added cell 336 at 12, 021, 012, peak: 5.852, thresh: 2.238, 217 frames, 17 pixels
#    Iter 0042: running 08 ROIs in parallel
#       Added cell 337 at 21, 008, 043, peak: 5.850, thresh: 2.158, 164 frames, 13 pixels
#       Added cell 338 at 12, 095, 056, peak: 5.848, thresh: 2.404, 177 frames, 13 pixels
#       Added cell 339 at 10, 023, 073, peak: 5.847, thresh: 2.308, 187 frames, 15 pixels
#       Added cell 340 at 10, 008, 040, peak: 5.847, thresh: 2.154, 215 frames, 17 pixels
#       Added cell 341 at 12, 055, 025, peak: 5.845, thresh: 2.324, 183 frames, 17 pixels
#       Added cell 342 at 06, 082, 019, peak: 5.845, thresh: 2.287, 172 frames, 14 pixels
#       Added cell 343 at 20, 093, 042, peak: 5.844, thresh: 2.335, 202 frames, 14 pixels
#       Added cell 344 at 07, 041, 063, peak: 5.844, thresh: 2.308, 165 frames, 12 pixels
#    Iter 0043: running 08 ROIs in parallel
#       Added cell 345 at 01, 049, 046, peak: 5.842, thresh: 2.367, 212 frames, 17 pixels
#       Added cell 346 at 16, 078, 057, peak: 5.841, thresh: 2.240, 184 frames, 16 pixels
#       Added cell 347 at 04, 018, 091, peak: 5.841, thresh: 2.340, 157 frames, 10 pixels
#       Added cell 348 at 11, 072, 054, peak: 5.841, thresh: 2.296, 170 frames, 13 pixels
#       Added cell 349 at 21, 010, 048, peak: 5.836, thresh: 2.212, 177 frames, 12 pixels
#       Added cell 350 at 07, 074, 090, peak: 5.829, thresh: 2.364, 157 frames, 14 pixels
#       Added cell 351 at 08, 072, 007, peak: 5.828, thresh: 2.335, 183 frames, 15 pixels
#       Added cell 352 at 13, 071, 066, peak: 5.828, thresh: 2.516, 491 frames, 57 pixels
#    Iter 0044: running 08 ROIs in parallel
#       Added cell 353 at 18, 072, 066, peak: 5.826, thresh: 2.392, 311 frames, 25 pixels
#       Added cell 354 at 16, 084, 045, peak: 5.825, thresh: 2.314, 234 frames, 20 pixels
#       Added cell 355 at 01, 095, 049, peak: 5.821, thresh: 2.269, 216 frames, 20 pixels
#       Added cell 356 at 21, 068, 085, peak: 5.818, thresh: 2.211, 162 frames, 11 pixels
#       Added cell 357 at 12, 048, 020, peak: 5.818, thresh: 2.234, 223 frames, 19 pixels
#       Added cell 358 at 06, 023, 082, peak: 5.815, thresh: 2.359, 168 frames, 11 pixels
#       Added cell 359 at 12, 099, 096, peak: 5.813, thresh: 2.338, 150 frames, 10 pixels
#       Added cell 360 at 21, 034, 053, peak: 5.811, thresh: 2.233, 182 frames, 14 pixels
#    Iter 0045: running 08 ROIs in parallel
#       Added cell 361 at 21, 054, 047, peak: 5.811, thresh: 2.266, 149 frames, 10 pixels
#       Added cell 362 at 21, 058, 075, peak: 5.810, thresh: 2.241, 238 frames, 21 pixels
#       Added cell 363 at 06, 057, 090, peak: 5.807, thresh: 2.353, 182 frames, 12 pixels
#       Added cell 364 at 16, 019, 089, peak: 5.807, thresh: 2.365, 235 frames, 14 pixels
#       Added cell 365 at 18, 052, 075, peak: 5.806, thresh: 2.374, 201 frames, 13 pixels
#       Added cell 366 at 07, 095, 085, peak: 5.805, thresh: 2.408, 151 frames, 11 pixels
#       Added cell 367 at 04, 048, 051, peak: 5.802, thresh: 2.278, 204 frames, 19 pixels
#       Added cell 368 at 09, 089, 083, peak: 5.801, thresh: 2.244, 165 frames, 15 pixels
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#    Iter 0046: running 01 ROIs in parallel
#       Added cell 369 at 06, 078, 006, peak: 5.800, thresh: 2.308, 204 frames, 15 pixels
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#       Iter 0047: peak is too small  - ending extraction
#    Found 369 cells in 47 iterations
#    Saving cells to Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0000\stats.npy
#    Saving iscell.npy to Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0000\iscell.npy
#    Computing neuropil masks
#    Starting MP
#    Ended MP
#    Detecting from patch: 1/30
#    Updated main params file
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection with tag detection
#    Created dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0001 with tag patch-0001
#    Running cell detection on patch 0001 at Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0001, max 10000 iters
#    Patch bounds are [ 0 22], [  0 120], [ 85 205]
#    Cell center bounds are [ 0 22], [  0 100], [102 187]
#    Time bounds are (None, None)
# mov_sub
#    Loading 15.48 GB movie to memory
#    Loaded
#    Loading from Y:\runs\Coconut\s3d-Coconut-Demo\iters\batch0032
#       Movie shape: (13120, 22, 120, 120)
#    Saving cell stats and info to Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0001
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 5.800 and Th2: 4.000
#    Iter 0000: running 08 ROIs in parallel
#       Added cell 1 at 16, 012, 028, peak: 19.075, thresh: 4.000, 356 frames, 27 pixels
#       Added cell 2 at 19, 075, 030, peak: 17.156, thresh: 3.175, 740 frames, 69 pixels
#       Added cell 3 at 17, 054, 038, peak: 16.842, thresh: 3.250, 770 frames, 54 pixels
#       Added cell 4 at 11, 051, 031, peak: 12.246, thresh: 2.758, 336 frames, 21 pixels
#       Added cell 5 at 17, 076, 028, peak: 12.161, thresh: 2.871, 1181 frames, 134 pixels
#       Added cell 6 at 16, 088, 033, peak: 11.596, thresh: 3.067, 407 frames, 33 pixels
#       Added cell 7 at 20, 051, 029, peak: 11.304, thresh: 2.885, 931 frames, 80 pixels
#       Added cell 8 at 17, 074, 051, peak: 11.033, thresh: 2.811, 414 frames, 32 pixels
#    Iter 0001: running 08 ROIs in parallel
#       Added cell 9 at 17, 041, 023, peak: 10.852, thresh: 3.045, 210 frames, 20 pixels
#       Added cell 10 at 16, 004, 019, peak: 10.756, thresh: 3.046, 298 frames, 18 pixels
#       Added cell 11 at 16, 025, 054, peak: 10.462, thresh: 3.270, 195 frames, 15 pixels
#       Added cell 12 at 19, 081, 038, peak: 10.457, thresh: 2.878, 244 frames, 16 pixels
#       Added cell 13 at 08, 065, 038, peak: 10.406, thresh: 2.610, 361 frames, 31 pixels
#       Added cell 14 at 12, 096, 036, peak: 10.362, thresh: 2.439, 795 frames, 62 pixels
#       Added cell 15 at 13, 095, 092, peak: 10.118, thresh: 2.975, 443 frames, 35 pixels
#       Added cell 16 at 17, 084, 037, peak: 10.041, thresh: 2.771, 242 frames, 15 pixels
#    Iter 0002: running 08 ROIs in parallel
#       Added cell 17 at 17, 038, 026, peak: 9.850, thresh: 2.566, 456 frames, 31 pixels
#       Added cell 18 at 16, 097, 034, peak: 9.622, thresh: 3.109, 184 frames, 16 pixels
#       Added cell 19 at 09, 048, 031, peak: 9.586, thresh: 2.533, 875 frames, 78 pixels
#       Added cell 20 at 12, 040, 033, peak: 9.462, thresh: 2.655, 278 frames, 20 pixels
#       Added cell 21 at 17, 061, 052, peak: 9.308, thresh: 2.747, 266 frames, 25 pixels
#       Added cell 22 at 12, 088, 090, peak: 9.295, thresh: 2.484, 225 frames, 19 pixels
#       Added cell 23 at 16, 070, 046, peak: 9.151, thresh: 2.843, 505 frames, 60 pixels
#       Added cell 24 at 13, 056, 023, peak: 8.935, thresh: 2.797, 270 frames, 27 pixels
#    Iter 0003: running 08 ROIs in parallel
#       Added cell 25 at 07, 030, 031, peak: 8.934, thresh: 2.620, 187 frames, 14 pixels
#       Added cell 26 at 19, 061, 055, peak: 8.905, thresh: 2.637, 258 frames, 25 pixels
#       Added cell 27 at 16, 008, 058, peak: 8.722, thresh: 2.856, 187 frames, 13 pixels
#       Added cell 28 at 12, 078, 051, peak: 8.659, thresh: 2.483, 315 frames, 28 pixels
#       Added cell 29 at 19, 093, 030, peak: 8.331, thresh: 2.553, 273 frames, 14 pixels
#       Added cell 30 at 12, 004, 050, peak: 8.323, thresh: 2.366, 245 frames, 19 pixels
#       Added cell 31 at 12, 014, 038, peak: 8.189, thresh: 2.436, 187 frames, 15 pixels
#       Added cell 32 at 11, 084, 095, peak: 8.119, thresh: 2.607, 181 frames, 12 pixels
#    Iter 0004: running 08 ROIs in parallel
#       Added cell 33 at 11, 080, 031, peak: 8.076, thresh: 2.450, 217 frames, 14 pixels
#       Added cell 34 at 09, 055, 041, peak: 7.967, thresh: 2.443, 187 frames, 14 pixels
#       Added cell 35 at 16, 032, 034, peak: 7.939, thresh: 2.669, 188 frames, 13 pixels
#       Added cell 36 at 12, 084, 056, peak: 7.920, thresh: 2.367, 227 frames, 22 pixels
#       Added cell 37 at 17, 007, 022, peak: 7.900, thresh: 2.436, 409 frames, 30 pixels
#       Added cell 38 at 09, 093, 095, peak: 7.898, thresh: 2.464, 182 frames, 10 pixels
#       Added cell 39 at 09, 038, 017, peak: 7.846, thresh: 2.699, 241 frames, 19 pixels
#       Added cell 40 at 12, 065, 031, peak: 7.824, thresh: 2.406, 172 frames, 13 pixels
#    Iter 0005: running 08 ROIs in parallel
#       Added cell 41 at 20, 033, 029, peak: 7.767, thresh: 2.766, 299 frames, 28 pixels
#       Added cell 42 at 12, 030, 057, peak: 7.701, thresh: 2.420, 296 frames, 31 pixels
#       Added cell 43 at 12, 077, 038, peak: 7.652, thresh: 2.452, 211 frames, 17 pixels
#       Added cell 44 at 20, 091, 033, peak: 7.543, thresh: 2.625, 347 frames, 26 pixels
#       Added cell 45 at 09, 038, 046, peak: 7.533, thresh: 2.381, 176 frames, 13 pixels
#       Added cell 46 at 05, 031, 061, peak: 7.497, thresh: 2.606, 158 frames, 15 pixels
#       Added cell 47 at 03, 008, 030, peak: 7.464, thresh: 2.642, 185 frames, 13 pixels
#       Added cell 48 at 12, 089, 026, peak: 7.430, thresh: 2.403, 204 frames, 17 pixels
#    Iter 0006: running 08 ROIs in parallel
#       Added cell 49 at 09, 070, 052, peak: 7.384, thresh: 2.470, 166 frames, 13 pixels
#       Added cell 50 at 12, 025, 028, peak: 7.370, thresh: 2.471, 253 frames, 24 pixels
#       Added cell 51 at 06, 023, 062, peak: 7.343, thresh: 2.448, 208 frames, 14 pixels
#       Added cell 52 at 12, 041, 027, peak: 7.325, thresh: 2.501, 182 frames, 15 pixels
#       Added cell 53 at 11, 028, 058, peak: 7.324, thresh: 2.317, 195 frames, 16 pixels
#       Added cell 54 at 17, 057, 019, peak: 7.287, thresh: 2.482, 278 frames, 20 pixels
#       Added cell 55 at 12, 049, 055, peak: 7.230, thresh: 2.391, 232 frames, 17 pixels
#       Added cell 56 at 12, 021, 051, peak: 7.210, thresh: 2.283, 269 frames, 23 pixels
#    Iter 0007: running 08 ROIs in parallel
#       Added cell 57 at 12, 018, 036, peak: 7.180, thresh: 2.463, 185 frames, 17 pixels
#       Added cell 58 at 08, 031, 033, peak: 7.108, thresh: 2.437, 198 frames, 17 pixels
#       Added cell 59 at 12, 042, 060, peak: 7.108, thresh: 2.316, 180 frames, 17 pixels
#       Added cell 60 at 10, 020, 033, peak: 7.106, thresh: 2.328, 239 frames, 21 pixels
#       Added cell 61 at 16, 040, 056, peak: 7.097, thresh: 2.529, 561 frames, 67 pixels
#       Added cell 62 at 10, 084, 022, peak: 7.096, thresh: 2.422, 153 frames, 10 pixels
#       Added cell 63 at 20, 048, 019, peak: 7.083, thresh: 2.350, 270 frames, 21 pixels
#       Added cell 64 at 17, 038, 049, peak: 7.059, thresh: 2.590, 176 frames, 11 pixels
#    Iter 0008: running 08 ROIs in parallel
#       Added cell 65 at 16, 096, 024, peak: 7.058, thresh: 2.746, 169 frames, 12 pixels
#       Added cell 66 at 12, 037, 030, peak: 7.050, thresh: 2.311, 227 frames, 20 pixels
#       Added cell 67 at 18, 071, 017, peak: 7.043, thresh: 2.475, 214 frames, 17 pixels
#       Added cell 68 at 12, 053, 031, peak: 6.966, thresh: 2.424, 266 frames, 17 pixels
#       Added cell 69 at 04, 035, 054, peak: 6.963, thresh: 2.506, 176 frames, 13 pixels
#       Added cell 70 at 09, 088, 033, peak: 6.952, thresh: 2.569, 203 frames, 14 pixels
#       Added cell 71 at 12, 088, 041, peak: 6.927, thresh: 2.432, 159 frames, 10 pixels
#       Added cell 72 at 09, 042, 098, peak: 6.919, thresh: 2.258, 191 frames, 11 pixels
#    Iter 0009: running 08 ROIs in parallel
#       Added cell 73 at 08, 092, 038, peak: 6.862, thresh: 2.386, 201 frames, 14 pixels
#       Added cell 74 at 10, 097, 036, peak: 6.860, thresh: 2.232, 183 frames, 14 pixels
#       Added cell 75 at 16, 044, 025, peak: 6.835, thresh: 2.495, 344 frames, 27 pixels
#       Added cell 76 at 08, 089, 094, peak: 6.811, thresh: 2.408, 134 frames, 11 pixels
#       Added cell 77 at 13, 005, 095, peak: 6.785, thresh: 2.760, 204 frames, 12 pixels
#       Added cell 78 at 19, 019, 033, peak: 6.779, thresh: 2.456, 198 frames, 15 pixels
#       Added cell 79 at 07, 006, 027, peak: 6.777, thresh: 2.506, 189 frames, 16 pixels
#       Added cell 80 at 09, 058, 051, peak: 6.768, thresh: 2.402, 195 frames, 18 pixels
#    Iter 0010: running 08 ROIs in parallel
#       Added cell 81 at 07, 091, 035, peak: 6.827, thresh: 2.348, 155 frames, 10 pixels
#       Added cell 82 at 10, 094, 034, peak: 6.789, thresh: 2.277, 214 frames, 16 pixels
#       Added cell 83 at 08, 009, 053, peak: 6.758, thresh: 2.377, 186 frames, 17 pixels
#       Added cell 84 at 07, 062, 037, peak: 6.747, thresh: 2.353, 287 frames, 21 pixels
#       Added cell 85 at 17, 028, 097, peak: 6.741, thresh: 2.369, 186 frames, 10 pixels
#       Added cell 86 at 13, 015, 019, peak: 6.716, thresh: 2.653, 181 frames, 14 pixels
#       Added cell 87 at 11, 057, 019, peak: 6.706, thresh: 2.450, 176 frames, 17 pixels
#       Added cell 88 at 07, 085, 038, peak: 6.683, thresh: 2.316, 188 frames, 17 pixels
#    Iter 0011: running 08 ROIs in parallel
#       Added cell 89 at 09, 090, 026, peak: 6.670, thresh: 2.280, 176 frames, 11 pixels
#       Added cell 90 at 17, 031, 054, peak: 6.633, thresh: 2.448, 165 frames, 10 pixels
#       Added cell 91 at 12, 076, 023, peak: 6.618, thresh: 2.350, 280 frames, 27 pixels
#       Added cell 92 at 08, 075, 018, peak: 6.617, thresh: 2.319, 214 frames, 24 pixels
#       Added cell 93 at 09, 078, 056, peak: 6.616, thresh: 2.335, 157 frames, 10 pixels
#       Added cell 94 at 03, 060, 021, peak: 6.610, thresh: 2.264, 172 frames, 13 pixels
#       Added cell 95 at 17, 018, 036, peak: 6.599, thresh: 2.413, 209 frames, 21 pixels
#       Added cell 96 at 11, 075, 040, peak: 6.590, thresh: 2.326, 172 frames, 14 pixels
#    Iter 0012: running 08 ROIs in parallel
#       Added cell 97 at 09, 028, 057, peak: 6.582, thresh: 2.318, 202 frames, 18 pixels
#       Added cell 98 at 16, 016, 052, peak: 6.577, thresh: 2.460, 262 frames, 24 pixels
#       Added cell 99 at 16, 042, 038, peak: 6.575, thresh: 2.622, 246 frames, 22 pixels
#       Added cell 100 at 06, 065, 038, peak: 6.549, thresh: 2.267, 219 frames, 22 pixels
#       Added cell 101 at 12, 011, 041, peak: 6.539, thresh: 2.268, 215 frames, 15 pixels
#       Added cell 102 at 12, 011, 054, peak: 6.539, thresh: 2.228, 210 frames, 15 pixels
#       Added cell 103 at 08, 087, 030, peak: 6.527, thresh: 2.550, 183 frames, 13 pixels
#       Added cell 104 at 09, 014, 037, peak: 6.524, thresh: 2.275, 158 frames, 10 pixels
#    Iter 0013: running 08 ROIs in parallel
#       Added cell 105 at 10, 082, 094, peak: 6.517, thresh: 2.355, 149 frames, 9 pixels
#       Added cell 106 at 13, 095, 018, peak: 6.517, thresh: 2.612, 184 frames, 12 pixels
#       Added cell 107 at 16, 040, 048, peak: 6.515, thresh: 2.474, 514 frames, 57 pixels
#       Added cell 108 at 11, 089, 039, peak: 6.514, thresh: 2.292, 145 frames, 11 pixels
#       Added cell 109 at 06, 060, 042, peak: 6.512, thresh: 2.314, 263 frames, 26 pixels
#       Added cell 110 at 04, 039, 057, peak: 6.500, thresh: 2.355, 193 frames, 16 pixels
#       Added cell 111 at 07, 012, 034, peak: 6.482, thresh: 2.437, 182 frames, 20 pixels
#       Added cell 112 at 11, 014, 018, peak: 6.467, thresh: 2.190, 184 frames, 12 pixels
#    Iter 0014: running 08 ROIs in parallel
#       Added cell 113 at 12, 085, 042, peak: 6.509, thresh: 2.433, 175 frames, 15 pixels
#       Added cell 114 at 06, 097, 037, peak: 6.466, thresh: 2.350, 173 frames, 14 pixels
#       Added cell 115 at 12, 003, 022, peak: 6.465, thresh: 2.424, 150 frames, 9 pixels
#       Added cell 116 at 06, 030, 029, peak: 6.432, thresh: 2.379, 290 frames, 18 pixels
#       Added cell 117 at 04, 020, 017, peak: 6.427, thresh: 2.453, 281 frames, 14 pixels
#       Added cell 118 at 12, 071, 026, peak: 6.420, thresh: 2.357, 186 frames, 14 pixels
#       Added cell 119 at 08, 067, 025, peak: 6.398, thresh: 2.368, 206 frames, 19 pixels
#       Added cell 120 at 06, 018, 041, peak: 6.386, thresh: 2.324, 149 frames, 11 pixels
#    Iter 0015: running 08 ROIs in parallel
# ...
#    Iter 0030: running 08 ROIs in parallel
#       Added cell 241 at 00, 057, 050, peak: 6.231, thresh: 2.293, 173 frames, 14 pixels
#       Added cell 242 at 12, 063, 104, peak: 6.229, thresh: 2.324, 187 frames, 15 pixels
#       Added cell 243 at 04, 048, 023, peak: 6.224, thresh: 2.335, 185 frames, 15 pixels
#       Added cell 244 at 07, 076, 018, peak: 6.223, thresh: 2.380, 195 frames, 14 pixels
#       Added cell 245 at 11, 070, 061, peak: 6.217, thresh: 2.284, 288 frames, 23 pixels
#       Added cell 246 at 14, 118, 090, peak: 6.208, thresh: 2.737, 239 frames, 18 pixels
#       Added cell 247 at 17, 093, 022, peak: 6.206, thresh: 2.310, 179 frames, 9 pixels
#       Added cell 248 at 17, 034, 021, peak: 6.203, thresh: 2.318, 181 frames, 12 pixels
#    Iter 0031: running 08 ROIs in parallel
#       Added cell 249 at 05, 057, 058, peak: 6.198, thresh: 2.342, 229 frames, 15 pixels
#       Added cell 250 at 08, 053, 064, peak: 6.196, thresh: 2.236, 167 frames, 15 pixels
#       Added cell 251 at 15, 118, 028, peak: 6.195, thresh: 2.543, 245 frames, 18 pixels
#       Added cell 252 at 18, 118, 095, peak: 6.187, thresh: 2.594, 200 frames, 16 pixels
#       Added cell 253 at 12, 033, 070, peak: 6.185, thresh: 2.377, 190 frames, 15 pixels
#       Added cell 254 at 10, 076, 052, peak: 6.181, thresh: 2.287, 205 frames, 14 pixels
#       Added cell 255 at 20, 078, 118, peak: 6.177, thresh: 2.399, 180 frames, 13 pixels
#       Added cell 256 at 08, 052, 030, peak: 6.176, thresh: 2.414, 221 frames, 20 pixels
#    Iter 0032: running 08 ROIs in parallel
#       Added cell 257 at 04, 060, 113, peak: 6.174, thresh: 2.373, 172 frames, 12 pixels
#       Added cell 258 at 05, 033, 029, peak: 6.173, thresh: 2.475, 157 frames, 10 pixels
#       Added cell 259 at 04, 051, 070, peak: 6.172, thresh: 2.296, 229 frames, 22 pixels
#       Added cell 260 at 18, 118, 111, peak: 6.164, thresh: 2.574, 215 frames, 18 pixels
#       Added cell 261 at 17, 039, 034, peak: 6.164, thresh: 2.302, 237 frames, 19 pixels
#       Added cell 262 at 00, 022, 036, peak: 6.162, thresh: 2.282, 177 frames, 12 pixels
#       Added cell 263 at 06, 047, 072, peak: 6.149, thresh: 2.351, 193 frames, 18 pixels
#       Added cell 264 at 10, 058, 044, peak: 6.142, thresh: 2.272, 219 frames, 19 pixels
#    Iter 0033: running 08 ROIs in parallel
#       Added cell 265 at 10, 038, 065, peak: 6.135, thresh: 2.321, 150 frames, 10 pixels
#       Added cell 266 at 01, 060, 078, peak: 6.134, thresh: 2.319, 180 frames, 12 pixels
#       Added cell 267 at 00, 118, 112, peak: 6.130, thresh: 2.251, 206 frames, 14 pixels
#       Added cell 268 at 01, 037, 030, peak: 6.129, thresh: 2.382, 174 frames, 14 pixels
#       Added cell 269 at 13, 055, 061, peak: 6.129, thresh: 2.431, 289 frames, 18 pixels
#       Added cell 270 at 16, 069, 017, peak: 6.125, thresh: 2.389, 537 frames, 29 pixels
#       Added cell 271 at 04, 021, 064, peak: 6.119, thresh: 2.385, 177 frames, 15 pixels
#       Added cell 272 at 19, 118, 065, peak: 6.117, thresh: 2.564, 245 frames, 16 pixels
#    Iter 0034: running 08 ROIs in parallel
#       Added cell 273 at 06, 050, 031, peak: 6.116, thresh: 2.356, 207 frames, 18 pixels
#       Added cell 274 at 12, 019, 052, peak: 6.115, thresh: 2.319, 229 frames, 16 pixels
#       Added cell 275 at 11, 058, 028, peak: 6.114, thresh: 2.395, 169 frames, 11 pixels
#       Added cell 276 at 15, 117, 111, peak: 6.113, thresh: 2.663, 587 frames, 56 pixels
#       Added cell 277 at 10, 094, 017, peak: 6.105, thresh: 2.488, 168 frames, 12 pixels
#       Added cell 278 at 06, 059, 024, peak: 6.104, thresh: 2.356, 245 frames, 22 pixels
#       Added cell 279 at 08, 086, 089, peak: 6.102, thresh: 2.351, 196 frames, 11 pixels
#       Added cell 280 at 04, 046, 066, peak: 6.097, thresh: 2.316, 165 frames, 14 pixels
#    Iter 0035: running 08 ROIs in parallel
#       Added cell 281 at 12, 091, 021, peak: 6.080, thresh: 2.230, 191 frames, 15 pixels
#       Added cell 282 at 04, 072, 116, peak: 6.078, thresh: 2.335, 170 frames, 12 pixels
#       Added cell 283 at 15, 118, 038, peak: 6.076, thresh: 2.564, 227 frames, 20 pixels
#       Added cell 284 at 21, 117, 119, peak: 6.075, thresh: 2.550, 356 frames, 12 pixels
#       Added cell 285 at 04, 030, 045, peak: 6.068, thresh: 2.460, 254 frames, 15 pixels
#       Added cell 286 at 04, 042, 041, peak: 6.068, thresh: 2.366, 171 frames, 10 pixels
#       Added cell 287 at 09, 051, 070, peak: 6.058, thresh: 2.307, 178 frames, 16 pixels
#       Added cell 288 at 01, 061, 072, peak: 6.057, thresh: 2.295, 158 frames, 11 pixels
#    Iter 0036: running 08 ROIs in parallel
#       Added cell 289 at 08, 046, 053, peak: 6.052, thresh: 2.191, 155 frames, 13 pixels
#       Added cell 290 at 03, 057, 071, peak: 6.044, thresh: 2.267, 200 frames, 15 pixels
#       Added cell 291 at 06, 049, 017, peak: 6.040, thresh: 2.263, 217 frames, 15 pixels
#       Added cell 292 at 12, 063, 062, peak: 6.037, thresh: 2.304, 167 frames, 10 pixels
#       Added cell 293 at 06, 054, 044, peak: 6.029, thresh: 2.334, 192 frames, 19 pixels
#       Added cell 294 at 12, 079, 028, peak: 6.028, thresh: 2.284, 205 frames, 15 pixels
#       Added cell 295 at 10, 033, 020, peak: 6.023, thresh: 2.650, 186 frames, 13 pixels
#       Added cell 296 at 05, 032, 117, peak: 6.021, thresh: 2.382, 157 frames, 9 pixels
#    Iter 0037: running 08 ROIs in parallel
#       Added cell 297 at 05, 044, 049, peak: 6.014, thresh: 2.429, 183 frames, 12 pixels
#       Added cell 298 at 06, 026, 051, peak: 5.999, thresh: 2.284, 175 frames, 11 pixels
#       Added cell 299 at 00, 117, 049, peak: 5.999, thresh: 2.243, 204 frames, 19 pixels
#       Added cell 300 at 15, 118, 022, peak: 5.987, thresh: 2.603, 221 frames, 16 pixels
#       Added cell 301 at 04, 037, 021, peak: 5.983, thresh: 2.396, 246 frames, 14 pixels
#       Added cell 302 at 03, 055, 079, peak: 5.981, thresh: 2.304, 173 frames, 13 pixels
#       Added cell 303 at 15, 118, 049, peak: 5.979, thresh: 2.502, 302 frames, 20 pixels
#       Added cell 304 at 16, 118, 089, peak: 5.976, thresh: 2.513, 162 frames, 12 pixels
#    Iter 0038: running 08 ROIs in parallel
#       Added cell 305 at 06, 042, 049, peak: 6.006, thresh: 2.411, 177 frames, 12 pixels
#       Added cell 306 at 06, 050, 069, peak: 5.972, thresh: 2.311, 173 frames, 11 pixels
#       Added cell 307 at 19, 118, 069, peak: 5.970, thresh: 2.507, 239 frames, 16 pixels
#       Added cell 308 at 00, 118, 099, peak: 5.969, thresh: 2.331, 177 frames, 11 pixels
#       Added cell 309 at 14, 117, 017, peak: 5.966, thresh: 2.480, 350 frames, 20 pixels
#       Added cell 310 at 09, 041, 065, peak: 5.963, thresh: 2.348, 144 frames, 10 pixels
#       Added cell 311 at 00, 073, 103, peak: 5.957, thresh: 2.278, 206 frames, 19 pixels
#       Added cell 312 at 11, 033, 083, peak: 5.954, thresh: 2.237, 190 frames, 13 pixels
#    Iter 0039: running 08 ROIs in parallel
#       Added cell 313 at 04, 019, 091, peak: 5.943, thresh: 2.342, 175 frames, 11 pixels
#       Added cell 314 at 00, 030, 096, peak: 5.943, thresh: 2.276, 185 frames, 16 pixels
#       Added cell 315 at 11, 090, 049, peak: 5.940, thresh: 2.253, 167 frames, 12 pixels
#       Added cell 316 at 00, 027, 038, peak: 5.935, thresh: 2.331, 173 frames, 15 pixels
#       Added cell 317 at 11, 045, 030, peak: 5.932, thresh: 2.240, 181 frames, 12 pixels
#       Added cell 318 at 09, 082, 105, peak: 5.931, thresh: 2.382, 166 frames, 13 pixels
#       Added cell 319 at 04, 024, 072, peak: 5.931, thresh: 2.282, 176 frames, 10 pixels
#       Added cell 320 at 06, 088, 019, peak: 5.929, thresh: 2.264, 155 frames, 11 pixels
#    Iter 0040: running 08 ROIs in parallel
#       Added cell 321 at 04, 025, 025, peak: 5.919, thresh: 2.399, 181 frames, 13 pixels
#       Added cell 322 at 07, 060, 028, peak: 5.919, thresh: 2.404, 160 frames, 10 pixels
#       Added cell 323 at 19, 118, 093, peak: 5.917, thresh: 2.545, 225 frames, 17 pixels
#       Added cell 324 at 08, 089, 028, peak: 5.917, thresh: 2.434, 215 frames, 17 pixels
#       Added cell 325 at 03, 077, 025, peak: 5.910, thresh: 2.262, 150 frames, 11 pixels
#       Added cell 326 at 05, 022, 056, peak: 5.909, thresh: 2.241, 200 frames, 16 pixels
#       Added cell 327 at 04, 095, 111, peak: 5.908, thresh: 2.312, 167 frames, 11 pixels
#       Added cell 328 at 00, 034, 040, peak: 5.905, thresh: 2.194, 190 frames, 13 pixels
#    Iter 0041: running 08 ROIs in parallel
#       Added cell 329 at 03, 082, 116, peak: 5.899, thresh: 2.364, 175 frames, 12 pixels
#       Added cell 330 at 06, 050, 035, peak: 5.895, thresh: 2.463, 163 frames, 12 pixels
#       Added cell 331 at 05, 041, 066, peak: 5.890, thresh: 2.300, 187 frames, 16 pixels
#       Added cell 332 at 09, 026, 109, peak: 5.886, thresh: 2.252, 168 frames, 11 pixels
#       Added cell 333 at 09, 033, 029, peak: 5.879, thresh: 2.589, 179 frames, 10 pixels
#       Added cell 334 at 05, 021, 017, peak: 5.878, thresh: 2.197, 186 frames, 11 pixels
#       Added cell 335 at 07, 024, 026, peak: 5.877, thresh: 2.354, 173 frames, 16 pixels
#       Added cell 336 at 09, 093, 086, peak: 5.876, thresh: 2.183, 190 frames, 12 pixels
#    Iter 0042: running 08 ROIs in parallel
#       Added cell 337 at 00, 118, 062, peak: 5.874, thresh: 2.301, 181 frames, 15 pixels
#       Added cell 338 at 00, 041, 067, peak: 5.867, thresh: 2.177, 175 frames, 15 pixels
#       Added cell 339 at 06, 036, 078, peak: 5.866, thresh: 2.269, 163 frames, 12 pixels
#       Added cell 340 at 09, 034, 067, peak: 5.864, thresh: 2.270, 171 frames, 13 pixels
#       Added cell 341 at 06, 039, 017, peak: 5.862, thresh: 2.261, 144 frames, 10 pixels
#       Added cell 342 at 12, 084, 113, peak: 5.862, thresh: 2.300, 249 frames, 20 pixels
#       Added cell 343 at 11, 099, 114, peak: 5.862, thresh: 2.294, 167 frames, 12 pixels
#       Added cell 344 at 00, 020, 048, peak: 5.861, thresh: 2.283, 163 frames, 15 pixels
#    Iter 0043: running 08 ROIs in parallel
#       Added cell 345 at 00, 118, 081, peak: 5.855, thresh: 2.291, 172 frames, 13 pixels
#       Added cell 346 at 09, 067, 037, peak: 5.854, thresh: 2.401, 152 frames, 9 pixels
#       Added cell 347 at 21, 046, 039, peak: 5.852, thresh: 2.147, 167 frames, 12 pixels
#       Added cell 348 at 17, 095, 018, peak: 5.848, thresh: 2.329, 202 frames, 8 pixels
#       Added cell 349 at 04, 061, 059, peak: 5.845, thresh: 2.441, 170 frames, 16 pixels
#       Added cell 350 at 06, 037, 063, peak: 5.843, thresh: 2.239, 185 frames, 13 pixels
#       Added cell 351 at 07, 025, 076, peak: 5.840, thresh: 2.218, 173 frames, 12 pixels
#       Added cell 352 at 06, 054, 111, peak: 5.840, thresh: 2.337, 281 frames, 19 pixels
#    Iter 0044: running 08 ROIs in parallel
#       Added cell 353 at 10, 079, 101, peak: 5.838, thresh: 2.317, 221 frames, 10 pixels
#       Added cell 354 at 06, 030, 035, peak: 5.836, thresh: 2.250, 187 frames, 13 pixels
#       Added cell 355 at 20, 119, 037, peak: 5.835, thresh: 2.412, 239 frames, 15 pixels
#       Added cell 356 at 06, 019, 020, peak: 5.832, thresh: 2.205, 185 frames, 15 pixels
#       Added cell 357 at 00, 075, 035, peak: 5.824, thresh: 2.221, 167 frames, 12 pixels
#       Added cell 358 at 08, 059, 030, peak: 5.821, thresh: 2.272, 207 frames, 17 pixels
#       Added cell 359 at 04, 019, 066, peak: 5.819, thresh: 2.297, 224 frames, 20 pixels
#       Added cell 360 at 06, 053, 034, peak: 5.814, thresh: 2.284, 202 frames, 18 pixels
#    Iter 0045: running 08 ROIs in parallel
#       Added cell 361 at 06, 068, 042, peak: 5.813, thresh: 2.300, 199 frames, 18 pixels
#       Added cell 362 at 13, 097, 025, peak: 5.813, thresh: 2.362, 245 frames, 24 pixels
#       Added cell 363 at 06, 024, 031, peak: 5.809, thresh: 2.256, 192 frames, 16 pixels
#       Added cell 364 at 16, 052, 052, peak: 5.808, thresh: 2.508, 212 frames, 15 pixels
#       Added cell 365 at 07, 032, 019, peak: 5.807, thresh: 2.322, 170 frames, 11 pixels
#       Added cell 366 at 00, 055, 087, peak: 5.806, thresh: 2.203, 160 frames, 12 pixels
#       Added cell 367 at 06, 055, 064, peak: 5.805, thresh: 2.304, 175 frames, 13 pixels
#       Added cell 368 at 05, 073, 105, peak: 5.803, thresh: 2.307, 190 frames, 16 pixels
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#    Iter 0046: running 01 ROIs in parallel
#       Added cell 369 at 11, 056, 031, peak: 5.801, thresh: 2.229, 246 frames, 18 pixels
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#          Skipping
#       Iter 0047: peak is too small  - ending extraction
#    Found 369 cells in 47 iterations
#    Saving cells to Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0029\stats.npy
#    Saving iscell.npy to Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0029\iscell.npy
#    Computing neuropil masks
#    Starting MP
#    Ended MP
#    Created dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\combined-full with tag detection-combined-full
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0000 with tag detection-patch-0000
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0001 with tag detection-patch-0001
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0002 with tag detection-patch-0002
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0003 with tag detection-patch-0003
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0004 with tag detection-patch-0004
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0005 with tag detection-patch-0005
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0006 with tag detection-patch-0006
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0007 with tag detection-patch-0007
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0008 with tag detection-patch-0008
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0009 with tag detection-patch-0009
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0010 with tag detection-patch-0010
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0011 with tag detection-patch-0011
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0012 with tag detection-patch-0012
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0013 with tag detection-patch-0013
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0014 with tag detection-patch-0014
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0015 with tag detection-patch-0015
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0016 with tag detection-patch-0016
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0017 with tag detection-patch-0017
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0018 with tag detection-patch-0018
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0019 with tag detection-patch-0019
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0020 with tag detection-patch-0020
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0021 with tag detection-patch-0021
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0022 with tag detection-patch-0022
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0023 with tag detection-patch-0023
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0024 with tag detection-patch-0024
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0025 with tag detection-patch-0025
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0026 with tag detection-patch-0026
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0027 with tag detection-patch-0027
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0028 with tag detection-patch-0028
#       Found dir Y:\runs\Coconut\s3d-Coconut-Demo\detection\patch-0029 with tag detection-patch-0029
#    Combined 30 patches, 18107 cells
#    Saving combined files to Y:\runs\Coconut\s3d-Coconut-Demo\detection\combined-full
#       Saved stats
#       Saved iscell
#       Saved info (copied from patch) 29

# %%
traces = job.extract_and_deconvolve(stats_dir = combined_dir)
# Out:
#    Updated main params file
# 18107
#    Extracting 18107 valid cells, and saving cell flags to Y:\runs\Coconut\s3d-Coconut-Demo\detection\combined-full\iscell_extracted.npy
#    Extracting activity
# Will extract in 99 batches of 100
# Extracting batch 0000 of 0099
# Batch size: 1 GB
# Extracting batch 0001 of 0099
# Batch size: 1 GB
# Extracting batch 0002 of 0099
# Batch size: 1 GB
# Extracting batch 0003 of 0099
# Batch size: 1 GB
# Extracting batch 0004 of 0099
# Batch size: 1 GB
# Extracting batch 0005 of 0099
# Batch size: 1 GB
# Extracting batch 0006 of 0099
# Batch size: 1 GB
# Extracting batch 0007 of 0099
# Batch size: 1 GB
# Extracting batch 0008 of 0099
# Batch size: 1 GB
# Extracting batch 0009 of 0099
# Batch size: 1 GB
# Extracting batch 0010 of 0099
# Batch size: 1 GB
# Extracting batch 0011 of 0099
# Batch size: 1 GB
# Extracting batch 0012 of 0099
# Batch size: 1 GB
# Extracting batch 0013 of 0099
# Batch size: 1 GB
# Extracting batch 0014 of 0099
# Batch size: 1 GB
# Extracting batch 0015 of 0099
# Batch size: 1 GB
# Extracting batch 0016 of 0099
# Batch size: 1 GB
# Extracting batch 0017 of 0099
# Batch size: 1 GB
# Extracting batch 0018 of 0099
# Batch size: 1 GB
# Extracting batch 0019 of 0099
# Batch size: 1 GB
# Extracting batch 0020 of 0099
# Batch size: 1 GB
# Extracting batch 0021 of 0099
# Batch size: 1 GB
# Extracting batch 0022 of 0099
# Batch size: 1 GB
# Extracting batch 0023 of 0099
# Batch size: 1 GB
# Extracting batch 0024 of 0099
# Batch size: 1 GB
# Extracting batch 0025 of 0099
# Batch size: 1 GB
# Extracting batch 0026 of 0099
# Batch size: 1 GB
# Extracting batch 0027 of 0099
# Batch size: 1 GB
# Extracting batch 0028 of 0099
# Batch size: 1 GB
# Extracting batch 0029 of 0099
# Batch size: 1 GB
# Extracting batch 0030 of 0099
# Batch size: 1 GB
# Extracting batch 0031 of 0099
# Batch size: 1 GB
# Extracting batch 0032 of 0099
# Batch size: 1 GB
# Extracting batch 0033 of 0099
# Batch size: 1 GB
# Extracting batch 0034 of 0099
# Batch size: 1 GB
# Extracting batch 0035 of 0099
# Batch size: 1 GB
# Extracting batch 0036 of 0099
# Batch size: 1 GB
# Extracting batch 0037 of 0099
# Batch size: 1 GB
# Extracting batch 0038 of 0099
# Batch size: 1 GB
# Extracting batch 0039 of 0099
# Batch size: 1 GB
# Extracting batch 0040 of 0099
# Batch size: 1 GB
# Extracting batch 0041 of 0099
# Batch size: 1 GB
# Extracting batch 0042 of 0099
# Batch size: 1 GB
# Extracting batch 0043 of 0099
# Batch size: 1 GB
# Extracting batch 0044 of 0099
# Batch size: 1 GB
# Extracting batch 0045 of 0099
# Batch size: 1 GB
# Extracting batch 0046 of 0099
# Batch size: 1 GB
# Extracting batch 0047 of 0099
# Batch size: 1 GB
# Extracting batch 0048 of 0099
# Batch size: 1 GB
# Extracting batch 0049 of 0099
# Batch size: 1 GB
# Extracting batch 0050 of 0099
# Batch size: 1 GB
# Extracting batch 0051 of 0099
# Batch size: 1 GB
# Extracting batch 0052 of 0099
# Batch size: 1 GB
# Extracting batch 0053 of 0099
# Batch size: 1 GB
# Extracting batch 0054 of 0099
# Batch size: 1 GB
# Extracting batch 0055 of 0099
# Batch size: 1 GB
# Extracting batch 0056 of 0099
# Batch size: 1 GB
# Extracting batch 0057 of 0099
# Batch size: 1 GB
# Extracting batch 0058 of 0099
# Batch size: 1 GB
# Extracting batch 0059 of 0099
# Batch size: 1 GB
# Extracting batch 0060 of 0099
# Batch size: 1 GB
# Extracting batch 0061 of 0099
# Batch size: 1 GB
# Extracting batch 0062 of 0099
# Batch size: 1 GB
# Extracting batch 0063 of 0099
# Batch size: 1 GB
# Extracting batch 0064 of 0099
# Batch size: 1 GB
# Extracting batch 0065 of 0099
# Batch size: 1 GB
# Extracting batch 0066 of 0099
# Batch size: 1 GB
# Extracting batch 0067 of 0099
# Batch size: 1 GB
# Extracting batch 0068 of 0099
# Batch size: 1 GB
# Extracting batch 0069 of 0099
# Batch size: 1 GB
# Extracting batch 0070 of 0099
# Batch size: 1 GB
# Extracting batch 0071 of 0099
# Batch size: 1 GB
# Extracting batch 0072 of 0099
# Batch size: 1 GB
# Extracting batch 0073 of 0099
# Batch size: 1 GB
# Extracting batch 0074 of 0099
# Batch size: 1 GB
# Extracting batch 0075 of 0099
# Batch size: 1 GB
# Extracting batch 0076 of 0099
# Batch size: 1 GB
# Extracting batch 0077 of 0099
# Batch size: 1 GB
# Extracting batch 0078 of 0099
# Batch size: 1 GB
# Extracting batch 0079 of 0099
# Batch size: 1 GB
# Extracting batch 0080 of 0099
# Batch size: 1 GB
# Extracting batch 0081 of 0099
# Batch size: 1 GB
# Extracting batch 0082 of 0099
# Batch size: 1 GB
# Extracting batch 0083 of 0099
# Batch size: 1 GB
# Extracting batch 0084 of 0099
# Batch size: 1 GB
# Extracting batch 0085 of 0099
# Batch size: 1 GB
# Extracting batch 0086 of 0099
# Batch size: 1 GB
# Extracting batch 0087 of 0099
# Batch size: 1 GB
# Extracting batch 0088 of 0099
# Batch size: 1 GB
# Extracting batch 0089 of 0099
# Batch size: 1 GB
# Extracting batch 0090 of 0099
# Batch size: 1 GB
# Extracting batch 0091 of 0099
# Batch size: 1 GB
# Extracting batch 0092 of 0099
# Batch size: 1 GB
# Extracting batch 0093 of 0099
# Batch size: 1 GB
# Extracting batch 0094 of 0099
# Batch size: 1 GB
# Extracting batch 0095 of 0099
# Batch size: 1 GB
# Extracting batch 0096 of 0099
# Batch size: 1 GB
# Extracting batch 0097 of 0099
# Batch size: 1 GB
# Extracting batch 0098 of 0099
# Batch size: 0 GB
#    Deconvolving
#    Saving to Y:\runs\Coconut\s3d-Coconut-Demo\detection\combined-full

# %%
combined_dir = job.dirs['detection-combined-full']

# %%
outputs = ui.load_outputs(combined_dir, load_traces=True)
v,layers = ui.create_ui(outputs)
ui.add_callbacks_to_ui(v,layers,outputs,savedir=combined_dir)
# Out:
# Found old curated iscell with 18016 of 18107 marked as cells
# Saving old iscell_curated to backup path Y:\runs\Coconut\s3d-Coconut-Demo\detection\combined-full\iscell_curated_old_09-06-23_12-59-09.npy
# Cells
# Saving old iscell_curated to backup path Y:\runs\Coconut\s3d-Coconut-Demo\detection\combined-full\iscell_curated_slider_old_09-06-23_12-59-09.npy
# ('vmap_peak', (5.800059, 7.1653999328613285), 'peak_val', <function add_curation_sliders.<locals>.<lambda> at 0x000001B85597DE50>)
# 10267 cells valid
# Cells
# Updating cell 9617
# 10266 cells valid
# Cells
# Updating cell 9382
# 10265 cells valid
# Cells
# Updating cell 10309
# 10265 cells valid
# Cells
# Updating cell 10309
# 10265 cells valid
# Cells
# Updating cell 10309
# 10265 cells valid
# Cells
# Updating cell 10309
# 10265 cells valid
# Cells
# Updating cell 10505
# 10265 cells valid
# Cells
# Updating cell 10309
# 10265 cells valid
# Cells
# Updating cell 16716
# 10264 cells valid
# Cells
# Updating cell 12139
# 10263 cells valid
# Cells
# Updating cell 12202
# 10262 cells valid
# Cells
# Updating cell 10752
# 10261 cells valid
# Cells
# Updating cell 14978
# 10260 cells valid
# Cells
# Updating cell 10752
# 10261 cells valid
# Cells
# Updating cell 10752
# 10260 cells valid
# Cells
# Updating cell 10752
# 10261 cells valid
# Cells
# Updating cell 10698
# 10260 cells valid
# Cells
# Updating cell 10752
# 10259 cells valid
# Cells
# Updating cell 10752
# 10260 cells valid
# Cells
# 10010 cells valid
# Cells

# %%
outputs = ui.load_outputs(combined_dir, load_traces=True)
outputs['F'].shape
# Out:
# (18107, 9860)

# %%
v1, v2 = ui.make_label_vols(outputs['stats'], outputs['vmap'].shape, 
            iscell =  outputs['iscell_curated_slider'], 
                  cmap='Blues', lam_max = 0.3)

# %%
tfu.save_mrc(combined_dir, 'curated_cells.mrc',v2[:,:,:,3], voxel_size=(4,4,15))

# %%
v1.shape
# Out:
# (22, 529, 460)
