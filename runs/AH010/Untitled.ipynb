# %%
import napari

# %%
napari.Viewer()
# Out:
# WARNING: QFactoryLoader::QFactoryLoader() checking directory path "/home/ali/anaconda3/envs/suite3d-gpu/plugins/platforms" ...
# WARNING: QFactoryLoader::QFactoryLoader() looking at "/home/ali/anaconda3/envs/suite3d-gpu/plugins/platforms/libqeglfs.so"
# WARNING: Found metadata in lib /home/ali/anaconda3/envs/suite3d-gpu/plugins/platforms/libqeglfs.so, metadata=
# {
#     "IID": "org.qt-project.Qt.QPA.QPlatformIntegrationFactoryInterface.5.3",
#     "MetaData": {
#         "Keys": [
#             "eglfs"
#         ]
#     },
#     "archreq": 0,
#     "className": "QEglFSIntegrationPlugin",
#     "debug": false,
#     "version": 331520
# }
#
#
# WARNING: Got keys from plugin meta data ("eglfs")
# WARNING: QFactoryLoader::QFactoryLoader() looking at "/home/ali/anaconda3/envs/suite3d-gpu/plugins/platforms/libqminimal.so"
# WARNING: Found metadata in lib /home/ali/anaconda3/envs/suite3d-gpu/plugins/platforms/libqminimal.so, metadata=
# {
# ...

# %%
# %gui qt
