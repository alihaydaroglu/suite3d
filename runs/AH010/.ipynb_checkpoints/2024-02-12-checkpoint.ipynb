# %%
# %load_ext autoreload
# %autoreload 2

import os 
import shutil
import numpy as n
from datetime import date
from matplotlib import pyplot as plt
import time
import napari

# %%
os.chdir('/home/ali/packages/s2p-lbm/')

from suite3d.job import Job
from suite3d import lbmio, utils, ui
from suite3d import tiff_utils as tfu
from suite3d import file_utils as flu

# %%
job_params = {    
    'planes' :         n.arange(0,11),
    'n_ch_tif' : 15,
    'n_init_files' :   6,
    'fuse_shift_override' : 6,
    'subtract_crosstalk' : False,
    'fix_fastZ' : 0,
}

# %%
subjects_dir =   '/mnt/zortex-subjects/'
expt_info = { 
    'subject':         'AH010',
    'date' :          '2024-02-15',
    'expnum' :         [1,2,3,6],}

tifs, si_params, exp_str = flu.find_exp(subjects_dir, **expt_info, verbose=True, get_si_params=True)
job_params['fs'] = si_params['vol_rate']

# # savedir = os.path.join('/mnt/md0/runs', expt_info['subject'], expt_info['date'])
# # os.makedirs(savedir, exist_ok=True)
# Out:
# Looking for AH010/2024-02-15/1 in /mnt/zortex-subjects/
# Found
# Looking for AH010/2024-02-15/2 in /mnt/zortex-subjects/
# Found
# Looking for AH010/2024-02-15/3 in /mnt/zortex-subjects/
# Found
# Looking for AH010/2024-02-15/6 in /mnt/zortex-subjects/
# Found

# %%
# Create the job
job = Job('/mnt/md0/runs',exp_str, tifs = tifs,
          params=job_params, create=False, overwrite=True, verbosity = 3)
# job.update_root_path('/mnt/md0/runs')
# Out:
#    Found and loaded params from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/params.npy

# %%
# optional parameters for initialization
# load 1 file to initialize, and select 200 frames randomly to do initalization on
job.params['n_init_files'] = 6
job.params['init_n_frames'] = None
job.params['fuse_shift_override'] = 6

# %%
# %%time
# summary = job.run_init_pass()

# %%
job.show_summary_plots()

# %%
summary = job.load_summary()

# %%
# job.register_gpu()

# %%
# # Pick the parameters you want to sweep, and enter them in the tuples.
# # It will do all combinations of parameters, so if you have many parameters it will be many combinations! 
# job.params['t_batch_size'] = 200
# job.params['edge_crop_npix'] = 10
# params_to_sweep = {
#     'intensity_thresh' : (0.1,),
#     'conv_filt_xy': (1.0,),
#     'npil_filt_xy': (20.0,),
#     'conv_filt_z' : (1.0,1.5,),
#     'npil_filt_z' : (1.0,),
#     'sdnorm_exp' : (1.0,),
#     'edge_crop_npix' : (0,20),
# }

# # sweep_summary = job.sweep_params(params_to_sweep, mov = None,testing_dir_tag='sweep-test',
# #                            do_vmap=True, all_combinations=True, n_test_iters = 1)
# # # use this to access older sweep results
# # sweep_summary = n.load(os.path.join(job.dirs['sweep-full'], 'sweep_summary.npy'),allow_pickle=True).item()
# # job.vis_vmap_sweep(sweep_summary)

# %%
mov = job.get_registered_movie()

# %%
job.params['cell_filt_z_um']
# Out:
# '0'

# %%
job.params['t_batch_size'] = 400
job.params['voxel_size_um'] = (15, 2.5, 2.5)
job.params['npil_filt_type'] = 'unif'
job.params['npil_filt_xy_um'] = 70
job.params['npil_filt_z_um'] = 15.0
job.params['cell_filt_type'] = 'unif'
job.params['cell_filt_xy_um'] = 2.5
job.params['cell_filt_z_um'] = 15.0
job.params['edge_crop_npix'] = 7
job.params['fix_vmap_edge_planes'] = True
job.params['sdnorm_exp'] = 0.85
job.params['intensity_thresh'] = 0.1
job.params['n_proc'] = 32

params_to_sweep = { 
    'cell_filt_xy_um': [2.5, 5.0, 10.0],
    'intensity_thresh' : [0.1, 0.3],
    'sdnorm_exp' : [0.85, 1.0]
}

sweep_summary = job.sweep_corrmap(params_to_sweep, mov = mov[:,:100],all_combinations=True)
# Out:
#    Setting up sweep
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap
#       Updating self.dirs tag sweeps-corrmap
#    Total of 12 combinations
#       Created directory for comb_00000 with params comb00000-params-cell_filt_xy_um_2.500-intensity_thresh_0.100-sdnorm_exp_0.850
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00000
#       Updating self.dirs tag sweeps-corrmap-comb_00000
#       Created directory for comb_00001 with params comb00001-params-cell_filt_xy_um_2.500-intensity_thresh_0.100-sdnorm_exp_1.000
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00001
#       Updating self.dirs tag sweeps-corrmap-comb_00001
#       Created directory for comb_00002 with params comb00002-params-cell_filt_xy_um_2.500-intensity_thresh_0.300-sdnorm_exp_0.850
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00002
#       Updating self.dirs tag sweeps-corrmap-comb_00002
#       Created directory for comb_00003 with params comb00003-params-cell_filt_xy_um_2.500-intensity_thresh_0.300-sdnorm_exp_1.000
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00003
#       Updating self.dirs tag sweeps-corrmap-comb_00003
#       Created directory for comb_00004 with params comb00004-params-cell_filt_xy_um_5.000-intensity_thresh_0.100-sdnorm_exp_0.850
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00004
#       Updating self.dirs tag sweeps-corrmap-comb_00004
#       Created directory for comb_00005 with params comb00005-params-cell_filt_xy_um_5.000-intensity_thresh_0.100-sdnorm_exp_1.000
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00005
#       Updating self.dirs tag sweeps-corrmap-comb_00005
#       Created directory for comb_00006 with params comb00006-params-cell_filt_xy_um_5.000-intensity_thresh_0.300-sdnorm_exp_0.850
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00006
#       Updating self.dirs tag sweeps-corrmap-comb_00006
#       Created directory for comb_00007 with params comb00007-params-cell_filt_xy_um_5.000-intensity_thresh_0.300-sdnorm_exp_1.000
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00007
#       Updating self.dirs tag sweeps-corrmap-comb_00007
#       Created directory for comb_00008 with params comb00008-params-cell_filt_xy_um_10.000-intensity_thresh_0.100-sdnorm_exp_0.850
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00008
#       Updating self.dirs tag sweeps-corrmap-comb_00008
#       Created directory for comb_00009 with params comb00009-params-cell_filt_xy_um_10.000-intensity_thresh_0.100-sdnorm_exp_1.000
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00009
#       Updating self.dirs tag sweeps-corrmap-comb_00009
#       Created directory for comb_00010 with params comb00010-params-cell_filt_xy_um_10.000-intensity_thresh_0.300-sdnorm_exp_0.850
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00010
#       Updating self.dirs tag sweeps-corrmap-comb_00010
#       Created directory for comb_00011 with params comb00011-params-cell_filt_xy_um_10.000-intensity_thresh_0.300-sdnorm_exp_1.000
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00011
#       Updating self.dirs tag sweeps-corrmap-comb_00011
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 01/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00000/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00000-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00000/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00000-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00000/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 02/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00001/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00001-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00001/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00001-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00001/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 03/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00002/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00002-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00002/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00002-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00002/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 04/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00003/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00003-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00003/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00003-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00003/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 05/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00004/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00004-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00004/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00004-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00004/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 06/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00005/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00005-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00005/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00005-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00005/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 07/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00006/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00006-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00006/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00006-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00006/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 08/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00007/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00007-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00007/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00007-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00007/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 09/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00008/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00008-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00008/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00008-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00008/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 10/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00009/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00009-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00009/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00009-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00009/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 11/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00010/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00010-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00010/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00010-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00010/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
# Running combination 12/12
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00011/corrmap
#       Updating self.dirs tag sweeps-corrmap-comb_00011-corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00011/mov_sub
#       Updating self.dirs tag sweeps-corrmap-comb_00011-mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/comb_00011/corrmap
#    Updated main params file
#    Computing correlation map of movie with 100 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 1
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/corrmap/sweep_summary.npy

# %%
job.params['t_batch_size'] = 400
job.params['voxel_size_um'] = (15, 2.5, 2.5)
job.params['npil_filt_type'] = 'unif'
job.params['npil_filt_xy_um'] = 70
job.params['npil_filt_z_um'] = 15.0
job.params['cell_filt_type'] = 'unif'
job.params['cell_filt_xy_um'] = 10.0
job.params['cell_filt_z_um'] = 8.0
job.params['edge_crop_npix'] = 7
job.params['fix_vmap_edge_planes'] = True
job.params['sdnorm_exp'] = 0.85
job.params['intensity_thresh'] = 0.1
job.params['n_proc'] = 32

# %%
corrmap_new = job.calculate_corr_map(mov[:,:], save=True)
# Out:
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/corrmap
#       Updating self.dirs tag corrmap
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/mov_sub
#       Updating self.dirs tag mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/corrmap
#    Updated main params file
#    Computing correlation map of movie with 30640 frames, volume shape: 11, 1026, 725
#       Running batch 1 of 77
#       Running batch 2 of 77
#       Running batch 4 of 77
#       Running batch 5 of 77
#       Running batch 6 of 77
#       Running batch 7 of 77
#       Running batch 8 of 77
#       Running batch 9 of 77
#       Running batch 10 of 77
#       Running batch 11 of 77
#       Running batch 12 of 77
#       Running batch 13 of 77
#       Running batch 14 of 77
#       Running batch 15 of 77
#       Running batch 16 of 77
#       Running batch 17 of 77
#       Running batch 18 of 77
#       Running batch 19 of 77
#       Running batch 20 of 77
#       Running batch 21 of 77
#       Running batch 22 of 77
#       Running batch 23 of 77
#       Running batch 24 of 77
#       Running batch 25 of 77
#       Running batch 26 of 77
#       Running batch 27 of 77
#       Running batch 28 of 77
#       Running batch 29 of 77
#       Running batch 30 of 77
#       Running batch 31 of 77
#       Running batch 32 of 77
#       Running batch 33 of 77
#       Running batch 34 of 77
#       Running batch 35 of 77
#       Running batch 36 of 77
#       Running batch 37 of 77
#       Running batch 38 of 77
#       Running batch 39 of 77
#       Running batch 40 of 77
#       Running batch 41 of 77
#       Running batch 42 of 77
#       Running batch 43 of 77
#       Running batch 44 of 77
#       Running batch 45 of 77
#       Running batch 46 of 77
#       Running batch 47 of 77
#       Running batch 48 of 77
#       Running batch 49 of 77
#       Running batch 50 of 77
#       Running batch 51 of 77
#       Running batch 52 of 77
#       Running batch 53 of 77
#       Running batch 54 of 77
#       Running batch 55 of 77
#       Running batch 56 of 77
#       Running batch 57 of 77
#       Running batch 58 of 77
#       Running batch 59 of 77
#       Running batch 60 of 77
#       Running batch 61 of 77
#       Running batch 62 of 77
#       Running batch 63 of 77
#       Running batch 64 of 77
#       Running batch 65 of 77
#       Running batch 66 of 77
#       Running batch 67 of 77
#       Running batch 68 of 77
#       Running batch 69 of 77
#       Running batch 70 of 77
#       Running batch 71 of 77
#       Running batch 72 of 77
#       Running batch 73 of 77
#       Running batch 74 of 77
#       Running batch 75 of 77
#       Running batch 76 of 77
#       Running batch 77 of 77

# %%
results = job.load_corr_map_results()

# %%
job.verbosity = 2
job.params['detection_timebin'] = 2
job.params['detection_time_crop'] = (None,None)
job.params['max_pix'] = 250
job.params['peak_thresh'] = 2.6
job.params['patch_size_xy'] = (150,150)
job.params['n_proc_detect'] = 8
job.params['activity_thresh'] = 15.0
job.params['percentile'] = 99.0
job.params['extend_thresh'] = 0.2
job.params['max_iter'] = 10000 # maximum number of ROIs detected in given patch

# %%
job.segment_rois()
# Out:
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation
#       Updating self.dirs tag segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/rois
#       Updating self.dirs tag rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0000
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0060: peak is too small  - ending extraction
#    Found 480 cells in 60 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0000/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0000/iscell.npy
#    Detecting from patch 2 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0001
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0041: peak is too small  - ending extraction
#    Found 322 cells in 41 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0001/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0001/iscell.npy
#    Detecting from patch 3 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0002
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0017: peak is too small  - ending extraction
#    Found 135 cells in 17 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0002/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0002/iscell.npy
#    Detecting from patch 4 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0003
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0016: peak is too small  - ending extraction
#    Found 124 cells in 16 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0003/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0003/iscell.npy
#    Detecting from patch 5 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0004
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0028: peak is too small  - ending extraction
#    Found 224 cells in 28 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0004/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0004/iscell.npy
#    Detecting from patch 6 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0005
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0004: peak is too small  - ending extraction
#    Found 32 cells in 4 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0005/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0005/iscell.npy
#    Detecting from patch 7 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0006
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0055: peak is too small  - ending extraction
#    Found 436 cells in 55 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0006/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0006/iscell.npy
#    Detecting from patch 8 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0007
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0076: peak is too small  - ending extraction
#    Found 606 cells in 76 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0007/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0007/iscell.npy
#    Detecting from patch 9 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0008
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0069: peak is too small  - ending extraction
#    Found 548 cells in 69 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0008/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0008/iscell.npy
#    Detecting from patch 10 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0009
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0062: peak is too small  - ending extraction
#    Found 490 cells in 62 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0009/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0009/iscell.npy
#    Detecting from patch 11 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0010
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0023: peak is too small  - ending extraction
#    Found 177 cells in 23 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0010/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0010/iscell.npy
#    Detecting from patch 12 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0011
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0007: peak is too small  - ending extraction
#    Found 54 cells in 7 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0011/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0011/iscell.npy
#    Detecting from patch 13 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0012
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0056: peak is too small  - ending extraction
#    Found 442 cells in 56 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0012/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0012/iscell.npy
#    Detecting from patch 14 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0013
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0072: peak is too small  - ending extraction
#    Found 576 cells in 72 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0013/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0013/iscell.npy
#    Detecting from patch 15 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0014
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0056: peak is too small  - ending extraction
#    Found 441 cells in 56 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0014/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0014/iscell.npy
#    Detecting from patch 16 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0015
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0057: peak is too small  - ending extraction
#    Found 456 cells in 57 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0015/iscell.npy
#    Detecting from patch 17 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0016
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0033: peak is too small  - ending extraction
#    Found 261 cells in 33 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0016/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0016/iscell.npy
#    Detecting from patch 18 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0017
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0020: peak is too small  - ending extraction
#    Found 154 cells in 20 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0017/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0017/iscell.npy
#    Detecting from patch 19 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0018
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0085: peak is too small  - ending extraction
#    Found 676 cells in 85 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0018/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0018/iscell.npy
#    Detecting from patch 20 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0019
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0054: peak is too small  - ending extraction
#    Found 426 cells in 54 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0019/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0019/iscell.npy
#    Detecting from patch 21 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0020
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0056: peak is too small  - ending extraction
#    Found 443 cells in 56 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0020/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0020/iscell.npy
#    Detecting from patch 22 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0021
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0022: peak is too small  - ending extraction
#    Found 169 cells in 22 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0021/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0021/iscell.npy
#    Detecting from patch 23 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0022
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0004: peak is too small  - ending extraction
#    Found 26 cells in 4 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0022/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0022/iscell.npy
#    Detecting from patch 24 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0023
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0002: peak is too small  - ending extraction
#    Found 12 cells in 2 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0023/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0023/iscell.npy
#    Detecting from patch 25 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0024
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0059: peak is too small  - ending extraction
#    Found 469 cells in 59 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0024/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0024/iscell.npy
#    Detecting from patch 26 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0025
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0027: peak is too small  - ending extraction
#    Found 211 cells in 27 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0025/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0025/iscell.npy
#    Detecting from patch 27 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0026
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0015: peak is too small  - ending extraction
#    Found 116 cells in 15 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0026/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0026/iscell.npy
#    Detecting from patch 28 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0027
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0011: peak is too small  - ending extraction
#    Found 88 cells in 11 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0027/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0027/iscell.npy
#    Detecting from patch 29 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0028
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0025: peak is too small  - ending extraction
#    Found 196 cells in 25 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0028/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0028/iscell.npy
#    Detecting from patch 30 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0029
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0004: peak is too small  - ending extraction
#    Found 21 cells in 4 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0029/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0029/iscell.npy
#    Detecting from patch 31 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0030
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0100: peak is too small  - ending extraction
#    Found 795 cells in 100 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0030/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0030/iscell.npy
#    Detecting from patch 32 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0031
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0021: peak is too small  - ending extraction
#    Found 165 cells in 21 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0031/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0031/iscell.npy
#    Detecting from patch 33 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0032
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0044: peak is too small  - ending extraction
#    Found 349 cells in 44 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0032/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0032/iscell.npy
#    Detecting from patch 34 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0033
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0074: peak is too small  - ending extraction
#    Found 586 cells in 74 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0033/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0033/iscell.npy
#    Detecting from patch 35 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0034
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0038: peak is too small  - ending extraction
#    Found 300 cells in 38 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0034/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0034/iscell.npy
#    Detecting from patch 36 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0035
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0006: peak is too small  - ending extraction
#    Found 36 cells in 6 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0035/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0035/iscell.npy
#    Detecting from patch 37 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0036
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0024: peak is too small  - ending extraction
#    Found 190 cells in 24 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0036/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0036/iscell.npy
#    Detecting from patch 38 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0037
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0041: peak is too small  - ending extraction
#    Found 328 cells in 41 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0037/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0037/iscell.npy
#    Detecting from patch 39 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0038
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0079: peak is too small  - ending extraction
#    Found 628 cells in 79 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0038/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0038/iscell.npy
#    Detecting from patch 40 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0039
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0075: peak is too small  - ending extraction
#    Found 597 cells in 75 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0039/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0039/iscell.npy
#    Detecting from patch 41 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0040
# ...
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0015: peak is too small  - ending extraction
#    Found 113 cells in 15 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0047/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0047/iscell.npy
#    Detecting from patch 49 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0048
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0060: peak is too small  - ending extraction
#    Found 476 cells in 60 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0048/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0048/iscell.npy
#    Detecting from patch 50 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0049
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0022: peak is too small  - ending extraction
#    Found 174 cells in 22 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0049/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0049/iscell.npy
#    Detecting from patch 51 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0050
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0047: peak is too small  - ending extraction
#    Found 374 cells in 47 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0050/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0050/iscell.npy
#    Detecting from patch 52 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0051
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0040: peak is too small  - ending extraction
#    Found 315 cells in 40 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0051/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0051/iscell.npy
#    Detecting from patch 53 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0052
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0055: peak is too small  - ending extraction
#    Found 440 cells in 55 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0052/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0052/iscell.npy
#    Detecting from patch 54 / 54
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0053
#       Binning movie with a factor of 2.00
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Starting extraction with peak_thresh: 2.600 and Th2: 15.000
#       Iter 0023: peak is too small  - ending extraction
#    Found 173 cells in 23 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0053/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0053/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0000
#       Updating self.dirs tag segmentation-segmentation-patch-0000
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0001
#       Updating self.dirs tag segmentation-segmentation-patch-0001
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0002
#       Updating self.dirs tag segmentation-segmentation-patch-0002
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0003
#       Updating self.dirs tag segmentation-segmentation-patch-0003
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0004
#       Updating self.dirs tag segmentation-segmentation-patch-0004
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0005
#       Updating self.dirs tag segmentation-segmentation-patch-0005
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0006
#       Updating self.dirs tag segmentation-segmentation-patch-0006
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0007
#       Updating self.dirs tag segmentation-segmentation-patch-0007
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0008
#       Updating self.dirs tag segmentation-segmentation-patch-0008
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0009
#       Updating self.dirs tag segmentation-segmentation-patch-0009
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0010
#       Updating self.dirs tag segmentation-segmentation-patch-0010
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0011
#       Updating self.dirs tag segmentation-segmentation-patch-0011
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0012
#       Updating self.dirs tag segmentation-segmentation-patch-0012
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0013
#       Updating self.dirs tag segmentation-segmentation-patch-0013
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0014
#       Updating self.dirs tag segmentation-segmentation-patch-0014
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0015
#       Updating self.dirs tag segmentation-segmentation-patch-0015
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0016
#       Updating self.dirs tag segmentation-segmentation-patch-0016
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0017
#       Updating self.dirs tag segmentation-segmentation-patch-0017
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0018
#       Updating self.dirs tag segmentation-segmentation-patch-0018
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0019
#       Updating self.dirs tag segmentation-segmentation-patch-0019
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0020
#       Updating self.dirs tag segmentation-segmentation-patch-0020
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0021
#       Updating self.dirs tag segmentation-segmentation-patch-0021
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0022
#       Updating self.dirs tag segmentation-segmentation-patch-0022
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0023
#       Updating self.dirs tag segmentation-segmentation-patch-0023
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0024
#       Updating self.dirs tag segmentation-segmentation-patch-0024
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0025
#       Updating self.dirs tag segmentation-segmentation-patch-0025
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0026
#       Updating self.dirs tag segmentation-segmentation-patch-0026
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0027
#       Updating self.dirs tag segmentation-segmentation-patch-0027
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0028
#       Updating self.dirs tag segmentation-segmentation-patch-0028
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0029
#       Updating self.dirs tag segmentation-segmentation-patch-0029
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0030
#       Updating self.dirs tag segmentation-segmentation-patch-0030
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0031
#       Updating self.dirs tag segmentation-segmentation-patch-0031
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0032
#       Updating self.dirs tag segmentation-segmentation-patch-0032
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0033
#       Updating self.dirs tag segmentation-segmentation-patch-0033
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0034
#       Updating self.dirs tag segmentation-segmentation-patch-0034
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0035
#       Updating self.dirs tag segmentation-segmentation-patch-0035
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0036
#       Updating self.dirs tag segmentation-segmentation-patch-0036
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0037
#       Updating self.dirs tag segmentation-segmentation-patch-0037
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0038
#       Updating self.dirs tag segmentation-segmentation-patch-0038
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0039
#       Updating self.dirs tag segmentation-segmentation-patch-0039
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0040
#       Updating self.dirs tag segmentation-segmentation-patch-0040
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0041
#       Updating self.dirs tag segmentation-segmentation-patch-0041
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0042
#       Updating self.dirs tag segmentation-segmentation-patch-0042
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0043
#       Updating self.dirs tag segmentation-segmentation-patch-0043
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0044
#       Updating self.dirs tag segmentation-segmentation-patch-0044
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0045
#       Updating self.dirs tag segmentation-segmentation-patch-0045
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0046
#       Updating self.dirs tag segmentation-segmentation-patch-0046
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0047
#       Updating self.dirs tag segmentation-segmentation-patch-0047
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0048
#       Updating self.dirs tag segmentation-segmentation-patch-0048
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0049
#       Updating self.dirs tag segmentation-segmentation-patch-0049
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0050
#       Updating self.dirs tag segmentation-segmentation-patch-0050
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0051
#       Updating self.dirs tag segmentation-segmentation-patch-0051
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0052
#       Updating self.dirs tag segmentation-segmentation-patch-0052
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/segmentation/patch-0053
#       Updating self.dirs tag segmentation-segmentation-patch-0053
#       Deduplicating cells
#       Removed 836 duplicate cells
#    Combined 54 patches, 15857 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/rois
#       Saved stats
#       Saved iscell
# '/mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/rois'

# %%
# %%time
job.compute_npil_masks(job.dirs['rois'])

traces = job.extract_and_deconvolve(stats_dir = job.dirs['rois'], mov=mov, crop=False)
# Out:
#    Updated main params file
#    Movie shape: (11, 30640, 1026, 725)
# 15857
#    Extracting 15857 valid cells, and saving cell flags to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/rois/iscell_extracted.npy
#    Extracting activity
# Will extract in 62 batches of 500
# Saving intermediate results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/rois
# Extracting batch 0000 of 0062
# Batch size: 15 GB
# Extracting batch 0001 of 0062
# Batch size: 15 GB
# Extracting batch 0002 of 0062
# Batch size: 15 GB
# Extracting batch 0003 of 0062
# Batch size: 15 GB
# Extracting batch 0004 of 0062
# Batch size: 15 GB
# Extracting batch 0005 of 0062
# Batch size: 15 GB
# Extracting batch 0006 of 0062
# Batch size: 15 GB
# Extracting batch 0007 of 0062
# Batch size: 15 GB
# Extracting batch 0008 of 0062
# Batch size: 15 GB
# Extracting batch 0009 of 0062
# Batch size: 15 GB

# %%
params_to_sweep = {
    'activity_thresh' : (10.0, 15.0),
    'percentile' : (98.0, 99.0, 99.9),
    'extend_thresh' : (0.1,0.2,0.3)
}

# %%
sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
                               all_combinations = True, patches_to_segment = (15,), ts = (0,1200))
# Out:
#    Setting up sweep
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test
#       Updating self.dirs tag sweeps-seg-on-test
#    Total of 18 combinations
#       Created directory for comb_00000 with params comb00000-params-activity_thresh_10.000-percentile_98.000-extend_thresh_0.100
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000 with tag sweeps-seg-on-test-comb_00000
#       Updating self.dirs tag sweeps-seg-on-test-comb_00000
#       Created directory for comb_00001 with params comb00001-params-activity_thresh_10.000-percentile_98.000-extend_thresh_0.200
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001 with tag sweeps-seg-on-test-comb_00001
#       Updating self.dirs tag sweeps-seg-on-test-comb_00001
#       Created directory for comb_00002 with params comb00002-params-activity_thresh_10.000-percentile_98.000-extend_thresh_0.300
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002 with tag sweeps-seg-on-test-comb_00002
#       Updating self.dirs tag sweeps-seg-on-test-comb_00002
#       Created directory for comb_00003 with params comb00003-params-activity_thresh_10.000-percentile_99.000-extend_thresh_0.100
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003 with tag sweeps-seg-on-test-comb_00003
#       Updating self.dirs tag sweeps-seg-on-test-comb_00003
#       Created directory for comb_00004 with params comb00004-params-activity_thresh_10.000-percentile_99.000-extend_thresh_0.200
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004 with tag sweeps-seg-on-test-comb_00004
#       Updating self.dirs tag sweeps-seg-on-test-comb_00004
#       Created directory for comb_00005 with params comb00005-params-activity_thresh_10.000-percentile_99.000-extend_thresh_0.300
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005 with tag sweeps-seg-on-test-comb_00005
#       Updating self.dirs tag sweeps-seg-on-test-comb_00005
#       Created directory for comb_00006 with params comb00006-params-activity_thresh_10.000-percentile_99.900-extend_thresh_0.100
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006 with tag sweeps-seg-on-test-comb_00006
#       Updating self.dirs tag sweeps-seg-on-test-comb_00006
#       Created directory for comb_00007 with params comb00007-params-activity_thresh_10.000-percentile_99.900-extend_thresh_0.200
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007 with tag sweeps-seg-on-test-comb_00007
#       Updating self.dirs tag sweeps-seg-on-test-comb_00007
#       Created directory for comb_00008 with params comb00008-params-activity_thresh_10.000-percentile_99.900-extend_thresh_0.300
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008 with tag sweeps-seg-on-test-comb_00008
#       Updating self.dirs tag sweeps-seg-on-test-comb_00008
#       Created directory for comb_00009 with params comb00009-params-activity_thresh_15.000-percentile_98.000-extend_thresh_0.100
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009 with tag sweeps-seg-on-test-comb_00009
#       Updating self.dirs tag sweeps-seg-on-test-comb_00009
#       Created directory for comb_00010 with params comb00010-params-activity_thresh_15.000-percentile_98.000-extend_thresh_0.200
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010 with tag sweeps-seg-on-test-comb_00010
#       Updating self.dirs tag sweeps-seg-on-test-comb_00010
#       Created directory for comb_00011 with params comb00011-params-activity_thresh_15.000-percentile_98.000-extend_thresh_0.300
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011 with tag sweeps-seg-on-test-comb_00011
#       Updating self.dirs tag sweeps-seg-on-test-comb_00011
#       Created directory for comb_00012 with params comb00012-params-activity_thresh_15.000-percentile_99.000-extend_thresh_0.100
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012 with tag sweeps-seg-on-test-comb_00012
#       Updating self.dirs tag sweeps-seg-on-test-comb_00012
#       Created directory for comb_00013 with params comb00013-params-activity_thresh_15.000-percentile_99.000-extend_thresh_0.200
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013 with tag sweeps-seg-on-test-comb_00013
#       Updating self.dirs tag sweeps-seg-on-test-comb_00013
#       Created directory for comb_00014 with params comb00014-params-activity_thresh_15.000-percentile_99.000-extend_thresh_0.300
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014 with tag sweeps-seg-on-test-comb_00014
#       Updating self.dirs tag sweeps-seg-on-test-comb_00014
#       Created directory for comb_00015 with params comb00015-params-activity_thresh_15.000-percentile_99.900-extend_thresh_0.100
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015 with tag sweeps-seg-on-test-comb_00015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00015
#       Created directory for comb_00016 with params comb00016-params-activity_thresh_15.000-percentile_99.900-extend_thresh_0.200
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016 with tag sweeps-seg-on-test-comb_00016
#       Updating self.dirs tag sweeps-seg-on-test-comb_00016
#       Created directory for comb_00017 with params comb00017-params-activity_thresh_15.000-percentile_99.900-extend_thresh_0.300
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017 with tag sweeps-seg-on-test-comb_00017
#       Updating self.dirs tag sweeps-seg-on-test-comb_00017
# Running combination 01/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation with tag sweeps-seg-on-test-comb_00000-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00000-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/rois with tag sweeps-seg-on-test-comb_00000-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00000-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00000-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00000-segmentation-sweeps-seg-on-test-comb_00000-segmentation-patch-0015
#       Deduplicating cells
#       Removed 5 duplicate cells
#    Combined 1 patches, 995 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/rois/stats.npy
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00000/rois/info.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 02/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation with tag sweeps-seg-on-test-comb_00001-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00001-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/rois with tag sweeps-seg-on-test-comb_00001-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00001-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00001-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00001-segmentation-sweeps-seg-on-test-comb_00001-segmentation-patch-0015
#       Deduplicating cells
#       Removed 3 duplicate cells
#    Combined 1 patches, 997 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00001/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 03/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation with tag sweeps-seg-on-test-comb_00002-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00002-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/rois with tag sweeps-seg-on-test-comb_00002-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00002-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00002-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00002-segmentation-sweeps-seg-on-test-comb_00002-segmentation-patch-0015
#       Deduplicating cells
#       Removed 4 duplicate cells
#    Combined 1 patches, 996 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00002/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 04/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation with tag sweeps-seg-on-test-comb_00003-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00003-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/rois with tag sweeps-seg-on-test-comb_00003-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00003-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00003-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00003-segmentation-sweeps-seg-on-test-comb_00003-segmentation-patch-0015
#       Deduplicating cells
#       Removed 8 duplicate cells
#    Combined 1 patches, 992 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00003/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 05/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation with tag sweeps-seg-on-test-comb_00004-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00004-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/rois with tag sweeps-seg-on-test-comb_00004-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00004-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00004-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00004-segmentation-sweeps-seg-on-test-comb_00004-segmentation-patch-0015
#       Deduplicating cells
#       Removed 9 duplicate cells
#    Combined 1 patches, 991 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00004/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 06/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation with tag sweeps-seg-on-test-comb_00005-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00005-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/rois with tag sweeps-seg-on-test-comb_00005-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00005-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00005-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00005-segmentation-sweeps-seg-on-test-comb_00005-segmentation-patch-0015
#       Deduplicating cells
#       Removed 15 duplicate cells
#    Combined 1 patches, 985 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00005/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 07/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation with tag sweeps-seg-on-test-comb_00006-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00006-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/rois with tag sweeps-seg-on-test-comb_00006-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00006-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00006-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00006-segmentation-sweeps-seg-on-test-comb_00006-segmentation-patch-0015
#       Deduplicating cells
#       Removed 11 duplicate cells
#    Combined 1 patches, 989 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00006/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 08/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation with tag sweeps-seg-on-test-comb_00007-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00007-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/rois with tag sweeps-seg-on-test-comb_00007-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00007-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00007-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00007-segmentation-sweeps-seg-on-test-comb_00007-segmentation-patch-0015
#       Deduplicating cells
#       Removed 25 duplicate cells
#    Combined 1 patches, 975 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00007/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 09/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation with tag sweeps-seg-on-test-comb_00008-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00008-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/rois with tag sweeps-seg-on-test-comb_00008-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00008-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00008-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 10.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00008-segmentation-sweeps-seg-on-test-comb_00008-segmentation-patch-0015
#       Deduplicating cells
#       Removed 18 duplicate cells
#    Combined 1 patches, 982 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00008/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 10/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation with tag sweeps-seg-on-test-comb_00009-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00009-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/rois with tag sweeps-seg-on-test-comb_00009-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00009-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00009-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00009-segmentation-sweeps-seg-on-test-comb_00009-segmentation-patch-0015
#       Deduplicating cells
#       Removed 6 duplicate cells
#    Combined 1 patches, 994 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00009/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 11/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation with tag sweeps-seg-on-test-comb_00010-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00010-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/rois with tag sweeps-seg-on-test-comb_00010-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00010-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00010-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00010-segmentation-sweeps-seg-on-test-comb_00010-segmentation-patch-0015
#       Deduplicating cells
#       Removed 7 duplicate cells
#    Combined 1 patches, 993 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00010/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 12/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation with tag sweeps-seg-on-test-comb_00011-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00011-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/rois with tag sweeps-seg-on-test-comb_00011-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00011-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00011-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00011-segmentation-sweeps-seg-on-test-comb_00011-segmentation-patch-0015
#       Deduplicating cells
#       Removed 15 duplicate cells
#    Combined 1 patches, 985 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00011/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 13/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation with tag sweeps-seg-on-test-comb_00012-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00012-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/rois with tag sweeps-seg-on-test-comb_00012-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00012-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00012-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00012-segmentation-sweeps-seg-on-test-comb_00012-segmentation-patch-0015
#       Deduplicating cells
#       Removed 8 duplicate cells
#    Combined 1 patches, 992 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00012/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 14/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation with tag sweeps-seg-on-test-comb_00013-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00013-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/rois with tag sweeps-seg-on-test-comb_00013-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00013-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00013-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00013-segmentation-sweeps-seg-on-test-comb_00013-segmentation-patch-0015
#       Deduplicating cells
#       Removed 15 duplicate cells
#    Combined 1 patches, 985 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00013/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 15/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation with tag sweeps-seg-on-test-comb_00014-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00014-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/rois with tag sweeps-seg-on-test-comb_00014-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00014-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00014-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00014-segmentation-sweeps-seg-on-test-comb_00014-segmentation-patch-0015
#       Deduplicating cells
#       Removed 19 duplicate cells
#    Combined 1 patches, 981 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00014/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 16/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation with tag sweeps-seg-on-test-comb_00015-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00015-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/rois with tag sweeps-seg-on-test-comb_00015-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00015-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00015-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00015-segmentation-sweeps-seg-on-test-comb_00015-segmentation-patch-0015
#       Deduplicating cells
#       Removed 13 duplicate cells
#    Combined 1 patches, 987 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00015/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 17/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation with tag sweeps-seg-on-test-comb_00016-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00016-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/rois with tag sweeps-seg-on-test-comb_00016-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00016-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00016-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00016-segmentation-sweeps-seg-on-test-comb_00016-segmentation-patch-0015
#       Deduplicating cells
#       Removed 25 duplicate cells
#    Combined 1 patches, 975 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00016/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
# Running combination 18/18
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation with tag sweeps-seg-on-test-comb_00017-segmentation
#       Updating self.dirs tag sweeps-seg-on-test-comb_00017-segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation
#    Updated main params file
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/rois with tag sweeps-seg-on-test-comb_00017-rois
#       Updating self.dirs tag sweeps-seg-on-test-comb_00017-rois
#    Saving results to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation and /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#    Created dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation/patch-0015 with tag sweeps-seg-on-test-comb_00017-segmentation-patch-0015
#       Binning movie with a factor of 2.00
# /tmp/ipykernel_1717423/2500248111.py:1: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   sweep = job.sweep_segmentation(params_to_sweep,input_dir_name = 'test-corrmap', sweep_name='seg-on-test',
#       Starting extraction with peak_thresh: 0.310 and Th2: 15.000
#       Saving checkpoint to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation/patch-0015/stats.npy
#    Found 1000 cells in 124 iterations
#    Saving cells to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation/patch-0015/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation/patch-0015/iscell.npy
#       Found dir /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/segmentation/patch-0015
#       Updating self.dirs tag sweeps-seg-on-test-comb_00017-segmentation-sweeps-seg-on-test-comb_00017-segmentation-patch-0015
#       Deduplicating cells
#       Removed 41 duplicate cells
#    Combined 1 patches, 959 cells
#    Saving combined files to /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/rois
#       Saved stats
#       Saved iscell
#       Loading from /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/comb_00017/rois/stats.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
#       Overwriting existing /mnt/md0/runs/s3d-AH010_2024-02-15_1-2-3-6/sweeps/seg-on-test/sweep_summary.npy
