# %%
# %load_ext autoreload
# %autoreload 2

import os 
import shutil
import numpy as n
from datetime import date
from matplotlib import pyplot as plt
import time
import napari

# %%
os.chdir('/home/ali/packages/s2p-lbm/')

from suite3d.job import Job
from suite3d import lbmio, utils, ui
from suite3d import tiff_utils as tfu
from suite3d import file_utils as flu
from suite3d import extension as ext

# %%
tif_dir = '/mnt/zeytin-f0/baruchin-data/1/1/'

# %%
tifs = tfu.get_tif_paths(tif_dir)

# %%
import tifffile

# %%
job_params = {    
    # number of channels recorded in the tiff file, typically 30
    'n_ch_tif' : 8,    
    'planes' : n.arange(8),
    'multiplane_2p_use_planes' : n.arange(2,8),
    # convert from the Scanimage channel ordering to deep-to-shallow ordering
    # in our case, ScanImage channel numbers are in temporal order. 
    'n_init_files' :   1,
    
    # volume rate in acquisition
    'fs' : 30 / 8,
    'fuse_strips' : False,
    
    # 3D GPU registration - fast! 
    # for now, 3D + GPU are well-tested, other options might have minor bugs
    # if you run into them, let us know! we'll fix them
    '3d_reg' : True,
    'gpu_reg' : True,
    'lbm' : False,
}

# %%
# Create the job
job = Job('/mnt/md0/runs','baruchin-1', tifs = tifs,
          params=job_params, create=True, overwrite=True, verbosity = 3)
# Out:
# Job directory /mnt/md0/runs/s3d-baruchin-1 already exists
# Loading job directory for baruchin-1 in /mnt/md0/runs
#    Loading dirs
#       Found dir registered_fused_data
#       Found dir summary
#       Found dir iters
#    Loading default params
#       Updating param n_ch_tif
#       Updating param planes
#       Updating param multiplane_2p_use_planes
#       Updating param n_init_files
#       Updating param fs
#       Updating param fuse_strips
#       Updating param 3d_reg
#       Updating param gpu_reg
#       Updating param lbm
#    Updated main params file

# %%
# optional parameters for initialization
# load 1 file to initialize, and select 200 frames randomly to do initalization on
job.params['n_init_files'] = 3
job.params['init_n_frames'] = 400
job.params['init_file_sample_method'] = 'even'
job.params['voxel_size_um'] = (2,1,1)

# %%
# %%time
summary = job.run_init_pass()
# Out:
#    Saved a copy of params at /mnt/md0/runs/s3d-baruchin-1/summary
#    Updated main params file
# Launching initial pass
# Saving summary to /mnt/md0/runs/s3d-baruchin-1/summary/summary.npy
#    Loading init tifs with 8 channels
#       Loading tiff 1/3: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00004.tif
#       Loading tiff 2/3: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00008.tif
#       Loading tiff 3/3: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00011.tif
#    Loaded 3 files, total 1.10 GB
#    Selecting 400 random frames from the init tif files
#    Loaded movie with 400 frames and shape 6, 256, 256
#       Enforcing positivity in mean image
#    No crosstalk estimation or subtraction
#    Using 3d registration
#    Computing plane alignment shifts
#    Applying plane alignment shifts
#    Launching 3D GPU reference image calculation
#       Seeding reference image with most active frames
#       Completed iter 1 out of 8 in  0.75s using  59/400 frames
#       Completed iter 2 out of 8 in  0.67s using  101/400 frames
#       Completed iter 3 out of 8 in  0.73s using  144/400 frames
#       Completed iter 4 out of 8 in  0.78s using  187/400 frames
#       Completed iter 5 out of 8 in  0.84s using  230/400 frames
#       Completed iter 6 out of 8 in  0.89s using  273/400 frames
#       Completed iter 7 out of 8 in  0.94s using  316/400 frames
#       Completed iter 8 out of 8 in  0.54s using  359/400 frames
#       Used 359 frames to make the reference image
#    Saved init mov to /mnt/md0/runs/s3d-baruchin-1/summary/init_mov.npy
#    Saving summary to /mnt/md0/runs/s3d-baruchin-1/summary/summary.npy
#    Initial pass complete. See /mnt/md0/runs/s3d-baruchin-1/summary for details
# CPU times: user 46.9 s, sys: 12.5 s, total: 59.4 s
# Wall time: 25.2 s

# %%
summary = job.load_summary()

# %%
img = summary['ref_img_3d']

# %%
tfu.show_tif(img[:,130], px_py=(1,2))
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x7f42efddd970>)

# %%
tfu.show_tif(img[3])
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x7f42efe71b80>)

# %%
tfu.show_tif_all_planes(img,ncols=3)

# %%
# split the large tiffs into files of size 100 after registration
job.params['split_tif_size'] = 1500

# %%
# %%time
job.register()
# Out:
#       Found dir /mnt/md0/runs/s3d-baruchin-1/registered_fused_data
#       Updating self.dirs tag registered_fused_data
#    Saved a copy of params at /mnt/md0/runs/s3d-baruchin-1/registered_fused_data
#    Updated main params file
#    Starting registration: 3D: True, GPU: True
#    Not clipping frames for registration
# Will analyze 14 tifs in 14 batches
#    Enforcing positivity
#    Launching IO thread
#          Memory at batch 0.  Total Used: 131.990 GB, Virtual Available: 374.237 GB, Virtual Used: 128.958 GB, Swap Used: 003.032 GB
# Loading Batch 0 of 13
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00001.tif
#    Loaded 1 files, total 0.37 GB
#    Batch 0 IO thread joined
#          Memory after IO thread joinTotal Used: 132.393 GB, Virtual Available: 373.834 GB, Virtual Used: 129.362 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 132.765 GB, Virtual Available: 373.462 GB, Virtual Used: 129.733 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 132.393 GB, Virtual Available: 373.834 GB, Virtual Used: 129.362 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 132.393 GB, Virtual Available: 373.834 GB, Virtual Used: 129.362 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00002.tif
#    Completed rigid reg on batch in :1.1795296669006348s
#    Shifted the mov in: 0.38761448860168457s
#          After all GPU Batches:Total Used: 133.671 GB, Virtual Available: 372.556 GB, Virtual Used: 130.640 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0000.npy
#          Saved in 0.34 sec
#       Computing quality metrics and saving
# /home/ali/packages/s2p-lbm/suite3d/quality_metrics.py:41: RuntimeWarning: invalid value encountered in divide
#   dff = df / fs.mean(axis=1,keepdims=True)
# /home/ali/anaconda3/envs/suite3d-gpu/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#          After full batch saving:Total Used: 133.672 GB, Virtual Available: 372.555 GB, Virtual Used: 130.641 GB, Swap Used: 003.032 GB
#          Memory at batch 1.  Total Used: 133.672 GB, Virtual Available: 372.555 GB, Virtual Used: 130.641 GB, Swap Used: 003.032 GB
# Loading Batch 1 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 1 IO thread joined
#          Memory after IO thread joinTotal Used: 134.039 GB, Virtual Available: 372.188 GB, Virtual Used: 131.007 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.660 GB, Virtual Available: 372.567 GB, Virtual Used: 130.628 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.288 GB, Virtual Available: 372.939 GB, Virtual Used: 130.256 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.288 GB, Virtual Available: 372.939 GB, Virtual Used: 130.256 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00003.tif
#    Completed rigid reg on batch in :1.0756447315216064s
#    Shifted the mov in: 0.38538074493408203s
#          After all GPU Batches:Total Used: 134.430 GB, Virtual Available: 371.798 GB, Virtual Used: 131.398 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0001.npy
#          Saved in 0.34 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.688 GB, Virtual Available: 372.540 GB, Virtual Used: 130.656 GB, Swap Used: 003.032 GB
#          Memory at batch 2.  Total Used: 133.688 GB, Virtual Available: 372.540 GB, Virtual Used: 130.656 GB, Swap Used: 003.032 GB
# Loading Batch 2 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 2 IO thread joined
#          Memory after IO thread joinTotal Used: 134.067 GB, Virtual Available: 372.161 GB, Virtual Used: 131.035 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.687 GB, Virtual Available: 372.540 GB, Virtual Used: 130.656 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.317 GB, Virtual Available: 372.910 GB, Virtual Used: 130.286 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.317 GB, Virtual Available: 372.910 GB, Virtual Used: 130.286 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00004.tif
#    Completed rigid reg on batch in :1.0868897438049316s
#    Shifted the mov in: 0.38150620460510254s
#          After all GPU Batches:Total Used: 134.461 GB, Virtual Available: 371.766 GB, Virtual Used: 131.429 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0002.npy
#          Saved in 0.34 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.713 GB, Virtual Available: 372.514 GB, Virtual Used: 130.682 GB, Swap Used: 003.032 GB
#          Memory at batch 3.  Total Used: 133.713 GB, Virtual Available: 372.514 GB, Virtual Used: 130.682 GB, Swap Used: 003.032 GB
# Loading Batch 3 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 3 IO thread joined
#          Memory after IO thread joinTotal Used: 134.080 GB, Virtual Available: 372.147 GB, Virtual Used: 131.048 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.700 GB, Virtual Available: 372.527 GB, Virtual Used: 130.669 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.328 GB, Virtual Available: 372.900 GB, Virtual Used: 130.296 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.328 GB, Virtual Available: 372.900 GB, Virtual Used: 130.296 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00005.tif
#    Completed rigid reg on batch in :1.102691888809204s
#    Shifted the mov in: 0.3777487277984619s
#          After all GPU Batches:Total Used: 134.467 GB, Virtual Available: 371.760 GB, Virtual Used: 131.436 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0003.npy
#          Saved in 0.34 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.722 GB, Virtual Available: 372.506 GB, Virtual Used: 130.690 GB, Swap Used: 003.032 GB
#          Memory at batch 4.  Total Used: 133.722 GB, Virtual Available: 372.506 GB, Virtual Used: 130.690 GB, Swap Used: 003.032 GB
# Loading Batch 4 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 4 IO thread joined
#          Memory after IO thread joinTotal Used: 134.084 GB, Virtual Available: 372.143 GB, Virtual Used: 131.053 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.705 GB, Virtual Available: 372.522 GB, Virtual Used: 130.674 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.339 GB, Virtual Available: 372.888 GB, Virtual Used: 130.307 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.339 GB, Virtual Available: 372.888 GB, Virtual Used: 130.307 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00006.tif
#    Completed rigid reg on batch in :1.0775656700134277s
#    Shifted the mov in: 0.3815884590148926s
#          After all GPU Batches:Total Used: 134.472 GB, Virtual Available: 371.755 GB, Virtual Used: 131.440 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0004.npy
#          Saved in 0.34 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.729 GB, Virtual Available: 372.498 GB, Virtual Used: 130.697 GB, Swap Used: 003.032 GB
#          Memory at batch 5.  Total Used: 133.729 GB, Virtual Available: 372.498 GB, Virtual Used: 130.697 GB, Swap Used: 003.032 GB
# Loading Batch 5 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 5 IO thread joined
#          Memory after IO thread joinTotal Used: 134.095 GB, Virtual Available: 372.132 GB, Virtual Used: 131.064 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.716 GB, Virtual Available: 372.511 GB, Virtual Used: 130.684 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.343 GB, Virtual Available: 372.884 GB, Virtual Used: 130.312 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.343 GB, Virtual Available: 372.884 GB, Virtual Used: 130.312 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00007.tif
#    Completed rigid reg on batch in :1.0646240711212158s
#    Shifted the mov in: 0.3824117183685303s
#          After all GPU Batches:Total Used: 134.482 GB, Virtual Available: 371.745 GB, Virtual Used: 131.450 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0005.npy
#          Saved in 0.31 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.734 GB, Virtual Available: 372.493 GB, Virtual Used: 130.703 GB, Swap Used: 003.032 GB
#          Memory at batch 6.  Total Used: 133.735 GB, Virtual Available: 372.492 GB, Virtual Used: 130.703 GB, Swap Used: 003.032 GB
# Loading Batch 6 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 6 IO thread joined
#          Memory after IO thread joinTotal Used: 134.099 GB, Virtual Available: 372.129 GB, Virtual Used: 131.067 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.719 GB, Virtual Available: 372.508 GB, Virtual Used: 130.688 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.347 GB, Virtual Available: 372.880 GB, Virtual Used: 130.315 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.347 GB, Virtual Available: 372.880 GB, Virtual Used: 130.315 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00008.tif
#    Completed rigid reg on batch in :1.0854055881500244s
#    Shifted the mov in: 0.38965773582458496s
#          After all GPU Batches:Total Used: 134.492 GB, Virtual Available: 371.735 GB, Virtual Used: 131.460 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0006.npy
#          Saved in 0.33 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.741 GB, Virtual Available: 372.487 GB, Virtual Used: 130.709 GB, Swap Used: 003.032 GB
#          Memory at batch 7.  Total Used: 133.741 GB, Virtual Available: 372.487 GB, Virtual Used: 130.709 GB, Swap Used: 003.032 GB
# Loading Batch 7 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 7 IO thread joined
#          Memory after IO thread joinTotal Used: 134.112 GB, Virtual Available: 372.116 GB, Virtual Used: 131.080 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.732 GB, Virtual Available: 372.495 GB, Virtual Used: 130.701 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.362 GB, Virtual Available: 372.865 GB, Virtual Used: 130.331 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.362 GB, Virtual Available: 372.865 GB, Virtual Used: 130.331 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00009.tif
#    Completed rigid reg on batch in :1.0778334140777588s
#    Shifted the mov in: 0.4166722297668457s
#          After all GPU Batches:Total Used: 134.500 GB, Virtual Available: 371.727 GB, Virtual Used: 131.468 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0007.npy
#          Saved in 0.33 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.754 GB, Virtual Available: 372.473 GB, Virtual Used: 130.723 GB, Swap Used: 003.032 GB
#          Memory at batch 8.  Total Used: 133.754 GB, Virtual Available: 372.473 GB, Virtual Used: 130.723 GB, Swap Used: 003.032 GB
# Loading Batch 8 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 8 IO thread joined
#          Memory after IO thread joinTotal Used: 134.109 GB, Virtual Available: 372.118 GB, Virtual Used: 131.078 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.722 GB, Virtual Available: 372.505 GB, Virtual Used: 130.691 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.355 GB, Virtual Available: 372.872 GB, Virtual Used: 130.323 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.355 GB, Virtual Available: 372.872 GB, Virtual Used: 130.323 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00010.tif
#    Completed rigid reg on batch in :1.0883762836456299s
#    Shifted the mov in: 0.40571141242980957s
#          After all GPU Batches:Total Used: 134.496 GB, Virtual Available: 371.731 GB, Virtual Used: 131.465 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0008.npy
#          Saved in 0.33 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.750 GB, Virtual Available: 372.477 GB, Virtual Used: 130.719 GB, Swap Used: 003.032 GB
#          Memory at batch 9.  Total Used: 133.750 GB, Virtual Available: 372.477 GB, Virtual Used: 130.719 GB, Swap Used: 003.032 GB
# Loading Batch 9 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 9 IO thread joined
#          Memory after IO thread joinTotal Used: 134.115 GB, Virtual Available: 372.113 GB, Virtual Used: 131.083 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.735 GB, Virtual Available: 372.492 GB, Virtual Used: 130.704 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.362 GB, Virtual Available: 372.865 GB, Virtual Used: 130.330 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.362 GB, Virtual Available: 372.865 GB, Virtual Used: 130.330 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00011.tif
#    Completed rigid reg on batch in :1.0866367816925049s
#    Shifted the mov in: 0.40970778465270996s
#          After all GPU Batches:Total Used: 134.504 GB, Virtual Available: 371.723 GB, Virtual Used: 131.472 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0009.npy
#          Saved in 0.32 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.758 GB, Virtual Available: 372.469 GB, Virtual Used: 130.727 GB, Swap Used: 003.032 GB
#          Memory at batch 10. Total Used: 133.758 GB, Virtual Available: 372.469 GB, Virtual Used: 130.727 GB, Swap Used: 003.032 GB
# Loading Batch 10 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 10 IO thread joined
#          Memory after IO thread joinTotal Used: 134.124 GB, Virtual Available: 372.103 GB, Virtual Used: 131.092 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.745 GB, Virtual Available: 372.482 GB, Virtual Used: 130.713 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.378 GB, Virtual Available: 372.849 GB, Virtual Used: 130.346 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.378 GB, Virtual Available: 372.849 GB, Virtual Used: 130.346 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00012.tif
#    Completed rigid reg on batch in :1.0742616653442383s
#    Shifted the mov in: 0.41437768936157227s
#          After all GPU Batches:Total Used: 134.513 GB, Virtual Available: 371.714 GB, Virtual Used: 131.482 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0010.npy
#          Saved in 0.33 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.766 GB, Virtual Available: 372.461 GB, Virtual Used: 130.734 GB, Swap Used: 003.032 GB
#          Memory at batch 11. Total Used: 133.766 GB, Virtual Available: 372.461 GB, Virtual Used: 130.734 GB, Swap Used: 003.032 GB
# Loading Batch 11 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 11 IO thread joined
#          Memory after IO thread joinTotal Used: 134.131 GB, Virtual Available: 372.096 GB, Virtual Used: 131.099 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.752 GB, Virtual Available: 372.476 GB, Virtual Used: 130.720 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.384 GB, Virtual Available: 372.843 GB, Virtual Used: 130.353 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.384 GB, Virtual Available: 372.843 GB, Virtual Used: 130.353 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00013.tif
#    Completed rigid reg on batch in :1.0635240077972412s
#    Shifted the mov in: 0.4169151782989502s
#          After all GPU Batches:Total Used: 134.517 GB, Virtual Available: 371.710 GB, Virtual Used: 131.486 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0011.npy
#          Saved in 0.32 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.775 GB, Virtual Available: 372.452 GB, Virtual Used: 130.743 GB, Swap Used: 003.032 GB
#          Memory at batch 12. Total Used: 133.775 GB, Virtual Available: 372.452 GB, Virtual Used: 130.743 GB, Swap Used: 003.032 GB
# Loading Batch 12 of 13
#    Loaded 1 files, total 0.37 GB
#    Batch 12 IO thread joined
#          Memory after IO thread joinTotal Used: 134.139 GB, Virtual Available: 372.089 GB, Virtual Used: 131.107 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.760 GB, Virtual Available: 372.468 GB, Virtual Used: 130.728 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 133.392 GB, Virtual Available: 372.835 GB, Virtual Used: 130.361 GB, Swap Used: 003.032 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 133.392 GB, Virtual Available: 372.835 GB, Virtual Used: 130.361 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 500, 256, 256)
#       Loading tiff 1/1: /mnt/zeytin-f0/baruchin-data/1/1/file_00001_00014.tif
#    Completed rigid reg on batch in :1.089916706085205s
#    Loaded 1 files, total 0.09 GB
#    Shifted the mov in: 0.4112703800201416s
#          After all GPU Batches:Total Used: 134.606 GB, Virtual Available: 371.621 GB, Virtual Used: 131.574 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 500, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0012.npy
#          Saved in 0.31 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 133.860 GB, Virtual Available: 372.367 GB, Virtual Used: 130.828 GB, Swap Used: 003.032 GB
#          Memory at batch 13. Total Used: 133.860 GB, Virtual Available: 372.368 GB, Virtual Used: 130.828 GB, Swap Used: 003.032 GB
# Loading Batch 13 of 13
#    Batch 13 IO thread joined
#          Memory after IO thread joinTotal Used: 133.860 GB, Virtual Available: 372.368 GB, Virtual Used: 130.828 GB, Swap Used: 003.032 GB
#          Memory after movie copied from threadTotal Used: 133.049 GB, Virtual Available: 373.178 GB, Virtual Used: 130.017 GB, Swap Used: 003.032 GB
#          Memory after thread memory clearedTotal Used: 132.210 GB, Virtual Available: 374.018 GB, Virtual Used: 129.178 GB, Swap Used: 003.032 GB
#       Loaded batch of size (6, 126, 256, 256)
#    Completed rigid reg on batch in :0.2754032611846924s
#    Shifted the mov in: 0.10727047920227051s
#          After all GPU Batches:Total Used: 132.380 GB, Virtual Available: 373.847 GB, Virtual Used: 129.348 GB, Swap Used: 003.032 GB
#       Saving fused, registered file of shape (6, 126, 256, 261) to /mnt/md0/runs/s3d-baruchin-1/registered_fused_data/fused_reg_data0013.npy
#          Saved in 0.08 sec
#       Computing quality metrics and saving
#          After full batch saving:Total Used: 131.627 GB, Virtual Available: 374.600 GB, Virtual Used: 128.595 GB, Swap Used: 003.032 GB
# CPU times: user 2min 58s, sys: 34.8 s, total: 3min 33s
# Wall time: 1min 5s

# %%
reg3d = job.load_registration_results()

# %%
mov_full = job.get_registered_movie('registered_fused_data', 'fused')
im_full = mov_full[:,:200].mean(axis=1).compute()

# %%
job.params['cell_filt_type'] = 'gaussian'

job.params['voxel_size_um'] = (2, 1, 1)
job.params['npil_filt_xy_um'] = 70
job.params['cell_filt_xy_um'] = 1
job.params['sdnorm_exp'] = 1.0
job.params['t_batch_size'] = 1000

# %%
# %%time
corr_map = job.calculate_corr_map()
# Out:
#       Found dir /mnt/md0/runs/s3d-baruchin-1/corrmap
#       Updating self.dirs tag corrmap
#       Found dir /mnt/md0/runs/s3d-baruchin-1/mov_sub
#       Updating self.dirs tag mov_sub
#    Saved a copy of params at /mnt/md0/runs/s3d-baruchin-1/corrmap
#    Updated main params file
#    Computing correlation map of movie with 6626 frames, volume shape: 6, 256, 261
#       Running batch 1 of 7
#          Timer prep completed in 11.527 sec
#          Timer batch_setup completed in 3.121 sec
#          Timer batch_edgecrop completed in 0.056 sec
#          Timer accum_meanmeax completed in 0.286 sec
#          Timer batch_rolling_mean_filt completed in 0.282 sec
#          Timer batch_accum_sdmov completed in 16.185 sec
#          Timer batch_norm_sdmov completed in 0.148 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.346 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.393 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.504 sec
#          Timer dtu_cleanup completed in 8.397 sec
#          Timer batch_filt_reduce completed in 12.643 sec
#          Timer batch_accum_vmap completed in 0.002 sec
#          Timer batch completed in 32.750 sec
#          Timer save completed in 0.738 sec
#       Running batch 2 of 7
#          Timer prep completed in 12.461 sec
#          Timer batch_setup completed in 3.898 sec
#          Timer batch_edgecrop completed in 0.057 sec
#          Timer accum_meanmeax completed in 0.299 sec
#          Timer batch_rolling_mean_filt completed in 0.291 sec
#          Timer batch_accum_sdmov completed in 17.222 sec
#          Timer batch_norm_sdmov completed in 0.152 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.264 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.629 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.292 sec
#          Timer dtu_cleanup completed in 5.836 sec
#          Timer batch_filt_reduce completed in 10.023 sec
#          Timer batch_accum_vmap completed in 0.002 sec
#          Timer batch completed in 32.021 sec
#          Timer save completed in 0.698 sec
#       Running batch 3 of 7
#          Timer prep completed in 15.992 sec
#          Timer batch_setup completed in 0.401 sec
#          Timer batch_edgecrop completed in 0.123 sec
#          Timer accum_meanmeax completed in 0.301 sec
#          Timer batch_rolling_mean_filt completed in 0.295 sec
#          Timer batch_accum_sdmov completed in 21.555 sec
#          Timer batch_norm_sdmov completed in 0.152 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.324 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.500 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.332 sec
#          Timer dtu_cleanup completed in 11.104 sec
#          Timer batch_filt_reduce completed in 15.262 sec
#          Timer batch_accum_vmap completed in 0.002 sec
#          Timer batch completed in 38.143 sec
#          Timer save completed in 0.702 sec
#       Running batch 4 of 7
#          Timer prep completed in 8.611 sec
#          Timer batch_setup completed in 0.383 sec
#          Timer batch_edgecrop completed in 0.117 sec
#          Timer accum_meanmeax completed in 0.289 sec
#          Timer batch_rolling_mean_filt completed in 0.285 sec
#          Timer batch_accum_sdmov completed in 21.288 sec
#          Timer batch_norm_sdmov completed in 0.147 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.296 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.418 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.333 sec
#          Timer dtu_cleanup completed in 10.864 sec
#          Timer batch_filt_reduce completed in 14.912 sec
#          Timer batch_accum_vmap completed in 0.002 sec
#          Timer batch completed in 37.496 sec
#          Timer save completed in 0.691 sec
#       Running batch 5 of 7
#          Timer prep completed in 4.579 sec
#          Timer batch_setup completed in 0.376 sec
#          Timer batch_edgecrop completed in 0.053 sec
#          Timer accum_meanmeax completed in 0.290 sec
#          Timer batch_rolling_mean_filt completed in 0.283 sec
#          Timer batch_accum_sdmov completed in 23.538 sec
#          Timer batch_norm_sdmov completed in 0.150 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.276 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.316 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.281 sec
#          Timer dtu_cleanup completed in 11.048 sec
#          Timer batch_filt_reduce completed in 14.923 sec
#          Timer batch_accum_vmap completed in 0.002 sec
#          Timer batch completed in 39.683 sec
#          Timer save completed in 0.699 sec
#       Running batch 6 of 7
#          Timer prep completed in 4.659 sec
#          Timer batch_setup completed in 0.375 sec
#          Timer batch_edgecrop completed in 0.117 sec
#          Timer accum_meanmeax completed in 0.288 sec
#          Timer batch_rolling_mean_filt completed in 0.285 sec
#          Timer batch_accum_sdmov completed in 23.440 sec
#          Timer batch_norm_sdmov completed in 0.147 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 1.265 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 2.258 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.280 sec
#          Timer dtu_cleanup completed in 10.279 sec
#          Timer batch_filt_reduce completed in 14.084 sec
#          Timer batch_accum_vmap completed in 0.002 sec
#          Timer batch completed in 38.793 sec
#          Timer save completed in 0.702 sec
#       Running batch 7 of 7
#          Timer prep completed in 0.761 sec
#          Timer batch_setup completed in 0.266 sec
#          Timer batch_edgecrop completed in 0.077 sec
#          Timer accum_meanmeax completed in 0.187 sec
#          Timer batch_rolling_mean_filt completed in 0.184 sec
#          Timer batch_accum_sdmov completed in 4.289 sec
#          Timer batch_norm_sdmov completed in 0.096 sec
#          Loading movie into shared memory
#          Timer dtu_shmem completed in 0.801 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 1.786 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.189 sec
#          Timer dtu_cleanup completed in 0.423 sec
#          Timer batch_filt_reduce completed in 3.200 sec
#          Timer batch_accum_vmap completed in 0.002 sec
#          Timer batch completed in 8.358 sec
#          Timer save completed in 0.435 sec
# CPU times: user 17.3 s, sys: 4min 23s, total: 4min 40s
# Wall time: 4min 50s

# %%
res = job.load_corr_map_results()
vmap = res['vmap']
vmap = ext.thresh_mask_corr_map(vmap)

# %%
tfu.show_tif(img[:,100], vminmax=(00,4000.0), cmap='Greys_r', px_py=(0.33,2))
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x7f42edea3190>)

# %%
tfu.show_tif(img[3], vminmax=(00,4000.0), cmap='Greys_r')
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x7f42eded8b50>)

# %%
tfu.show_tif_all_planes(img,ncols=3)

# %%
tfu.show_tif_all_planes(vmap,ncols=3, vminmax=(0.02, 0.0201))

# %%
# %%time
job.params['peak_thresh'] = 0.02
# optionally, bin the movie in time to speed up detection
# probably a good idea if you have high framerate (>5 Hz?)
job.params['detection_timebin'] = 1

# when extending an ROI, compare its activity to its neighboring pixels
# in frames where the fluorescence is above this percentile
job.params['percentile'] = 99.0

job.params['extend_thresh'] = 0.025
job.params['activity_thresh'] = 4.0
job.params['max_iter'] = 1000
job.params['ext_subtract_iters'] = 3
job.params['n_proc_detect'] = 64
job.params['patch_size_xy'] = (300, 300)

# corr_map = job.load_corr_map_results()['vmap']
job.segment_rois(vmap=vmap)
# Out:
#       Found dir /mnt/md0/runs/s3d-baruchin-1/segmentation
#       Updating self.dirs tag segmentation
#    Saved a copy of params at /mnt/md0/runs/s3d-baruchin-1/segmentation
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-baruchin-1/rois
#       Updating self.dirs tag rois
#    Saving results to /mnt/md0/runs/s3d-baruchin-1/segmentation and /mnt/md0/runs/s3d-baruchin-1/rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 1
#       Found dir /mnt/md0/runs/s3d-baruchin-1/segmentation/patch-0000
#          Loading 9.90 GB movie to memory, shape: (6626, 6, 256, 261)
#          Loaded
#          Loading movie patch to shared memory
#          Loaded
#       Starting extraction with peak_thresh: 0.020 and Th2: 4.000
#          Iter 0000: running 64 ROIs in parallel
#          Added cell 1 at 03, 105, 247, peak: 0.110, thresh: 3.405, 741 frames, 761 pixels
#          Added cell 2 at 00, 105, 247, peak: 0.110, thresh: 2.448, 924 frames, 804 pixels
#          Added cell 3 at 03, 089, 200, peak: 0.106, thresh: 3.335, 779 frames, 498 pixels
#          Added cell 4 at 00, 089, 200, peak: 0.106, thresh: 2.290, 1040 frames, 498 pixels
#          Added cell 5 at 03, 105, 064, peak: 0.103, thresh: 2.992, 771 frames, 164 pixels
#          Added cell 6 at 00, 105, 064, peak: 0.103, thresh: 2.751, 902 frames, 167 pixels
#          Added cell 7 at 03, 203, 243, peak: 0.102, thresh: 3.028, 1061 frames, 882 pixels
#          Added cell 8 at 00, 203, 243, peak: 0.102, thresh: 2.303, 1211 frames, 856 pixels
#          Added cell 9 at 03, 129, 220, peak: 0.088, thresh: 2.987, 701 frames, 552 pixels
#          Added cell 10 at 00, 129, 220, peak: 0.088, thresh: 2.094, 975 frames, 310 pixels
#          Added cell 11 at 03, 051, 058, peak: 0.083, thresh: 2.910, 745 frames, 555 pixels
#          Added cell 12 at 00, 051, 058, peak: 0.083, thresh: 2.395, 874 frames, 531 pixels
#          Added cell 13 at 03, 213, 039, peak: 0.082, thresh: 3.125, 817 frames, 323 pixels
#          Added cell 14 at 00, 213, 039, peak: 0.082, thresh: 2.062, 946 frames, 158 pixels
#          Added cell 15 at 03, 089, 243, peak: 0.079, thresh: 2.894, 877 frames, 678 pixels
#          Added cell 16 at 00, 089, 243, peak: 0.079, thresh: 2.309, 1007 frames, 653 pixels
#          Added cell 17 at 03, 204, 194, peak: 0.079, thresh: 2.711, 1003 frames, 659 pixels
#          Added cell 18 at 00, 204, 194, peak: 0.079, thresh: 2.401, 1117 frames, 649 pixels
#          Added cell 19 at 03, 101, 225, peak: 0.077, thresh: 3.246, 764 frames, 835 pixels
#          Added cell 20 at 00, 101, 225, peak: 0.077, thresh: 2.557, 942 frames, 976 pixels
#          Added cell 21 at 03, 197, 145, peak: 0.077, thresh: 3.063, 783 frames, 787 pixels
#          Added cell 22 at 00, 197, 145, peak: 0.077, thresh: 2.136, 1011 frames, 749 pixels
#          Added cell 23 at 03, 228, 183, peak: 0.075, thresh: 3.319, 910 frames, 931 pixels
#          Added cell 24 at 00, 228, 183, peak: 0.075, thresh: 2.196, 1168 frames, 779 pixels
#          Added cell 25 at 03, 115, 030, peak: 0.074, thresh: 2.180, 1655 frames, 995 pixels
#          Added cell 26 at 00, 115, 030, peak: 0.074, thresh: 3.219, 1276 frames, 995 pixels
#          Added cell 27 at 03, 096, 101, peak: 0.074, thresh: 2.608, 678 frames, 211 pixels
#          Added cell 28 at 00, 096, 101, peak: 0.074, thresh: 2.729, 607 frames, 189 pixels
#          Added cell 29 at 03, 153, 138, peak: 0.074, thresh: 2.700, 774 frames, 527 pixels
#          Added cell 30 at 00, 153, 138, peak: 0.074, thresh: 2.537, 830 frames, 516 pixels
#          Added cell 31 at 02, 181, 093, peak: 0.072, thresh: 3.216, 780 frames, 579 pixels
#          Added cell 32 at 05, 181, 093, peak: 0.072, thresh: 2.177, 155 frames, 13 pixels
#          Added cell 33 at 03, 147, 245, peak: 0.071, thresh: 3.310, 691 frames, 808 pixels
#          Added cell 34 at 00, 147, 245, peak: 0.071, thresh: 2.261, 941 frames, 806 pixels
#          Added cell 35 at 03, 121, 122, peak: 0.069, thresh: 2.277, 1157 frames, 511 pixels
#          Added cell 36 at 00, 121, 122, peak: 0.069, thresh: 2.484, 944 frames, 484 pixels
#          Added cell 37 at 03, 122, 235, peak: 0.068, thresh: 2.974, 732 frames, 529 pixels
#          Added cell 38 at 00, 122, 235, peak: 0.068, thresh: 2.064, 1013 frames, 533 pixels
#          Added cell 39 at 03, 172, 138, peak: 0.060, thresh: 2.648, 773 frames, 579 pixels
#          Added cell 40 at 00, 172, 138, peak: 0.060, thresh: 2.188, 297 frames, 179 pixels
#          Added cell 41 at 03, 241, 043, peak: 0.059, thresh: 2.932, 366 frames, 197 pixels
#          Added cell 42 at 00, 241, 043, peak: 0.059, thresh: 2.415, 538 frames, 180 pixels
#          Added cell 43 at 03, 241, 134, peak: 0.059, thresh: 2.555, 623 frames, 401 pixels
#          Added cell 44 at 00, 241, 134, peak: 0.059, thresh: 2.506, 513 frames, 273 pixels
#          Added cell 45 at 03, 178, 248, peak: 0.058, thresh: 2.717, 752 frames, 555 pixels
#          Added cell 46 at 00, 178, 248, peak: 0.058, thresh: 2.549, 124 frames, 82 pixels
#          Added cell 47 at 03, 076, 069, peak: 0.055, thresh: 2.541, 594 frames, 579 pixels
#          Added cell 48 at 00, 076, 069, peak: 0.055, thresh: 2.353, 659 frames, 552 pixels
#          Added cell 49 at 03, 124, 045, peak: 0.055, thresh: 2.941, 297 frames, 86 pixels
#          Added cell 50 at 00, 124, 045, peak: 0.055, thresh: 2.282, 107 frames, 14 pixels
#          Added cell 51 at 03, 077, 122, peak: 0.054, thresh: 2.439, 935 frames, 544 pixels
#          Added cell 52 at 00, 077, 122, peak: 0.054, thresh: 2.298, 613 frames, 279 pixels
#          Added cell 53 at 03, 027, 229, peak: 0.053, thresh: 2.173, 1166 frames, 812 pixels
#          Added cell 54 at 00, 027, 229, peak: 0.053, thresh: 2.494, 1070 frames, 862 pixels
#          Added cell 55 at 03, 062, 085, peak: 0.053, thresh: 2.608, 1102 frames, 984 pixels
#          Added cell 56 at 00, 062, 085, peak: 0.053, thresh: 2.056, 102 frames, 12 pixels
#          Added cell 57 at 03, 169, 170, peak: 0.053, thresh: 2.861, 275 frames, 141 pixels
#          Added cell 58 at 00, 169, 170, peak: 0.053, thresh: 2.292, 104 frames, 10 pixels
#          Added cell 59 at 03, 156, 103, peak: 0.052, thresh: 2.492, 1025 frames, 603 pixels
#          Added cell 60 at 00, 156, 103, peak: 0.052, thresh: 2.103, 124 frames, 10 pixels
#          Added cell 61 at 03, 064, 157, peak: 0.052, thresh: 2.533, 233 frames, 120 pixels
#          Added cell 62 at 00, 064, 157, peak: 0.052, thresh: 2.127, 248 frames, 87 pixels
#          Added cell 63 at 03, 156, 154, peak: 0.051, thresh: 2.796, 240 frames, 111 pixels
#          Added cell 64 at 00, 156, 154, peak: 0.051, thresh: 2.202, 93 frames, 13 pixels
#          Iter 0001: running 64 ROIs in parallel
#          Added cell 65 at 00, 111, 060, peak: 0.068, thresh: 2.257, 461 frames, 98 pixels
#          Added cell 66 at 04, 111, 060, peak: 0.068, thresh: 2.519, 446 frames, 115 pixels
#          Added cell 67 at 00, 194, 248, peak: 0.063, thresh: 2.174, 809 frames, 180 pixels
#          Added cell 68 at 03, 088, 217, peak: 0.062, thresh: 2.521, 896 frames, 535 pixels
#          Added cell 69 at 00, 088, 217, peak: 0.062, thresh: 2.255, 1016 frames, 534 pixels
#          Added cell 70 at 03, 116, 207, peak: 0.060, thresh: 2.108, 878 frames, 535 pixels
#          Added cell 71 at 00, 116, 207, peak: 0.060, thresh: 3.186, 578 frames, 453 pixels
#          Added cell 72 at 03, 139, 248, peak: 0.059, thresh: 2.553, 672 frames, 321 pixels
#          Added cell 73 at 03, 194, 158, peak: 0.057, thresh: 2.822, 259 frames, 171 pixels
#          Added cell 74 at 00, 194, 158, peak: 0.057, thresh: 2.211, 764 frames, 434 pixels
#          Added cell 75 at 05, 208, 233, peak: 0.050, thresh: 3.247, 674 frames, 735 pixels
#          Added cell 76 at 03, 057, 169, peak: 0.050, thresh: 2.713, 559 frames, 353 pixels
#          Added cell 77 at 00, 057, 169, peak: 0.050, thresh: 2.218, 98 frames, 23 pixels
#          Added cell 78 at 03, 203, 110, peak: 0.050, thresh: 2.296, 1028 frames, 529 pixels
#          Added cell 79 at 00, 203, 110, peak: 0.050, thresh: 2.364, 887 frames, 379 pixels
#          Added cell 80 at 00, 195, 194, peak: 0.050, thresh: 2.360, 91 frames, 11 pixels
#          Added cell 81 at 04, 195, 194, peak: 0.050, thresh: 2.554, 731 frames, 590 pixels
#          Added cell 82 at 03, 032, 178, peak: 0.050, thresh: 2.481, 1175 frames, 681 pixels
#          Added cell 83 at 00, 032, 178, peak: 0.050, thresh: 2.217, 104 frames, 72 pixels
#          Added cell 84 at 03, 126, 187, peak: 0.049, thresh: 2.527, 603 frames, 354 pixels
#          Added cell 85 at 00, 126, 187, peak: 0.049, thresh: 2.031, 126 frames, 14 pixels
#          Added cell 86 at 03, 135, 041, peak: 0.048, thresh: 2.348, 676 frames, 261 pixels
#          Added cell 87 at 00, 135, 041, peak: 0.048, thresh: 2.433, 621 frames, 209 pixels
#          Added cell 88 at 00, 082, 201, peak: 0.047, thresh: 2.206, 891 frames, 544 pixels
#          Added cell 89 at 03, 025, 144, peak: 0.047, thresh: 2.634, 555 frames, 346 pixels
#          Added cell 90 at 00, 025, 144, peak: 0.047, thresh: 2.008, 83 frames, 9 pixels
#          Added cell 91 at 03, 056, 152, peak: 0.047, thresh: 2.705, 560 frames, 335 pixels
#          Added cell 92 at 00, 056, 152, peak: 0.047, thresh: 2.206, 87 frames, 23 pixels
#          Added cell 93 at 03, 169, 238, peak: 0.047, thresh: 2.682, 546 frames, 524 pixels
#          Added cell 94 at 00, 169, 238, peak: 0.047, thresh: 2.193, 232 frames, 143 pixels
#          Added cell 95 at 05, 213, 194, peak: 0.046, thresh: 2.218, 132 frames, 44 pixels
#          Added cell 96 at 03, 205, 094, peak: 0.046, thresh: 2.543, 320 frames, 246 pixels
#          Added cell 97 at 00, 205, 094, peak: 0.046, thresh: 2.359, 735 frames, 537 pixels
#          Added cell 98 at 03, 075, 053, peak: 0.045, thresh: 2.584, 352 frames, 142 pixels
#          Added cell 99 at 00, 075, 053, peak: 0.045, thresh: 2.244, 320 frames, 117 pixels
#          Added cell 100 at 03, 169, 055, peak: 0.045, thresh: 2.500, 548 frames, 548 pixels
#          Added cell 101 at 00, 169, 055, peak: 0.045, thresh: 2.303, 569 frames, 448 pixels
#          Added cell 102 at 00, 217, 200, peak: 0.045, thresh: 2.120, 92 frames, 10 pixels
#          Added cell 103 at 03, 087, 025, peak: 0.045, thresh: 2.793, 273 frames, 110 pixels
#          Added cell 104 at 00, 087, 025, peak: 0.045, thresh: 2.248, 164 frames, 25 pixels
#          Added cell 105 at 03, 128, 101, peak: 0.044, thresh: 2.132, 1011 frames, 550 pixels
#          Added cell 106 at 00, 128, 101, peak: 0.044, thresh: 2.872, 779 frames, 561 pixels
#          Added cell 107 at 03, 097, 125, peak: 0.044, thresh: 2.517, 272 frames, 152 pixels
#          Added cell 108 at 00, 097, 125, peak: 0.044, thresh: 2.492, 216 frames, 151 pixels
#          Added cell 109 at 03, 240, 077, peak: 0.043, thresh: 2.600, 659 frames, 555 pixels
#          Added cell 110 at 00, 240, 077, peak: 0.043, thresh: 2.125, 143 frames, 17 pixels
#          Added cell 111 at 05, 195, 250, peak: 0.043, thresh: 0.229, 3541 frames, 760 pixels
#          Added cell 112 at 03, 240, 123, peak: 0.042, thresh: 2.453, 295 frames, 141 pixels
#          Added cell 113 at 00, 240, 123, peak: 0.042, thresh: 2.159, 162 frames, 37 pixels
#          Added cell 114 at 03, 060, 206, peak: 0.041, thresh: 2.021, 825 frames, 513 pixels
#          Added cell 115 at 00, 060, 206, peak: 0.041, thresh: 2.742, 678 frames, 653 pixels
#          Added cell 116 at 03, 167, 013, peak: 0.041, thresh: 2.365, 303 frames, 73 pixels
#          Added cell 117 at 00, 167, 013, peak: 0.041, thresh: 2.313, 125 frames, 29 pixels
#          Added cell 118 at 00, 207, 232, peak: 0.041, thresh: 2.099, 90 frames, 20 pixels
#          Added cell 119 at 03, 136, 151, peak: 0.040, thresh: 2.464, 419 frames, 201 pixels
#          Added cell 120 at 00, 136, 151, peak: 0.040, thresh: 2.466, 151 frames, 64 pixels
#          Added cell 121 at 02, 230, 156, peak: 0.040, thresh: 2.660, 212 frames, 117 pixels
#          Added cell 122 at 05, 230, 156, peak: 0.040, thresh: 2.209, 206 frames, 192 pixels
#          Added cell 123 at 03, 130, 067, peak: 0.040, thresh: 2.473, 161 frames, 55 pixels
#          Added cell 124 at 00, 130, 067, peak: 0.040, thresh: 2.107, 88 frames, 14 pixels
#          Added cell 125 at 03, 024, 088, peak: 0.039, thresh: 2.460, 248 frames, 229 pixels
#          Added cell 126 at 00, 024, 088, peak: 0.039, thresh: 2.274, 164 frames, 147 pixels
#          Added cell 127 at 03, 048, 248, peak: 0.038, thresh: 2.593, 419 frames, 318 pixels
#          Added cell 128 at 00, 048, 248, peak: 0.038, thresh: 2.122, 147 frames, 10 pixels
#          Iter 0002: running 64 ROIs in parallel
#          Added cell 129 at 03, 108, 212, peak: 0.050, thresh: 2.581, 419 frames, 219 pixels
#          Added cell 130 at 00, 107, 211, peak: 0.047, thresh: 2.061, 214 frames, 67 pixels
#          Added cell 131 at 03, 217, 200, peak: 0.045, thresh: 2.727, 368 frames, 316 pixels
#          Added cell 132 at 05, 125, 029, peak: 0.044, thresh: 2.098, 106 frames, 35 pixels
#          Added cell 133 at 05, 130, 181, peak: 0.044, thresh: 2.225, 177 frames, 15 pixels
#          Added cell 134 at 00, 116, 176, peak: 0.043, thresh: 2.118, 135 frames, 36 pixels
#          Added cell 135 at 00, 221, 193, peak: 0.043, thresh: 2.064, 84 frames, 17 pixels
#          Added cell 136 at 03, 144, 045, peak: 0.043, thresh: 2.879, 204 frames, 63 pixels
#          Added cell 137 at 00, 144, 045, peak: 0.043, thresh: 2.153, 99 frames, 12 pixels
#          Added cell 138 at 03, 165, 229, peak: 0.043, thresh: 2.615, 115 frames, 58 pixels
#          Added cell 139 at 00, 165, 229, peak: 0.043, thresh: 2.409, 108 frames, 35 pixels
#          Added cell 140 at 03, 046, 140, peak: 0.042, thresh: 2.590, 156 frames, 61 pixels
#          Added cell 141 at 00, 046, 140, peak: 0.042, thresh: 2.110, 120 frames, 11 pixels
#          Added cell 142 at 00, 246, 122, peak: 0.040, thresh: 2.666, 154 frames, 50 pixels
#          Added cell 143 at 04, 246, 122, peak: 0.040, thresh: 2.212, 89 frames, 34 pixels
#          Added cell 144 at 05, 129, 114, peak: 0.040, thresh: 2.245, 109 frames, 51 pixels
#          Added cell 145 at 01, 047, 117, peak: 0.038, thresh: 2.193, 102 frames, 38 pixels
#          Added cell 146 at 04, 047, 117, peak: 0.038, thresh: 2.562, 638 frames, 477 pixels
#          Added cell 147 at 03, 103, 177, peak: 0.037, thresh: 2.446, 234 frames, 88 pixels
#          Added cell 148 at 03, 029, 026, peak: 0.037, thresh: 2.257, 563 frames, 255 pixels
#          Added cell 149 at 00, 029, 026, peak: 0.037, thresh: 2.606, 453 frames, 313 pixels
#          Added cell 150 at 03, 160, 161, peak: 0.037, thresh: 2.436, 294 frames, 232 pixels
#          Added cell 151 at 00, 160, 161, peak: 0.037, thresh: 2.317, 134 frames, 14 pixels
#          Added cell 152 at 00, 163, 142, peak: 0.036, thresh: 2.444, 182 frames, 89 pixels
#          Added cell 153 at 05, 163, 142, peak: 0.036, thresh: 2.303, 335 frames, 150 pixels
#          Added cell 154 at 03, 030, 213, peak: 0.036, thresh: 2.069, 282 frames, 92 pixels
#          Added cell 155 at 00, 030, 213, peak: 0.036, thresh: 2.434, 259 frames, 101 pixels
#          Added cell 156 at 01, 051, 100, peak: 0.036, thresh: 2.684, 467 frames, 276 pixels
#          Added cell 157 at 04, 051, 100, peak: 0.036, thresh: 2.192, 179 frames, 20 pixels
#          Added cell 158 at 00, 135, 237, peak: 0.036, thresh: 2.175, 95 frames, 11 pixels
#          Added cell 159 at 03, 217, 217, peak: 0.036, thresh: 2.744, 186 frames, 44 pixels
#          Added cell 160 at 00, 217, 217, peak: 0.036, thresh: 2.141, 102 frames, 15 pixels
#          Added cell 161 at 03, 071, 149, peak: 0.036, thresh: 2.443, 735 frames, 543 pixels
#          Added cell 162 at 00, 071, 149, peak: 0.036, thresh: 2.241, 125 frames, 22 pixels
#          Added cell 163 at 03, 012, 238, peak: 0.036, thresh: 2.335, 665 frames, 616 pixels
#          Added cell 164 at 00, 012, 238, peak: 0.036, thresh: 2.014, 622 frames, 437 pixels
#          Added cell 165 at 03, 102, 021, peak: 0.035, thresh: 2.208, 800 frames, 685 pixels
#          Added cell 166 at 00, 102, 021, peak: 0.035, thresh: 2.232, 671 frames, 558 pixels
#          Added cell 167 at 03, 120, 069, peak: 0.035, thresh: 2.273, 572 frames, 257 pixels
#          Added cell 168 at 00, 120, 069, peak: 0.035, thresh: 2.111, 129 frames, 11 pixels
#          Added cell 169 at 03, 190, 023, peak: 0.035, thresh: 2.594, 212 frames, 111 pixels
#          Added cell 170 at 00, 190, 023, peak: 0.035, thresh: 2.125, 100 frames, 11 pixels
#          Added cell 171 at 03, 031, 116, peak: 0.035, thresh: 2.362, 343 frames, 307 pixels
#          Added cell 172 at 00, 031, 116, peak: 0.035, thresh: 2.368, 160 frames, 15 pixels
#          Added cell 173 at 00, 125, 216, peak: 0.035, thresh: 2.190, 178 frames, 37 pixels
#          Added cell 174 at 00, 084, 120, peak: 0.034, thresh: 2.126, 105 frames, 9 pixels
#          Added cell 175 at 03, 209, 020, peak: 0.034, thresh: 2.601, 360 frames, 210 pixels
#          Added cell 176 at 00, 209, 020, peak: 0.034, thresh: 2.049, 124 frames, 11 pixels
#          Added cell 177 at 03, 189, 179, peak: 0.033, thresh: 2.321, 208 frames, 130 pixels
#          Added cell 178 at 00, 189, 179, peak: 0.033, thresh: 2.266, 96 frames, 19 pixels
#          Added cell 179 at 03, 066, 177, peak: 0.033, thresh: 2.436, 108 frames, 41 pixels
#          Added cell 180 at 00, 066, 177, peak: 0.033, thresh: 2.316, 117 frames, 15 pixels
#          Added cell 181 at 03, 145, 231, peak: 0.033, thresh: 2.146, 463 frames, 283 pixels
#          Added cell 182 at 00, 189, 103, peak: 0.033, thresh: 2.202, 122 frames, 40 pixels
#          Added cell 183 at 05, 069, 098, peak: 0.033, thresh: 2.412, 147 frames, 22 pixels
#          Added cell 184 at 01, 069, 098, peak: 0.033, thresh: 2.389, 161 frames, 69 pixels
#          Added cell 185 at 03, 153, 071, peak: 0.033, thresh: 2.482, 142 frames, 29 pixels
#          Added cell 186 at 00, 153, 071, peak: 0.033, thresh: 2.177, 162 frames, 13 pixels
#          Added cell 187 at 03, 240, 091, peak: 0.032, thresh: 2.287, 364 frames, 288 pixels
#          Added cell 188 at 00, 240, 091, peak: 0.032, thresh: 2.201, 88 frames, 9 pixels
#          Added cell 189 at 05, 070, 118, peak: 0.032, thresh: 2.082, 115 frames, 14 pixels
#          Added cell 190 at 03, 183, 211, peak: 0.032, thresh: 2.427, 114 frames, 61 pixels
#          Added cell 191 at 00, 183, 211, peak: 0.032, thresh: 2.204, 140 frames, 11 pixels
#          Added cell 192 at 00, 096, 181, peak: 0.032, thresh: 2.182, 108 frames, 12 pixels
#          Iter 0003: running 64 ROIs in parallel
#          Added cell 193 at 03, 121, 176, peak: 0.043, thresh: 2.592, 555 frames, 308 pixels
#          Added cell 194 at 05, 125, 037, peak: 0.040, thresh: 2.034, 112 frames, 12 pixels
#          Added cell 195 at 00, 218, 206, peak: 0.039, thresh: 2.088, 97 frames, 9 pixels
#          Added cell 196 at 00, 130, 180, peak: 0.039, thresh: 2.278, 164 frames, 62 pixels
#          Added cell 197 at 03, 148, 147, peak: 0.035, thresh: 2.471, 211 frames, 82 pixels
#          Added cell 198 at 00, 148, 147, peak: 0.035, thresh: 2.137, 125 frames, 11 pixels
#          Added cell 199 at 01, 132, 049, peak: 0.035, thresh: 2.189, 94 frames, 36 pixels
#          Added cell 200 at 00, 107, 186, peak: 0.034, thresh: 2.194, 144 frames, 53 pixels
#          Added cell 201 at 03, 232, 126, peak: 0.033, thresh: 2.120, 102 frames, 39 pixels
#          Added cell 202 at 00, 232, 126, peak: 0.033, thresh: 2.151, 375 frames, 136 pixels
#          Added cell 203 at 03, 133, 231, peak: 0.033, thresh: 2.429, 203 frames, 57 pixels
#          Added cell 204 at 00, 133, 231, peak: 0.033, thresh: 2.326, 73 frames, 16 pixels
#          Added cell 205 at 03, 168, 156, peak: 0.032, thresh: 2.697, 138 frames, 115 pixels
#          Added cell 206 at 00, 168, 156, peak: 0.032, thresh: 2.339, 176 frames, 115 pixels
#          Added cell 207 at 04, 096, 181, peak: 0.032, thresh: 2.418, 414 frames, 257 pixels
#          Added cell 208 at 00, 080, 146, peak: 0.031, thresh: 2.368, 188 frames, 10 pixels
#          Added cell 209 at 05, 212, 188, peak: 0.031, thresh: 2.032, 114 frames, 13 pixels
#          Added cell 210 at 00, 201, 185, peak: 0.031, thresh: 2.313, 192 frames, 69 pixels
#          Added cell 211 at 03, 180, 065, peak: 0.031, thresh: 2.151, 149 frames, 35 pixels
#          Added cell 212 at 00, 180, 065, peak: 0.031, thresh: 2.188, 122 frames, 47 pixels
#          Added cell 213 at 03, 244, 027, peak: 0.031, thresh: 2.356, 150 frames, 62 pixels
#          Added cell 214 at 00, 244, 027, peak: 0.031, thresh: 2.169, 104 frames, 18 pixels
#          Added cell 215 at 03, 030, 158, peak: 0.031, thresh: 2.428, 95 frames, 40 pixels
#          Added cell 216 at 00, 030, 158, peak: 0.031, thresh: 2.294, 115 frames, 47 pixels
#          Added cell 217 at 00, 121, 246, peak: 0.031, thresh: 2.189, 72 frames, 10 pixels
#          Added cell 218 at 03, 148, 038, peak: 0.031, thresh: 2.125, 242 frames, 60 pixels
#          Added cell 219 at 00, 148, 038, peak: 0.031, thresh: 2.249, 71 frames, 10 pixels
#          Added cell 220 at 03, 036, 067, peak: 0.031, thresh: 2.414, 311 frames, 213 pixels
#          Added cell 221 at 00, 036, 067, peak: 0.031, thresh: 2.120, 101 frames, 9 pixels
#          Added cell 222 at 00, 214, 023, peak: 0.030, thresh: 2.505, 141 frames, 44 pixels
#          Added cell 223 at 05, 217, 207, peak: 0.030, thresh: 2.258, 318 frames, 83 pixels
#          Added cell 224 at 03, 235, 055, peak: 0.030, thresh: 2.044, 340 frames, 139 pixels
#          Added cell 225 at 00, 235, 055, peak: 0.030, thresh: 2.156, 661 frames, 280 pixels
#          Added cell 226 at 03, 215, 023, peak: 0.030, thresh: 2.509, 102 frames, 53 pixels
#          Added cell 227 at 00, 125, 074, peak: 0.029, thresh: 3.039, 215 frames, 108 pixels
#          Added cell 228 at 05, 125, 074, peak: 0.029, thresh: 2.016, 96 frames, 13 pixels
#          Added cell 229 at 05, 027, 239, peak: 0.029, thresh: 2.356, 295 frames, 200 pixels
#          Added cell 230 at 03, 216, 090, peak: 0.029, thresh: 2.638, 163 frames, 48 pixels
#          Added cell 231 at 00, 216, 090, peak: 0.029, thresh: 2.206, 87 frames, 9 pixels
#          Added cell 232 at 00, 018, 218, peak: 0.029, thresh: 2.234, 81 frames, 13 pixels
#          Added cell 233 at 03, 213, 162, peak: 0.029, thresh: 2.199, 146 frames, 41 pixels
#          Added cell 234 at 00, 213, 162, peak: 0.029, thresh: 2.363, 166 frames, 35 pixels
#          Added cell 235 at 05, 095, 030, peak: 0.029, thresh: 2.346, 87 frames, 12 pixels
#          Added cell 236 at 00, 150, 162, peak: 0.029, thresh: 2.209, 141 frames, 34 pixels
#          Added cell 237 at 05, 122, 191, peak: 0.029, thresh: 2.155, 176 frames, 11 pixels
#          Added cell 238 at 00, 046, 186, peak: 0.028, thresh: 2.229, 108 frames, 9 pixels
#          Added cell 239 at 03, 083, 057, peak: 0.028, thresh: 2.311, 110 frames, 50 pixels
#          Added cell 240 at 00, 083, 057, peak: 0.028, thresh: 2.047, 129 frames, 23 pixels
#          Added cell 241 at 00, 037, 227, peak: 0.028, thresh: 2.125, 139 frames, 23 pixels
#          Added cell 242 at 03, 184, 231, peak: 0.028, thresh: 2.566, 296 frames, 251 pixels
#          Added cell 243 at 00, 184, 231, peak: 0.028, thresh: 2.217, 87 frames, 17 pixels
#          Added cell 244 at 03, 118, 152, peak: 0.028, thresh: 2.289, 168 frames, 64 pixels
#          Added cell 245 at 00, 118, 152, peak: 0.028, thresh: 2.093, 229 frames, 10 pixels
#          Added cell 246 at 03, 057, 244, peak: 0.028, thresh: 2.449, 213 frames, 133 pixels
#          Added cell 247 at 00, 057, 244, peak: 0.028, thresh: 2.212, 134 frames, 9 pixels
#          Added cell 248 at 03, 020, 189, peak: 0.028, thresh: 2.417, 414 frames, 181 pixels
#          Added cell 249 at 00, 020, 189, peak: 0.028, thresh: 2.340, 115 frames, 9 pixels
#          Added cell 250 at 03, 122, 246, peak: 0.028, thresh: 2.343, 269 frames, 128 pixels
#          Added cell 251 at 04, 149, 162, peak: 0.027, thresh: 2.095, 101 frames, 20 pixels
#          Added cell 252 at 02, 240, 163, peak: 0.027, thresh: 2.702, 152 frames, 29 pixels
#          Added cell 253 at 05, 240, 163, peak: 0.027, thresh: 2.160, 119 frames, 13 pixels
#          Added cell 254 at 03, 148, 209, peak: 0.027, thresh: 2.269, 122 frames, 67 pixels
#          Added cell 255 at 00, 148, 209, peak: 0.027, thresh: 2.400, 99 frames, 23 pixels
#          Added cell 256 at 00, 036, 121, peak: 0.027, thresh: 2.250, 107 frames, 66 pixels
#          Iter 0004: running 64 ROIs in parallel
#          Added cell 257 at 01, 216, 195, peak: 0.038, thresh: 2.241, 639 frames, 314 pixels
#          Added cell 258 at 00, 122, 190, peak: 0.035, thresh: 2.115, 134 frames, 57 pixels
#          Added cell 259 at 05, 107, 186, peak: 0.034, thresh: 2.089, 116 frames, 78 pixels
#          Added cell 260 at 05, 232, 126, peak: 0.033, thresh: 2.039, 106 frames, 9 pixels
#          Added cell 261 at 03, 139, 051, peak: 0.033, thresh: 2.289, 123 frames, 42 pixels
#          Added cell 262 at 00, 138, 051, peak: 0.033, thresh: 2.371, 109 frames, 49 pixels
#          Added cell 263 at 05, 205, 186, peak: 0.031, thresh: 2.219, 84 frames, 21 pixels
#          Added cell 264 at 01, 154, 165, peak: 0.030, thresh: 2.224, 102 frames, 63 pixels
#          Added cell 265 at 05, 217, 160, peak: 0.029, thresh: 2.191, 100 frames, 21 pixels
#          Added cell 266 at 03, 171, 068, peak: 0.029, thresh: 2.426, 243 frames, 201 pixels
#          Added cell 267 at 00, 171, 068, peak: 0.029, thresh: 1.983, 112 frames, 22 pixels
#          Added cell 268 at 05, 233, 053, peak: 0.028, thresh: 2.133, 88 frames, 11 pixels
#          Added cell 269 at 05, 037, 226, peak: 0.028, thresh: 2.523, 397 frames, 524 pixels
#          Added cell 270 at 03, 133, 075, peak: 0.027, thresh: 2.336, 132 frames, 110 pixels
#          Added cell 271 at 00, 133, 075, peak: 0.027, thresh: 2.120, 104 frames, 22 pixels
#          Added cell 272 at 00, 066, 244, peak: 0.027, thresh: 2.172, 176 frames, 9 pixels
#          Added cell 273 at 00, 222, 167, peak: 0.027, thresh: 2.363, 209 frames, 30 pixels
#          Added cell 274 at 00, 113, 073, peak: 0.027, thresh: 2.723, 253 frames, 71 pixels
#          Added cell 275 at 05, 227, 208, peak: 0.027, thresh: 2.172, 102 frames, 11 pixels
#          Added cell 276 at 03, 017, 210, peak: 0.026, thresh: 2.431, 326 frames, 354 pixels
#          Added cell 277 at 00, 017, 210, peak: 0.026, thresh: 2.118, 142 frames, 35 pixels
#          Added cell 278 at 00, 076, 153, peak: 0.026, thresh: 2.545, 190 frames, 96 pixels
#          Added cell 279 at 05, 068, 125, peak: 0.026, thresh: 2.316, 110 frames, 52 pixels
#          Added cell 280 at 03, 032, 199, peak: 0.025, thresh: 2.414, 187 frames, 55 pixels
#          Added cell 281 at 00, 032, 199, peak: 0.025, thresh: 2.277, 108 frames, 8 pixels
#          Added cell 282 at 00, 168, 147, peak: 0.025, thresh: 2.165, 185 frames, 16 pixels
#          Added cell 283 at 03, 050, 012, peak: 0.025, thresh: 2.413, 86 frames, 44 pixels
#          Added cell 284 at 00, 050, 012, peak: 0.025, thresh: 1.852, 226 frames, 48 pixels
#          Added cell 285 at 00, 043, 229, peak: 0.025, thresh: 2.115, 149 frames, 16 pixels
#          Added cell 286 at 02, 240, 061, peak: 0.025, thresh: 2.590, 199 frames, 61 pixels
#          Added cell 287 at 03, 066, 245, peak: 0.025, thresh: 2.405, 107 frames, 48 pixels
#          Added cell 288 at 00, 169, 047, peak: 0.025, thresh: 2.331, 99 frames, 45 pixels
#          Added cell 289 at 03, 216, 246, peak: 0.025, thresh: 2.565, 118 frames, 61 pixels
#          Added cell 290 at 00, 216, 246, peak: 0.025, thresh: 2.276, 98 frames, 13 pixels
#          Added cell 291 at 00, 183, 106, peak: 0.025, thresh: 2.267, 112 frames, 27 pixels
#          Added cell 292 at 05, 183, 106, peak: 0.025, thresh: 2.308, 104 frames, 52 pixels
#          Added cell 293 at 03, 103, 128, peak: 0.025, thresh: 2.103, 118 frames, 55 pixels
#          Added cell 294 at 03, 069, 222, peak: 0.025, thresh: 2.270, 285 frames, 139 pixels
#          Added cell 295 at 00, 069, 222, peak: 0.025, thresh: 2.115, 86 frames, 23 pixels
#          Added cell 296 at 02, 231, 117, peak: 0.025, thresh: 2.766, 98 frames, 49 pixels
#          Added cell 297 at 05, 043, 083, peak: 0.025, thresh: 1.910, 125 frames, 11 pixels
#          Added cell 298 at 00, 104, 128, peak: 0.025, thresh: 2.048, 104 frames, 35 pixels
#          Added cell 299 at 03, 230, 144, peak: 0.024, thresh: 2.335, 112 frames, 59 pixels
#          Added cell 300 at 00, 230, 144, peak: 0.024, thresh: 2.154, 227 frames, 9 pixels
#          Added cell 301 at 03, 210, 071, peak: 0.024, thresh: 2.305, 100 frames, 54 pixels
#          Added cell 302 at 00, 210, 071, peak: 0.024, thresh: 2.199, 160 frames, 10 pixels
#          Added cell 303 at 03, 191, 060, peak: 0.024, thresh: 2.406, 176 frames, 80 pixels
#          Added cell 304 at 00, 191, 060, peak: 0.024, thresh: 2.239, 139 frames, 11 pixels
#          Added cell 305 at 03, 180, 201, peak: 0.024, thresh: 2.414, 153 frames, 64 pixels
#          Added cell 306 at 00, 180, 201, peak: 0.024, thresh: 2.247, 138 frames, 10 pixels
#          Added cell 307 at 00, 203, 228, peak: 0.024, thresh: 2.192, 92 frames, 10 pixels
#          Added cell 308 at 02, 084, 119, peak: 0.024, thresh: 2.263, 84 frames, 16 pixels
#          Added cell 309 at 00, 042, 082, peak: 0.023, thresh: 2.149, 165 frames, 13 pixels
#          Added cell 310 at 03, 191, 033, peak: 0.023, thresh: 2.322, 446 frames, 201 pixels
#          Added cell 311 at 00, 191, 033, peak: 0.023, thresh: 2.363, 181 frames, 10 pixels
#          Added cell 312 at 03, 110, 148, peak: 0.023, thresh: 2.205, 174 frames, 24 pixels
#          Added cell 313 at 00, 110, 148, peak: 0.023, thresh: 2.309, 174 frames, 74 pixels
#          Added cell 314 at 05, 116, 035, peak: 0.023, thresh: 2.023, 82 frames, 16 pixels
#          Added cell 315 at 00, 238, 197, peak: 0.023, thresh: 1.985, 88 frames, 15 pixels
#          Added cell 316 at 02, 132, 119, peak: 0.023, thresh: 2.404, 139 frames, 41 pixels
#          Added cell 317 at 05, 132, 119, peak: 0.023, thresh: 2.071, 107 frames, 14 pixels
#          Added cell 318 at 00, 024, 183, peak: 0.022, thresh: 2.242, 80 frames, 11 pixels
#          Added cell 319 at 03, 247, 190, peak: 0.022, thresh: 2.307, 116 frames, 21 pixels
#          Added cell 320 at 05, 035, 156, peak: 0.022, thresh: 2.065, 146 frames, 12 pixels
#          Iter 0005: running 62 ROIs in parallel
#          Added cell 321 at 00, 161, 151, peak: 0.028, thresh: 2.049, 123 frames, 27 pixels
#          Added cell 322 at 05, 213, 167, peak: 0.027, thresh: 2.121, 141 frames, 12 pixels
#          Added cell 323 at 00, 227, 208, peak: 0.027, thresh: 2.196, 70 frames, 9 pixels
#          Added cell 324 at 05, 115, 197, peak: 0.027, thresh: 2.108, 127 frames, 8 pixels
#          Added cell 325 at 03, 014, 195, peak: 0.026, thresh: 2.317, 179 frames, 95 pixels
#          Added cell 326 at 00, 014, 195, peak: 0.026, thresh: 2.343, 250 frames, 119 pixels
#          Added cell 327 at 03, 145, 071, peak: 0.026, thresh: 2.112, 122 frames, 29 pixels
#          Added cell 328 at 00, 145, 071, peak: 0.026, thresh: 2.193, 313 frames, 86 pixels
#          Added cell 329 at 00, 177, 053, peak: 0.026, thresh: 2.645, 492 frames, 218 pixels
#          Added cell 330 at 05, 240, 061, peak: 0.025, thresh: 2.091, 125 frames, 11 pixels
#          Added cell 331 at 00, 111, 124, peak: 0.023, thresh: 2.120, 114 frames, 10 pixels
#          Added cell 332 at 03, 212, 249, peak: 0.023, thresh: 2.442, 122 frames, 41 pixels
#          Added cell 333 at 00, 196, 228, peak: 0.023, thresh: 2.154, 130 frames, 9 pixels
#          Added cell 334 at 03, 175, 108, peak: 0.023, thresh: 2.337, 107 frames, 47 pixels
#          Added cell 335 at 00, 175, 108, peak: 0.023, thresh: 2.502, 127 frames, 58 pixels
#          Added cell 336 at 00, 200, 038, peak: 0.023, thresh: 2.232, 130 frames, 35 pixels
#          Added cell 337 at 03, 238, 197, peak: 0.023, thresh: 2.308, 119 frames, 69 pixels
#          Added cell 338 at 00, 190, 205, peak: 0.023, thresh: 2.386, 123 frames, 11 pixels
#          Added cell 339 at 03, 040, 086, peak: 0.023, thresh: 2.172, 154 frames, 57 pixels
#          Added cell 340 at 00, 208, 175, peak: 0.022, thresh: 2.210, 177 frames, 13 pixels
#          Added cell 341 at 05, 193, 094, peak: 0.022, thresh: 2.348, 75 frames, 17 pixels
#          Added cell 342 at 02, 225, 152, peak: 0.022, thresh: 2.580, 88 frames, 52 pixels
#          Added cell 343 at 00, 045, 053, peak: 0.022, thresh: 2.335, 82 frames, 33 pixels
#          Added cell 344 at 03, 228, 082, peak: 0.022, thresh: 2.504, 113 frames, 17 pixels
#          Added cell 345 at 00, 228, 082, peak: 0.022, thresh: 2.118, 102 frames, 9 pixels
#          Added cell 346 at 03, 082, 036, peak: 0.022, thresh: 2.320, 252 frames, 74 pixels
#          Added cell 347 at 00, 082, 036, peak: 0.022, thresh: 2.161, 94 frames, 11 pixels
#          Added cell 348 at 05, 178, 054, peak: 0.022, thresh: 2.012, 127 frames, 12 pixels
#          Added cell 349 at 02, 220, 190, peak: 0.022, thresh: 2.351, 173 frames, 71 pixels
#          Added cell 350 at 03, 179, 124, peak: 0.022, thresh: 2.325, 118 frames, 44 pixels
#          Added cell 351 at 00, 179, 124, peak: 0.022, thresh: 2.367, 84 frames, 9 pixels
#          Added cell 352 at 05, 192, 166, peak: 0.021, thresh: 2.342, 155 frames, 11 pixels
#          Added cell 353 at 05, 044, 011, peak: 0.021, thresh: 2.242, 102 frames, 10 pixels
#          Added cell 354 at 03, 138, 209, peak: 0.021, thresh: 2.182, 137 frames, 49 pixels
#          Added cell 355 at 00, 138, 209, peak: 0.021, thresh: 2.169, 102 frames, 8 pixels
#          Added cell 356 at 03, 153, 187, peak: 0.021, thresh: 2.378, 108 frames, 44 pixels
#          Added cell 357 at 00, 153, 187, peak: 0.021, thresh: 2.311, 186 frames, 10 pixels
#          Added cell 358 at 03, 044, 053, peak: 0.021, thresh: 2.251, 93 frames, 40 pixels
#          Added cell 359 at 00, 192, 187, peak: 0.021, thresh: 2.230, 154 frames, 16 pixels
#          Added cell 360 at 03, 154, 234, peak: 0.021, thresh: 2.335, 114 frames, 64 pixels
#          Added cell 361 at 00, 154, 234, peak: 0.021, thresh: 2.230, 97 frames, 22 pixels
#          Added cell 362 at 05, 080, 192, peak: 0.021, thresh: 2.326, 167 frames, 14 pixels
#          Added cell 363 at 03, 215, 129, peak: 0.021, thresh: 2.209, 103 frames, 52 pixels
#          Added cell 364 at 00, 215, 129, peak: 0.021, thresh: 2.084, 148 frames, 40 pixels
#          Added cell 365 at 03, 078, 101, peak: 0.021, thresh: 2.262, 183 frames, 61 pixels
#          Added cell 366 at 00, 078, 101, peak: 0.021, thresh: 2.173, 198 frames, 10 pixels
#          Added cell 367 at 00, 175, 172, peak: 0.021, thresh: 2.169, 101 frames, 33 pixels
#          Added cell 368 at 01, 165, 068, peak: 0.021, thresh: 2.304, 153 frames, 56 pixels
#          Added cell 369 at 03, 061, 145, peak: 0.021, thresh: 2.316, 99 frames, 41 pixels
#          Added cell 370 at 00, 061, 145, peak: 0.021, thresh: 2.353, 112 frames, 32 pixels
#          Added cell 371 at 03, 083, 233, peak: 0.021, thresh: 2.280, 133 frames, 35 pixels
#          Added cell 372 at 00, 083, 233, peak: 0.021, thresh: 2.055, 105 frames, 11 pixels
#          Added cell 373 at 04, 098, 160, peak: 0.020, thresh: 2.170, 96 frames, 10 pixels
#          Added cell 374 at 03, 090, 085, peak: 0.020, thresh: 2.163, 189 frames, 20 pixels
#          Added cell 375 at 00, 090, 085, peak: 0.020, thresh: 2.244, 87 frames, 22 pixels
#          Added cell 376 at 00, 098, 160, peak: 0.020, thresh: 2.102, 98 frames, 16 pixels
#          Added cell 377 at 00, 040, 087, peak: 0.020, thresh: 2.123, 80 frames, 21 pixels
#          Added cell 378 at 05, 195, 228, peak: 0.020, thresh: 2.556, 476 frames, 540 pixels
#          Added cell 379 at 05, 247, 039, peak: 0.020, thresh: 2.234, 152 frames, 9 pixels
#          Added cell 380 at 05, 162, 070, peak: 0.020, thresh: 2.117, 86 frames, 20 pixels
#          Added cell 381 at 03, 210, 113, peak: 0.020, thresh: 2.122, 88 frames, 17 pixels
#          Added cell 382 at 00, 210, 113, peak: 0.020, thresh: 2.531, 304 frames, 101 pixels
#          Iter 0006: running 17 ROIs in parallel
#          Added cell 383 at 05, 141, 077, peak: 0.025, thresh: 2.149, 130 frames, 10 pixels
#          Added cell 384 at 02, 141, 078, peak: 0.023, thresh: 2.589, 344 frames, 253 pixels
#          Added cell 385 at 02, 229, 207, peak: 0.023, thresh: 2.438, 144 frames, 85 pixels
#          Added cell 386 at 03, 208, 175, peak: 0.022, thresh: 2.333, 186 frames, 80 pixels
#          Added cell 387 at 05, 165, 067, peak: 0.022, thresh: 2.116, 84 frames, 44 pixels
#          Added cell 388 at 00, 192, 198, peak: 0.022, thresh: 2.212, 134 frames, 9 pixels
#          Added cell 389 at 00, 181, 242, peak: 0.022, thresh: 1.937, 229 frames, 46 pixels
#          Added cell 390 at 03, 147, 193, peak: 0.021, thresh: 2.171, 173 frames, 17 pixels
#          Added cell 391 at 00, 147, 193, peak: 0.021, thresh: 2.515, 180 frames, 46 pixels
#          Added cell 392 at 00, 213, 188, peak: 0.021, thresh: 2.377, 124 frames, 58 pixels
#          Added cell 393 at 00, 214, 168, peak: 0.021, thresh: 2.140, 160 frames, 9 pixels
#          Added cell 394 at 03, 066, 103, peak: 0.021, thresh: 2.351, 102 frames, 102 pixels
#          Added cell 395 at 03, 094, 038, peak: 0.020, thresh: 2.350, 135 frames, 51 pixels
#          Added cell 396 at 00, 094, 038, peak: 0.020, thresh: 2.224, 88 frames, 22 pixels
#          Added cell 397 at 03, 099, 090, peak: 0.020, thresh: 2.209, 111 frames, 33 pixels
#          Added cell 398 at 00, 099, 090, peak: 0.020, thresh: 2.119, 84 frames, 13 pixels
#          Added cell 399 at 05, 190, 103, peak: 0.020, thresh: 2.393, 351 frames, 225 pixels
#          Iter 0007: running 05 ROIs in parallel
#          Added cell 400 at 03, 150, 064, peak: 0.022, thresh: 2.282, 112 frames, 57 pixels
#          Added cell 401 at 00, 150, 064, peak: 0.022, thresh: 2.193, 197 frames, 141 pixels
#          Added cell 402 at 02, 214, 168, peak: 0.021, thresh: 2.309, 154 frames, 100 pixels
#          Added cell 403 at 03, 141, 181, peak: 0.020, thresh: 2.429, 233 frames, 163 pixels
#          Added cell 404 at 00, 141, 181, peak: 0.020, thresh: 2.141, 193 frames, 11 pixels
#       Iter 0008: peak is too small - ending extraction
#    Found 404 cells in 9 iterations
#    Saving cells to /mnt/md0/runs/s3d-baruchin-1/segmentation/patch-0000/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-baruchin-1/segmentation/patch-0000/iscell.npy
#       Found dir /mnt/md0/runs/s3d-baruchin-1/segmentation/patch-0000
#       Updating self.dirs tag segmentation-segmentation-patch-0000
#       Deduplicating 404 cells
#       Removed 0 duplicate cells in 0.01s
#    Combined 1 patches, 404 cells
#    Saving combined files to /mnt/md0/runs/s3d-baruchin-1/rois
#       Saved stats
#       Saved iscell
#       Found dir /mnt/md0/runs/s3d-baruchin-1/segmentation/patch-0000
#       Updating self.dirs tag segmentation-segmentation-patch-0000
#       Deduplicating 404 cells
#       Removed 0 duplicate cells in 0.01s
#    Combined 1 patches, 404 cells
#    Saving combined files to /mnt/md0/runs/s3d-baruchin-1/rois
#       Saved stats
#       Saved iscell
# CPU times: user 26.5 s, sys: 1min 51s, total: 2min 17s
# Wall time: 4min 46s
# '/mnt/md0/runs/s3d-baruchin-1/rois'

# %%
import  colorcet
from suite3d import plot_utils as plot
from suite3d import nbtools as nbui


seg = job.load_segmentation_results()


cell_id_vol, rgb_vol = ui.make_label_vols(seg['stats'], vmap.shape, lam_max=0.075, cmap='cet_glasbey_dark')
nbui.ImageSliceViewer3D(vmap, overlay=rgb_vol,cmap='Greys')

# %%
nbui.ImageSliceViewer3D(vmap, overlay=rgb_vol,cmap='Greys')
# Out:
# interactive(children=(RadioButtons(description='Slice plane selection:', options=('x-y', 'y-z', 'z-x'), style=…

# %%
nbui.ImageSliceViewer3D(vmap, overlay=rgb_vol,cmap='Greys')
# Out:
# interactive(children=(RadioButtons(description='Slice plane selection:', options=('x-y', 'y-z', 'z-x'), style=…

# %%
filt = npix > -1

# %%
n_files = 8
shuff_cells = n.where(filt)[0]
n.random.shuffle(shuff_cells)
nc = len(shuff_cells)
batchsize = nc // n_files
for i in range(n_files):
    cx = shuff_cells[i*batchsize:i*batchsize + batchsize]
    filefilt = n.zeros_like(filt)
    filefilt[cx] = True

    __, filevol = ui.make_label_vols(seg['stats'], corr_map.shape, lam_max=1.0, cmap='cet_glasbey_dark',
                                             iscell = filefilt)
    tfu.save_mrc('/mnt/md0/runs/pub-figs/',f'baruchin-boutons_c{i:02d}.mrc', filevol[:,:,:,-1],
            voxel_size=(0.33, 0.33, 2))

# %%
filevol.shape
# Out:
# (6, 256, 261, 4)

# %%
traces = job.extract_and_deconvolve(stats_dir=job.dirs['rois'],iscell=iscell)

# %%
job.export_results('/mnt/zeytin-f1/s3d-results/',result_dir_name='rois')
