# %%
# %load_ext autoreload
# %autoreload 2

import os 
import shutil
import numpy as n
from datetime import date
from matplotlib import pyplot as plt
import time
import napari

# %%
os.chdir('/home/ali/packages/s2p-lbm/')

from suite3d.job import Job
from suite3d import lbmio, utils, ui
from suite3d import tiff_utils as tfu

# %%
## Find all the tiffiles in the tif path
tif_path = r'/mnt/md0/data/demo'
tifs = tfu.get_tif_paths(tif_path)

# %%
# Set the mandatory parameters
params = {
    # volume rate
    'fs': tfu.get_vol_rate(tifs[0]),
    # planes to analyze. 0 is deepest, 30 is shallowest (corrected for ScanImage channel IDs)
    # you should keep all the planes to do crosstalk estimation! 
    'planes' : n.arange(30),
    # Decay time of the Ca indicator in seconds. 1.3 for GCaMP6s. This example is for GCamP8m
    'tau' : 1.3
}

# %%
# Create the job
job = Job('/mnt/md0/runs','Full-Demo-GPU', tifs = tifs,
          params=params, create=True, overwrite=True, verbosity = 3)
# Out:
# Job directory /mnt/md0/runs/s3d-Full-Demo-GPU already exists
# Loading job directory for Full-Demo-GPU in /mnt/md0/runs
#    Loading dirs
#       Found dir registered_data
#       Found dir summary
#       Found dir iters
#    Loading default params
#       Updating param fs
#       Updating param planes
#       Updating param tau
#    Updated main params file

# %% [markdown]
# ## Initial pass
# This pass takes a few files (`n_init_files`, usually ~200-300 frames is enough) and does the following:
# - estimates the crosstalk coefficient between the lower set of 15 planes and the higher 15 planes
# - computes the shifts between successive planes caused by the xy-shift of the light beads
# - estimates the optimal number of pixels that overlap between successive strips, so they can be fused together
# - calculates a "reference volume" that will be used later in registration

# %%
# optional parameters for initialization
# load 1 file to initialize
job.params['n_init_files'] = 1
# If set to None, use all of the frames in the loaded init files 
# if your files are really big, set this to <300
job.params['init_n_frames'] = None

# Set to None to auto-compute the crosstalk coefficient
# You can set a float value between 0-1 (usually around 0.1-0.3) to override the calculation
job.params['override_crosstalk'] = None
# number of processors to use
job.params['n_proc_corr'] = 20

# %%
# %%time
# this is still somewhat slow, because I haven't GPU-ified it yet. Will do soon
# This step only uses `n_init_files` files, so the  runtime will stay the same even with larger recordings
job.run_init_pass()
# Out:
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-GPU/summary
#    Updated main params file
# Launching initial pass
# Saving summary to /mnt/md0/runs/s3d-Full-Demo-GPU/summary/summary.npy
# Loading /mnt/md0/data/demo/AH007_ROI3p33um_NOSCREEN_-400um_00001_00002.tif
# Loaded 1 files, total 6.82 GB
#    Loaded movie with 100 frames and shape 30, 1202, 1015
#          Enforcing positivity in mean image
# /home/ali/packages/s2p-lbm/suite3d/utils.py:186: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Saving figure to /mnt/md0/runs/s3d-Full-Demo-GPU/summary/crosstalk_plots
# saved
# Close figure
#    Subtracting with estimated coefficient 0.295
#          Subtracting plane 0 from 15
#          Subtracting plane 1 from 16
#          Subtracting plane 2 from 17
#          Subtracting plane 3 from 18
#          Subtracting plane 4 from 19
#          Subtracting plane 5 from 20
#          Subtracting plane 6 from 21
#          Subtracting plane 7 from 22
#          Subtracting plane 8 from 23
#          Subtracting plane 9 from 24
#          Subtracting plane 10 from 25
#          Subtracting plane 11 from 26
#          Subtracting plane 12 from 27
#          Subtracting plane 13 from 28
#          Subtracting plane 14 from 29
#    Estimating fusing shifts
#    Using best fuse shift of 13
#    Building ops file
#    Saved init mov to /mnt/md0/runs/s3d-Full-Demo-GPU/summary/init_mov.npy
#    Aligning planes
# float64
# 20
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,Traceback (most recent call last):
#
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# RuntimeError:     Undefined plan with nthreads. This is a bugFFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
#
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'Exception ignored in:
# 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'Traceback (most recent call last):
#
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# Traceback (most recent call last):
#       File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,RuntimeError:
# Undefined plan with nthreads. This is a bug
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# Exception ignored in:     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
#
# RuntimeErrorTraceback (most recent call last):
# :   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# Undefined plan with nthreads. This is a bug
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null''pyfftw.pyfftw._fftw_plan_with_nthreads_null'
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#         FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
#
# RuntimeErrorRuntimeError: : Undefined plan with nthreads. This is a bugUndefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# ...
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# Exception ignored in:     'pyfftw.pyfftw._fftw_plan_with_nthreads_null'FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
#
# Traceback (most recent call last):
# RuntimeError  File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
# : Undefined plan with nthreads. This is a bug
# FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: Undefined plan with nthreads. This is a bug
# Exception ignored in: 'pyfftw.pyfftw._fftw_plan_with_nthreads_null'
# Traceback (most recent call last):
#   File "/home/ali/anaconda3/envs/s2p-lbm/lib/python3.8/site-packages/pyfftw/builders/_utils.py", line 285, in _Xfftn
#     FFTW_object = pyfftw.FFTW(input_array, output_array, axes, direction,
# RuntimeError: Undefined plan with nthreads. This is a bug
#       Fixing plane alignment outliers
#    Fusing and padding init mov
# Setting smooth_sigma: 1.15
# Setting maxregshift: 0.15
# Setting Ly: 1256
# Setting Lx: 974
# Setting nonrigid: True
#    Computing reference images
# /home/ali/packages/s2p-lbm/suite2p/suite2p/registration/register.py:89: RuntimeWarning: invalid value encountered in matmul
#   cc = np.matmul(frames, frames.T)
#         Computed reference for plane 0
#         Computed reference for plane 1
#         Computed reference for plane 2
#         Computed reference for plane 3
#         Computed reference for plane 4
#         Computed reference for plane 5
#         Computed reference for plane 6
#         Computed reference for plane 7
#         Computed reference for plane 8
#         Computed reference for plane 9
#         Computed reference for plane 10
#         Computed reference for plane 11
#         Computed reference for plane 12
#         Computed reference for plane 13
#         Computed reference for plane 14
#         Computed reference for plane 15
#         Computed reference for plane 16
#         Computed reference for plane 17
#         Computed reference for plane 18
#         Computed reference for plane 19
#         Computed reference for plane 20
#         Computed reference for plane 21
#         Computed reference for plane 22
#         Computed reference for plane 23
#         Computed reference for plane 24
#         Computed reference for plane 25
#         Computed reference for plane 26
#         Computed reference for plane 27
#         Computed reference for plane 28
#         Computed reference for plane 29
#    Saving summary to /mnt/md0/runs/s3d-Full-Demo-GPU/summary/summary.npy
#    Initial pass complete. See /mnt/md0/runs/s3d-Full-Demo-GPU/summary for details
# CPU times: user 2h 19min 59s, sys: 44min 24s, total: 3h 4min 23s
# Wall time: 7min 4s

# %%
job.show_summary_plots()

# %% [markdown]
# ## Registration
# First, we do registration over time of the  xy-drift caused by brain movement. This is similar to Suite2P registratrion, it does rigid registration followed by non-rigid registration. This is accelerated on the GPU. Suite2P registration parameters can be changed, see `default_params.py` for a list of all parameters related to registration. After you have registered, you can load the registered fused movie into memory and take a look at the mean image. I suggest cropping the dark edges if you have any as shown in the cells below.

# %%
# If you have large tiffs, split the large tiffs into files of size 100 after registration
job.params['split_tif_size'] = 100

# %%
# %%time
job.register_gpu()
# Out:
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/registered_fused_data with tag registered_fused_data
# Will analyze 3 tifs in 3 batches
#    Enforcing positivity
#    Launching IO thread
#       Loading /mnt/md0/data/demo/AH007_ROI3p33um_NOSCREEN_-400um_00001_00001.tif
#          Memory at batch 0.  Total Used: 087.602 GB, Virtual Available: 416.334 GB, Virtual Used: 086.862 GB, Swap Used: 000.740 GB
# Loading Batch 0 of 2
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#    Loaded 1 files, total 6.82 GB
#    Batch 0 IO thread joined
#          Memory after IO thread joinTotal Used: 095.407 GB, Virtual Available: 408.529 GB, Virtual Used: 094.667 GB, Swap Used: 000.740 GB
#    Launching IO thread for next batch
#       Loading /mnt/md0/data/demo/AH007_ROI3p33um_NOSCREEN_-400um_00001_00002.tif
#          After IO thread launch:Total Used: 102.232 GB, Virtual Available: 401.704 GB, Virtual Used: 101.492 GB, Swap Used: 000.740 GB
#       Loaded batch of size (30, 100, 1202, 1015)
#       Sending frames 0-10 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.52 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.88 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.37 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.48 sec
#       Transferred to CPU in 0.33 sec
#    Non rigid transformed (on CPU) in 2.05 sec
#       Sending frames 10-20 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.29 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.19 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.37 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.44 sec
#       Transferred to CPU in 0.36 sec
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#    Non rigid transformed (on CPU) in 5.56 sec
#       Sending frames 20-30 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.63 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 1.00 sec
#          Allocated GPU array for non-rigid reg in 0.21 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.59 sec
#       Transferred to CPU in 0.37 sec
#    Non rigid transformed (on CPU) in 2.11 sec
#       Sending frames 30-40 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.51 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.32 sec
#          Freeing all blocks
#       Completed rigid registration in 0.89 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.37 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.50 sec
#       Transferred to CPU in 0.37 sec
#    Loaded 1 files, total 6.82 GB
#    Non rigid transformed (on CPU) in 2.38 sec
#       Sending frames 40-50 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.49 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.86 sec
#          Allocated GPU array for non-rigid reg in 0.19 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.44 sec
#       Transferred to CPU in 0.35 sec
#    Non rigid transformed (on CPU) in 2.01 sec
#       Sending frames 50-60 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.31 sec
#          Freeing all blocks
#       Completed rigid registration in 0.87 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.46 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.03 sec
#       Sending frames 60-70 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.86 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.45 sec
#       Transferred to CPU in 0.33 sec
#    Non rigid transformed (on CPU) in 1.97 sec
#       Sending frames 70-80 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.06 sec
#       Sending frames 80-90 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.87 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.37 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.47 sec
#       Transferred to CPU in 0.35 sec
#    Non rigid transformed (on CPU) in 2.00 sec
#       Sending frames 90-100 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.31 sec
#          Freeing all blocks
#       Completed rigid registration in 0.88 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.47 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.01 sec
#       Concatenating movie
#          Concat in 3.48 sec
#       Saving fused, registered file of shape (30, 100, 1256, 974) to /mnt/md0/runs/s3d-Full-Demo-GPU/registered_fused_data/fused_reg_data0000.npy
#          Saved in 62.17 sec
#          Memory at batch 1.  Total Used: 117.330 GB, Virtual Available: 386.607 GB, Virtual Used: 116.589 GB, Swap Used: 000.740 GB
# Loading Batch 1 of 2
#    Batch 1 IO thread joined
#          Memory after IO thread joinTotal Used: 117.330 GB, Virtual Available: 386.607 GB, Virtual Used: 116.589 GB, Swap Used: 000.740 GB
#    Launching IO thread for next batch
#       Loading /mnt/md0/data/demo/AH007_ROI3p33um_NOSCREEN_-400um_00001_00003.tif
#          After IO thread launch:Total Used: 117.335 GB, Virtual Available: 386.602 GB, Virtual Used: 116.594 GB, Swap Used: 000.740 GB
#       Loaded batch of size (30, 100, 1202, 1015)
#       Sending frames 0-10 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.51 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.87 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.45 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 1.95 sec
#       Sending frames 10-20 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.86 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.44 sec
#       Transferred to CPU in 0.36 sec
#    Non rigid transformed (on CPU) in 1.94 sec
#       Sending frames 20-30 to GPU for rigid registration
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#          Loaded mov and masks to GPU for rigid reg in 1.46 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#          Allocating memory for shifted movie
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#          Registered batch in 0.49 sec
#          Shifted batch in 0.43 sec
#          Freeing all blocks
#       Completed rigid registration in 3.00 sec
#          Allocated GPU array for non-rigid reg in 0.25 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 3.62 sec
#       Transferred to CPU in 0.44 sec
#          Fusing and padding movie
#          Allocating memory for shifted movie
#    Non rigid transformed (on CPU) in 2.66 sec
#       Sending frames 30-40 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.86 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.36 sec
#    Non rigid transformed (on CPU) in 2.43 sec
#       Sending frames 40-50 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.51 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.87 sec
#    Loaded 1 files, total 6.82 GB
#          Allocated GPU array for non-rigid reg in 0.38 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.63 sec
#       Transferred to CPU in 0.35 sec
#    Non rigid transformed (on CPU) in 1.92 sec
#       Sending frames 50-60 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.29 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.07 sec
#       Sending frames 60-70 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 1.98 sec
#       Sending frames 70-80 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.29 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.00 sec
#       Sending frames 80-90 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.29 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.01 sec
#       Sending frames 90-100 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.86 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.35 sec
#    Non rigid transformed (on CPU) in 1.90 sec
#       Concatenating movie
#          Concat in 3.50 sec
#       Saving fused, registered file of shape (30, 100, 1256, 974) to /mnt/md0/runs/s3d-Full-Demo-GPU/registered_fused_data/fused_reg_data0001.npy
#          Saved in 60.78 sec
#          Memory at batch 2.  Total Used: 118.242 GB, Virtual Available: 385.694 GB, Virtual Used: 117.502 GB, Swap Used: 000.740 GB
# Loading Batch 2 of 2
#    Batch 2 IO thread joined
#          Memory after IO thread joinTotal Used: 118.242 GB, Virtual Available: 385.694 GB, Virtual Used: 117.502 GB, Swap Used: 000.740 GB
#       Loaded batch of size (30, 100, 1202, 1015)
#       Sending frames 0-10 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.51 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.33 sec
#          Freeing all blocks
#       Completed rigid registration in 0.87 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.37 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.46 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.02 sec
#       Sending frames 10-20 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.51 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.32 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.36 sec
#    Non rigid transformed (on CPU) in 1.96 sec
#       Sending frames 20-30 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.49 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.37 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.45 sec
#       Transferred to CPU in 0.36 sec
#    Non rigid transformed (on CPU) in 1.97 sec
#       Sending frames 30-40 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.31 sec
#          Freeing all blocks
#       Completed rigid registration in 0.86 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.44 sec
#       Transferred to CPU in 0.35 sec
#    Non rigid transformed (on CPU) in 1.98 sec
#       Sending frames 40-50 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.44 sec
#       Transferred to CPU in 0.35 sec
#    Non rigid transformed (on CPU) in 2.01 sec
#       Sending frames 50-60 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.49 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.29 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.44 sec
#       Transferred to CPU in 0.38 sec
#    Non rigid transformed (on CPU) in 2.14 sec
#       Sending frames 60-70 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.51 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.31 sec
#          Freeing all blocks
#       Completed rigid registration in 0.88 sec
#          Allocated GPU array for non-rigid reg in 0.21 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.36 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.48 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.01 sec
#       Sending frames 70-80 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.49 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.29 sec
#          Freeing all blocks
#       Completed rigid registration in 0.85 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.43 sec
#       Transferred to CPU in 0.34 sec
#    Non rigid transformed (on CPU) in 2.04 sec
#       Sending frames 80-90 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.30 sec
#          Freeing all blocks
#       Completed rigid registration in 0.86 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.35 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.44 sec
#       Transferred to CPU in 0.33 sec
#    Non rigid transformed (on CPU) in 2.19 sec
#       Sending frames 90-100 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.50 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 1256, 974; 2.73 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.31 sec
#          Freeing all blocks
#       Completed rigid registration in 0.87 sec
#          Allocated GPU array for non-rigid reg in 0.20 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.37 sec
#          Computed subpixel shifts in 0.02 sec
#       Computed non-rigid shifts in 1.47 sec
#       Transferred to CPU in 0.38 sec
#    Non rigid transformed (on CPU) in 2.04 sec
#       Concatenating movie
#          Concat in 3.56 sec
#       Saving fused, registered file of shape (30, 100, 1256, 974) to /mnt/md0/runs/s3d-Full-Demo-GPU/registered_fused_data/fused_reg_data0002.npy
#          Saved in 61.36 sec
# CPU times: user 9min 20s, sys: 2min 7s, total: 11min 28s
# Wall time: 5min 42s

# %%
# if GPU fails, the following *should* work
# note that in the GPU version fusing is incorporated into registration
# job.register()
# job.params['n_skip'] = job.load_summary()['fuse_shift']
# job.fuse_registered_movie()

# %%
mov_full = job.get_registered_movie('registered_fused_data','f')
im_full = mov_full.mean(axis=1).compute()

# %%
# find crop values that minimize dark zones - check planes 0 and 15 in the following cell to 
# make sure you're not cutting out parts of the brain
crop = ((0,18), (100,1100), (50, 900))

# %%
tfu.show_tif(im_full[0,crop[1][0]:crop[1][1], crop[2][0]:crop[2][1]])
tfu.show_tif(im_full[15,crop[1][0]:crop[1][1], crop[2][0]:crop[2][1]])
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x7feb6c2d3550>)

# %% [markdown]
# ## SVD Denoising
# We compute an SVD of the volumetric movie, and keep the top N components to denoise. This is done by blocking the volume to make it computationally tractable. The blocks have overlaps, and I find that for noisy movies you will get some grid-like artifacts if your block overlaps aren't set such that each non-edge pixel is included in at least two blocks. So, I usually set the overlaps to be half of the block shape to achieve this. Feel free to try with smaller (or zero) overlaps on your data to see if it works better (overlaps increase the number of blocks that need to be SVD-d, so less overlap = less blocks = faster compute).
#
# The SVD decomposition is implemented with Dask, which can be blazing fast (compared to other methods) if implemented correctly, but there are a few parameters that can make it really slow if set incorrectly. If the SVD feels slow, try playing with the `svd_pix_chunk` and `svd_time_chunk` parameters. If you really care about speed, probably install the Dask profiler and see if there are any obvious bottlenecks.
#
# Note that the Dask SVD uses an approximate algorithm and its runtime scales **sub-linearly** with movie length! So for a short movie, it might take >10x the movie duration, but for longer movies it should be much less.

# %%
# tag (not path) for the directory where the SVD will be saved
svd_dir_tag = 'svd_cropped'

# Number of components to compute per block
job.params['n_svd_comp'] = 200
# Size of each block in pixels in z,y,x
job.params['svd_block_shape'] = (4,200,200)
# overlap in z,y,x between two neighboring blocks
job.params['svd_block_overlaps'] = (2,100,100)
# crop the movie before computing svd
job.params['svd_crop'] = crop

# Number of pixels in each Dask "chunk" when computing SVD. Unless you have ridiculously 
# large blocks, manually setting the chunksize to the total number of pixels in a block
# seems to be substantially faster than having multiple chunks per block
job.params['svd_pix_chunk'] = n.product(job.params['svd_block_shape'])
# When computing SVD, we can compute multiple blocks (4-8) at the same time, which is sometimes 
# faster since we save on some disk I/O for neighboring blocks (I  think)
# for longer recordings (1000+frames) or if you have issues with RAM, set to 1
job.params['n_svd_blocks_per_batch'] = 8

# %%
# create the directory where we'll save the SVD, and run the SVD decomposition
job.make_new_dir(svd_dir_tag)
svd_info = job.svd_decompose_movie(svd_dir_tag, run_svd=True)
# Out:
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped with tag svd_cropped
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped
#    Updated main params file
#    Loaded mov of size (30, 300, 1256, 974)
#    Cropped to size (18, 300, 1000, 850)
#    Time-cropped to size (18, 300, 1000, 850)
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped
#    Updated main params file
# 576 blocks with overlap (125 without, 4.61x increase)
#    Will compute SVD in 576 blocks in a grid shaped (8, 9, 8)
#    Batching 8 blocks together, for a total of 72 batches. Pix chunksize: 160000
#    Saving SVD blocks in /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/blocks
# Starting with batch 0
#       Starting batch 1 / 72, blocks 0 - 8
#       Sending batch 1 to dask
#       Dask completed in 26.070 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 1 completed in 26.292
#    Estimated time remaining for 71 batches: 00h31m06s
#       Starting batch 2 / 72, blocks 8 - 16
#       Sending batch 2 to dask
#       Dask completed in 25.182 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 2 completed in 25.437
#    Estimated time remaining for 70 batches: 00h30m28s
#       Starting batch 3 / 72, blocks 16 - 24
#       Sending batch 3 to dask
#       Dask completed in 25.322 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 3 completed in 25.494
#    Estimated time remaining for 69 batches: 00h29m53s
#       Starting batch 4 / 72, blocks 24 - 32
#       Sending batch 4 to dask
#       Dask completed in 24.174 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 4 completed in 24.396
#    Estimated time remaining for 68 batches: 00h29m05s
#       Starting batch 5 / 72, blocks 32 - 40
#       Sending batch 5 to dask
#       Dask completed in 25.100 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 5 completed in 25.261
#    Estimated time remaining for 67 batches: 00h28m34s
#       Starting batch 6 / 72, blocks 40 - 48
#       Sending batch 6 to dask
#       Dask completed in 25.345 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 6 completed in 25.608
#    Estimated time remaining for 66 batches: 00h28m09s
#       Starting batch 7 / 72, blocks 48 - 56
#       Sending batch 7 to dask
#       Dask completed in 25.899 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 7 completed in 26.056
#    Estimated time remaining for 65 batches: 00h27m49s
#       Starting batch 8 / 72, blocks 56 - 64
#       Sending batch 8 to dask
#       Dask completed in 23.859 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 8 completed in 24.027
#    Estimated time remaining for 64 batches: 00h27m02s
#       Starting batch 9 / 72, blocks 64 - 72
#       Sending batch 9 to dask
#       Dask completed in 23.956 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 9 completed in 24.124
#    Estimated time remaining for 63 batches: 00h26m21s
#       Starting batch 10 / 72, blocks 72 - 80
#       Sending batch 10 to dask
#       Dask completed in 25.503 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 10 completed in 25.668
#    Estimated time remaining for 62 batches: 00h26m03s
#       Starting batch 11 / 72, blocks 80 - 88
#       Sending batch 11 to dask
#       Dask completed in 25.476 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 11 completed in 25.646
#    Estimated time remaining for 61 batches: 00h25m43s
#       Starting batch 12 / 72, blocks 88 - 96
#       Sending batch 12 to dask
#       Dask completed in 23.715 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 12 completed in 23.933
#    Estimated time remaining for 60 batches: 00h25m01s
#       Starting batch 13 / 72, blocks 96 - 104
#       Sending batch 13 to dask
#       Dask completed in 24.057 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 13 completed in 24.223
#    Estimated time remaining for 59 batches: 00h24m27s
#       Starting batch 14 / 72, blocks 104 - 112
#       Sending batch 14 to dask
#       Dask completed in 25.960 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 14 completed in 26.177
#    Estimated time remaining for 58 batches: 00h24m17s
#       Starting batch 15 / 72, blocks 112 - 120
#       Sending batch 15 to dask
#       Dask completed in 25.636 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 15 completed in 25.804
#    Estimated time remaining for 57 batches: 00h24m00s
#       Starting batch 16 / 72, blocks 120 - 128
#       Sending batch 16 to dask
#       Dask completed in 24.839 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 16 completed in 25.005
#    Estimated time remaining for 56 batches: 00h23m31s
#       Starting batch 17 / 72, blocks 128 - 136
#       Sending batch 17 to dask
#       Dask completed in 26.690 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 17 completed in 26.855
#    Estimated time remaining for 55 batches: 00h23m24s
#       Starting batch 18 / 72, blocks 136 - 144
#       Sending batch 18 to dask
#       Dask completed in 25.094 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 18 completed in 25.267
#    Estimated time remaining for 54 batches: 00h22m56s
#       Starting batch 19 / 72, blocks 144 - 152
#       Sending batch 19 to dask
#       Dask completed in 24.896 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 19 completed in 25.066
#    Estimated time remaining for 53 batches: 00h22m26s
#       Starting batch 20 / 72, blocks 152 - 160
#       Sending batch 20 to dask
#       Dask completed in 25.318 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 20 completed in 25.485
#    Estimated time remaining for 52 batches: 00h22m01s
#       Starting batch 21 / 72, blocks 160 - 168
#       Sending batch 21 to dask
#       Dask completed in 26.787 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 21 completed in 26.976
#    Estimated time remaining for 51 batches: 00h21m52s
#       Starting batch 22 / 72, blocks 168 - 176
#       Sending batch 22 to dask
#       Dask completed in 25.520 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 22 completed in 25.690
#    Estimated time remaining for 50 batches: 00h21m26s
#       Starting batch 23 / 72, blocks 176 - 184
#       Sending batch 23 to dask
#       Dask completed in 25.642 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 23 completed in 25.816
#    Estimated time remaining for 49 batches: 00h21m01s
#       Starting batch 24 / 72, blocks 184 - 192
#       Sending batch 24 to dask
#       Dask completed in 26.189 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 24 completed in 26.355
#    Estimated time remaining for 48 batches: 00h20m41s
#       Starting batch 25 / 72, blocks 192 - 200
#       Sending batch 25 to dask
#       Dask completed in 23.557 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 25 completed in 23.940
#    Estimated time remaining for 47 batches: 00h19m57s
#       Starting batch 26 / 72, blocks 200 - 208
#       Sending batch 26 to dask
#       Dask completed in 25.169 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 26 completed in 25.333
#    Estimated time remaining for 46 batches: 00h19m30s
#       Starting batch 27 / 72, blocks 208 - 216
#       Sending batch 27 to dask
#       Dask completed in 25.128 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 27 completed in 25.286
#    Estimated time remaining for 45 batches: 00h19m03s
#       Starting batch 28 / 72, blocks 216 - 224
#       Sending batch 28 to dask
#       Dask completed in 23.934 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 28 completed in 24.111
#    Estimated time remaining for 44 batches: 00h18m26s
#       Starting batch 29 / 72, blocks 224 - 232
#       Sending batch 29 to dask
#       Dask completed in 25.277 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 29 completed in 25.531
#    Estimated time remaining for 43 batches: 00h18m04s
#       Starting batch 30 / 72, blocks 232 - 240
#       Sending batch 30 to dask
#       Dask completed in 26.115 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 30 completed in 26.334
#    Estimated time remaining for 42 batches: 00h17m48s
#       Starting batch 31 / 72, blocks 240 - 248
#       Sending batch 31 to dask
#       Dask completed in 24.531 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 31 completed in 24.703
#    Estimated time remaining for 41 batches: 00h17m17s
#       Starting batch 32 / 72, blocks 248 - 256
#       Sending batch 32 to dask
#       Dask completed in 24.982 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 32 completed in 25.190
#    Estimated time remaining for 40 batches: 00h16m51s
#       Starting batch 33 / 72, blocks 256 - 264
#       Sending batch 33 to dask
#       Dask completed in 24.094 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 33 completed in 24.263
#    Estimated time remaining for 39 batches: 00h16m17s
#       Starting batch 34 / 72, blocks 264 - 272
#       Sending batch 34 to dask
#       Dask completed in 25.851 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 34 completed in 26.023
#    Estimated time remaining for 38 batches: 00h16m00s
#       Starting batch 35 / 72, blocks 272 - 280
#       Sending batch 35 to dask
#       Dask completed in 24.878 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 35 completed in 25.037
#    Estimated time remaining for 37 batches: 00h15m33s
#       Starting batch 36 / 72, blocks 280 - 288
#       Sending batch 36 to dask
#       Dask completed in 25.537 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 36 completed in 25.780
#    Estimated time remaining for 36 batches: 00h15m11s
#       Starting batch 37 / 72, blocks 288 - 296
#       Sending batch 37 to dask
#       Dask completed in 25.026 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 37 completed in 25.198
#    Estimated time remaining for 35 batches: 00h14m45s
#       Starting batch 38 / 72, blocks 296 - 304
#       Sending batch 38 to dask
#       Dask completed in 25.558 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 38 completed in 25.777
#    Estimated time remaining for 34 batches: 00h14m23s
#       Starting batch 39 / 72, blocks 304 - 312
#       Sending batch 39 to dask
#       Dask completed in 25.096 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 39 completed in 25.265
#    Estimated time remaining for 33 batches: 00h13m57s
#       Starting batch 40 / 72, blocks 312 - 320
#       Sending batch 40 to dask
#       Dask completed in 25.200 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 40 completed in 25.364
#    Estimated time remaining for 32 batches: 00h13m31s
#       Starting batch 41 / 72, blocks 320 - 328
#       Sending batch 41 to dask
#       Dask completed in 25.193 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 41 completed in 25.374
#    Estimated time remaining for 31 batches: 00h13m06s
#       Starting batch 42 / 72, blocks 328 - 336
#       Sending batch 42 to dask
#       Dask completed in 25.340 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 42 completed in 25.501
#    Estimated time remaining for 30 batches: 00h12m41s
#       Starting batch 43 / 72, blocks 336 - 344
#       Sending batch 43 to dask
#       Dask completed in 25.420 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 43 completed in 25.576
#    Estimated time remaining for 29 batches: 00h12m17s
#       Starting batch 44 / 72, blocks 344 - 352
#       Sending batch 44 to dask
#       Dask completed in 23.587 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 44 completed in 23.760
#    Estimated time remaining for 28 batches: 00h11m42s
#       Starting batch 45 / 72, blocks 352 - 360
#       Sending batch 45 to dask
#       Dask completed in 26.192 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 45 completed in 26.409
#    Estimated time remaining for 27 batches: 00h11m24s
#       Starting batch 46 / 72, blocks 360 - 368
#       Sending batch 46 to dask
#       Dask completed in 26.688 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 46 completed in 26.859
#    Estimated time remaining for 26 batches: 00h11m07s
#       Starting batch 47 / 72, blocks 368 - 376
#       Sending batch 47 to dask
#       Dask completed in 26.123 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 47 completed in 26.291
#    Estimated time remaining for 25 batches: 00h10m44s
#       Starting batch 48 / 72, blocks 376 - 384
#       Sending batch 48 to dask
#       Dask completed in 24.502 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 48 completed in 24.719
#    Estimated time remaining for 24 batches: 00h10m13s
#       Starting batch 49 / 72, blocks 384 - 392
#       Sending batch 49 to dask
#       Dask completed in 24.799 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 49 completed in 24.964
#    Estimated time remaining for 23 batches: 00h09m45s
#       Starting batch 50 / 72, blocks 392 - 400
#       Sending batch 50 to dask
#       Dask completed in 25.051 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 50 completed in 25.417
#    Estimated time remaining for 22 batches: 00h09m19s
#       Starting batch 51 / 72, blocks 400 - 408
#       Sending batch 51 to dask
#       Dask completed in 25.165 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 51 completed in 25.376
#    Estimated time remaining for 21 batches: 00h08m54s
#       Starting batch 52 / 72, blocks 408 - 416
#       Sending batch 52 to dask
#       Dask completed in 25.366 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 52 completed in 25.525
#    Estimated time remaining for 20 batches: 00h08m28s
#       Starting batch 53 / 72, blocks 416 - 424
#       Sending batch 53 to dask
#       Dask completed in 24.846 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 53 completed in 25.014
#    Estimated time remaining for 19 batches: 00h08m01s
#       Starting batch 54 / 72, blocks 424 - 432
#       Sending batch 54 to dask
#       Dask completed in 24.277 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 54 completed in 24.441
#    Estimated time remaining for 18 batches: 00h07m33s
#       Starting batch 55 / 72, blocks 432 - 440
#       Sending batch 55 to dask
#       Dask completed in 25.148 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 55 completed in 25.314
#    Estimated time remaining for 17 batches: 00h07m08s
#       Starting batch 56 / 72, blocks 440 - 448
#       Sending batch 56 to dask
#       Dask completed in 24.028 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 56 completed in 24.194
#    Estimated time remaining for 16 batches: 00h06m40s
#       Starting batch 57 / 72, blocks 448 - 456
#       Sending batch 57 to dask
#       Dask completed in 24.704 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 57 completed in 24.872
#    Estimated time remaining for 15 batches: 00h06m14s
#       Starting batch 58 / 72, blocks 456 - 464
#       Sending batch 58 to dask
#       Dask completed in 24.455 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 58 completed in 24.620
#    Estimated time remaining for 14 batches: 00h05m48s
#       Starting batch 59 / 72, blocks 464 - 472
#       Sending batch 59 to dask
#       Dask completed in 24.335 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 59 completed in 24.499
#    Estimated time remaining for 13 batches: 00h05m22s
#       Starting batch 60 / 72, blocks 472 - 480
#       Sending batch 60 to dask
#       Dask completed in 26.322 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 60 completed in 26.489
#    Estimated time remaining for 12 batches: 00h05m01s
#       Starting batch 61 / 72, blocks 480 - 488
#       Sending batch 61 to dask
#       Dask completed in 25.625 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 61 completed in 25.791
#    Estimated time remaining for 11 batches: 00h04m38s
#       Starting batch 62 / 72, blocks 488 - 496
#       Sending batch 62 to dask
#       Dask completed in 25.465 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 62 completed in 25.628
#    Estimated time remaining for 10 batches: 00h04m13s
#       Starting batch 63 / 72, blocks 496 - 504
#       Sending batch 63 to dask
#       Dask completed in 24.810 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 63 completed in 24.973
#    Estimated time remaining for 9 batches: 00h03m47s
#       Starting batch 64 / 72, blocks 504 - 512
#       Sending batch 64 to dask
#       Dask completed in 25.021 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 64 completed in 25.183
#    Estimated time remaining for 8 batches: 00h03m22s
#       Starting batch 65 / 72, blocks 512 - 520
#       Sending batch 65 to dask
#       Dask completed in 25.952 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 65 completed in 26.119
#    Estimated time remaining for 7 batches: 00h02m58s
#       Starting batch 66 / 72, blocks 520 - 528
#       Sending batch 66 to dask
#       Dask completed in 26.771 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 66 completed in 26.936
#    Estimated time remaining for 6 batches: 00h02m34s
#       Starting batch 67 / 72, blocks 528 - 536
#       Sending batch 67 to dask
#       Dask completed in 25.576 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 67 completed in 25.741
#    Estimated time remaining for 5 batches: 00h02m08s
#       Starting batch 68 / 72, blocks 536 - 544
#       Sending batch 68 to dask
#       Dask completed in 24.380 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 68 completed in 24.544
#    Estimated time remaining for 4 batches: 00h01m41s
#       Starting batch 69 / 72, blocks 544 - 552
#       Sending batch 69 to dask
#       Dask completed in 26.479 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 69 completed in 26.647
#    Estimated time remaining for 3 batches: 00h01m17s
#       Starting batch 70 / 72, blocks 552 - 560
#       Sending batch 70 to dask
#       Dask completed in 25.975 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 70 completed in 26.144
#    Estimated time remaining for 2 batches: 00h00m51s
#       Starting batch 71 / 72, blocks 560 - 568
#       Sending batch 71 to dask
#       Dask completed in 25.043 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 71 completed in 25.209
#    Estimated time remaining for 1 batches: 00h00m25s
#       Starting batch 72 / 72, blocks 568 - 576
#       Sending batch 72 to dask
#       Dask completed in 24.984 sec
#       Saving svd_info to /mnt/md0/runs/s3d-Full-Demo-GPU/svd_cropped/svd_info.npy
#    Batch 72 completed in 25.205
#    Estimated time remaining for 0 batches: 00h00m00s

# %% [markdown]
# ## Calculating the correlation map
#
# The correlation map is the most important part of the cell detection process. It spatially and temporally filters the denoised movie, normalizes it, thresholds it, and accumulates it over time to create a volume where cells should be made more visible and neuropil is removed.
#
# **You should tune some of these parameters for your data**, each described below. To enable easy tuning, there is an **parameter sweep interface** that can try many combinations for a subset of the movie quickly, and visualize the results (you will find this below).
#
# Correlation map improves the more frames you have!

# %%
# number of SVD components to use when calculating the correlation map
# lower number means more denoising, but if it's too low you will start losing cells!
# This can't be larger than the number of svd components you used in the decomposition above
job.params['n_svd_comp'] = 50

# spatial filter sizes for neuropil subtraction, and cell detection
# npil_filt is a low_pass filter that attempts to remove any features larger than the filter size (neuropil!)
# conv_filt_xy is a high_pass filter that amplifies any features that are smaller than ~2x the filter size (cells!)
# these values worked well for me with ~4um xy pixel spacing and ~15 um z pixel spacing, for detecting mouse somata
# When you change resolution, or if you're trying to detect smaller things, you will need to adjust these values
# because the units here are _pixels_, not microns!
job.params['conv_filt_type'] = 'gaussian'
job.params['conv_filt_xy'] = 1.0
job.params['conv_filt_z'] = 1.0
job.params['npil_filt_type'] = 'unif'
job.params['npil_filt_xy'] = 5.0
job.params['npil_filt_z']=  1.5

# normalization exponent, should be around 1. 
# If you find blood vessels or the background being too bright in the correlation map, reduce it to ~0.7-0.8! 
job.params['sdnorm_exp']= 0.8

# threshold applied to the normalized, filtered movie before it is accumulated into the correlation map
# if you increase it, the background will become darker (which is good!), however at some point you will
# start excluding dimmer cells (which is bad!)
job.params['intensity_thresh'] : 0.2

## Compute parameters 
# number of frames to compute at one iteration 
# (any value above ~100-200 shouldn't affect results, 
# decrease if you have RAM issues or if Dask reconstruction gets stuck)
job.params['t_batch_size'] = 300
# number of processors to use when calculating the correlation map
job.params['n_proc_corr'] = 70
# number of frames per smaller batch within the batch, should be ~t_batch_size / n_proc_corr, but above ~5
job.params['mproc_batchsize'] = 5

# %%
# use this line to load svd_info for and svd you did earlier
# svd_info = n.load(os.path.join(job.dirs['svd_cropped'], 'svd_info.npy'), allow_pickle=True).item()
(vmap, mean_img, max_img), __, __ = job.calculate_corr_map(mov = svd_info)
# Out:
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/mov_sub with tag mov_sub
#    Saving mov_sub to /mnt/md0/runs/s3d-Full-Demo-GPU/mov_sub
#    Using conv_filt: gaussian, 1.00, 1.00
#    Using np_filt: unif, 1.50, 5.00
#    Will reconstruct SVD movie on-the-fly from  with 50 components
#    Created files and dirs for 1 batches
#       Running batch 1 of 1
#          Will process 300 frames (0-300, t_batch_size: 300)
#          Reconstructing from svd (re-loading spatial components each iteration)
# Sending all blocks to dask to compute
# Dask reconstruction complete
#          Reconstructed (300, 18, 1000, 850) mov in 191.60 seconds
#       Loaded and swapped, idx 0 to 300
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#    Calculated corr map in 147.50 seconds
#       Saving to /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000

# %% [markdown]
# ### Optional: sweep correlation map parameters

# %%
# load a snippet of the movie to sweep parameters over
from suite3d import svd_utils as svu
movx = svu.reconstruct_overlapping_movie(svd_info, t_indices = (0, 100),n_comps=50)

# NOTE: if you want to also sweep over the n_svd_comp param, you need to compute the correlation map from the svd
# to do that, just set mov = svd_info instead of movx
# note, this means it will reconstruct the movie from svd for each iteration of the sweep, which might be slow
# Out:
# Sending all blocks to dask to compute
# Dask reconstruction complete

# %%
# Pick the parameters you want to sweep, and enter them in the tuples.
# It will do all combinations of parameters, so if you have many parameters it will be many combinations! 

params_to_sweep = {
    'intensity_thresh' : (0.25,),
    'n_svd_comp' : (50,), # if you have multiple values here, make sure you pass mov=svd_info
    'conv_filt_xy': (1.0,),
    'npil_filt_xy': (3.0, 5.0, 10.0, 15.0),
    'conv_filt_z' : (1.0,),
    'npil_filt_z' : (1.5,),
    'sdnorm_exp' : (0.75,)
}

sweep_summary = job.sweep_params(params_to_sweep, mov = movx,testing_dir_tag='sweep-full',
                           do_vmap=True, all_combinations=True, n_test_iters = 1)
# use this to access older sweep results
# sweep_summary = n.load(os.path.join(job.dirs['sweep-full'], 'sweep_summary.npy'),allow_pickle=True).item()
# Out:
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full with tag sweep-full
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000 with tag sweep-full-comb_00000
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001 with tag sweep-full-comb_00001
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002 with tag sweep-full-comb_00002
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003 with tag sweep-full-comb_00003
#    Saving summary for 4 combinations to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep_summary.npy
# Running combination 01/04Total Used: 108.043 GB, Virtual Available: 410.767 GB, Virtual Used: 092.429 GB, Swap Used: 015.615 GB
#    Summary dict size: 00 GB
#       Combination params: comb00000-params-intensity_thresh_0.250-n_svd_comp_50.000-conv_filt_xy_1.000-npil_filt_xy_3.000-conv_filt_z_1.000-npil_filt_z_1.500-sdnorm_exp_0.750
#       Saving to tag sweep-full-comb_00000 at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000/iters with tag sweep-full-comb_00000-iters
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000/mov_sub with tag sweep-full-comb_00000-mov_sub
#    Saving mov_sub to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000/mov_sub
#    Using conv_filt: gaussian, 1.00, 1.00
#    Using np_filt: unif, 1.50, 3.00
#    Shape is unexpected ((100, 18, 1000, 850)). Modifying such that nt: 100 and nz: 18
#    Created files and dirs for 1 batches
#    Running only 1 iters
#       Running batch 1 of 1
#          Will process 100 frames (0-100, t_batch_size: 300)
#          Not a dask array
#       Loaded and swapped, idx 0 to 100
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#    Calculated corr map in 38.70 seconds
#       Saving to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000/iters/batch0000
#    Removing mov_sub from /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00000/mov_sub
# Running combination 02/04Total Used: 108.241 GB, Virtual Available: 410.570 GB, Virtual Used: 092.626 GB, Swap Used: 015.615 GB
#    Summary dict size: 00 GB
#       Combination params: comb00001-params-intensity_thresh_0.250-n_svd_comp_50.000-conv_filt_xy_1.000-npil_filt_xy_5.000-conv_filt_z_1.000-npil_filt_z_1.500-sdnorm_exp_0.750
#       Saving to tag sweep-full-comb_00001 at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001/iters with tag sweep-full-comb_00001-iters
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001/mov_sub with tag sweep-full-comb_00001-mov_sub
#    Saving mov_sub to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001/mov_sub
#    Using conv_filt: gaussian, 1.00, 1.00
#    Using np_filt: unif, 1.50, 5.00
#    Shape is unexpected ((100, 18, 1000, 850)). Modifying such that nt: 100 and nz: 18
#    Created files and dirs for 1 batches
#    Running only 1 iters
#       Running batch 1 of 1
#          Will process 100 frames (0-100, t_batch_size: 300)
#          Not a dask array
#       Loaded and swapped, idx 0 to 100
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#    Calculated corr map in 38.77 seconds
#       Saving to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001/iters/batch0000
#    Removing mov_sub from /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00001/mov_sub
# Running combination 03/04Total Used: 108.351 GB, Virtual Available: 410.460 GB, Virtual Used: 092.736 GB, Swap Used: 015.615 GB
#    Summary dict size: 00 GB
#       Combination params: comb00002-params-intensity_thresh_0.250-n_svd_comp_50.000-conv_filt_xy_1.000-npil_filt_xy_10.000-conv_filt_z_1.000-npil_filt_z_1.500-sdnorm_exp_0.750
#       Saving to tag sweep-full-comb_00002 at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002/iters with tag sweep-full-comb_00002-iters
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002/mov_sub with tag sweep-full-comb_00002-mov_sub
#    Saving mov_sub to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002/mov_sub
#    Using conv_filt: gaussian, 1.00, 1.00
#    Using np_filt: unif, 1.50, 10.00
#    Shape is unexpected ((100, 18, 1000, 850)). Modifying such that nt: 100 and nz: 18
#    Created files and dirs for 1 batches
#    Running only 1 iters
#       Running batch 1 of 1
#          Will process 100 frames (0-100, t_batch_size: 300)
#          Not a dask array
#       Loaded and swapped, idx 0 to 100
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#    Calculated corr map in 39.09 seconds
#       Saving to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002/iters/batch0000
#    Removing mov_sub from /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00002/mov_sub
# Running combination 04/04Total Used: 108.469 GB, Virtual Available: 410.342 GB, Virtual Used: 092.854 GB, Swap Used: 015.615 GB
#    Summary dict size: 00 GB
#       Combination params: comb00003-params-intensity_thresh_0.250-n_svd_comp_50.000-conv_filt_xy_1.000-npil_filt_xy_15.000-conv_filt_z_1.000-npil_filt_z_1.500-sdnorm_exp_0.750
#       Saving to tag sweep-full-comb_00003 at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003/iters with tag sweep-full-comb_00003-iters
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003/mov_sub with tag sweep-full-comb_00003-mov_sub
#    Saving mov_sub to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003/mov_sub
#    Using conv_filt: gaussian, 1.00, 1.00
#    Using np_filt: unif, 1.50, 15.00
#    Shape is unexpected ((100, 18, 1000, 850)). Modifying such that nt: 100 and nz: 18
#    Created files and dirs for 1 batches
#    Running only 1 iters
#       Running batch 1 of 1
#          Will process 100 frames (0-100, t_batch_size: 300)
#          Not a dask array
#       Loaded and swapped, idx 0 to 100
#       Calculating corr map
#          Rolling mean filter
#          Stdev over time
#          Sharr creation
#          Sub and conv
#          Vmap
#    Calculated corr map in 39.02 seconds
#       Saving to /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003/iters/batch0000
#    Removing mov_sub from /mnt/md0/runs/s3d-Full-Demo-GPU/sweep-full/sweep-full-comb_00003/mov_sub

# %%
v = job.vis_vmap_sweep(sweep_summary)
# Out:
# [1, 1, 1, 4, 1, 1, 1]
# (1, 1, 1, 4, 1, 1, 1, 18, 1000, 850)

# %% [markdown]
# ## Detection
# Now that we have a correlation map, we can segment the cells. The algorithm is similar to suite2p, it does the following:
# 1. Choose the peak value on the correlation map, and set this pixel as your _seed cell_
# 2. Identify the _active frames_ of the candidate cell by taking all frames where the activity of the cell is greater than a threshold (`activity_thresh`) or have activity above a certain percentile (`percentile`)
# 3. Look at the activity of all neighboring pixels of the _seed cell_ during the _active frames_ of the seed cell. If a candidate pixel's activity is similar to the activity of the _seed cell_ (similarity above `extend_thresh`), include the pixel in the _seed cell_.
# 4. Repeat steps 2-3 until you've grown the cell as much as you can
# 5. Remove the cell from the correlation map
# 6. Find the next largest peak of the correlation map, take this as your seed cell and repeat steps 2-6
# 7. Stop when the peak value of the remaining correlation map is below a user-specified threhsold (`peak_thresh`)
# Two main improvements over Suite2p: first, this is done in 3D. Second, it is parallelized to be much faster, as it works on patches of the movie separately!
#
# **The most important variable that you *must* set is `peak_thresh`**. To do this, use the cell below to visualize the correlation map (`vmap` for short) using napari. Use the contrast sliders to find a minimum value where all spots above this value look like they might be cells. I find it useful to set the range to be very small, all pixels above the minimum are basically white. You should try to get rid of most of the obvious noise (e.g. artifacts at edges or around blood vessels, specks of single-pixel white spots, stuff outside the brain). It is not critical to exclude everything, you can be generous here and remove ROIs based on other criteria later. However, if you are too generous, you'll end up with too many pixels above the threhsold and your detection will take forever, with a lot of extra junk cells. I recommend starting a little conservative, and then push the limits.
#
# **Other useful variables**: When you have long enough recordings, 0.2 for `extend_thresh` is OK. However, if you have only a very short recording, or you find many cells that are much larger than they should be (with large, sprinkly footprints that extend way beyond the cell), or you have large cloudy blobs of noise being picked up as cells, increase `extend_thresh`. `activity_thresh` and `percentile` work together, usually it's good enough to just pick one and change it. If you have few frames, or you feel like you have low signal, it's better to set these to be lower, so you include more frames when evaluating a cell. However, if you can afford to, it's good to keep them high (`activity_thresh` around 10, `percentile` around 99.0), because then sparsely-firing cells will be picked up easier. Play around and see!
#
# **To make it faster to try parameters, you can run the detection only on a subset of the patches**. By default the movie is split into ~100 patches (I think), but if you pass `job.patch_and_detect(do_patch_idxs=(10,20,50,80))` then the detection will only run on the specified patches.
#
# **Detection always works better with more frames!** 300 frames is a very small number, so don't expect it to work perfectly on this demo.

# %%
# visualize the correlation map
# here you can identify the best "peak_thresh"
# play with the contrast limits of vmap until only cells are visible
# the lower contrast limit should be used as "peak_thresh"
v = napari.view_image(vmap)
v.add_image(mean_img)
# Out:
# <Image layer 'mean_img' at 0x7fbb4426f910>

# %%
# %%time
job.params['detection_timebin'] = 1 
job.params['detection_time_crop'] = (None,None)
job.params['max_pix'] = 250
job.params['peak_thresh'] = 2.75

job.params['activity_thresh'] = 1.0
job.params['extend_thresh'] = 0.3
job.params['max_iter'] = 10000 # maximum number of ROIs detected in given patch
combined_dir = job.patch_and_detect(combined_name='combined-full') #, do_patch_idxs=(20,30,50,60,80,90))
# Out:
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
# 99 blocks with overlap (72 without, 1.38x increase)
# 99 blocks with overlap (72 without, 1.38x increase)
#    Detecting from patch: 0/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0000 with tag patch-0000
#    Running cell detection on patch 0000 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0000, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [  0 120]
#    Cell center bounds are [ 0 18], [  0 104], [  0 105]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0000
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 01 ROIs in parallel
#       Added cell 1 at 00, 034, 056, peak: 2.788, thresh: 1.000, 62 frames, 10 pixels
#       Iter 0001: peak is too small  - ending extraction
#    Found 1 cells in 1 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0000/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0000/iscell.npy
#    Detecting from patch: 1/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0001 with tag patch-0001
#    Running cell detection on patch 0001 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0001, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [ 91 211]
#    Cell center bounds are [ 0 18], [  0 104], [105 196]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0001
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 04 ROIs in parallel
#       Added cell 1 at 09, 100, 167, peak: 2.905, thresh: 1.000, 53 frames, 14 pixels
#       Added cell 2 at 05, 038, 184, peak: 2.847, thresh: 1.000, 46 frames, 12 pixels
#       Added cell 3 at 07, 090, 193, peak: 2.825, thresh: 1.000, 57 frames, 15 pixels
#       Added cell 4 at 07, 098, 186, peak: 2.773, thresh: 1.000, 70 frames, 14 pixels
#       Iter 0001: peak is too small  - ending extraction
#    Found 4 cells in 1 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0001/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0001/iscell.npy
#    Detecting from patch: 2/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0002 with tag patch-0002
#    Running cell detection on patch 0002 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0002, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [182 302]
#    Cell center bounds are [ 0 18], [  0 104], [196 287]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0002
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 08 ROIs in parallel
#       Added cell 1 at 15, 096, 232, peak: 3.992, thresh: 1.000, 119 frames, 25 pixels
#       Added cell 2 at 16, 008, 278, peak: 3.081, thresh: 1.000, 57 frames, 11 pixels
#       Added cell 3 at 00, 073, 214, peak: 3.042, thresh: 1.000, 76 frames, 11 pixels
#       Added cell 4 at 08, 088, 211, peak: 3.023, thresh: 1.000, 54 frames, 19 pixels
#       Added cell 5 at 08, 090, 264, peak: 3.001, thresh: 1.000, 59 frames, 13 pixels
#       Added cell 6 at 05, 056, 284, peak: 2.962, thresh: 1.000, 66 frames, 15 pixels
#       Added cell 7 at 00, 100, 277, peak: 2.940, thresh: 1.000, 82 frames, 14 pixels
#       Added cell 8 at 17, 097, 247, peak: 2.931, thresh: 1.000, 69 frames, 17 pixels
#    Iter 0001: running 08 ROIs in parallel
#       Added cell 9 at 00, 059, 263, peak: 2.922, thresh: 1.000, 86 frames, 6 pixels
#       Added cell 10 at 13, 103, 271, peak: 2.917, thresh: 1.000, 107 frames, 16 pixels
#       Added cell 11 at 17, 096, 231, peak: 2.916, thresh: 1.000, 74 frames, 7 pixels
#       Added cell 12 at 09, 103, 254, peak: 2.914, thresh: 1.000, 78 frames, 15 pixels
#       Added cell 13 at 11, 090, 199, peak: 2.909, thresh: 1.000, 57 frames, 5 pixels
#       Added cell 14 at 11, 096, 241, peak: 2.904, thresh: 1.000, 85 frames, 11 pixels
#       Added cell 15 at 09, 074, 233, peak: 2.878, thresh: 1.000, 68 frames, 12 pixels
#       Added cell 16 at 00, 083, 202, peak: 2.878, thresh: 1.000, 79 frames, 18 pixels
#    Iter 0002: running 08 ROIs in parallel
#       Added cell 17 at 07, 099, 232, peak: 2.866, thresh: 1.000, 79 frames, 9 pixels
#       Added cell 18 at 05, 103, 252, peak: 2.852, thresh: 1.000, 61 frames, 6 pixels
#       Added cell 19 at 06, 093, 284, peak: 2.846, thresh: 1.000, 68 frames, 13 pixels
#       Added cell 20 at 12, 096, 224, peak: 2.839, thresh: 1.000, 66 frames, 13 pixels
#       Added cell 21 at 09, 064, 261, peak: 2.829, thresh: 1.000, 62 frames, 15 pixels
#       Added cell 22 at 15, 087, 254, peak: 2.823, thresh: 1.000, 68 frames, 12 pixels
#       Added cell 23 at 00, 090, 280, peak: 2.821, thresh: 1.000, 85 frames, 6 pixels
#       Added cell 24 at 11, 040, 254, peak: 2.818, thresh: 1.000, 46 frames, 8 pixels
#    Iter 0003: running 08 ROIs in parallel
#       Added cell 25 at 09, 084, 224, peak: 2.815, thresh: 1.000, 59 frames, 14 pixels
#       Added cell 26 at 11, 102, 267, peak: 2.803, thresh: 1.000, 68 frames, 8 pixels
#       Added cell 27 at 08, 072, 282, peak: 2.799, thresh: 1.000, 72 frames, 17 pixels
#       Added cell 28 at 08, 103, 232, peak: 2.777, thresh: 1.000, 82 frames, 11 pixels
#       Added cell 29 at 01, 091, 285, peak: 2.775, thresh: 1.000, 89 frames, 13 pixels
#       Added cell 30 at 09, 090, 230, peak: 2.770, thresh: 1.000, 58 frames, 9 pixels
#       Added cell 31 at 00, 081, 206, peak: 2.767, thresh: 1.000, 72 frames, 6 pixels
#       Added cell 32 at 11, 083, 281, peak: 2.763, thresh: 1.000, 71 frames, 5 pixels
#    Iter 0004: running 08 ROIs in parallel
#       Added cell 33 at 07, 071, 278, peak: 2.774, thresh: 1.000, 73 frames, 10 pixels
#       Added cell 34 at 10, 061, 255, peak: 2.758, thresh: 1.000, 61 frames, 15 pixels
#       Added cell 35 at 11, 094, 253, peak: 2.755, thresh: 1.000, 69 frames, 11 pixels
#       Added cell 36 at 00, 089, 222, peak: 2.755, thresh: 1.000, 87 frames, 12 pixels
#       Added cell 37 at 00, 034, 259, peak: 2.755, thresh: 1.000, 66 frames, 12 pixels
#       Added cell 38 at 13, 078, 269, peak: 2.752, thresh: 1.000, 77 frames, 7 pixels
#       Added cell 39 at 15, 093, 254, peak: 2.752, thresh: 1.000, 90 frames, 6 pixels
#       Added cell 40 at 12, 091, 264, peak: 2.751, thresh: 1.000, 75 frames, 11 pixels
#       Iter 0005: peak is too small  - ending extraction
#    Found 40 cells in 5 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0002/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0002/iscell.npy
#    Detecting from patch: 3/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0003 with tag patch-0003
#    Running cell detection on patch 0003 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0003, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [273 393]
#    Cell center bounds are [ 0 18], [  0 104], [287 379]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0003
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 08 ROIs in parallel
#       Added cell 1 at 09, 090, 333, peak: 4.169, thresh: 1.000, 58 frames, 15 pixels
#       Added cell 2 at 09, 095, 331, peak: 3.827, thresh: 1.000, 82 frames, 16 pixels
#       Added cell 3 at 06, 088, 296, peak: 3.463, thresh: 1.000, 65 frames, 9 pixels
#       Added cell 4 at 08, 043, 324, peak: 3.241, thresh: 1.000, 78 frames, 11 pixels
#       Added cell 5 at 16, 019, 335, peak: 3.183, thresh: 1.000, 113 frames, 15 pixels
#       Added cell 6 at 02, 098, 311, peak: 3.157, thresh: 1.000, 82 frames, 17 pixels
#       Added cell 7 at 08, 064, 343, peak: 3.155, thresh: 1.000, 63 frames, 8 pixels
#       Added cell 8 at 17, 090, 291, peak: 3.120, thresh: 1.000, 75 frames, 13 pixels
#    Iter 0001: running 08 ROIs in parallel
#       Added cell 9 at 11, 026, 360, peak: 3.047, thresh: 1.000, 76 frames, 15 pixels
#       Added cell 10 at 00, 088, 303, peak: 2.991, thresh: 1.000, 71 frames, 11 pixels
#       Added cell 11 at 11, 070, 346, peak: 2.986, thresh: 1.000, 61 frames, 8 pixels
#       Added cell 12 at 04, 051, 291, peak: 2.984, thresh: 1.000, 82 frames, 17 pixels
#       Added cell 13 at 11, 075, 321, peak: 2.978, thresh: 1.000, 78 frames, 8 pixels
#       Added cell 14 at 09, 058, 289, peak: 2.963, thresh: 1.000, 67 frames, 17 pixels
#       Added cell 15 at 06, 100, 352, peak: 2.958, thresh: 1.000, 57 frames, 8 pixels
#       Added cell 16 at 08, 056, 321, peak: 2.958, thresh: 1.000, 69 frames, 7 pixels
#    Iter 0002: running 08 ROIs in parallel
#       Added cell 17 at 12, 098, 297, peak: 2.956, thresh: 1.000, 76 frames, 17 pixels
#       Added cell 18 at 00, 043, 353, peak: 2.950, thresh: 1.000, 76 frames, 10 pixels
#       Added cell 19 at 07, 094, 375, peak: 2.946, thresh: 1.000, 70 frames, 12 pixels
#       Added cell 20 at 01, 090, 352, peak: 2.945, thresh: 1.000, 92 frames, 12 pixels
#       Added cell 21 at 09, 098, 323, peak: 2.944, thresh: 1.000, 59 frames, 10 pixels
#       Added cell 22 at 10, 051, 288, peak: 2.937, thresh: 1.000, 90 frames, 41 pixels
#       Added cell 23 at 07, 071, 304, peak: 2.916, thresh: 1.000, 69 frames, 12 pixels
#       Added cell 24 at 06, 047, 325, peak: 2.904, thresh: 1.000, 72 frames, 9 pixels
#    Iter 0003: running 08 ROIs in parallel
#       Added cell 25 at 00, 063, 308, peak: 2.902, thresh: 1.000, 82 frames, 16 pixels
#       Added cell 26 at 04, 064, 332, peak: 2.894, thresh: 1.000, 83 frames, 14 pixels
#       Added cell 27 at 00, 090, 300, peak: 2.890, thresh: 1.000, 91 frames, 6 pixels
#       Added cell 28 at 10, 065, 310, peak: 2.888, thresh: 1.000, 62 frames, 9 pixels
#       Added cell 29 at 11, 087, 325, peak: 2.884, thresh: 1.000, 57 frames, 11 pixels
#       Added cell 30 at 00, 080, 327, peak: 2.877, thresh: 1.000, 77 frames, 8 pixels
#       Added cell 31 at 00, 034, 370, peak: 2.870, thresh: 1.000, 82 frames, 8 pixels
#       Added cell 32 at 07, 090, 359, peak: 2.866, thresh: 1.000, 87 frames, 17 pixels
#    Iter 0004: running 08 ROIs in parallel
#       Added cell 33 at 09, 053, 333, peak: 2.865, thresh: 1.000, 69 frames, 7 pixels
#       Added cell 34 at 10, 098, 298, peak: 2.864, thresh: 1.000, 70 frames, 8 pixels
#       Added cell 35 at 04, 061, 327, peak: 2.861, thresh: 1.000, 70 frames, 11 pixels
#       Added cell 36 at 05, 077, 350, peak: 2.860, thresh: 1.000, 72 frames, 10 pixels
#       Added cell 37 at 11, 064, 342, peak: 2.858, thresh: 1.000, 76 frames, 8 pixels
#       Added cell 38 at 04, 079, 329, peak: 2.857, thresh: 1.000, 82 frames, 12 pixels
#       Added cell 39 at 10, 071, 331, peak: 2.853, thresh: 1.000, 69 frames, 15 pixels
#       Added cell 40 at 09, 100, 348, peak: 2.848, thresh: 1.000, 64 frames, 7 pixels
#    Iter 0005: running 08 ROIs in parallel
#       Added cell 41 at 15, 025, 362, peak: 2.847, thresh: 1.000, 110 frames, 13 pixels
#       Added cell 42 at 17, 071, 319, peak: 2.844, thresh: 1.000, 70 frames, 9 pixels
#       Added cell 43 at 08, 097, 297, peak: 2.842, thresh: 1.000, 70 frames, 10 pixels
#       Added cell 44 at 11, 051, 297, peak: 2.837, thresh: 1.000, 74 frames, 12 pixels
#       Added cell 45 at 03, 094, 347, peak: 2.836, thresh: 1.000, 99 frames, 21 pixels
#       Added cell 46 at 05, 046, 307, peak: 2.830, thresh: 1.000, 75 frames, 5 pixels
#       Added cell 47 at 00, 093, 325, peak: 2.830, thresh: 1.000, 86 frames, 12 pixels
#       Added cell 48 at 10, 048, 334, peak: 2.828, thresh: 1.000, 82 frames, 7 pixels
#    Iter 0006: running 08 ROIs in parallel
#       Added cell 49 at 00, 100, 290, peak: 2.826, thresh: 1.000, 92 frames, 15 pixels
#       Added cell 50 at 09, 094, 350, peak: 2.826, thresh: 1.000, 74 frames, 5 pixels
#       Added cell 51 at 01, 029, 319, peak: 2.825, thresh: 1.000, 96 frames, 12 pixels
#       Added cell 52 at 09, 050, 356, peak: 2.825, thresh: 1.000, 64 frames, 9 pixels
#       Added cell 53 at 02, 043, 308, peak: 2.824, thresh: 1.000, 87 frames, 6 pixels
#       Added cell 54 at 02, 060, 327, peak: 2.820, thresh: 1.000, 71 frames, 6 pixels
#       Added cell 55 at 11, 071, 374, peak: 2.820, thresh: 1.000, 72 frames, 8 pixels
#       Added cell 56 at 09, 097, 334, peak: 2.817, thresh: 1.000, 68 frames, 10 pixels
#    Iter 0007: running 08 ROIs in parallel
#       Added cell 57 at 01, 062, 349, peak: 2.815, thresh: 1.000, 85 frames, 13 pixels
#       Added cell 58 at 03, 018, 332, peak: 2.814, thresh: 1.000, 83 frames, 15 pixels
#       Added cell 59 at 09, 072, 290, peak: 2.812, thresh: 1.000, 75 frames, 9 pixels
#       Added cell 60 at 08, 080, 295, peak: 2.811, thresh: 1.000, 68 frames, 19 pixels
#       Added cell 61 at 12, 067, 342, peak: 2.809, thresh: 1.000, 74 frames, 11 pixels
#       Added cell 62 at 11, 055, 332, peak: 2.805, thresh: 1.000, 61 frames, 17 pixels
#       Added cell 63 at 04, 092, 364, peak: 2.804, thresh: 1.000, 67 frames, 9 pixels
#       Added cell 64 at 05, 061, 321, peak: 2.801, thresh: 1.000, 76 frames, 12 pixels
#    Iter 0008: running 08 ROIs in parallel
#       Added cell 65 at 00, 095, 304, peak: 2.801, thresh: 1.000, 80 frames, 8 pixels
#       Added cell 66 at 08, 085, 313, peak: 2.793, thresh: 1.000, 66 frames, 15 pixels
#       Added cell 67 at 07, 027, 348, peak: 2.793, thresh: 1.000, 61 frames, 16 pixels
#       Added cell 68 at 02, 085, 359, peak: 2.793, thresh: 1.000, 88 frames, 11 pixels
#       Added cell 69 at 00, 051, 311, peak: 2.792, thresh: 1.000, 74 frames, 10 pixels
#       Added cell 70 at 10, 060, 350, peak: 2.791, thresh: 1.000, 90 frames, 17 pixels
#       Added cell 71 at 11, 092, 339, peak: 2.790, thresh: 1.000, 91 frames, 11 pixels
#       Added cell 72 at 09, 078, 347, peak: 2.790, thresh: 1.000, 88 frames, 7 pixels
#    Iter 0009: running 08 ROIs in parallel
#       Added cell 73 at 03, 052, 345, peak: 2.789, thresh: 1.000, 86 frames, 7 pixels
#       Added cell 74 at 15, 071, 356, peak: 2.788, thresh: 1.000, 60 frames, 9 pixels
#       Added cell 75 at 00, 021, 315, peak: 2.787, thresh: 1.000, 65 frames, 12 pixels
#       Added cell 76 at 10, 049, 302, peak: 2.787, thresh: 1.000, 61 frames, 11 pixels
#       Added cell 77 at 08, 100, 310, peak: 2.786, thresh: 1.000, 70 frames, 10 pixels
#       Added cell 78 at 08, 040, 328, peak: 2.781, thresh: 1.000, 70 frames, 9 pixels
#       Added cell 79 at 05, 056, 329, peak: 2.780, thresh: 1.000, 76 frames, 6 pixels
#       Added cell 80 at 08, 079, 346, peak: 2.779, thresh: 1.000, 83 frames, 11 pixels
#    Iter 0010: running 08 ROIs in parallel
#       Added cell 81 at 00, 026, 355, peak: 2.777, thresh: 1.000, 93 frames, 17 pixels
#       Added cell 82 at 03, 078, 336, peak: 2.775, thresh: 1.000, 101 frames, 8 pixels
#       Added cell 83 at 04, 053, 354, peak: 2.774, thresh: 1.000, 70 frames, 15 pixels
#       Added cell 84 at 11, 036, 340, peak: 2.773, thresh: 1.000, 71 frames, 12 pixels
#       Added cell 85 at 00, 042, 340, peak: 2.773, thresh: 1.000, 88 frames, 11 pixels
#       Added cell 86 at 04, 101, 353, peak: 2.772, thresh: 1.000, 89 frames, 18 pixels
#       Added cell 87 at 09, 037, 364, peak: 2.771, thresh: 1.000, 63 frames, 22 pixels
#       Added cell 88 at 00, 097, 329, peak: 2.770, thresh: 1.000, 82 frames, 5 pixels
#    Iter 0011: running 08 ROIs in parallel
#       Added cell 89 at 05, 079, 305, peak: 2.769, thresh: 1.000, 72 frames, 11 pixels
#       Added cell 90 at 09, 070, 287, peak: 2.768, thresh: 1.000, 70 frames, 10 pixels
#       Added cell 91 at 07, 092, 360, peak: 2.768, thresh: 1.000, 66 frames, 10 pixels
#       Added cell 92 at 04, 100, 339, peak: 2.768, thresh: 1.000, 89 frames, 12 pixels
#       Added cell 93 at 00, 098, 369, peak: 2.767, thresh: 1.000, 90 frames, 13 pixels
#       Added cell 94 at 07, 061, 300, peak: 2.767, thresh: 1.000, 60 frames, 5 pixels
#       Added cell 95 at 10, 068, 308, peak: 2.767, thresh: 1.000, 63 frames, 6 pixels
#       Added cell 96 at 10, 078, 310, peak: 2.765, thresh: 1.000, 80 frames, 18 pixels
#    Iter 0012: running 08 ROIs in parallel
#       Added cell 97 at 00, 046, 328, peak: 2.763, thresh: 1.000, 74 frames, 12 pixels
#       Added cell 98 at 12, 097, 347, peak: 2.762, thresh: 1.000, 73 frames, 8 pixels
#       Added cell 99 at 07, 036, 295, peak: 2.761, thresh: 1.000, 65 frames, 11 pixels
#       Added cell 100 at 11, 076, 347, peak: 2.757, thresh: 1.000, 70 frames, 12 pixels
#       Added cell 101 at 07, 094, 303, peak: 2.756, thresh: 1.000, 80 frames, 8 pixels
#       Added cell 102 at 08, 053, 320, peak: 2.754, thresh: 1.000, 70 frames, 9 pixels
#       Added cell 103 at 07, 091, 331, peak: 2.754, thresh: 1.000, 71 frames, 6 pixels
#       Added cell 104 at 08, 071, 339, peak: 2.753, thresh: 1.000, 65 frames, 10 pixels
#    Iter 0013: running 05 ROIs in parallel
#       Added cell 105 at 12, 072, 287, peak: 2.753, thresh: 1.000, 63 frames, 9 pixels
#       Added cell 106 at 00, 081, 322, peak: 2.752, thresh: 1.000, 85 frames, 7 pixels
#       Added cell 107 at 06, 050, 307, peak: 2.751, thresh: 1.000, 69 frames, 10 pixels
#       Added cell 108 at 00, 054, 350, peak: 2.750, thresh: 1.000, 82 frames, 10 pixels
#       Added cell 109 at 02, 100, 354, peak: 2.750, thresh: 1.000, 89 frames, 10 pixels
#       Iter 0014: peak is too small  - ending extraction
#    Found 109 cells in 14 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0003/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0003/iscell.npy
#    Detecting from patch: 4/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0004 with tag patch-0004
#    Running cell detection on patch 0004 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0004, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [365 485]
#    Cell center bounds are [ 0 18], [  0 104], [379 470]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0004
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 04 ROIs in parallel
#       Added cell 1 at 04, 092, 382, peak: 2.834, thresh: 1.000, 67 frames, 13 pixels
#       Added cell 2 at 00, 082, 379, peak: 2.811, thresh: 1.000, 82 frames, 9 pixels
#       Added cell 3 at 13, 044, 393, peak: 2.801, thresh: 1.000, 67 frames, 12 pixels
#       Added cell 4 at 00, 091, 385, peak: 2.800, thresh: 1.000, 85 frames, 12 pixels
#       Iter 0001: peak is too small  - ending extraction
#    Found 4 cells in 1 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0004/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0004/iscell.npy
#    Detecting from patch: 5/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0005 with tag patch-0005
#    Running cell detection on patch 0005 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0005, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [456 576]
#    Cell center bounds are [ 0 18], [  0 104], [470 561]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0005
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#       Iter 0000: peak is too small  - ending extraction
#    Found 0 cells in 0 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0005/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0005/iscell.npy
#    Detecting from patch: 6/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0006 with tag patch-0006
#    Running cell detection on patch 0006 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0006, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [547 667]
#    Cell center bounds are [ 0 18], [  0 104], [561 652]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0006
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#       Iter 0000: peak is too small  - ending extraction
#    Found 0 cells in 0 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0006/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0006/iscell.npy
#    Detecting from patch: 7/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0007 with tag patch-0007
#    Running cell detection on patch 0007 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0007, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [638 758]
#    Cell center bounds are [ 0 18], [  0 104], [652 744]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0007
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#       Iter 0000: peak is too small  - ending extraction
#    Found 0 cells in 0 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0007/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0007/iscell.npy
#    Detecting from patch: 8/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0008 with tag patch-0008
#    Running cell detection on patch 0008 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0008, max 10000 iters
#    Patch bounds are [ 0 18], [  0 120], [730 850]
#    Cell center bounds are [ 0 18], [  0 104], [744 850]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0008
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#       Iter 0000: peak is too small  - ending extraction
#    Found 0 cells in 0 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0008/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0008/iscell.npy
#    Detecting from patch: 9/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0009 with tag patch-0009
#    Running cell detection on patch 0009 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0009, max 10000 iters
#    Patch bounds are [ 0 18], [ 88 208], [  0 120]
#    Cell center bounds are [ 0 18], [104 192], [  0 105]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0009
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#       Iter 0000: peak is too small  - ending extraction
#    Found 0 cells in 0 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0009/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0009/iscell.npy
#    Detecting from patch: 10/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0010 with tag patch-0010
#    Running cell detection on patch 0010 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0010, max 10000 iters
#    Patch bounds are [ 0 18], [ 88 208], [ 91 211]
#    Cell center bounds are [ 0 18], [104 192], [105 196]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0010
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 08 ROIs in parallel
#       Added cell 1 at 00, 127, 152, peak: 3.206, thresh: 1.000, 66 frames, 8 pixels
#       Added cell 2 at 07, 131, 152, peak: 3.138, thresh: 1.000, 54 frames, 12 pixels
#       Added cell 3 at 06, 135, 165, peak: 3.074, thresh: 1.000, 45 frames, 10 pixels
#       Added cell 4 at 10, 191, 165, peak: 2.966, thresh: 1.000, 75 frames, 10 pixels
#       Added cell 5 at 07, 190, 191, peak: 2.961, thresh: 1.000, 80 frames, 14 pixels
#       Added cell 6 at 08, 129, 163, peak: 2.943, thresh: 1.000, 62 frames, 8 pixels
#       Added cell 7 at 07, 173, 171, peak: 2.938, thresh: 1.000, 54 frames, 9 pixels
#       Added cell 8 at 00, 157, 168, peak: 2.934, thresh: 1.000, 62 frames, 8 pixels
#    Iter 0001: running 08 ROIs in parallel
#       Added cell 9 at 02, 166, 162, peak: 2.927, thresh: 1.000, 57 frames, 10 pixels
#       Added cell 10 at 02, 147, 165, peak: 2.923, thresh: 1.000, 67 frames, 11 pixels
#       Added cell 11 at 11, 115, 189, peak: 2.923, thresh: 1.000, 54 frames, 12 pixels
#       Added cell 12 at 00, 119, 180, peak: 2.920, thresh: 1.000, 82 frames, 6 pixels
#       Added cell 13 at 08, 127, 181, peak: 2.875, thresh: 1.000, 65 frames, 10 pixels
#       Added cell 14 at 06, 128, 149, peak: 2.872, thresh: 1.000, 47 frames, 10 pixels
#       Added cell 15 at 00, 139, 172, peak: 2.857, thresh: 1.000, 67 frames, 9 pixels
#       Added cell 16 at 00, 172, 138, peak: 2.849, thresh: 1.000, 61 frames, 8 pixels
#    Iter 0002: running 08 ROIs in parallel
#       Added cell 17 at 15, 182, 154, peak: 2.829, thresh: 1.000, 45 frames, 7 pixels
#       Added cell 18 at 07, 179, 153, peak: 2.826, thresh: 1.000, 55 frames, 10 pixels
#       Added cell 19 at 02, 135, 185, peak: 2.817, thresh: 1.000, 73 frames, 9 pixels
#       Added cell 20 at 08, 130, 136, peak: 2.815, thresh: 1.000, 50 frames, 13 pixels
#       Added cell 21 at 07, 143, 121, peak: 2.800, thresh: 1.000, 30 frames, 6 pixels
#       Added cell 22 at 16, 172, 190, peak: 2.798, thresh: 1.000, 63 frames, 11 pixels
#       Added cell 23 at 07, 110, 163, peak: 2.796, thresh: 1.000, 51 frames, 16 pixels
#       Added cell 24 at 12, 120, 192, peak: 2.790, thresh: 1.000, 59 frames, 9 pixels
#    Iter 0003: running 04 ROIs in parallel
#       Added cell 25 at 03, 191, 121, peak: 2.779, thresh: 1.000, 57 frames, 8 pixels
#       Added cell 26 at 15, 190, 168, peak: 2.758, thresh: 1.000, 69 frames, 20 pixels
#       Added cell 27 at 05, 179, 124, peak: 2.757, thresh: 1.000, 68 frames, 13 pixels
#       Added cell 28 at 02, 129, 188, peak: 2.757, thresh: 1.000, 53 frames, 9 pixels
#       Iter 0004: peak is too small  - ending extraction
#    Found 28 cells in 4 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0010/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0010/iscell.npy
#    Detecting from patch: 11/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0011 with tag patch-0011
#    Running cell detection on patch 0011 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0011, max 10000 iters
#    Patch bounds are [ 0 18], [ 88 208], [182 302]
#    Cell center bounds are [ 0 18], [104 192], [196 287]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0011
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 08 ROIs in parallel
#       Added cell 1 at 01, 130, 255, peak: 5.144, thresh: 1.000, 120 frames, 44 pixels
#       Added cell 2 at 01, 138, 265, peak: 4.384, thresh: 1.000, 116 frames, 22 pixels
#       Added cell 3 at 00, 150, 263, peak: 4.351, thresh: 1.000, 120 frames, 18 pixels
#       Added cell 4 at 12, 158, 235, peak: 4.291, thresh: 1.000, 73 frames, 16 pixels
#       Added cell 5 at 00, 119, 265, peak: 4.206, thresh: 1.000, 98 frames, 13 pixels
#       Added cell 6 at 09, 189, 223, peak: 4.147, thresh: 1.000, 87 frames, 17 pixels
#       Added cell 7 at 02, 171, 271, peak: 4.119, thresh: 1.000, 135 frames, 25 pixels
#       Added cell 8 at 15, 130, 280, peak: 4.075, thresh: 1.000, 120 frames, 13 pixels
#    Iter 0001: running 08 ROIs in parallel
#       Added cell 9 at 12, 151, 230, peak: 3.936, thresh: 1.000, 76 frames, 18 pixels
#       Added cell 10 at 09, 163, 264, peak: 3.800, thresh: 1.000, 59 frames, 10 pixels
#       Added cell 11 at 13, 104, 270, peak: 3.597, thresh: 1.000, 102 frames, 16 pixels
#       Added cell 12 at 02, 117, 286, peak: 3.567, thresh: 1.000, 103 frames, 40 pixels
#       Added cell 13 at 07, 188, 269, peak: 3.560, thresh: 1.000, 88 frames, 11 pixels
#       Added cell 14 at 09, 104, 255, peak: 3.530, thresh: 1.000, 102 frames, 35 pixels
#       Added cell 15 at 05, 173, 281, peak: 3.491, thresh: 1.000, 101 frames, 23 pixels
#       Added cell 16 at 14, 173, 228, peak: 3.490, thresh: 1.000, 74 frames, 18 pixels
#    Iter 0002: running 08 ROIs in parallel
#       Added cell 17 at 09, 168, 275, peak: 3.458, thresh: 1.000, 71 frames, 9 pixels
#       Added cell 18 at 15, 120, 278, peak: 3.446, thresh: 1.000, 118 frames, 11 pixels
#       Added cell 19 at 08, 124, 256, peak: 3.441, thresh: 1.000, 98 frames, 21 pixels
#       Added cell 20 at 01, 137, 273, peak: 3.423, thresh: 1.000, 94 frames, 23 pixels
#       Added cell 21 at 12, 136, 235, peak: 3.421, thresh: 1.000, 89 frames, 27 pixels
#       Added cell 22 at 00, 139, 243, peak: 3.411, thresh: 1.000, 89 frames, 9 pixels
#       Added cell 23 at 07, 139, 260, peak: 3.376, thresh: 1.000, 71 frames, 12 pixels
#       Added cell 24 at 16, 184, 237, peak: 3.355, thresh: 1.000, 72 frames, 16 pixels
#    Iter 0003: running 08 ROIs in parallel
#       Added cell 25 at 11, 132, 263, peak: 3.354, thresh: 1.000, 51 frames, 12 pixels
#       Added cell 26 at 09, 161, 262, peak: 3.345, thresh: 1.000, 55 frames, 13 pixels
#       Added cell 27 at 08, 186, 246, peak: 3.338, thresh: 1.000, 90 frames, 19 pixels
#       Added cell 28 at 00, 164, 212, peak: 3.337, thresh: 1.000, 72 frames, 9 pixels
#       Added cell 29 at 05, 128, 245, peak: 3.299, thresh: 1.000, 67 frames, 19 pixels
#       Added cell 30 at 06, 139, 262, peak: 3.271, thresh: 1.000, 77 frames, 12 pixels
#       Added cell 31 at 12, 182, 239, peak: 3.257, thresh: 1.000, 94 frames, 19 pixels
#       Added cell 32 at 06, 183, 275, peak: 3.235, thresh: 1.000, 93 frames, 15 pixels
#    Iter 0004: running 08 ROIs in parallel
#       Added cell 33 at 10, 121, 254, peak: 3.227, thresh: 1.000, 74 frames, 26 pixels
#       Added cell 34 at 03, 131, 254, peak: 3.222, thresh: 1.000, 67 frames, 16 pixels
#       Added cell 35 at 03, 180, 200, peak: 3.159, thresh: 1.000, 87 frames, 5 pixels
#       Added cell 36 at 07, 190, 221, peak: 3.146, thresh: 1.000, 89 frames, 14 pixels
#       Added cell 37 at 06, 131, 214, peak: 3.080, thresh: 1.000, 50 frames, 21 pixels
#       Added cell 38 at 08, 172, 219, peak: 3.079, thresh: 1.000, 70 frames, 15 pixels
#       Added cell 39 at 07, 166, 257, peak: 3.072, thresh: 1.000, 54 frames, 7 pixels
#       Added cell 40 at 03, 141, 264, peak: 3.071, thresh: 1.000, 101 frames, 13 pixels
#    Iter 0005: running 08 ROIs in parallel
#       Added cell 41 at 07, 184, 229, peak: 3.065, thresh: 1.000, 71 frames, 14 pixels
#       Added cell 42 at 02, 164, 214, peak: 3.065, thresh: 1.000, 87 frames, 10 pixels
#       Added cell 43 at 09, 129, 256, peak: 3.064, thresh: 1.000, 50 frames, 9 pixels
#       Added cell 44 at 04, 156, 256, peak: 3.057, thresh: 1.000, 72 frames, 8 pixels
#       Added cell 45 at 01, 136, 249, peak: 3.039, thresh: 1.000, 75 frames, 9 pixels
#       Added cell 46 at 13, 108, 258, peak: 3.036, thresh: 1.000, 58 frames, 8 pixels
#       Added cell 47 at 03, 187, 225, peak: 3.018, thresh: 1.000, 94 frames, 10 pixels
#       Added cell 48 at 01, 132, 215, peak: 3.015, thresh: 1.000, 93 frames, 9 pixels
#    Iter 0006: running 08 ROIs in parallel
#       Added cell 49 at 09, 104, 252, peak: 3.011, thresh: 1.000, 67 frames, 10 pixels
#       Added cell 50 at 08, 163, 269, peak: 3.011, thresh: 1.000, 52 frames, 9 pixels
#       Added cell 51 at 08, 104, 232, peak: 3.004, thresh: 1.000, 95 frames, 7 pixels
#       Added cell 52 at 12, 109, 257, peak: 3.004, thresh: 1.000, 76 frames, 6 pixels
#       Added cell 53 at 15, 145, 286, peak: 2.997, thresh: 1.000, 100 frames, 13 pixels
#       Added cell 54 at 11, 186, 216, peak: 2.993, thresh: 1.000, 82 frames, 9 pixels
#       Added cell 55 at 02, 173, 283, peak: 2.984, thresh: 1.000, 89 frames, 14 pixels
#       Added cell 56 at 13, 186, 215, peak: 2.984, thresh: 1.000, 84 frames, 14 pixels
#    Iter 0007: running 08 ROIs in parallel
#       Added cell 57 at 08, 105, 236, peak: 2.980, thresh: 1.000, 74 frames, 15 pixels
#       Added cell 58 at 11, 127, 253, peak: 2.980, thresh: 1.000, 81 frames, 9 pixels
#       Added cell 59 at 10, 114, 266, peak: 2.973, thresh: 1.000, 78 frames, 21 pixels
#       Added cell 60 at 15, 109, 279, peak: 2.966, thresh: 1.000, 85 frames, 25 pixels
#       Added cell 61 at 02, 151, 264, peak: 2.966, thresh: 1.000, 64 frames, 10 pixels
#       Added cell 62 at 13, 138, 221, peak: 2.957, thresh: 1.000, 70 frames, 12 pixels
#       Added cell 63 at 09, 152, 230, peak: 2.957, thresh: 1.000, 84 frames, 8 pixels
#       Added cell 64 at 05, 163, 272, peak: 2.956, thresh: 1.000, 80 frames, 17 pixels
#    Iter 0008: running 08 ROIs in parallel
#       Added cell 65 at 12, 124, 263, peak: 2.950, thresh: 1.000, 102 frames, 14 pixels
#       Added cell 66 at 10, 153, 226, peak: 2.936, thresh: 1.000, 73 frames, 9 pixels
#       Added cell 67 at 07, 141, 236, peak: 2.935, thresh: 1.000, 64 frames, 6 pixels
#       Added cell 68 at 07, 161, 263, peak: 2.926, thresh: 1.000, 72 frames, 14 pixels
#       Added cell 69 at 00, 140, 202, peak: 2.925, thresh: 1.000, 81 frames, 4 pixels
#       Added cell 70 at 10, 114, 248, peak: 2.923, thresh: 1.000, 73 frames, 8 pixels
#       Added cell 71 at 01, 112, 220, peak: 2.921, thresh: 1.000, 71 frames, 11 pixels
#       Added cell 72 at 07, 185, 221, peak: 2.919, thresh: 1.000, 78 frames, 7 pixels
#    Iter 0009: running 08 ROIs in parallel
#       Added cell 73 at 17, 143, 263, peak: 2.915, thresh: 1.000, 62 frames, 8 pixels
#       Added cell 74 at 00, 145, 286, peak: 2.914, thresh: 1.000, 92 frames, 9 pixels
#       Added cell 75 at 01, 148, 207, peak: 2.910, thresh: 1.000, 94 frames, 12 pixels
#       Added cell 76 at 03, 153, 204, peak: 2.910, thresh: 1.000, 86 frames, 8 pixels
#       Added cell 77 at 00, 187, 262, peak: 2.908, thresh: 1.000, 67 frames, 6 pixels
#       Added cell 78 at 07, 179, 279, peak: 2.906, thresh: 1.000, 62 frames, 17 pixels
#       Added cell 79 at 13, 152, 235, peak: 2.901, thresh: 1.000, 66 frames, 16 pixels
#       Added cell 80 at 05, 187, 196, peak: 2.898, thresh: 1.000, 78 frames, 16 pixels
#    Iter 0010: running 08 ROIs in parallel
#       Added cell 81 at 00, 111, 217, peak: 2.898, thresh: 1.000, 65 frames, 7 pixels
#       Added cell 82 at 07, 178, 206, peak: 2.898, thresh: 1.000, 78 frames, 21 pixels
#       Added cell 83 at 09, 140, 266, peak: 2.897, thresh: 1.000, 64 frames, 8 pixels
#       Added cell 84 at 07, 181, 224, peak: 2.896, thresh: 1.000, 75 frames, 7 pixels
#       Added cell 85 at 04, 137, 264, peak: 2.894, thresh: 1.000, 72 frames, 15 pixels
#       Added cell 86 at 02, 120, 265, peak: 2.889, thresh: 1.000, 81 frames, 24 pixels
#       Added cell 87 at 03, 161, 252, peak: 2.889, thresh: 1.000, 72 frames, 8 pixels
#       Added cell 88 at 10, 104, 232, peak: 2.888, thresh: 1.000, 83 frames, 7 pixels
#    Iter 0011: running 08 ROIs in parallel
#       Added cell 89 at 03, 148, 244, peak: 2.888, thresh: 1.000, 88 frames, 8 pixels
#       Added cell 90 at 08, 122, 247, peak: 2.888, thresh: 1.000, 67 frames, 7 pixels
#       Added cell 91 at 11, 113, 242, peak: 2.884, thresh: 1.000, 84 frames, 13 pixels
#       Added cell 92 at 17, 172, 262, peak: 2.884, thresh: 1.000, 65 frames, 6 pixels
#       Added cell 93 at 00, 166, 214, peak: 2.880, thresh: 1.000, 66 frames, 5 pixels
#       Added cell 94 at 07, 156, 256, peak: 2.879, thresh: 1.000, 77 frames, 28 pixels
#       Added cell 95 at 17, 186, 265, peak: 2.877, thresh: 1.000, 81 frames, 16 pixels
#       Added cell 96 at 07, 182, 286, peak: 2.876, thresh: 1.000, 81 frames, 15 pixels
#    Iter 0012: running 08 ROIs in parallel
#       Added cell 97 at 12, 110, 245, peak: 2.876, thresh: 1.000, 76 frames, 12 pixels
#       Added cell 98 at 09, 107, 229, peak: 2.876, thresh: 1.000, 61 frames, 7 pixels
#       Added cell 99 at 06, 191, 209, peak: 2.875, thresh: 1.000, 73 frames, 19 pixels
#       Added cell 100 at 10, 170, 237, peak: 2.874, thresh: 1.000, 74 frames, 18 pixels
#       Added cell 101 at 15, 106, 281, peak: 2.873, thresh: 1.000, 74 frames, 7 pixels
#       Added cell 102 at 09, 150, 238, peak: 2.869, thresh: 1.000, 90 frames, 16 pixels
#       Added cell 103 at 11, 150, 231, peak: 2.865, thresh: 1.000, 77 frames, 21 pixels
#       Added cell 104 at 07, 106, 269, peak: 2.861, thresh: 1.000, 70 frames, 5 pixels
#    Iter 0013: running 08 ROIs in parallel
#       Added cell 105 at 09, 144, 263, peak: 2.858, thresh: 1.000, 54 frames, 9 pixels
#       Added cell 106 at 12, 114, 248, peak: 2.856, thresh: 1.000, 64 frames, 8 pixels
#       Added cell 107 at 00, 191, 285, peak: 2.854, thresh: 1.000, 87 frames, 8 pixels
#       Added cell 108 at 04, 158, 247, peak: 2.853, thresh: 1.000, 74 frames, 12 pixels
#       Added cell 109 at 07, 166, 246, peak: 2.853, thresh: 1.000, 72 frames, 8 pixels
#       Added cell 110 at 09, 138, 229, peak: 2.851, thresh: 1.000, 55 frames, 9 pixels
#       Added cell 111 at 12, 178, 241, peak: 2.850, thresh: 1.000, 75 frames, 12 pixels
#       Added cell 112 at 17, 156, 220, peak: 2.847, thresh: 1.000, 72 frames, 5 pixels
#    Iter 0014: running 08 ROIs in parallel
#       Added cell 113 at 08, 121, 262, peak: 2.847, thresh: 1.000, 79 frames, 9 pixels
#       Added cell 114 at 02, 169, 284, peak: 2.847, thresh: 1.000, 73 frames, 6 pixels
#       Added cell 115 at 15, 158, 213, peak: 2.845, thresh: 1.000, 75 frames, 16 pixels
#       Added cell 116 at 07, 188, 223, peak: 2.843, thresh: 1.000, 52 frames, 9 pixels
#       Added cell 117 at 05, 191, 224, peak: 2.834, thresh: 1.000, 80 frames, 7 pixels
#       Added cell 118 at 09, 161, 204, peak: 2.832, thresh: 1.000, 59 frames, 19 pixels
#       Added cell 119 at 04, 141, 281, peak: 2.832, thresh: 1.000, 91 frames, 17 pixels
#       Added cell 120 at 07, 165, 281, peak: 2.832, thresh: 1.000, 51 frames, 12 pixels
#    Iter 0015: running 08 ROIs in parallel
#       Added cell 121 at 00, 133, 213, peak: 2.831, thresh: 1.000, 82 frames, 7 pixels
#       Added cell 122 at 12, 119, 278, peak: 2.831, thresh: 1.000, 84 frames, 12 pixels
#       Added cell 123 at 17, 142, 197, peak: 2.829, thresh: 1.000, 51 frames, 4 pixels
#       Added cell 124 at 02, 139, 245, peak: 2.825, thresh: 1.000, 87 frames, 22 pixels
#       Added cell 125 at 11, 127, 250, peak: 2.823, thresh: 1.000, 75 frames, 6 pixels
#       Added cell 126 at 10, 135, 257, peak: 2.820, thresh: 1.000, 64 frames, 4 pixels
#       Added cell 127 at 04, 188, 201, peak: 2.819, thresh: 1.000, 80 frames, 5 pixels
#       Added cell 128 at 15, 122, 240, peak: 2.818, thresh: 1.000, 101 frames, 10 pixels
#    Iter 0016: running 08 ROIs in parallel
#       Added cell 129 at 10, 174, 277, peak: 2.812, thresh: 1.000, 59 frames, 19 pixels
#       Added cell 130 at 02, 111, 255, peak: 2.811, thresh: 1.000, 63 frames, 6 pixels
#       Added cell 131 at 10, 128, 277, peak: 2.811, thresh: 1.000, 61 frames, 8 pixels
#       Added cell 132 at 08, 166, 209, peak: 2.810, thresh: 1.000, 63 frames, 16 pixels
#       Added cell 133 at 10, 105, 242, peak: 2.809, thresh: 1.000, 78 frames, 9 pixels
#       Added cell 134 at 00, 106, 220, peak: 2.803, thresh: 1.000, 61 frames, 4 pixels
#       Added cell 135 at 11, 116, 275, peak: 2.801, thresh: 1.000, 80 frames, 30 pixels
#       Added cell 136 at 05, 171, 250, peak: 2.800, thresh: 1.000, 76 frames, 13 pixels
#    Iter 0017: running 08 ROIs in parallel
#       Added cell 137 at 05, 182, 207, peak: 2.800, thresh: 1.000, 78 frames, 12 pixels
#       Added cell 138 at 03, 173, 258, peak: 2.799, thresh: 1.000, 66 frames, 7 pixels
#       Added cell 139 at 00, 147, 240, peak: 2.796, thresh: 1.000, 86 frames, 12 pixels
#       Added cell 140 at 09, 180, 234, peak: 2.794, thresh: 1.000, 87 frames, 28 pixels
#       Added cell 141 at 06, 183, 216, peak: 2.793, thresh: 1.000, 66 frames, 7 pixels
#       Added cell 142 at 08, 183, 208, peak: 2.791, thresh: 1.000, 79 frames, 19 pixels
#       Added cell 143 at 15, 111, 206, peak: 2.791, thresh: 1.000, 67 frames, 6 pixels
#       Added cell 144 at 09, 173, 212, peak: 2.789, thresh: 1.000, 67 frames, 11 pixels
#    Iter 0018: running 08 ROIs in parallel
#       Added cell 145 at 17, 172, 230, peak: 2.784, thresh: 1.000, 56 frames, 14 pixels
#       Added cell 146 at 00, 115, 275, peak: 2.782, thresh: 1.000, 80 frames, 9 pixels
#       Added cell 147 at 00, 191, 220, peak: 2.779, thresh: 1.000, 76 frames, 11 pixels
#       Added cell 148 at 08, 157, 275, peak: 2.779, thresh: 1.000, 60 frames, 8 pixels
#       Added cell 149 at 16, 170, 249, peak: 2.774, thresh: 1.000, 71 frames, 9 pixels
#       Added cell 150 at 16, 168, 275, peak: 2.774, thresh: 1.000, 82 frames, 11 pixels
#       Added cell 151 at 12, 165, 217, peak: 2.773, thresh: 1.000, 59 frames, 7 pixels
#       Added cell 152 at 03, 134, 249, peak: 2.773, thresh: 1.000, 94 frames, 17 pixels
#    Iter 0019: running 08 ROIs in parallel
#       Added cell 153 at 10, 180, 208, peak: 2.772, thresh: 1.000, 57 frames, 11 pixels
#       Added cell 154 at 06, 149, 197, peak: 2.772, thresh: 1.000, 57 frames, 13 pixels
#       Added cell 155 at 17, 147, 269, peak: 2.768, thresh: 1.000, 54 frames, 6 pixels
#       Added cell 156 at 02, 179, 241, peak: 2.768, thresh: 1.000, 83 frames, 10 pixels
#       Added cell 157 at 00, 151, 257, peak: 2.764, thresh: 1.000, 84 frames, 5 pixels
#       Added cell 158 at 09, 120, 286, peak: 2.764, thresh: 1.000, 59 frames, 5 pixels
#       Added cell 159 at 00, 171, 272, peak: 2.764, thresh: 1.000, 86 frames, 8 pixels
#       Added cell 160 at 00, 131, 218, peak: 2.763, thresh: 1.000, 104 frames, 11 pixels
#    Iter 0020: running 08 ROIs in parallel
#       Added cell 161 at 08, 155, 217, peak: 2.761, thresh: 1.000, 65 frames, 20 pixels
#       Added cell 162 at 04, 133, 205, peak: 2.760, thresh: 1.000, 66 frames, 11 pixels
#       Added cell 163 at 09, 123, 277, peak: 2.759, thresh: 1.000, 65 frames, 5 pixels
#       Added cell 164 at 00, 140, 258, peak: 2.758, thresh: 1.000, 73 frames, 15 pixels
#       Added cell 165 at 17, 134, 234, peak: 2.757, thresh: 1.000, 73 frames, 8 pixels
#       Added cell 166 at 07, 111, 260, peak: 2.756, thresh: 1.000, 61 frames, 17 pixels
#       Added cell 167 at 03, 132, 218, peak: 2.755, thresh: 1.000, 83 frames, 10 pixels
#       Added cell 168 at 07, 138, 265, peak: 2.755, thresh: 1.000, 59 frames, 8 pixels
#    Iter 0021: running 03 ROIs in parallel
#       Added cell 169 at 15, 159, 223, peak: 2.753, thresh: 1.000, 69 frames, 13 pixels
#       Added cell 170 at 00, 139, 205, peak: 2.750, thresh: 1.000, 78 frames, 5 pixels
#       Added cell 171 at 10, 120, 246, peak: 2.750, thresh: 1.000, 71 frames, 11 pixels
#       Iter 0022: peak is too small  - ending extraction
#    Found 171 cells in 22 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0011/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0011/iscell.npy
#    Detecting from patch: 12/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0012 with tag patch-0012
#    Running cell detection on patch 0012 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0012, max 10000 iters
#    Patch bounds are [ 0 18], [ 88 208], [273 393]
#    Cell center bounds are [ 0 18], [104 192], [287 379]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0012
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 08 ROIs in parallel
#       Added cell 1 at 03, 135, 312, peak: 7.925, thresh: 1.000, 129 frames, 30 pixels
#       Added cell 2 at 01, 173, 298, peak: 7.143, thresh: 1.000, 152 frames, 30 pixels
#       Added cell 3 at 07, 148, 303, peak: 6.768, thresh: 1.000, 148 frames, 39 pixels
#       Added cell 4 at 06, 163, 312, peak: 6.352, thresh: 1.000, 138 frames, 35 pixels
#       Added cell 5 at 06, 148, 339, peak: 5.689, thresh: 1.000, 126 frames, 16 pixels
#       Added cell 6 at 06, 162, 335, peak: 5.342, thresh: 1.000, 131 frames, 44 pixels
#       Added cell 7 at 01, 163, 377, peak: 5.248, thresh: 1.000, 135 frames, 27 pixels
#       Added cell 8 at 01, 183, 360, peak: 5.200, thresh: 1.000, 151 frames, 31 pixels
#    Iter 0001: running 08 ROIs in parallel
#       Added cell 9 at 06, 179, 375, peak: 5.066, thresh: 1.000, 98 frames, 19 pixels
#       Added cell 10 at 06, 181, 346, peak: 4.943, thresh: 1.000, 106 frames, 27 pixels
#       Added cell 11 at 00, 164, 288, peak: 4.914, thresh: 1.000, 118 frames, 27 pixels
#       Added cell 12 at 08, 162, 355, peak: 4.787, thresh: 1.000, 111 frames, 20 pixels
#       Added cell 13 at 04, 119, 304, peak: 4.639, thresh: 1.000, 97 frames, 20 pixels
#       Added cell 14 at 02, 116, 334, peak: 4.623, thresh: 1.000, 120 frames, 44 pixels
#       Added cell 15 at 09, 166, 289, peak: 4.565, thresh: 1.000, 104 frames, 22 pixels
# ...
#       Added cell 59 at 00, 943, 663, peak: 2.840, thresh: 1.000, 80 frames, 6 pixels
#       Added cell 60 at 01, 949, 673, peak: 2.840, thresh: 1.000, 87 frames, 8 pixels
#       Added cell 61 at 07, 967, 653, peak: 2.832, thresh: 1.000, 78 frames, 7 pixels
#       Added cell 62 at 09, 931, 670, peak: 2.832, thresh: 1.000, 75 frames, 17 pixels
#       Added cell 63 at 17, 906, 691, peak: 2.831, thresh: 1.000, 69 frames, 13 pixels
#       Added cell 64 at 12, 923, 691, peak: 2.830, thresh: 1.000, 76 frames, 16 pixels
#    Iter 0008: running 08 ROIs in parallel
#       Added cell 65 at 04, 927, 689, peak: 2.830, thresh: 1.000, 83 frames, 12 pixels
#       Added cell 66 at 04, 941, 682, peak: 2.830, thresh: 1.000, 82 frames, 13 pixels
#       Added cell 67 at 03, 971, 701, peak: 2.829, thresh: 1.000, 63 frames, 10 pixels
#       Added cell 68 at 01, 947, 687, peak: 2.823, thresh: 1.000, 80 frames, 6 pixels
#       Added cell 69 at 09, 929, 653, peak: 2.821, thresh: 1.000, 75 frames, 10 pixels
#       Added cell 70 at 10, 932, 660, peak: 2.820, thresh: 1.000, 79 frames, 8 pixels
#       Added cell 71 at 03, 919, 697, peak: 2.817, thresh: 1.000, 88 frames, 9 pixels
#       Added cell 72 at 00, 936, 686, peak: 2.815, thresh: 1.000, 81 frames, 11 pixels
#    Iter 0009: running 08 ROIs in parallel
#       Added cell 73 at 11, 911, 689, peak: 2.815, thresh: 1.000, 88 frames, 14 pixels
#       Added cell 74 at 06, 928, 659, peak: 2.814, thresh: 1.000, 107 frames, 20 pixels
#       Added cell 75 at 00, 900, 662, peak: 2.813, thresh: 1.000, 78 frames, 14 pixels
#       Added cell 76 at 11, 915, 676, peak: 2.808, thresh: 1.000, 69 frames, 11 pixels
#       Added cell 77 at 00, 950, 690, peak: 2.805, thresh: 1.000, 78 frames, 7 pixels
#       Added cell 78 at 11, 954, 680, peak: 2.805, thresh: 1.000, 68 frames, 16 pixels
#       Added cell 79 at 00, 967, 668, peak: 2.798, thresh: 1.000, 87 frames, 8 pixels
#       Added cell 80 at 04, 900, 654, peak: 2.794, thresh: 1.000, 89 frames, 26 pixels
#    Iter 0010: running 08 ROIs in parallel
#       Added cell 81 at 12, 903, 664, peak: 2.793, thresh: 1.000, 78 frames, 11 pixels
#       Added cell 82 at 07, 900, 659, peak: 2.787, thresh: 1.000, 86 frames, 19 pixels
#       Added cell 83 at 17, 926, 712, peak: 2.784, thresh: 1.000, 51 frames, 9 pixels
#       Added cell 84 at 12, 916, 725, peak: 2.784, thresh: 1.000, 77 frames, 22 pixels
#       Added cell 85 at 10, 910, 695, peak: 2.783, thresh: 1.000, 66 frames, 6 pixels
#       Added cell 86 at 03, 934, 680, peak: 2.776, thresh: 1.000, 81 frames, 13 pixels
#       Added cell 87 at 06, 958, 703, peak: 2.776, thresh: 1.000, 42 frames, 11 pixels
#       Added cell 88 at 01, 945, 684, peak: 2.775, thresh: 1.000, 84 frames, 11 pixels
#    Iter 0011: running 08 ROIs in parallel
#       Added cell 89 at 15, 907, 728, peak: 2.773, thresh: 1.000, 54 frames, 8 pixels
#       Added cell 90 at 00, 924, 676, peak: 2.772, thresh: 1.000, 79 frames, 12 pixels
#       Added cell 91 at 04, 908, 685, peak: 2.769, thresh: 1.000, 81 frames, 11 pixels
#       Added cell 92 at 09, 931, 660, peak: 2.766, thresh: 1.000, 87 frames, 7 pixels
#       Added cell 93 at 07, 911, 734, peak: 2.766, thresh: 1.000, 58 frames, 9 pixels
#       Added cell 94 at 00, 937, 665, peak: 2.766, thresh: 1.000, 80 frames, 8 pixels
#       Added cell 95 at 13, 914, 657, peak: 2.763, thresh: 1.000, 65 frames, 16 pixels
#       Added cell 96 at 07, 915, 710, peak: 2.762, thresh: 1.000, 62 frames, 16 pixels
#    Iter 0012: running 08 ROIs in parallel
#       Added cell 97 at 05, 907, 684, peak: 2.766, thresh: 1.000, 66 frames, 9 pixels
#       Added cell 98 at 01, 924, 671, peak: 2.762, thresh: 1.000, 93 frames, 6 pixels
#       Added cell 99 at 03, 946, 689, peak: 2.759, thresh: 1.000, 95 frames, 15 pixels
#       Added cell 100 at 11, 922, 662, peak: 2.758, thresh: 1.000, 89 frames, 13 pixels
#       Added cell 101 at 00, 902, 655, peak: 2.757, thresh: 1.000, 70 frames, 4 pixels
#       Added cell 102 at 02, 955, 659, peak: 2.755, thresh: 1.000, 114 frames, 12 pixels
#       Added cell 103 at 07, 913, 693, peak: 2.753, thresh: 1.000, 80 frames, 7 pixels
#       Added cell 104 at 15, 919, 696, peak: 2.750, thresh: 1.000, 55 frames, 8 pixels
#       Iter 0013: peak is too small  - ending extraction
#    Found 104 cells in 13 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0097/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0097/iscell.npy
#    Detecting from patch: 98/99
#    Updated main params file
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection with tag detection
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0098 with tag patch-0098
#    Running cell detection on patch 0098 at /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0098, max 10000 iters
#    Patch bounds are [ 0 18], [ 880 1000], [730 850]
#    Cell center bounds are [ 0 18], [ 896 1000], [744 850]
#    Time bounds are (None, None)
# mov_sub
#    Loading 0.39 GB movie to memory
#    Loaded
#    Loading from /mnt/md0/runs/s3d-Full-Demo-GPU/iters/batch0000
#       Movie shape: (400, 18, 120, 120)
#    Saving cell stats and info to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0098
#    Loading movie patch to shared memory
#    Starting extraction with peak_thresh: 2.750 and Th2: 1.000
#    Iter 0000: running 03 ROIs in parallel
#       Added cell 1 at 04, 902, 774, peak: 3.007, thresh: 1.000, 55 frames, 13 pixels
#       Added cell 2 at 08, 926, 772, peak: 2.952, thresh: 1.000, 52 frames, 20 pixels
#       Added cell 3 at 00, 898, 772, peak: 2.847, thresh: 1.000, 75 frames, 11 pixels
#       Iter 0001: peak is too small  - ending extraction
#    Found 3 cells in 1 iterations
#    Saving cells to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0098/stats.npy
#    Saving iscell.npy to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0098/iscell.npy
#    Created dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/combined-full with tag detection-combined-full
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0000 with tag detection-patch-0000
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0001 with tag detection-patch-0001
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0002 with tag detection-patch-0002
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0003 with tag detection-patch-0003
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0004 with tag detection-patch-0004
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0005 with tag detection-patch-0005
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0006 with tag detection-patch-0006
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0007 with tag detection-patch-0007
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0008 with tag detection-patch-0008
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0009 with tag detection-patch-0009
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0010 with tag detection-patch-0010
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0011 with tag detection-patch-0011
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0012 with tag detection-patch-0012
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0013 with tag detection-patch-0013
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0014 with tag detection-patch-0014
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0015 with tag detection-patch-0015
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0016 with tag detection-patch-0016
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0017 with tag detection-patch-0017
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0018 with tag detection-patch-0018
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0019 with tag detection-patch-0019
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0020 with tag detection-patch-0020
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0021 with tag detection-patch-0021
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0022 with tag detection-patch-0022
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0023 with tag detection-patch-0023
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0024 with tag detection-patch-0024
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0025 with tag detection-patch-0025
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0026 with tag detection-patch-0026
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0027 with tag detection-patch-0027
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0028 with tag detection-patch-0028
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0029 with tag detection-patch-0029
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0030 with tag detection-patch-0030
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0031 with tag detection-patch-0031
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0032 with tag detection-patch-0032
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0033 with tag detection-patch-0033
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0034 with tag detection-patch-0034
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0035 with tag detection-patch-0035
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0036 with tag detection-patch-0036
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0037 with tag detection-patch-0037
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0038 with tag detection-patch-0038
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0039 with tag detection-patch-0039
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0040 with tag detection-patch-0040
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0041 with tag detection-patch-0041
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0042 with tag detection-patch-0042
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0043 with tag detection-patch-0043
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0044 with tag detection-patch-0044
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0045 with tag detection-patch-0045
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0046 with tag detection-patch-0046
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0047 with tag detection-patch-0047
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0048 with tag detection-patch-0048
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0049 with tag detection-patch-0049
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0050 with tag detection-patch-0050
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0051 with tag detection-patch-0051
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0052 with tag detection-patch-0052
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0053 with tag detection-patch-0053
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0054 with tag detection-patch-0054
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0055 with tag detection-patch-0055
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0056 with tag detection-patch-0056
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0057 with tag detection-patch-0057
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0058 with tag detection-patch-0058
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0059 with tag detection-patch-0059
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0060 with tag detection-patch-0060
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0061 with tag detection-patch-0061
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0062 with tag detection-patch-0062
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0063 with tag detection-patch-0063
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0064 with tag detection-patch-0064
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0065 with tag detection-patch-0065
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0066 with tag detection-patch-0066
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0067 with tag detection-patch-0067
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0068 with tag detection-patch-0068
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0069 with tag detection-patch-0069
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0070 with tag detection-patch-0070
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0071 with tag detection-patch-0071
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0072 with tag detection-patch-0072
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0073 with tag detection-patch-0073
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0074 with tag detection-patch-0074
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0075 with tag detection-patch-0075
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0076 with tag detection-patch-0076
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0077 with tag detection-patch-0077
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0078 with tag detection-patch-0078
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0079 with tag detection-patch-0079
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0080 with tag detection-patch-0080
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0081 with tag detection-patch-0081
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0082 with tag detection-patch-0082
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0083 with tag detection-patch-0083
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0084 with tag detection-patch-0084
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0085 with tag detection-patch-0085
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0086 with tag detection-patch-0086
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0087 with tag detection-patch-0087
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0088 with tag detection-patch-0088
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0089 with tag detection-patch-0089
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0090 with tag detection-patch-0090
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0091 with tag detection-patch-0091
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0092 with tag detection-patch-0092
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0093 with tag detection-patch-0093
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0094 with tag detection-patch-0094
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0095 with tag detection-patch-0095
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0096 with tag detection-patch-0096
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0097 with tag detection-patch-0097
#       Found dir /mnt/md0/runs/s3d-Full-Demo-GPU/detection/patch-0098 with tag detection-patch-0098
#    Combined 99 patches, 12635 cells
#    Saving combined files to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/combined-full
#       Saved stats
#       Saved iscell
#       Saved info (copied from patch) 98
# CPU times: user 54.4 s, sys: 2min 28s, total: 3min 22s
# Wall time: 6min 30s

# %% [markdown]
# ### Compute neuropil masks, extract activity and deconvolve
# For each cell, compute a donut around it excluding all other cells to use it to estimate the local neuropil activity. Then, extract the activity of the cell and the neuropil, subtract 0.7\*neuropil activity from the ROI activity, and deconvolve using Oasis. Make sure you have set the `tau` parameter correctly for the deconvolution.

# %%
job.compute_npil_masks(combined_dir)
# Out:
# '/mnt/md0/runs/s3d-Full-Demo-GPU/detection/combined-full'

# %%
traces = job.extract_and_deconvolve(stats_dir = combined_dir)
# Out:
#    Updated main params file
#    Cropping with bounds: ((0, 18), (100, 1100), (50, 900))
#    Movie shape: (18, 300, 1000, 850)
# 12635
#    Extracting 12635 valid cells, and saving cell flags to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/combined-full/iscell_extracted.npy
#    Extracting activity
# Will extract in 1 batches of 500
# Saving intermediate results to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/combined-full
# Extracting batch 0000 of 0001
# Batch size: 17 GB
#    Deconvolving
#    Saving to /mnt/md0/runs/s3d-Full-Demo-GPU/detection/combined-full

# %% [markdown]
# ## Visualization
# Visualize using napari. You can right click to manually mark cells as "non-cells", and you can use the sliders to filter cells based on size or the correlation map peak.

# %%
combined_dir = job.dirs['detection-combined-full']

# %%
outputs = ui.load_outputs(combined_dir, load_traces=True)
v,layers = ui.create_ui(outputs)
ui.add_callbacks_to_ui(v,layers,outputs,savedir=combined_dir)
# Out:
# Cells
# Found old curated + slider-ed iscell with 12635 of 12635 marked as cells
# Saving old iscell_curated to backup path /mnt/md0/runs/s3d-Full-Demo-GPU/detection/combined-full/iscell_curated_slider_old_22-09-23_11-46-55.npy
# ('vmap_peak', (2.7500184, 3.259639072418213), 'peak_val', <function add_curation_sliders.<locals>.<lambda> at 0x7fbb9f5b59d0>)

# %% [markdown]
# ## Load outputs and analyze
# This is how you can access the traces for each cell, and the locations for each cell

# %%
outputs = ui.load_outputs(combined_dir, load_traces=True)
print(outputs.keys())
# Out:
# dict_keys(['dir', 'vmap', 'max_img', 'mean_img', 'fs', 'stats', 'iscell', 'iscell_extracted', 'iscell_curated', 'iscell_curated_slider', 'F', 'Fneu', 'spks'])

# %%
n_cells, n_t = outputs['F'].shape
frame_times = n.arange(n_t) / outputs['fs']
example_cell = 1200
plt.plot(frame_times, outputs['F'][example_cell], label='ROI Fluorescence')
plt.plot(frame_times, outputs['Fneu'][example_cell], label='Neuropil Fluorescence')
plt.plot(frame_times, outputs['spks'][example_cell], label='Deconvolved activity')
plt.legend()
plt.xlabel("Time (s)")
plt.ylabel("Activity")
# Out:
# Text(0, 0.5, 'Activity')

# %%
# results of your manual curation will be saved here
# ROIs that are marked as cells will be 1, non-cells 0
iscell = outputs['iscell_curated_slider']

# %%
# suite2p-style list of all cells
cell_stats = outputs['stats']
print(cell_stats[example_cell].keys())
# Out:
# dict_keys(['idx', 'threshold', 'coords', 'lam', 'med', 'peak_val', 'patch_idx', 'med_patch', 'npcoords', 'npcoords_patch'])

# %%
cell_coords = [stat['coords'] for stat in cell_stats]
cell_centers = n.array([stat['med'] for stat in cell_stats])
vmap_shape = outputs['vmap'].shape

# %%
# make a volume with the footprints of all cells and plot a max-projection of it along z
cell_vol = ui.fill_cells_vol(cell_coords, fill_vals = n.ones(len(cell_coords)), empty=0)
tfu.show_tif((cell_vol ).max(axis=0))
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x7fbb9e9d5190>)

# %%
hist,bins = n.histogram(cell_centers[:,0],bins = n.arange(vmap_shape[0]))
bins = bins[:-1]

plt.plot(hist, bins)
plt.xlabel("# of neurons at a given depth")
plt.ylabel("Depth from surface (um)")
plt.yticks(n.arange(bins.max(),0,-bins.max()//6), -15*(bins.max()-n.arange(bins.max(),0,-bins.max()//6)));

# from the plot, seems like the shallowest plane has lots of cells, 
# possibly because it's out of the brain and it's mostly noise...
# it might be a good idea to exclude them in the curation 
# probably, when you have a longer recording you won't have this issue as much

# %% [markdown]
# ### Save a fancy 3D plot
# Use UCSF Chimera to open the .mrc file and visualize your cells

# %%
v1, v2 = ui.make_label_vols(outputs['stats'], outputs['vmap'].shape, 
            iscell =  outputs['iscell_curated_slider'], 
                  cmap='Blues', lam_max = 0.3)

# %%
tfu.save_mrc(combined_dir, 'curated_cells.mrc',v2[:,:,:,3], voxel_size=(4,4,15))
