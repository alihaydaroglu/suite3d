# %%
# %load_ext autoreload
# %autoreload 2

import os 
import shutil
import numpy as n
from datetime import date
from matplotlib import pyplot as plt
import time
import napari

# %%
os.chdir('/home/ali/packages/s2p-lbm/')

from suite3d.job import Job
from suite3d import lbmio, utils, ui
from suite3d import tiff_utils as tfu

# %%
## Find all the tiffiles in the tif path
# File I/O is pipelined, so the data doesn't have to be on a fast SSD 
# single HDDs or reasonably fast network drives should work without much difference in speed 
tif_path = r'/mnt/md0/data/Coconut'
tifs = tfu.get_tif_paths(tif_path)

# %%
tifs = tifs[:1]

# %%
# Set the mandatory parameters
params = {
    # volume rate
    'fs': tfu.get_vol_rate(tifs[0]),
    # planes to analyze. 0 is deepest, 30 is shallowest (corrected for ScanImage channel IDs)
    # you should keep all the planes to do crosstalk estimation! 
    'planes' : n.arange(30),
    # Decay time of the Ca indicator in seconds. 1.3 for GCaMP6s. This example is for GCamP8m
    'tau' : 1.3
}

# %% [markdown]
# ### "Job" structure
# The unimaginatively named `Job` structure is meant to contain all of the parameters, data, logs, and results for a single recording. It will be created in the root directory provided with the given name. All intermediate and final results will be saved in this directory, so I recommend using a fast SSD for this (and moving results to slow HDD once processing is complete).
#
# All the print statements you see (and more) are also logged in `<job dir>/logfile.txt`. If you want things to look cleaner, reduce the verbosity to 2 (full logs will still be in the logfile).
#
# To load a previously created job (to do more processing or load results), set `create=False`. If `create=True` but there exists another job of the same name in the root directory, it will either overwrite the parameters of the previous job or throw an error (depending on the `overwrite` parameter). Note, overwriting isn't as catastrophic as it sounds since data isn't deleted and remains accessible, but you might lose the saved parameters and some metadata.

# %%
# Create the job
job = Job('/mnt/md0/runs','Full-Demo-Coconut', tifs = tifs,
          params=params, create=False, overwrite=True, verbosity = 3)
# Out:
#    Found and loaded params from /mnt/md0/runs/s3d-Full-Demo-Coconut/params.npy

# %% [markdown]
# ## Initial pass
# This pass takes a few files (`n_init_files`, usually ~200-300 frames is enough) and does the following:
# - estimates the crosstalk coefficient between the lower set of 15 planes and the higher 15 planes
# - computes the shifts between successive planes caused by the xy-shift of the light beads
# - estimates the optimal number of pixels that overlap between successive strips, so they can be fused together
# - calculates a "reference volume" that will be used later in registration

# %%
# optional parameters for initialization
# load 1 file to initialize
job.params['n_init_files'] = 1
# If set to None, use all of the frames in the loaded init files 
# if your files are really big, set this to <300
job.params['init_n_frames'] = 200

# Set to None to auto-compute the crosstalk coefficient
# You can set a float value between 0-1 (usually around 0.1-0.3) to override the calculation
job.params['override_crosstalk'] = None
# number of processors to use
job.params['n_proc_corr'] = 20

# %%
job.params['fuse_shift_override'] = 1

# %%
# %%time
# This step only uses `n_init_files` files, so the  runtime will stay the same even with larger recordings
# soon this will also be gpu-ified to be faster!
job.run_init_pass()
# Out:
#    Saved a copy of params at /mnt/md0/runs/s3d-Full-Demo-Coconut/summary
#    Updated main params file
# Launching initial pass
# Saving summary to /mnt/md0/runs/s3d-Full-Demo-Coconut/summary/summary.npy
# Loading /mnt/md0/data/Coconut/Max30_500umdeep_1p75by1p75mm_3umppix_9p86Hz_250mW_00001_00001.tif
# <tifffile.TiffFile 'Max30_500umdeep…_00001_00001.tif'> asarray failed to reshape (29580, 2414, 146) to (36000, 30, 2414, 146)
# Loaded 1 files, total 18.79 GB
#    Selecting 200 random frames from the init tif files
#    Loaded movie with 200 frames and shape 30, 584, 584
#          Enforcing positivity in mean image
# /home/ali/packages/s2p-lbm/suite3d/utils.py:186: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Saving figure to /mnt/md0/runs/s3d-Full-Demo-Coconut/summary/crosstalk_plots
# saved
# Close figure
#    Subtracting with estimated coefficient 0.107
#          Subtracting plane 0 from 15
#          Subtracting plane 1 from 16
#          Subtracting plane 2 from 17
#          Subtracting plane 3 from 18
#          Subtracting plane 4 from 19
#          Subtracting plane 5 from 20
#          Subtracting plane 6 from 21
#          Subtracting plane 7 from 22
#          Subtracting plane 8 from 23
#          Subtracting plane 9 from 24
#          Subtracting plane 10 from 25
#          Subtracting plane 11 from 26
#          Subtracting plane 12 from 27
#          Subtracting plane 13 from 28
#          Subtracting plane 14 from 29
#    Estimating fusing shifts
# <tifffile.TiffFile 'Max30_500umdeep…_00001_00001.tif'> asarray failed to reshape (29580, 2414, 146) to (36000, 30, 2414, 146)
#       Overriding
#    Using best fuse shift of 1
#    Building ops file
#    Saved init mov to /mnt/md0/runs/s3d-Full-Demo-Coconut/summary/init_mov.npy
#    Aligning planes
# float64
# 20
#       Fixing plane alignment outliers
#    Fusing and padding init mov
# Setting smooth_sigma: 1.15
# Setting maxregshift: 0.15
# Setting Ly: 709
# Setting Lx: 671
# Setting nonrigid: True
#    Computing reference images
#         Computed reference for plane 0
#         Computed reference for plane 1
#         Computed reference for plane 2
#         Computed reference for plane 3
#         Computed reference for plane 4
#         Computed reference for plane 5
#         Computed reference for plane 6
#         Computed reference for plane 7
#         Computed reference for plane 8
#         Computed reference for plane 9
#         Computed reference for plane 10
#         Computed reference for plane 11
#         Computed reference for plane 12
#         Computed reference for plane 13
#         Computed reference for plane 14
#         Computed reference for plane 15
#         Computed reference for plane 16
#         Computed reference for plane 17
#         Computed reference for plane 18
#         Computed reference for plane 19
#         Computed reference for plane 20
#         Computed reference for plane 21
#         Computed reference for plane 22
#         Computed reference for plane 23
#         Computed reference for plane 24
#         Computed reference for plane 25
#         Computed reference for plane 26
#         Computed reference for plane 27
#         Computed reference for plane 28
#         Computed reference for plane 29
#    Saving summary to /mnt/md0/runs/s3d-Full-Demo-Coconut/summary/summary.npy
#    Initial pass complete. See /mnt/md0/runs/s3d-Full-Demo-Coconut/summary for details
# CPU times: user 2h 11min 18s, sys: 33min 14s, total: 2h 44min 33s
# Wall time: 6min 31s

# %%
summary = job.load_summary()

# %%
job.show_summary_plots()

# %% [markdown]
# ## Registration
# First, we do registration over time of the  xy-drift caused by brain movement. This is similar to Suite2P registratrion, it does rigid registration followed by non-rigid registration. This is accelerated on the GPU. Suite2P registration parameters can be changed, see `default_params.py` for a list of all parameters related to registration. After you have registered, you can load the registered fused movie into memory and take a look at the mean image. I suggest cropping the dark edges if you have any as shown in the cells below.
#
# If you run out of gpu memory, try reducing the `gpu_reg_batchsize` parameter. I have a A4500 with 20GB memory which works well with a batchsize of 10.

# %%
# If you have large tiffs, split the large tiffs into files of size 100 after registration
job.params['split_tif_size'] = 100
job.params['gpu_reg_batchsize'] = 10

# %%
# %%time
job.register_gpu()
# Out:
#       Found dir /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data with tag registered_fused_data
# Will analyze 1 tifs in 1 batches
#    Enforcing positivity
#    Launching IO thread
#       Loading /mnt/md0/data/Coconut/Max30_500umdeep_1p75by1p75mm_3umppix_9p86Hz_250mW_00001_00001.tif
#          Memory at batch 0.  Total Used: 196.823 GB, Virtual Available: 322.034 GB, Virtual Used: 181.162 GB, Swap Used: 015.661 GB
# Loading Batch 0 of 0
# <tifffile.TiffFile 'Max30_500umdeep…_00001_00001.tif'> asarray failed to reshape (29580, 2414, 146) to (36000, 30, 2414, 146)
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
#    Loaded 1 files, total 18.79 GB
#    Batch 0 IO thread joined
#          Memory after IO thread joinTotal Used: 215.604 GB, Virtual Available: 303.252 GB, Virtual Used: 199.944 GB, Swap Used: 015.661 GB
#          Memory after movie copied from threadTotal Used: 234.440 GB, Virtual Available: 284.417 GB, Virtual Used: 218.779 GB, Swap Used: 015.661 GB
#          Memory after thread memory clearedTotal Used: 215.631 GB, Virtual Available: 303.226 GB, Virtual Used: 199.970 GB, Swap Used: 015.661 GB
#       Loaded batch of size (30, 986, 584, 584)
#       Sending frames 0-10 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.22 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.15 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.51 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.05 sec
#    Computed SNR and smoothed phase corrs in 0.10 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.75 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#       Allocated array of shape (30, 986, 709, 671) to store CPU movie
#          After array alloc:  Total Used: 216.416 GB, Virtual Available: 302.441 GB, Virtual Used: 200.755 GB, Swap Used: 015.661 GB
#    Non rigid transformed (on CPU) in 1.04 sec
#          After GPU Batch:    Total Used: 216.999 GB, Virtual Available: 301.858 GB, Virtual Used: 201.338 GB, Swap Used: 015.661 GB
#       Sending frames 10-20 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 217.549 GB, Virtual Available: 301.308 GB, Virtual Used: 201.888 GB, Swap Used: 015.661 GB
#       Sending frames 20-30 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.08 sec
#          After GPU Batch:    Total Used: 218.069 GB, Virtual Available: 300.787 GB, Virtual Used: 202.409 GB, Swap Used: 015.661 GB
#       Sending frames 30-40 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 218.603 GB, Virtual Available: 300.254 GB, Virtual Used: 202.942 GB, Swap Used: 015.661 GB
#       Sending frames 40-50 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 219.134 GB, Virtual Available: 299.723 GB, Virtual Used: 203.473 GB, Swap Used: 015.661 GB
#       Sending frames 50-60 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 219.664 GB, Virtual Available: 299.193 GB, Virtual Used: 204.003 GB, Swap Used: 015.661 GB
#       Sending frames 60-70 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.09 sec
#          After GPU Batch:    Total Used: 220.199 GB, Virtual Available: 298.657 GB, Virtual Used: 204.538 GB, Swap Used: 015.661 GB
#       Sending frames 70-80 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 220.730 GB, Virtual Available: 298.127 GB, Virtual Used: 205.069 GB, Swap Used: 015.661 GB
#       Sending frames 80-90 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.08 sec
#          After GPU Batch:    Total Used: 221.262 GB, Virtual Available: 297.595 GB, Virtual Used: 205.601 GB, Swap Used: 015.661 GB
#       Sending frames 90-100 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.05 sec
#          After GPU Batch:    Total Used: 221.795 GB, Virtual Available: 297.062 GB, Virtual Used: 206.134 GB, Swap Used: 015.661 GB
#       Sending frames 100-110 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.10 sec
#          After GPU Batch:    Total Used: 222.325 GB, Virtual Available: 296.532 GB, Virtual Used: 206.664 GB, Swap Used: 015.661 GB
#       Sending frames 110-120 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.15 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 222.865 GB, Virtual Available: 295.991 GB, Virtual Used: 207.205 GB, Swap Used: 015.661 GB
#       Sending frames 120-130 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.09 sec
#          After GPU Batch:    Total Used: 223.397 GB, Virtual Available: 295.460 GB, Virtual Used: 207.736 GB, Swap Used: 015.661 GB
#       Sending frames 130-140 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 223.925 GB, Virtual Available: 294.932 GB, Virtual Used: 208.264 GB, Swap Used: 015.661 GB
#       Sending frames 140-150 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 224.459 GB, Virtual Available: 294.398 GB, Virtual Used: 208.798 GB, Swap Used: 015.661 GB
#       Sending frames 150-160 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.08 sec
#          After GPU Batch:    Total Used: 224.988 GB, Virtual Available: 293.868 GB, Virtual Used: 209.328 GB, Swap Used: 015.661 GB
#       Sending frames 160-170 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 225.524 GB, Virtual Available: 293.332 GB, Virtual Used: 209.864 GB, Swap Used: 015.661 GB
#       Sending frames 170-180 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 226.050 GB, Virtual Available: 292.807 GB, Virtual Used: 210.389 GB, Swap Used: 015.661 GB
#       Sending frames 180-190 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.05 sec
#          After GPU Batch:    Total Used: 226.585 GB, Virtual Available: 292.272 GB, Virtual Used: 210.924 GB, Swap Used: 015.661 GB
#       Sending frames 190-200 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 227.119 GB, Virtual Available: 291.737 GB, Virtual Used: 211.459 GB, Swap Used: 015.661 GB
#       Sending frames 200-210 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.08 sec
#          After GPU Batch:    Total Used: 227.652 GB, Virtual Available: 291.204 GB, Virtual Used: 211.991 GB, Swap Used: 015.661 GB
#       Sending frames 210-220 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 228.185 GB, Virtual Available: 290.671 GB, Virtual Used: 212.525 GB, Swap Used: 015.661 GB
#       Sending frames 220-230 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.05 sec
#          After GPU Batch:    Total Used: 228.711 GB, Virtual Available: 290.145 GB, Virtual Used: 213.051 GB, Swap Used: 015.661 GB
#       Sending frames 230-240 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.04 sec
#          After GPU Batch:    Total Used: 229.246 GB, Virtual Available: 289.611 GB, Virtual Used: 213.585 GB, Swap Used: 015.661 GB
#       Sending frames 240-250 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.30 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.13 sec
#    Non rigid transformed (on CPU) in 1.08 sec
#          After GPU Batch:    Total Used: 229.778 GB, Virtual Available: 289.079 GB, Virtual Used: 214.117 GB, Swap Used: 015.661 GB
#       Sending frames 250-260 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.13 sec
#    Non rigid transformed (on CPU) in 1.08 sec
#          After GPU Batch:    Total Used: 230.310 GB, Virtual Available: 288.547 GB, Virtual Used: 214.649 GB, Swap Used: 015.661 GB
#       Sending frames 260-270 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 230.840 GB, Virtual Available: 288.016 GB, Virtual Used: 215.179 GB, Swap Used: 015.661 GB
#       Sending frames 270-280 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.13 sec
#    Non rigid transformed (on CPU) in 1.03 sec
#          After GPU Batch:    Total Used: 231.374 GB, Virtual Available: 287.482 GB, Virtual Used: 215.714 GB, Swap Used: 015.661 GB
#       Sending frames 280-290 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.05 sec
#          After GPU Batch:    Total Used: 231.908 GB, Virtual Available: 286.949 GB, Virtual Used: 216.247 GB, Swap Used: 015.661 GB
#       Sending frames 290-300 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.13 sec
#    Non rigid transformed (on CPU) in 1.04 sec
#          After GPU Batch:    Total Used: 232.440 GB, Virtual Available: 286.417 GB, Virtual Used: 216.779 GB, Swap Used: 015.661 GB
#       Sending frames 300-310 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.02 sec
#          After GPU Batch:    Total Used: 232.971 GB, Virtual Available: 285.886 GB, Virtual Used: 217.310 GB, Swap Used: 015.661 GB
#       Sending frames 310-320 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.00 sec
#          After GPU Batch:    Total Used: 233.506 GB, Virtual Available: 285.351 GB, Virtual Used: 217.845 GB, Swap Used: 015.661 GB
#       Sending frames 320-330 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.05 sec
#          After GPU Batch:    Total Used: 234.034 GB, Virtual Available: 284.823 GB, Virtual Used: 218.373 GB, Swap Used: 015.661 GB
#       Sending frames 330-340 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.54 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.04 sec
#          After GPU Batch:    Total Used: 234.562 GB, Virtual Available: 284.295 GB, Virtual Used: 218.901 GB, Swap Used: 015.661 GB
#       Sending frames 340-350 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.04 sec
#          After GPU Batch:    Total Used: 235.094 GB, Virtual Available: 283.763 GB, Virtual Used: 219.433 GB, Swap Used: 015.661 GB
#       Sending frames 350-360 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.04 sec
#          After GPU Batch:    Total Used: 235.629 GB, Virtual Available: 283.228 GB, Virtual Used: 219.968 GB, Swap Used: 015.661 GB
#       Sending frames 360-370 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 236.188 GB, Virtual Available: 282.669 GB, Virtual Used: 220.527 GB, Swap Used: 015.661 GB
#       Sending frames 370-380 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.05 sec
#          After GPU Batch:    Total Used: 236.710 GB, Virtual Available: 282.146 GB, Virtual Used: 221.050 GB, Swap Used: 015.661 GB
#       Sending frames 380-390 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.03 sec
#          After GPU Batch:    Total Used: 237.233 GB, Virtual Available: 281.623 GB, Virtual Used: 221.573 GB, Swap Used: 015.661 GB
#       Sending frames 390-400 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 237.772 GB, Virtual Available: 281.085 GB, Virtual Used: 222.111 GB, Swap Used: 015.661 GB
#       Sending frames 400-410 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 238.307 GB, Virtual Available: 280.550 GB, Virtual Used: 222.646 GB, Swap Used: 015.661 GB
#       Sending frames 410-420 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
# ...
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 263.173 GB, Virtual Available: 255.683 GB, Virtual Used: 247.513 GB, Swap Used: 015.661 GB
#       Sending frames 870-880 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.05 sec
#          After GPU Batch:    Total Used: 263.711 GB, Virtual Available: 255.146 GB, Virtual Used: 248.050 GB, Swap Used: 015.661 GB
#       Sending frames 880-890 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.15 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 264.250 GB, Virtual Available: 254.607 GB, Virtual Used: 248.589 GB, Swap Used: 015.661 GB
#       Sending frames 890-900 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 264.833 GB, Virtual Available: 254.024 GB, Virtual Used: 249.172 GB, Swap Used: 015.661 GB
#       Sending frames 900-910 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.15 sec
#    Non rigid transformed (on CPU) in 1.11 sec
#          After GPU Batch:    Total Used: 265.228 GB, Virtual Available: 253.629 GB, Virtual Used: 249.567 GB, Swap Used: 015.661 GB
#       Sending frames 910-920 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 265.771 GB, Virtual Available: 253.085 GB, Virtual Used: 250.110 GB, Swap Used: 015.661 GB
#       Sending frames 920-930 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.16 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.56 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.15 sec
#    Non rigid transformed (on CPU) in 1.06 sec
#          After GPU Batch:    Total Used: 266.296 GB, Virtual Available: 252.561 GB, Virtual Used: 250.635 GB, Swap Used: 015.661 GB
#       Sending frames 930-940 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.11 sec
#          After GPU Batch:    Total Used: 266.814 GB, Virtual Available: 252.043 GB, Virtual Used: 251.153 GB, Swap Used: 015.661 GB
#       Sending frames 940-950 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.15 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.57 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.09 sec
#          After GPU Batch:    Total Used: 267.355 GB, Virtual Available: 251.502 GB, Virtual Used: 251.694 GB, Swap Used: 015.661 GB
#       Sending frames 950-960 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.01 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.15 sec
#    Non rigid transformed (on CPU) in 1.08 sec
#          After GPU Batch:    Total Used: 267.868 GB, Virtual Available: 250.989 GB, Virtual Used: 252.207 GB, Swap Used: 015.661 GB
#       Sending frames 960-970 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.31 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.07 sec
#          After GPU Batch:    Total Used: 268.408 GB, Virtual Available: 250.449 GB, Virtual Used: 252.747 GB, Swap Used: 015.661 GB
#       Sending frames 970-980 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.15 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 10, 709, 671; 1.06 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#       Completed rigid registration in 0.32 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.00 sec
#    Computed SNR and smoothed phase corrs in 0.14 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.55 sec
#       Transferred shifted mov of shape (10, 30, 709, 671) to CPU in 0.14 sec
#    Non rigid transformed (on CPU) in 1.09 sec
#          After GPU Batch:    Total Used: 268.923 GB, Virtual Available: 249.933 GB, Virtual Used: 253.263 GB, Swap Used: 015.661 GB
#       Sending frames 980-986 to GPU for rigid registration
#          Loaded mov and masks to GPU for rigid reg in 0.14 sec
#          Subtracting min pix vals to enforce positivity
#          Subtracting crosstalk
#          Fusing and padding movie
#          Mov of shape 30, 6, 709, 671; 0.64 GB
#          Allocating memory for shifted movie
#          Registered batch in 0.02 sec
#          Shifted batch in 0.07 sec
#          Freeing all blocks
#       Completed rigid registration in 0.24 sec
#          Allocated GPU array for non-rigid reg in 0.08 sec
#    Clipped movie in 0.00 sec
#    Split movie into blocks in 0.00 sec
#    Completed FFT of blocks and computed phase correlations in 0.04 sec
#    Computed SNR and smoothed phase corrs in 0.06 sec
#          Computed subpixel shifts in 0.00 sec
#       Computed non-rigid shifts in 0.43 sec
#       Transferred shifted mov of shape (6, 30, 709, 671) to CPU in 0.09 sec
#    Non rigid transformed (on CPU) in 0.80 sec
#          After GPU Batch:    Total Used: 269.183 GB, Virtual Available: 249.674 GB, Virtual Used: 253.522 GB, Swap Used: 015.661 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 269.183 GB, Virtual Available: 249.674 GB, Virtual Used: 253.522 GB, Swap Used: 015.661 GB
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0000.npy
#          Saved in 23.77 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0001.npy
#          Saved in 23.97 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0002.npy
#          Saved in 24.51 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0003.npy
#          Saved in 24.24 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0004.npy
#          Saved in 25.00 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0005.npy
#          Saved in 24.06 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0006.npy
#          Saved in 23.42 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0007.npy
#          Saved in 24.88 sec
#       Saving fused, registered file of shape (30, 100, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0008.npy
#          Saved in 25.82 sec
#       Saving fused, registered file of shape (30, 86, 709, 671) to /mnt/md0/runs/s3d-Full-Demo-Coconut/registered_fused_data/fused_reg_data0009.npy
#          Saved in 22.55 sec
#          After full batch saving:Total Used: 269.457 GB, Virtual Available: 249.399 GB, Virtual Used: 253.797 GB, Swap Used: 015.661 GB
# CPU times: user 12min 37s, sys: 2min 31s, total: 15min 8s
# Wall time: 7min 49s

# %%
mov_full = job.get_registered_movie('registered_fused_data','f')
im_full = mov_full.mean(axis=1).compute()

# %%
# find crop values that minimize dark zones - check planes 0 and 15 in the following cell to 
# make sure you're not cutting out parts of the brain
crop = ((0,18), (100,500), (100, 500))

# %%
f,ax,__  = tfu.show_tif(im_full[0,crop[1][0]:crop[1][1], crop[2][0]:crop[2][1]])
# tfu.show_tif(im_full[15,crop[1][0]:crop[1][1], crop[2][0]:crop[2][1]])
ax.axis('off')
# Out:
# (-0.5, 399.5, 399.5, -0.5)

# %%
job.logfile
# Out:
# '/mnt/md0/runs/s3d-Full-Demo-Coconut/log.txt'

# %%
from datetime import datetime

# %%
mem_log_lines = []
with open(job.logfile, 'r') as logf:
    lines = logf.readlines()
    for line in lines:
        if line.find("Virtual Available") > -1:
#             print(line)
            mem_log_lines.append(line)

timestamps = []
used_mem = []
used_swp = []
used_vrt = []
avail_vrt = []
for line in mem_log_lines:
    tstamp = datetime.strptime(line[1:20], '%Y-%m-%d %H:%M:%S')
    timestamps.append(tstamp)
    
    
    tag = 'Total Used: '
    num_len = 7
    num_idx = line.find(tag) + len(tag)
    num_str = line[num_idx:num_idx + 7]
    num_float = float(num_str)
    used_mem.append(num_float)
    
    tag = 'Swap Used: '
    num_idx = line.find(tag) + len(tag)
    num_str = line[num_idx:num_idx + 7]
    num_float = float(num_str)
    used_swp.append(num_float)
    
    tag = 'Virtual Used: '
    num_idx = line.find(tag) + len(tag)
    num_str = line[num_idx:num_idx + 7]
    num_float = float(num_str)
    used_vrt.append(num_float)
    
    tag = 'Virtual Available: '
    num_idx = line.find(tag) + len(tag)
    num_str = line[num_idx:num_idx + 7]
    num_float = float(num_str)
    avail_vrt.append(num_float)

# %%
timestamps, used_mem, used_swp, used_vrt, avail_vrt, descriptors = job.get_logged_mem_usage()

# %%
job.plot_memory_usage()
# Out:
# (<Figure size 800x800 with 2 Axes>,
#  array([<Axes: ylabel='Memory usage (GB)'>,
#         <Axes: xlabel='Timestamp', ylabel='Change in memory usage (GB)'>],
#        dtype=object))
