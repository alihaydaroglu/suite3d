# %%
# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path
import numpy as n
from matplotlib import pyplot as plt
import napari

# path to wherever the s2p-lbm repository is cloned on your computer
os.chdir(os.path.dirname(os.path.abspath("")))

# set to "false" to run code without messages intended for developers
os.environ["SUITE3D_DEVELOPER"] = "true"

from suite3d.job import Job
from suite3d import ui
from suite3d import io
from suite3d import tiff_utils as tfu

# %% [markdown]
# ## Filepaths
#
# Here, tiffs are in:
#
# `D:\W2_DATA\wsnyder\2025_03_06\raw`
#
# Results are saved in
#
# `D:\W2_DATA\wsnyder\2025_03_06\results`

# %%
fpath = Path(r"D:\W2_DATA\wsnyder\2025_03_06")
job_path = fpath.joinpath("results")
tif_path = fpath.joinpath("raw")
tifs = io.get_tif_paths(tif_path)
tifs[:4]
# Out:
# ['D:\\W2_DATA\\wsnyder\\2025_03_06\\raw\\DotLv6-3145992-100um-17p07hz-32power_00001.tif',
#  'D:\\W2_DATA\\wsnyder\\2025_03_06\\raw\\DotLv6-3145992-100um-17p07hz-32power_00002.tif',
#  'D:\\W2_DATA\\wsnyder\\2025_03_06\\raw\\DotLv6-3145992-100um-17p07hz-32power_00003.tif',
#  'D:\\W2_DATA\\wsnyder\\2025_03_06\\raw\\DotLv6-3145992-100um-17p07hz-32power_00004.tif']

# %%
# Set the mandatory parameters
params = {
    # volume rate
    'fs': io.get_vol_rate(tifs[0]),
    'cavity_size': 1,
    'planes' : n.arange(14),
    'n_ch_tif' : 14,
    'max_reg_xy_reference': 140,
    'tau' : 1.3,
    'lbm' : True,
    'fuse_strips' : True,
    'subtract_crosstalk' : False,
    '3d_reg': True,
    'gpu_reg': True,
    'voxel_size_um': (17, 2, 2),
    'intensity_thresh' : 0.1,
    'block_size': [128, 128],
}

# %%
# create new
# job = Job(job_path, 'v1', create=True, overwrite=True, verbosity = 3, tifs=tifs, params=params)

# or load
job = Job(job_path, 'v1', create=False, overwrite=False, verbosity = 1)
# Out:
#    Found and loaded params from D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\params.npy

# %%
job.params['n_init_files'] = 1
job.params["fuse_shift_override"] = None
job.params['init_n_frames'] = None
job.params['override_crosstalk'] = None
job.params['voxel_size_um'] = (17, 2, 2)
job.params['n_proc_corr'] = 12
job.params['gpu_reg_batchsize'] = 10
job.params["max_rigid_shift_pix"] = 150
job.params["3d_reg"] = True
job.params["gpu_reg"] = True

# %%
# %%time
# This step only uses `n_init_files` files, so the  runtime will stay the same even with larger recordings
# soon this will also be gpu-ified to be faster!
job.run_init_pass()
# Out:
#    Saved a copy of params at D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\summary
#    Updated main params file
# Launching initial pass
# Saving summary to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\summary\summary.npy
#    Loading init tifs with 14 channels
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00004.tif
# c:\Users\RBO\repos\suite3d\suite3d\init_pass.py:86: UserWarning: Check work. This is a big change. Before, all the parameters were passed directly with a params.get('name', default) call.Now, they are inherited from job.params (because job is an attribute of the jobio object.)
#   todo(
# c:\Users\RBO\repos\suite3d\suite3d\io\s3dio.py:221: UserWarning: Add explanation of how lbm tiffs are organized to the docstring.
#   todo("Add explanation of how lbm tiffs are organized to the docstring.")
# c:\Users\RBO\repos\suite3d\suite3d\io\s3dio.py:238: UserWarning: Removed the **mp_args argument from load_and_stitch_full_tif_mp, should we add it back?
#   todo(
# c:\Users\RBO\repos\suite3d\suite3d\io\lbmio.py:30: UserWarning: imread from tifffile has an overhead of ~20-30 seconds before it actually reads the file? Can we speed this up?
#   todo(
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00004.tif'> asarray failed to reshape (1792, 912, 224) to (6000, 14, 912, 224)
#     Loaded file into shared memory in 0.55 sec
#     Workers completed in 1.18 sec
#     Total time: 1.73 sec
#    Loaded 1 files, total 0.67 GB
#    Loaded movie with 128 frames and shape 14, 449, 448
# c:\Users\RBO\repos\suite3d\suite3d\io\s3dio.py:64: UserWarning: This function is not implemented yet. Please implement it before using it!
#   todo("This function is not implemented yet. Please implement it before using it!")
#       Enforcing positivity in mean image
# c:\Users\RBO\repos\suite3d\suite3d\io\s3dio.py:272: UserWarning: Check if this assumption is correct, that the roi_start_pix values don't depend on which tif we use.
#   todo(
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00001.tif'> asarray failed to reshape (126, 912, 224) to (6000, 14, 912, 224)
#    No crosstalk estimation or subtraction
# [{'uid': 'E08EFBAE60699568', 'center': array([-6.35515873,  2.48809521]), 'sizeXY': array([ 7.3442623 , 14.68852459]), 'pixXY': array([145, 448])}, {'uid': '60A0E5C7B3BAA077', 'center': array([0.98910356, 2.48809521]), 'sizeXY': array([ 7.3442623 , 14.68852459]), 'pixXY': array([224, 448])}]
# [  0 224]
# [  0 224]
#    Estimating fusing shifts
#    Using best fuse shift of 20
#    Using 3d registration
#    Computing plane alignment shifts
#    Applying plane alignment shifts
#    Launching 3D GPU reference image calculation
#       Seeding reference image with most active frames
#       Completed iter 1 out of 8 in  1.84s using  31/128 frames
#       Completed iter 2 out of 8 in  1.57s using  43/128 frames
#       Completed iter 3 out of 8 in  1.61s using  55/128 frames
#       Completed iter 4 out of 8 in  1.66s using  67/128 frames
#       Completed iter 5 out of 8 in  1.70s using  78/128 frames
#       Completed iter 6 out of 8 in  1.75s using  90/128 frames
#       Completed iter 7 out of 8 in  1.84s using  102/128 frames
#       Completed iter 8 out of 8 in  1.37s using  114/128 frames
#       Used 114 frames to make the reference image
#    Saved init mov to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\summary\init_mov.npy
#    Saving summary to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\summary\summary.npy
#    Initial pass complete. See D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\summary for details
# CPU times: total: 32.2 s
# Wall time: 22.2 s

# %% [markdown]
# ## Registration
# First, we do registration over time of the  xy-drift caused by brain movement. This is similar to Suite2P registratrion, it does rigid registration followed by non-rigid registration. This is accelerated on the GPU. Suite2P registration parameters can be changed, see `default_params.py` for a list of all parameters related to registration. After you have registered, you can load the registered fused movie into memory and take a look at the mean image. I suggest cropping the dark edges if you have any as shown in the cells below.
#
# If you run out of gpu memory, try reducing the `gpu_reg_batchsize` parameter. I have a A4500 with 20GB memory which works well with a batchsize of 10.

# %%
job.register_gpu()
# Out:
#       Found dir D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data
#       Updating self.dirs tag registered_fused_data
#    Not clipping frames for registration
# Will analyze 7 tifs in 7 batches
#    Enforcing positivity
#    Launching IO thread
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00001.tif'> asarray failed to reshape (126, 912, 224) to (6000, 14, 912, 224)
#          Memory at batch 0.  Total Used: 044.467 GB, Virtual Available: 087.655 GB, Virtual Used: 040.158 GB, Swap Used: 004.309 GB
# Loading Batch 0 of 6
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00001.tif
#     Loaded file into shared memory in 0.05 sec
#     Workers completed in 0.98 sec
#     Total time: 1.03 sec
#    Loaded 1 files, total 0.05 GB
#    Batch 0 IO thread joined
#          Memory after IO thread joinTotal Used: 044.463 GB, Virtual Available: 087.659 GB, Virtual Used: 040.154 GB, Swap Used: 004.309 GB
#          Memory after movie copied from threadTotal Used: 044.511 GB, Virtual Available: 087.612 GB, Virtual Used: 040.202 GB, Swap Used: 004.309 GB
#          Memory after thread memory clearedTotal Used: 044.464 GB, Virtual Available: 087.659 GB, Virtual Used: 040.155 GB, Swap Used: 004.309 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 044.464 GB, Virtual Available: 087.659 GB, Virtual Used: 040.155 GB, Swap Used: 004.309 GB
#       Loaded batch of size (14, 9, 449, 448)
#          Sending frames 0-9 to GPU for rigid registration
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00002.tif
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00002.tif'> asarray failed to reshape (1806, 912, 224) to (6000, 14, 912, 224)
#          Registered batch in 0.08 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.47 sec
#     Loaded file into shared memory in 0.61 sec
#          Computed non-rigid shifts in 0.84 sec
#          Transferred shifted mov of shape (9, 14, 569, 439) to CPU in 0.00 sec
#          Allocated array of shape (14, 9, 569, 439) to store CPU movie
#          After array alloc:  Total Used: 046.959 GB, Virtual Available: 085.164 GB, Virtual Used: 042.650 GB, Swap Used: 004.309 GB
#          Non rigid transformed (on CPU) in 0.40 sec
#          After GPU Batch:    Total Used: 047.497 GB, Virtual Available: 084.626 GB, Virtual Used: 043.188 GB, Swap Used: 004.309 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 047.553 GB, Virtual Available: 084.570 GB, Virtual Used: 043.244 GB, Swap Used: 004.309 GB
#       Saving fused, registered file of shape (14, 9, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0000.npy
#          Saved in 0.09 sec
#          After full batch saving:Total Used: 047.699 GB, Virtual Available: 084.424 GB, Virtual Used: 043.390 GB, Swap Used: 004.309 GB
#          Memory at batch 1.  Total Used: 047.717 GB, Virtual Available: 084.406 GB, Virtual Used: 043.408 GB, Swap Used: 004.309 GB
# Loading Batch 1 of 6
#     Workers completed in 1.30 sec
#     Total time: 1.90 sec
#    Loaded 1 files, total 0.68 GB
#    Batch 1 IO thread joined
#          Memory after IO thread joinTotal Used: 046.047 GB, Virtual Available: 086.076 GB, Virtual Used: 041.737 GB, Swap Used: 004.309 GB
#          Memory after movie copied from threadTotal Used: 046.678 GB, Virtual Available: 085.445 GB, Virtual Used: 042.369 GB, Swap Used: 004.309 GB
#          Memory after thread memory clearedTotal Used: 046.039 GB, Virtual Available: 086.084 GB, Virtual Used: 041.730 GB, Swap Used: 004.309 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 046.007 GB, Virtual Available: 086.116 GB, Virtual Used: 041.698 GB, Swap Used: 004.309 GB
#       Loaded batch of size (14, 129, 449, 448)
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00003.tif
#          Sending frames 0-10 to GPU for rigid registration
#          Registered batch in 0.07 sec
#          Shifted batch in 0.16 sec
#          Freeing all blocks
#          Completed rigid registration in 0.37 sec
#          Computed non-rigid shifts in 0.53 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Allocated array of shape (14, 129, 569, 439) to store CPU movie
#          After array alloc:  Total Used: 046.733 GB, Virtual Available: 085.390 GB, Virtual Used: 042.424 GB, Swap Used: 004.309 GB
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00003.tif'> asarray failed to reshape (1792, 912, 224) to (6000, 14, 912, 224)
#          Non rigid transformed (on CPU) in 0.32 sec
#          After GPU Batch:    Total Used: 047.404 GB, Virtual Available: 084.719 GB, Virtual Used: 043.095 GB, Swap Used: 004.309 GB
#          Sending frames 10-20 to GPU for rigid registration
#     Loaded file into shared memory in 0.95 sec
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.20 sec
#          Computed non-rigid shifts in 0.38 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.41 sec
#          After GPU Batch:    Total Used: 048.475 GB, Virtual Available: 083.648 GB, Virtual Used: 044.166 GB, Swap Used: 004.309 GB
#          Sending frames 20-30 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.29 sec
#          Computed non-rigid shifts in 0.56 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#     Workers completed in 1.37 sec
#     Total time: 2.33 sec
#          Non rigid transformed (on CPU) in 0.38 sec
#          After GPU Batch:    Total Used: 048.033 GB, Virtual Available: 084.090 GB, Virtual Used: 043.724 GB, Swap Used: 004.309 GB
#          Sending frames 30-40 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.17 sec
#          Computed non-rigid shifts in 0.36 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#    Loaded 1 files, total 0.67 GB
#          Non rigid transformed (on CPU) in 0.48 sec
#          After GPU Batch:    Total Used: 047.200 GB, Virtual Available: 084.923 GB, Virtual Used: 042.891 GB, Swap Used: 004.309 GB
#          Sending frames 40-50 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 047.339 GB, Virtual Available: 084.784 GB, Virtual Used: 043.030 GB, Swap Used: 004.309 GB
#          Sending frames 50-60 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 047.497 GB, Virtual Available: 084.626 GB, Virtual Used: 043.188 GB, Swap Used: 004.309 GB
#          Sending frames 60-70 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.26 sec
#          After GPU Batch:    Total Used: 047.628 GB, Virtual Available: 084.495 GB, Virtual Used: 043.318 GB, Swap Used: 004.309 GB
#          Sending frames 70-80 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.17 sec
#          Computed non-rigid shifts in 0.31 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.24 sec
#          After GPU Batch:    Total Used: 047.808 GB, Virtual Available: 084.315 GB, Virtual Used: 043.499 GB, Swap Used: 004.309 GB
#          Sending frames 80-90 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 047.877 GB, Virtual Available: 084.245 GB, Virtual Used: 043.568 GB, Swap Used: 004.309 GB
#          Sending frames 90-100 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 048.013 GB, Virtual Available: 084.109 GB, Virtual Used: 043.704 GB, Swap Used: 004.309 GB
#          Sending frames 100-110 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 048.128 GB, Virtual Available: 083.995 GB, Virtual Used: 043.819 GB, Swap Used: 004.309 GB
#          Sending frames 110-120 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.14 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 049.273 GB, Virtual Available: 082.850 GB, Virtual Used: 044.964 GB, Swap Used: 004.309 GB
#          Sending frames 120-129 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.14 sec
#          Computed non-rigid shifts in 0.26 sec
#          Transferred shifted mov of shape (9, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 048.777 GB, Virtual Available: 083.346 GB, Virtual Used: 044.468 GB, Swap Used: 004.309 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 048.681 GB, Virtual Available: 083.442 GB, Virtual Used: 044.372 GB, Swap Used: 004.309 GB
#       Saving fused, registered file of shape (14, 100, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0001.npy
#          Saved in 0.97 sec
#       Saving fused, registered file of shape (14, 29, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0002.npy
#          Saved in 0.30 sec
#          After full batch saving:Total Used: 048.843 GB, Virtual Available: 083.280 GB, Virtual Used: 044.533 GB, Swap Used: 004.309 GB
#          Memory at batch 2.  Total Used: 048.860 GB, Virtual Available: 083.263 GB, Virtual Used: 044.551 GB, Swap Used: 004.309 GB
# Loading Batch 2 of 6
#    Batch 2 IO thread joined
#          Memory after IO thread joinTotal Used: 048.875 GB, Virtual Available: 083.247 GB, Virtual Used: 044.566 GB, Swap Used: 004.309 GB
#          Memory after movie copied from threadTotal Used: 049.306 GB, Virtual Available: 082.816 GB, Virtual Used: 044.997 GB, Swap Used: 004.309 GB
#          Memory after thread memory clearedTotal Used: 049.118 GB, Virtual Available: 083.005 GB, Virtual Used: 044.809 GB, Swap Used: 004.309 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 049.146 GB, Virtual Available: 082.976 GB, Virtual Used: 044.837 GB, Swap Used: 004.309 GB
#       Loaded batch of size (14, 128, 449, 448)
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00004.tif
#          Sending frames 0-10 to GPU for rigid registration
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00004.tif'> asarray failed to reshape (1792, 912, 224) to (6000, 14, 912, 224)
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Allocated array of shape (14, 128, 569, 439) to store CPU movie
#          After array alloc:  Total Used: 048.517 GB, Virtual Available: 083.606 GB, Virtual Used: 044.208 GB, Swap Used: 004.309 GB
#          Non rigid transformed (on CPU) in 0.23 sec
#          After GPU Batch:    Total Used: 049.096 GB, Virtual Available: 083.027 GB, Virtual Used: 044.787 GB, Swap Used: 004.309 GB
#          Sending frames 10-20 to GPU for rigid registration
#     Loaded file into shared memory in 0.67 sec
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.20 sec
#          Computed non-rigid shifts in 0.37 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 050.027 GB, Virtual Available: 082.096 GB, Virtual Used: 045.718 GB, Swap Used: 004.309 GB
#          Sending frames 20-30 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.45 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#     Workers completed in 1.42 sec
#     Total time: 2.09 sec
#          Non rigid transformed (on CPU) in 0.39 sec
#          After GPU Batch:    Total Used: 049.401 GB, Virtual Available: 082.722 GB, Virtual Used: 045.092 GB, Swap Used: 004.309 GB
#          Sending frames 30-40 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.17 sec
#          Computed non-rigid shifts in 0.31 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.33 sec
#          After GPU Batch:    Total Used: 049.002 GB, Virtual Available: 083.121 GB, Virtual Used: 044.692 GB, Swap Used: 004.309 GB
#          Sending frames 40-50 to GPU for rigid registration
#    Loaded 1 files, total 0.67 GB
#          Registered batch in 0.02 sec
#          Shifted batch in 0.11 sec
#          Freeing all blocks
#          Completed rigid registration in 0.27 sec
#          Computed non-rigid shifts in 0.42 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.011 GB, Virtual Available: 083.112 GB, Virtual Used: 044.702 GB, Swap Used: 004.309 GB
#          Sending frames 50-60 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.29 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.26 sec
#          After GPU Batch:    Total Used: 049.176 GB, Virtual Available: 082.947 GB, Virtual Used: 044.867 GB, Swap Used: 004.309 GB
#          Sending frames 60-70 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.24 sec
#          After GPU Batch:    Total Used: 049.320 GB, Virtual Available: 082.803 GB, Virtual Used: 045.011 GB, Swap Used: 004.309 GB
#          Sending frames 70-80 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.27 sec
#          After GPU Batch:    Total Used: 049.486 GB, Virtual Available: 082.636 GB, Virtual Used: 045.177 GB, Swap Used: 004.309 GB
#          Sending frames 80-90 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.07 sec
#          Freeing all blocks
#          Completed rigid registration in 0.17 sec
#          Computed non-rigid shifts in 0.31 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.634 GB, Virtual Available: 082.489 GB, Virtual Used: 045.325 GB, Swap Used: 004.309 GB
#          Sending frames 90-100 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.855 GB, Virtual Available: 082.268 GB, Virtual Used: 045.546 GB, Swap Used: 004.309 GB
#          Sending frames 100-110 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.986 GB, Virtual Available: 082.136 GB, Virtual Used: 045.677 GB, Swap Used: 004.309 GB
#          Sending frames 110-120 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.17 sec
#          Computed non-rigid shifts in 0.31 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.23 sec
#          After GPU Batch:    Total Used: 049.957 GB, Virtual Available: 082.166 GB, Virtual Used: 045.647 GB, Swap Used: 004.309 GB
#          Sending frames 120-128 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.14 sec
#          Computed non-rigid shifts in 0.26 sec
#          Transferred shifted mov of shape (8, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.19 sec
#          After GPU Batch:    Total Used: 050.075 GB, Virtual Available: 082.048 GB, Virtual Used: 045.766 GB, Swap Used: 004.309 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 050.076 GB, Virtual Available: 082.046 GB, Virtual Used: 045.767 GB, Swap Used: 004.309 GB
#       Saving fused, registered file of shape (14, 100, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0003.npy
#          Saved in 0.97 sec
#       Saving fused, registered file of shape (14, 28, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0004.npy
#          Saved in 0.29 sec
#          After full batch saving:Total Used: 048.557 GB, Virtual Available: 083.566 GB, Virtual Used: 044.248 GB, Swap Used: 004.309 GB
#          Memory at batch 3.  Total Used: 048.557 GB, Virtual Available: 083.565 GB, Virtual Used: 044.248 GB, Swap Used: 004.309 GB
# Loading Batch 3 of 6
#    Batch 3 IO thread joined
#          Memory after IO thread joinTotal Used: 048.558 GB, Virtual Available: 083.565 GB, Virtual Used: 044.249 GB, Swap Used: 004.309 GB
#          Memory after movie copied from threadTotal Used: 048.572 GB, Virtual Available: 083.551 GB, Virtual Used: 044.263 GB, Swap Used: 004.309 GB
#          Memory after thread memory clearedTotal Used: 047.901 GB, Virtual Available: 084.222 GB, Virtual Used: 043.592 GB, Swap Used: 004.309 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 047.901 GB, Virtual Available: 084.221 GB, Virtual Used: 043.592 GB, Swap Used: 004.309 GB
#       Loaded batch of size (14, 128, 449, 448)
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00005.tif
#          Sending frames 0-10 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.16 sec
#          Freeing all blocks
#          Completed rigid registration in 0.28 sec
#          Computed non-rigid shifts in 0.42 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Allocated array of shape (14, 128, 569, 439) to store CPU movie
#          After array alloc:  Total Used: 047.881 GB, Virtual Available: 084.242 GB, Virtual Used: 043.572 GB, Swap Used: 004.309 GB
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00005.tif'> asarray failed to reshape (1806, 912, 224) to (6000, 14, 912, 224)
#          Non rigid transformed (on CPU) in 0.23 sec
#          After GPU Batch:    Total Used: 048.369 GB, Virtual Available: 083.754 GB, Virtual Used: 044.060 GB, Swap Used: 004.309 GB
#          Sending frames 10-20 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.17 sec
#          Computed non-rigid shifts in 0.31 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#     Loaded file into shared memory in 1.07 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 049.562 GB, Virtual Available: 082.561 GB, Virtual Used: 045.253 GB, Swap Used: 004.309 GB
#          Sending frames 20-30 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.39 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.29 sec
#          After GPU Batch:    Total Used: 050.423 GB, Virtual Available: 081.700 GB, Virtual Used: 046.113 GB, Swap Used: 004.309 GB
#          Sending frames 30-40 to GPU for rigid registration
#          Registered batch in 0.04 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.31 sec
#     Workers completed in 1.41 sec
#     Total time: 2.48 sec
#          Computed non-rigid shifts in 0.56 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.25 sec
#          After GPU Batch:    Total Used: 049.925 GB, Virtual Available: 082.198 GB, Virtual Used: 045.616 GB, Swap Used: 004.309 GB
#          Sending frames 40-50 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.18 sec
#          Computed non-rigid shifts in 0.34 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#    Loaded 1 files, total 0.68 GB
#          Non rigid transformed (on CPU) in 0.32 sec
#          After GPU Batch:    Total Used: 050.087 GB, Virtual Available: 082.035 GB, Virtual Used: 045.778 GB, Swap Used: 004.309 GB
#          Sending frames 50-60 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 049.151 GB, Virtual Available: 082.972 GB, Virtual Used: 044.842 GB, Swap Used: 004.309 GB
#          Sending frames 60-70 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.26 sec
#          After GPU Batch:    Total Used: 049.301 GB, Virtual Available: 082.821 GB, Virtual Used: 044.992 GB, Swap Used: 004.309 GB
#          Sending frames 70-80 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.20 sec
#          Computed non-rigid shifts in 0.34 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 049.473 GB, Virtual Available: 082.650 GB, Virtual Used: 045.164 GB, Swap Used: 004.309 GB
#          Sending frames 80-90 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 049.586 GB, Virtual Available: 082.537 GB, Virtual Used: 045.277 GB, Swap Used: 004.309 GB
#          Sending frames 90-100 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 050.905 GB, Virtual Available: 081.217 GB, Virtual Used: 046.596 GB, Swap Used: 004.309 GB
#          Sending frames 100-110 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.896 GB, Virtual Available: 082.227 GB, Virtual Used: 045.587 GB, Swap Used: 004.309 GB
#          Sending frames 110-120 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.31 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.930 GB, Virtual Available: 082.193 GB, Virtual Used: 045.621 GB, Swap Used: 004.309 GB
#          Sending frames 120-128 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (8, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 050.074 GB, Virtual Available: 082.049 GB, Virtual Used: 045.765 GB, Swap Used: 004.309 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 050.074 GB, Virtual Available: 082.049 GB, Virtual Used: 045.765 GB, Swap Used: 004.309 GB
#       Saving fused, registered file of shape (14, 100, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0005.npy
#          Saved in 0.98 sec
#       Saving fused, registered file of shape (14, 28, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0006.npy
#          Saved in 0.27 sec
#          After full batch saving:Total Used: 048.503 GB, Virtual Available: 083.619 GB, Virtual Used: 044.194 GB, Swap Used: 004.309 GB
#          Memory at batch 4.  Total Used: 048.517 GB, Virtual Available: 083.605 GB, Virtual Used: 044.208 GB, Swap Used: 004.309 GB
# Loading Batch 4 of 6
#    Batch 4 IO thread joined
#          Memory after IO thread joinTotal Used: 048.525 GB, Virtual Available: 083.597 GB, Virtual Used: 044.216 GB, Swap Used: 004.309 GB
#          Memory after movie copied from threadTotal Used: 048.490 GB, Virtual Available: 083.633 GB, Virtual Used: 044.180 GB, Swap Used: 004.309 GB
#          Memory after thread memory clearedTotal Used: 047.822 GB, Virtual Available: 084.300 GB, Virtual Used: 043.513 GB, Swap Used: 004.309 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 047.829 GB, Virtual Available: 084.294 GB, Virtual Used: 043.520 GB, Swap Used: 004.309 GB
#       Loaded batch of size (14, 129, 449, 448)
#          Sending frames 0-10 to GPU for rigid registration
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00006.tif
#          Registered batch in 0.01 sec
#          Shifted batch in 0.17 sec
#          Freeing all blocks
#          Completed rigid registration in 0.30 sec
#          Computed non-rigid shifts in 0.49 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Allocated array of shape (14, 129, 569, 439) to store CPU movie
#          After array alloc:  Total Used: 048.278 GB, Virtual Available: 083.845 GB, Virtual Used: 043.969 GB, Swap Used: 004.309 GB
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00006.tif'> asarray failed to reshape (1806, 912, 224) to (6000, 14, 912, 224)
#          Non rigid transformed (on CPU) in 0.23 sec
#          After GPU Batch:    Total Used: 048.733 GB, Virtual Available: 083.390 GB, Virtual Used: 044.424 GB, Swap Used: 004.309 GB
#          Sending frames 10-20 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.18 sec
#     Loaded file into shared memory in 1.05 sec
#          Computed non-rigid shifts in 0.32 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 049.965 GB, Virtual Available: 082.158 GB, Virtual Used: 045.656 GB, Swap Used: 004.309 GB
#          Sending frames 20-30 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.20 sec
#          Computed non-rigid shifts in 0.37 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 050.962 GB, Virtual Available: 081.160 GB, Virtual Used: 046.653 GB, Swap Used: 004.309 GB
#          Sending frames 30-40 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#     Workers completed in 1.41 sec
#     Total time: 2.46 sec
#          Completed rigid registration in 0.37 sec
#          Computed non-rigid shifts in 0.52 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.25 sec
#          After GPU Batch:    Total Used: 050.224 GB, Virtual Available: 081.899 GB, Virtual Used: 045.915 GB, Swap Used: 004.309 GB
#          Sending frames 40-50 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.20 sec
#          Computed non-rigid shifts in 0.39 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#    Loaded 1 files, total 0.68 GB
#          Non rigid transformed (on CPU) in 0.27 sec
#          After GPU Batch:    Total Used: 049.267 GB, Virtual Available: 082.856 GB, Virtual Used: 044.958 GB, Swap Used: 004.309 GB
#          Sending frames 50-60 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.25 sec
#          After GPU Batch:    Total Used: 049.352 GB, Virtual Available: 082.771 GB, Virtual Used: 045.043 GB, Swap Used: 004.309 GB
#          Sending frames 60-70 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.490 GB, Virtual Available: 082.633 GB, Virtual Used: 045.181 GB, Swap Used: 004.309 GB
#          Sending frames 70-80 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.29 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.622 GB, Virtual Available: 082.501 GB, Virtual Used: 045.313 GB, Swap Used: 004.309 GB
#          Sending frames 80-90 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.07 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 049.746 GB, Virtual Available: 082.377 GB, Virtual Used: 045.437 GB, Swap Used: 004.309 GB
#          Sending frames 90-100 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.33 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 049.876 GB, Virtual Available: 082.247 GB, Virtual Used: 045.567 GB, Swap Used: 004.309 GB
#          Sending frames 100-110 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.14 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 050.017 GB, Virtual Available: 082.106 GB, Virtual Used: 045.708 GB, Swap Used: 004.309 GB
#          Sending frames 110-120 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.17 sec
#          Computed non-rigid shifts in 0.31 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.20 sec
#          After GPU Batch:    Total Used: 050.133 GB, Virtual Available: 081.990 GB, Virtual Used: 045.824 GB, Swap Used: 004.309 GB
#          Sending frames 120-129 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.14 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (9, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.19 sec
#          After GPU Batch:    Total Used: 050.199 GB, Virtual Available: 081.924 GB, Virtual Used: 045.889 GB, Swap Used: 004.309 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 050.199 GB, Virtual Available: 081.924 GB, Virtual Used: 045.890 GB, Swap Used: 004.309 GB
#       Saving fused, registered file of shape (14, 100, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0007.npy
#          Saved in 0.99 sec
#       Saving fused, registered file of shape (14, 29, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0008.npy
#          Saved in 0.28 sec
#          After full batch saving:Total Used: 048.596 GB, Virtual Available: 083.527 GB, Virtual Used: 044.287 GB, Swap Used: 004.309 GB
#          Memory at batch 5.  Total Used: 048.609 GB, Virtual Available: 083.513 GB, Virtual Used: 044.300 GB, Swap Used: 004.309 GB
# Loading Batch 5 of 6
#    Batch 5 IO thread joined
#          Memory after IO thread joinTotal Used: 048.627 GB, Virtual Available: 083.496 GB, Virtual Used: 044.318 GB, Swap Used: 004.309 GB
#          Memory after movie copied from threadTotal Used: 048.561 GB, Virtual Available: 083.562 GB, Virtual Used: 044.251 GB, Swap Used: 004.309 GB
#          Memory after thread memory clearedTotal Used: 047.886 GB, Virtual Available: 084.237 GB, Virtual Used: 043.577 GB, Swap Used: 004.309 GB
#    Launching IO thread for next batch
#          After IO thread launch:Total Used: 047.886 GB, Virtual Available: 084.237 GB, Virtual Used: 043.577 GB, Swap Used: 004.309 GB
#       Loading D:\W2_DATA\wsnyder\2025_03_06\raw\DotLv6-3145992-100um-17p07hz-32power_00007.tif
#       Loaded batch of size (14, 129, 449, 448)
#          Sending frames 0-10 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.13 sec
#          Freeing all blocks
#          Completed rigid registration in 0.25 sec
#          Computed non-rigid shifts in 0.42 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Allocated array of shape (14, 129, 569, 439) to store CPU movie
#          After array alloc:  Total Used: 047.896 GB, Virtual Available: 084.227 GB, Virtual Used: 043.587 GB, Swap Used: 004.309 GB
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 048.392 GB, Virtual Available: 083.731 GB, Virtual Used: 044.083 GB, Swap Used: 004.309 GB
#          Sending frames 10-20 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.32 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
# <tifffile.TiffFile 'DotLv6-3145992-1…power_00007.tif'> asarray failed to reshape (3514, 912, 224) to (6000, 14, 912, 224)
#          Non rigid transformed (on CPU) in 0.21 sec
#          After GPU Batch:    Total Used: 049.623 GB, Virtual Available: 082.499 GB, Virtual Used: 045.314 GB, Swap Used: 004.309 GB
#          Sending frames 20-30 to GPU for rigid registration
#          Registered batch in 0.05 sec
#          Shifted batch in 0.02 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.23 sec
#          After GPU Batch:    Total Used: 052.105 GB, Virtual Available: 080.018 GB, Virtual Used: 047.796 GB, Swap Used: 004.309 GB
#          Sending frames 30-40 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#     Loaded file into shared memory in 2.04 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.33 sec
#          After GPU Batch:    Total Used: 051.616 GB, Virtual Available: 080.507 GB, Virtual Used: 047.307 GB, Swap Used: 004.309 GB
#          Sending frames 40-50 to GPU for rigid registration
#          Registered batch in 0.04 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.19 sec
#          Computed non-rigid shifts in 0.34 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.33 sec
#          After GPU Batch:    Total Used: 052.962 GB, Virtual Available: 079.161 GB, Virtual Used: 048.652 GB, Swap Used: 004.309 GB
#          Sending frames 50-60 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.43 sec
#          Computed non-rigid shifts in 0.70 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#     Workers completed in 1.85 sec
#     Total time: 3.89 sec
#          Non rigid transformed (on CPU) in 0.26 sec
#          After GPU Batch:    Total Used: 052.658 GB, Virtual Available: 079.465 GB, Virtual Used: 048.348 GB, Swap Used: 004.309 GB
#          Sending frames 60-70 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.32 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.24 sec
#          After GPU Batch:    Total Used: 052.350 GB, Virtual Available: 079.773 GB, Virtual Used: 048.041 GB, Swap Used: 004.309 GB
#          Sending frames 70-80 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.29 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.39 sec
#          After GPU Batch:    Total Used: 051.089 GB, Virtual Available: 081.034 GB, Virtual Used: 046.780 GB, Swap Used: 004.309 GB
#          Sending frames 80-90 to GPU for rigid registration
#    Loaded 1 files, total 1.32 GB
#          Registered batch in 0.01 sec
#          Shifted batch in 0.16 sec
#          Freeing all blocks
#          Completed rigid registration in 0.27 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.22 sec
#          After GPU Batch:    Total Used: 050.321 GB, Virtual Available: 081.802 GB, Virtual Used: 046.012 GB, Swap Used: 004.309 GB
#          Sending frames 90-100 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.30 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.27 sec
#          After GPU Batch:    Total Used: 050.437 GB, Virtual Available: 081.685 GB, Virtual Used: 046.128 GB, Swap Used: 004.309 GB
#          Sending frames 100-110 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.16 sec
#          Computed non-rigid shifts in 0.28 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.24 sec
#          After GPU Batch:    Total Used: 050.567 GB, Virtual Available: 081.555 GB, Virtual Used: 046.258 GB, Swap Used: 004.309 GB
#          Sending frames 110-120 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.15 sec
#          Computed non-rigid shifts in 0.29 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.24 sec
#          After GPU Batch:    Total Used: 050.691 GB, Virtual Available: 081.432 GB, Virtual Used: 046.382 GB, Swap Used: 004.309 GB
#          Sending frames 120-129 to GPU for rigid registration
#          Registered batch in 0.00 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.14 sec
#          Computed non-rigid shifts in 0.26 sec
#          Transferred shifted mov of shape (9, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.19 sec
#          After GPU Batch:    Total Used: 050.835 GB, Virtual Available: 081.288 GB, Virtual Used: 046.526 GB, Swap Used: 004.309 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 050.847 GB, Virtual Available: 081.276 GB, Virtual Used: 046.538 GB, Swap Used: 004.309 GB
#       Saving fused, registered file of shape (14, 100, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0009.npy
#          Saved in 0.94 sec
#       Saving fused, registered file of shape (14, 29, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0010.npy
#          Saved in 0.28 sec
#          After full batch saving:Total Used: 049.151 GB, Virtual Available: 082.972 GB, Virtual Used: 044.842 GB, Swap Used: 004.309 GB
#          Memory at batch 6.  Total Used: 049.151 GB, Virtual Available: 082.972 GB, Virtual Used: 044.842 GB, Swap Used: 004.309 GB
# Loading Batch 6 of 6
#    Batch 6 IO thread joined
#          Memory after IO thread joinTotal Used: 049.151 GB, Virtual Available: 082.972 GB, Virtual Used: 044.842 GB, Swap Used: 004.309 GB
#          Memory after movie copied from threadTotal Used: 049.797 GB, Virtual Available: 082.326 GB, Virtual Used: 045.488 GB, Swap Used: 004.309 GB
#          Memory after thread memory clearedTotal Used: 048.501 GB, Virtual Available: 083.622 GB, Virtual Used: 044.192 GB, Swap Used: 004.309 GB
#       Loaded batch of size (14, 251, 449, 448)
#          Sending frames 0-10 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.12 sec
#          Freeing all blocks
#          Completed rigid registration in 0.26 sec
#          Computed non-rigid shifts in 0.39 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Allocated array of shape (14, 251, 569, 439) to store CPU movie
#          After array alloc:  Total Used: 048.489 GB, Virtual Available: 083.634 GB, Virtual Used: 044.179 GB, Swap Used: 004.309 GB
#          Non rigid transformed (on CPU) in 0.24 sec
#          After GPU Batch:    Total Used: 048.686 GB, Virtual Available: 083.437 GB, Virtual Used: 044.377 GB, Swap Used: 004.309 GB
#          Sending frames 10-20 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 048.698 GB, Virtual Available: 083.425 GB, Virtual Used: 044.389 GB, Swap Used: 004.309 GB
#          Sending frames 20-30 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.39 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 048.854 GB, Virtual Available: 083.269 GB, Virtual Used: 044.545 GB, Swap Used: 004.309 GB
#          Sending frames 30-40 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 049.518 GB, Virtual Available: 082.605 GB, Virtual Used: 045.209 GB, Swap Used: 004.309 GB
#          Sending frames 40-50 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 049.122 GB, Virtual Available: 083.001 GB, Virtual Used: 044.812 GB, Swap Used: 004.309 GB
#          Sending frames 50-60 to GPU for rigid registration
#          Registered batch in 0.06 sec
#          Shifted batch in 0.02 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.40 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 049.269 GB, Virtual Available: 082.854 GB, Virtual Used: 044.960 GB, Swap Used: 004.309 GB
#          Sending frames 60-70 to GPU for rigid registration
#          Registered batch in 0.04 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.24 sec
#          Computed non-rigid shifts in 0.42 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 049.395 GB, Virtual Available: 082.727 GB, Virtual Used: 045.086 GB, Swap Used: 004.309 GB
#          Sending frames 70-80 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.42 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.29 sec
#          After GPU Batch:    Total Used: 049.529 GB, Virtual Available: 082.594 GB, Virtual Used: 045.220 GB, Swap Used: 004.309 GB
#          Sending frames 80-90 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.24 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.34 sec
#          After GPU Batch:    Total Used: 049.655 GB, Virtual Available: 082.468 GB, Virtual Used: 045.346 GB, Swap Used: 004.309 GB
#          Sending frames 90-100 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.07 sec
#          Freeing all blocks
#          Completed rigid registration in 0.24 sec
#          Computed non-rigid shifts in 0.42 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 049.766 GB, Virtual Available: 082.357 GB, Virtual Used: 045.457 GB, Swap Used: 004.309 GB
#          Sending frames 100-110 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.24 sec
#          Computed non-rigid shifts in 0.42 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 049.885 GB, Virtual Available: 082.237 GB, Virtual Used: 045.576 GB, Swap Used: 004.309 GB
#          Sending frames 110-120 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.29 sec
#          After GPU Batch:    Total Used: 050.016 GB, Virtual Available: 082.107 GB, Virtual Used: 045.707 GB, Swap Used: 004.309 GB
#          Sending frames 120-130 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 050.078 GB, Virtual Available: 082.045 GB, Virtual Used: 045.769 GB, Swap Used: 004.309 GB
#          Sending frames 130-140 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.07 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 050.251 GB, Virtual Available: 081.872 GB, Virtual Used: 045.942 GB, Swap Used: 004.309 GB
#          Sending frames 140-150 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 050.386 GB, Virtual Available: 081.736 GB, Virtual Used: 046.077 GB, Swap Used: 004.309 GB
#          Sending frames 150-160 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.40 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 050.560 GB, Virtual Available: 081.563 GB, Virtual Used: 046.251 GB, Swap Used: 004.309 GB
#          Sending frames 160-170 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.40 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 050.725 GB, Virtual Available: 081.398 GB, Virtual Used: 046.416 GB, Swap Used: 004.309 GB
#          Sending frames 170-180 to GPU for rigid registration
#          Registered batch in 0.01 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 050.849 GB, Virtual Available: 081.273 GB, Virtual Used: 046.540 GB, Swap Used: 004.309 GB
#          Sending frames 180-190 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.39 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 050.984 GB, Virtual Available: 081.139 GB, Virtual Used: 046.675 GB, Swap Used: 004.309 GB
#          Sending frames 190-200 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 052.739 GB, Virtual Available: 079.384 GB, Virtual Used: 048.430 GB, Swap Used: 004.309 GB
#          Sending frames 200-210 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.04 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.39 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.26 sec
#          After GPU Batch:    Total Used: 051.240 GB, Virtual Available: 080.883 GB, Virtual Used: 046.931 GB, Swap Used: 004.309 GB
#          Sending frames 210-220 to GPU for rigid registration
#          Registered batch in 0.02 sec
#          Shifted batch in 0.06 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.40 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.28 sec
#          After GPU Batch:    Total Used: 053.250 GB, Virtual Available: 078.873 GB, Virtual Used: 048.941 GB, Swap Used: 004.309 GB
#          Sending frames 220-230 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.05 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 051.498 GB, Virtual Available: 080.625 GB, Virtual Used: 047.188 GB, Swap Used: 004.309 GB
#          Sending frames 230-240 to GPU for rigid registration
#          Registered batch in 0.05 sec
#          Shifted batch in 0.03 sec
#          Freeing all blocks
#          Completed rigid registration in 0.22 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.31 sec
#          After GPU Batch:    Total Used: 051.584 GB, Virtual Available: 080.538 GB, Virtual Used: 047.275 GB, Swap Used: 004.309 GB
#          Sending frames 240-250 to GPU for rigid registration
#          Registered batch in 0.06 sec
#          Shifted batch in 0.02 sec
#          Freeing all blocks
#          Completed rigid registration in 0.23 sec
#          Computed non-rigid shifts in 0.41 sec
#          Transferred shifted mov of shape (10, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.30 sec
#          After GPU Batch:    Total Used: 051.750 GB, Virtual Available: 080.372 GB, Virtual Used: 047.441 GB, Swap Used: 004.309 GB
#          Sending frames 250-251 to GPU for rigid registration
#          Registered batch in 0.03 sec
#          Shifted batch in 0.00 sec
#          Freeing all blocks
#          Completed rigid registration in 0.09 sec
#          Computed non-rigid shifts in 0.23 sec
#          Transferred shifted mov of shape (1, 14, 569, 439) to CPU in 0.00 sec
#          Non rigid transformed (on CPU) in 0.09 sec
#          After GPU Batch:    Total Used: 051.656 GB, Virtual Available: 080.467 GB, Virtual Used: 047.346 GB, Swap Used: 004.309 GB
#       Concatenating movie
#          Concat in 0.00 sec
#          After all GPU Batches:Total Used: 051.686 GB, Virtual Available: 080.437 GB, Virtual Used: 047.377 GB, Swap Used: 004.309 GB
#       Saving fused, registered file of shape (14, 100, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0011.npy
#          Saved in 1.64 sec
#       Saving fused, registered file of shape (14, 100, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0012.npy
#          Saved in 1.66 sec
#       Saving fused, registered file of shape (14, 51, 569, 439) to D:\W2_DATA\wsnyder\2025_03_06\results\s3d-v1\registered_fused_data\fused_reg_data0013.npy
#          Saved in 0.81 sec
#          After full batch saving:Total Used: 049.993 GB, Virtual Available: 082.130 GB, Virtual Used: 045.684 GB, Swap Used: 004.309 GB

# %%
crop = ((0,14), (130,445), (10, 440))

mov_full = job.get_registered_movie('registered_fused_data','f').transpose([1, 0, 2, 3])[:, :, crop[1][0]:crop[1][1], crop[2][0]:crop[2][1]]
mov_full.shape
# im_full = mov_full.mean(axis=1).compute()
# Out:
# (903, 14, 315, 429)

# %%
def get_files(base_dir, str_contains="", max_depth=1, sort_ascending=True) -> list | Path:
    """
    Recursively searches for files with a specific extension up to a given depth and stores their paths in a pickle file.

    Parameters
    ----------
    base_dir : str or Path
        The base directory to start searching.
    str_contains : str
        The string that the file names should contain.
    max_depth : int
        The maximum depth of subdirectories to search.
    sort_ascending : bool, optional
        Whether to sort files alphanumerically by filename, with digits in ascending order (i.e. 1, 2, 10) (default is False).

    Returns
    -------
    list
        A list of full file paths matching the given extension.
    """
    import re
    base_path = Path(base_dir).expanduser().resolve()
    if not base_path.exists():
        raise FileNotFoundError(f"Directory '{base_path}' does not exist.")
    if not base_path.is_dir():
        raise NotADirectoryError(f"'{base_path}' is not a directory.")
    if max_depth == 0:
        print("Max-depth of 0 is not allowed. Setting to 1.")
        max_depth = 1

    base_depth = len(base_path.parts)
    pattern = f'*{str_contains}*' if str_contains else '*'

    files = [
        file for file in base_path.rglob(pattern)
        if len(file.parts) - base_depth <= max_depth
           and file.is_file()
    ]

    if sort_ascending:
        def numerical_sort_key(path):
            match = re.search(r'\d+', path.name)
            return int(match.group()) if match else float('inf')

        files.sort(key=numerical_sort_key)

    return [str(file) for file in files]

# Put behavior somewhere, point this path to it
frames_path = r"D:\W2_DATA\wsnyder\2025_03_06\frames"
frames = get_files(frames_path, 'tif', 1)

frames[:4]  # make sure we are getting the frames, and theyre ordered

# %%
stack = []
for path in frames:
    img = tifffile.imread(path)
    stack.append(img)

# remove first 2 frames
stack = np.stack(stack)[2:]
stack.shape

# %%
import napari

viewer = napari.Viewer(ndisplay=3)

# functional imaging stack (TZYX)
viewer.add_image(
    mov_full,
    name='Imaging Data',
    scale=(1, 8, 1, 1),  # account for the anisotropy (2um XY : 16um Z ratio)
    rendering='mip',
)

# Add the behavior stack (T, Y, X, 3) but with RGB baked into last dim
# this squeeze into (T, 1, Y, X, 3) is to avoid it being interpreted as a 3D volume
stack_expanded = stack[:, None, :, :, :]

# Add with rgb=True — napari will treat the 2nd dim as singleton
viewer.add_image(
    stack_expanded,
    name='Behavior',
    rgb=True,
    colormap=None,
    blending='translucent',
)

viewer.layers['Behavior'].depiction = 'volume'
viewer.layers['Behavior'].visible = True
viewer.dims.ndisplay = 3  # global 3D mode, but Behavior stays 2D
viewer.dims.current_step = (0,) * viewer.dims.ndim

# %% [markdown]
# # Below is unfinished

# %% [markdown]
# ## Calculating the correlation map
#
# The correlation map is the most important part of the cell detection process. It spatially and temporally filters the denoised movie, normalizes it, thresholds it, and accumulates it over time to create a volume where cells should be made more visible and neuropil is removed.
#
# **You should tune some of these parameters for your data**, each described below. To enable easy tuning, there is a **parameter sweep interface** that can try many combinations for a subset of the movie quickly, and visualize the results (you will find this below).
#
# Correlation map improves the more frames you have!

# %%
# spatial filter sizes for neuropil subtraction, and cell detection
# npil_filt is a low_pass filter that attempts to remove any features larger than the filter size (neuropil!)
# conv_filt_xy is a high_pass filter that amplifies any features that are smaller than ~2x the filter size (cells!)
# these values worked well for me with ~4um xy pixel spacing and ~15 um z pixel spacing, for detecting mouse somata
# When you change resolution, or if you're trying to detect smaller things, you will need to adjust these values
# because the units here are _pixels_, not microns!
job.params['cell_filt_type'] = 'gaussian'
job.params['npil_filt_type'] = 'gaussian'
job.params['cell_filt_xy_um'] = 5.0
job.params['npil_filt_xy_um'] = 3.0
job.params['cell_filt_z_um'] = 18
job.params['npil_filt_z']=  2.5

# normalization exponent, should be around 1.
# If you find blood vessels or the background being too bright in the correlation map, reduce it to ~0.7-0.8!
job.params['sdnorm_exp']= 0.8

# threshold applied to the normalized, filtered movie before it is accumulated into the correlation map
# if you increase it, the background will become darker (which is good!), however at some point you will
# start excluding dimmer cells (which is bad!)
job.params['intensity_thresh']= 1

## Compute parameters
# number of frames to compute at one iteration
# (any value above ~100-200 shouldn't affect results,
# decrease if you have RAM issues or if SVD reconstruction gets stuck on "Sending all blocks to dask to compute")
job.params['t_batch_size'] = 300
# number of processors to use when calculating the correlation map
job.params['n_proc_corr'] = 20
# number of frames per smaller batch within the batch, should be ~t_batch_size / n_proc_corr, but above ~5
job.params['mproc_batchsize'] = 5

import multiprocessing
num_cores = multiprocessing.cpu_count()
assert job.params['n_proc_corr'] < num_cores, f"Your computer has {num_cores} but job.params['n_proc_corr'] is set to {job.params['n_proc_corr']}"

# %%
# crop = ((0,13), (130,445), (10, 440))
im_full = job.get_registered_movie()
cropped = im_full[:, :, crop[1][0]:crop[1][1], crop[2][0]:crop[2][1]]
cropped.shape
# Out:
# (14, 5632, 315, 430)

# %%
# ~1.5*fs
job.params["detection_timebin"] = 25
job.calculate_corr_map()
# Out:
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\corrmap
#       Updating self.dirs tag corrmap
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\mov_sub
#       Updating self.dirs tag mov_sub
#    Saved a copy of params at D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\corrmap
#    Updated main params file
#    Computing correlation map of movie with 5632 frames, volume shape: 14, 561, 439
#       Running batch 1 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.441 sec
#          Timer batch_setup completed in 0.025 sec
#          Timer batch_edgecrop completed in 0.004 sec
#          Timer accum_meanmeax completed in 0.048 sec
#          Timer batch_rolling_mean_filt completed in 0.025 sec
#          Timer batch_accum_sdmov completed in 0.101 sec
#          Timer batch_norm_sdmov completed in 0.030 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.142 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.432 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.044 sec
#          Timer dtu_cleanup completed in 0.041 sec
#          Timer batch_filt_reduce completed in 4.661 sec
#          Timer batch_accum_vmap completed in 0.014 sec
#          Timer batch completed in 4.956 sec
#          Timer save completed in 0.140 sec
#       Running batch 2 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.633 sec
#          Timer batch_setup completed in 0.028 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.053 sec
#          Timer batch_rolling_mean_filt completed in 0.031 sec
#          Timer batch_accum_sdmov completed in 0.108 sec
#          Timer batch_norm_sdmov completed in 0.029 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.141 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.353 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.043 sec
#          Timer dtu_cleanup completed in 0.041 sec
#          Timer batch_filt_reduce completed in 4.580 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 5.004 sec
#          Timer save completed in 0.141 sec
#       Running batch 3 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.856 sec
#          Timer batch_setup completed in 0.028 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.054 sec
#          Timer batch_rolling_mean_filt completed in 0.033 sec
#          Timer batch_accum_sdmov completed in 0.120 sec
#          Timer batch_norm_sdmov completed in 0.033 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.147 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.408 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.046 sec
#          Timer dtu_cleanup completed in 0.042 sec
#          Timer batch_filt_reduce completed in 4.646 sec
#          Timer batch_accum_vmap completed in 0.013 sec
#          Timer batch completed in 5.109 sec
#          Timer save completed in 0.162 sec
#       Running batch 4 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 2.146 sec
#          Timer batch_setup completed in 0.025 sec
#          Timer batch_edgecrop completed in 0.004 sec
#          Timer accum_meanmeax completed in 0.043 sec
#          Timer batch_rolling_mean_filt completed in 0.025 sec
#          Timer batch_accum_sdmov completed in 0.102 sec
#          Timer batch_norm_sdmov completed in 0.031 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.143 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.372 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.044 sec
#          Timer dtu_cleanup completed in 0.040 sec
#          Timer batch_filt_reduce completed in 4.600 sec
#          Timer batch_accum_vmap completed in 0.011 sec
#          Timer batch completed in 4.994 sec
#          Timer save completed in 0.137 sec
#       Running batch 5 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.002 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 2.032 sec
#          Timer batch_setup completed in 0.027 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.045 sec
#          Timer batch_rolling_mean_filt completed in 0.025 sec
#          Timer batch_accum_sdmov completed in 0.093 sec
#          Timer batch_norm_sdmov completed in 0.027 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.131 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.365 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.044 sec
#          Timer dtu_cleanup completed in 0.041 sec
#          Timer batch_filt_reduce completed in 4.583 sec
#          Timer batch_accum_vmap completed in 0.013 sec
#          Timer batch completed in 4.985 sec
#          Timer save completed in 0.149 sec
#       Running batch 6 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.919 sec
#          Timer batch_setup completed in 0.031 sec
#          Timer batch_edgecrop completed in 0.004 sec
#          Timer accum_meanmeax completed in 0.044 sec
#          Timer batch_rolling_mean_filt completed in 0.031 sec
#          Timer batch_accum_sdmov completed in 0.116 sec
#          Timer batch_norm_sdmov completed in 0.032 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.146 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.453 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.045 sec
#          Timer dtu_cleanup completed in 0.043 sec
#          Timer batch_filt_reduce completed in 4.691 sec
#          Timer batch_accum_vmap completed in 0.013 sec
#          Timer batch completed in 5.117 sec
#          Timer save completed in 0.146 sec
#       Running batch 7 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 2.129 sec
#          Timer batch_setup completed in 0.030 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.045 sec
#          Timer batch_rolling_mean_filt completed in 0.032 sec
#          Timer batch_accum_sdmov completed in 0.124 sec
#          Timer batch_norm_sdmov completed in 0.033 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.148 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.425 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.046 sec
#          Timer dtu_cleanup completed in 0.045 sec
#          Timer batch_filt_reduce completed in 4.666 sec
#          Timer batch_accum_vmap completed in 0.014 sec
#          Timer batch completed in 5.109 sec
#          Timer save completed in 0.141 sec
#       Running batch 8 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 2.010 sec
#          Timer batch_setup completed in 0.026 sec
#          Timer batch_edgecrop completed in 0.006 sec
#          Timer accum_meanmeax completed in 0.049 sec
#          Timer batch_rolling_mean_filt completed in 0.028 sec
#          Timer batch_accum_sdmov completed in 0.117 sec
#          Timer batch_norm_sdmov completed in 0.030 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.143 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.371 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.045 sec
#          Timer dtu_cleanup completed in 0.040 sec
#          Timer batch_filt_reduce completed in 4.602 sec
#          Timer batch_accum_vmap completed in 0.011 sec
#          Timer batch completed in 5.028 sec
#          Timer save completed in 0.200 sec
#       Running batch 9 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.909 sec
#          Timer batch_setup completed in 0.025 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.034 sec
#          Timer batch_rolling_mean_filt completed in 0.021 sec
#          Timer batch_accum_sdmov completed in 0.095 sec
#          Timer batch_norm_sdmov completed in 0.029 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.142 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.304 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.043 sec
#          Timer dtu_cleanup completed in 0.039 sec
#          Timer batch_filt_reduce completed in 4.528 sec
#          Timer batch_accum_vmap completed in 0.011 sec
#          Timer batch completed in 4.877 sec
#          Timer save completed in 0.197 sec
#       Running batch 10 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 2.161 sec
#          Timer batch_setup completed in 0.026 sec
#          Timer batch_edgecrop completed in 0.004 sec
#          Timer accum_meanmeax completed in 0.037 sec
#          Timer batch_rolling_mean_filt completed in 0.023 sec
#          Timer batch_accum_sdmov completed in 0.100 sec
#          Timer batch_norm_sdmov completed in 0.030 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.145 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.407 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.045 sec
#          Timer dtu_cleanup completed in 0.041 sec
#          Timer batch_filt_reduce completed in 4.640 sec
#          Timer batch_accum_vmap completed in 0.011 sec
#          Timer batch completed in 5.000 sec
#          Timer save completed in 0.147 sec
#       Running batch 11 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.744 sec
#          Timer batch_setup completed in 0.024 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.043 sec
#          Timer batch_rolling_mean_filt completed in 0.030 sec
#          Timer batch_accum_sdmov completed in 0.122 sec
#          Timer batch_norm_sdmov completed in 0.033 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.143 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.350 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.042 sec
#          Timer dtu_cleanup completed in 0.039 sec
#          Timer batch_filt_reduce completed in 4.576 sec
#          Timer batch_accum_vmap completed in 0.011 sec
#          Timer batch completed in 4.981 sec
#          Timer save completed in 0.141 sec
#       Running batch 12 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.931 sec
#          Timer batch_setup completed in 0.032 sec
#          Timer batch_edgecrop completed in 0.006 sec
#          Timer accum_meanmeax completed in 0.048 sec
#          Timer batch_rolling_mean_filt completed in 0.033 sec
#          Timer batch_accum_sdmov completed in 0.118 sec
#          Timer batch_norm_sdmov completed in 0.030 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.145 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.334 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.045 sec
#          Timer dtu_cleanup completed in 0.038 sec
#          Timer batch_filt_reduce completed in 4.565 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 4.974 sec
#          Timer save completed in 0.142 sec
#       Running batch 13 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.881 sec
#          Timer batch_setup completed in 0.031 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.046 sec
#          Timer batch_rolling_mean_filt completed in 0.028 sec
#          Timer batch_accum_sdmov completed in 0.116 sec
#          Timer batch_norm_sdmov completed in 0.033 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.146 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.310 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.044 sec
#          Timer dtu_cleanup completed in 0.040 sec
#          Timer batch_filt_reduce completed in 4.543 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 4.967 sec
#          Timer save completed in 0.157 sec
#       Running batch 14 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.994 sec
#          Timer batch_setup completed in 0.028 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.038 sec
#          Timer batch_rolling_mean_filt completed in 0.029 sec
#          Timer batch_accum_sdmov completed in 0.120 sec
#          Timer batch_norm_sdmov completed in 0.032 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.146 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.277 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.043 sec
#          Timer dtu_cleanup completed in 0.042 sec
#          Timer batch_filt_reduce completed in 4.510 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 4.922 sec
#          Timer save completed in 0.142 sec
#       Running batch 15 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.002 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.866 sec
#          Timer batch_setup completed in 0.025 sec
#          Timer batch_edgecrop completed in 0.004 sec
#          Timer accum_meanmeax completed in 0.036 sec
#          Timer batch_rolling_mean_filt completed in 0.025 sec
#          Timer batch_accum_sdmov completed in 0.104 sec
#          Timer batch_norm_sdmov completed in 0.028 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.142 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.284 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.047 sec
#          Timer dtu_cleanup completed in 0.042 sec
#          Timer batch_filt_reduce completed in 4.516 sec
#          Timer batch_accum_vmap completed in 0.014 sec
#          Timer batch completed in 4.925 sec
#          Timer save completed in 0.142 sec
#       Running batch 16 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.002 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.974 sec
#          Timer batch_setup completed in 0.029 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.039 sec
#          Timer batch_rolling_mean_filt completed in 0.026 sec
#          Timer batch_accum_sdmov completed in 0.125 sec
#          Timer batch_norm_sdmov completed in 0.031 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.146 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.340 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.044 sec
#          Timer dtu_cleanup completed in 0.038 sec
#          Timer batch_filt_reduce completed in 4.571 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 4.989 sec
#          Timer save completed in 0.143 sec
#       Running batch 17 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.783 sec
#          Timer batch_setup completed in 0.028 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.035 sec
#          Timer batch_rolling_mean_filt completed in 0.024 sec
#          Timer batch_accum_sdmov completed in 0.119 sec
#          Timer batch_norm_sdmov completed in 0.039 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.143 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.405 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.043 sec
#          Timer dtu_cleanup completed in 0.039 sec
#          Timer batch_filt_reduce completed in 4.633 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 5.039 sec
#          Timer save completed in 0.146 sec
#       Running batch 18 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.001 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 2.227 sec
#          Timer batch_setup completed in 0.027 sec
#          Timer batch_edgecrop completed in 0.005 sec
#          Timer accum_meanmeax completed in 0.040 sec
#          Timer batch_rolling_mean_filt completed in 0.035 sec
#          Timer batch_accum_sdmov completed in 0.113 sec
#          Timer batch_norm_sdmov completed in 0.031 sec
#          Loading movie of size (12, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.143 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.319 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.054 sec
#          Timer dtu_cleanup completed in 0.039 sec
#          Timer batch_filt_reduce completed in 4.557 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 4.970 sec
#          Timer save completed in 0.137 sec
#       Running batch 19 of 19
#       Binning with timebin of size 25
#          Timer batch_timebin completed in 0.002 sec
# C:\Users\RBO\AppData\Local\Temp\ipykernel_22232\123689994.py:3: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   job.calculate_corr_map()
#          Timer prep completed in 1.489 sec
#          Timer batch_setup completed in 0.021 sec
#          Timer batch_edgecrop completed in 0.004 sec
#          Timer accum_meanmeax completed in 0.031 sec
#          Timer batch_rolling_mean_filt completed in 0.018 sec
#          Timer batch_accum_sdmov completed in 0.080 sec
#          Timer batch_norm_sdmov completed in 0.026 sec
#          Loading movie of size (9, 14, 561, 439) into shared memory
#          Timer dtu_shmem completed in 0.107 sec
#          Subtracting neuropil and applying cell filters
#          Timer dtu_npsub_conv3d completed in 4.004 sec
#          Reducing filtered movie to compute correlation map
#          Timer dtu_vmap completed in 0.035 sec
#          Timer dtu_cleanup completed in 0.032 sec
#          Timer batch_filt_reduce completed in 4.182 sec
#          Timer batch_accum_vmap completed in 0.012 sec
#          Timer batch completed in 4.533 sec
#          Timer save completed in 0.143 sec
# array([[[1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         ...,
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05]],
#
#        [[1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         ...,
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05]],
#
#        [[1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         ...,
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05]],
#
#        ...,
#
#        [[1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         ...,
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05]],
#
#        [[1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         ...,
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05]],
#
#        [[1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         ...,
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05],
#         [1.e-05, 1.e-05, 1.e-05, ..., 1.e-05, 1.e-05, 1.e-05]]],
#       dtype=float32)

# %%
results = job.load_corr_map_results()
vmap = results['vmap']
mean_img = results['mean_img']

job.params["npil_filt_xy_um"], job.params["cell_filt_xy_um"], job.params["cell_filt_z_um"], job.params["npil_filt_type"], job.params["cell_filt_type"]
# Out:
# (3.0, 5.0, 18, 'gaussian', 'gaussian')

# %%
io.show_tif(vmap[9])
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x222888c7b50>)

# %%
# visualize the correlation map
# here you can identify the best "peak_thresh"
# play with the contrast limits of vmap until only cells are visible
# the lower contrast limit should be used as "peak_thresh"

# as you change the contrast limit for the vmap image, the "viewer status" in the bottom left will print the value for you

results = job.load_corr_map_results()
mean_img = results['mean_img']
vmap = results['vmap']

v = napari.Viewer(title="Identify peak_thresh!")
v_meanimg = v.add_image(mean_img, name='mean image')
v_vmap = v.add_image(vmap, name='vmap')

def print_contrast_limits(event):
    v.status = f"Current peak_thresh: {v_vmap._contrast_limits[0]:.2f}"
    return None

_ = v_vmap.events.connect(print_contrast_limits)

# %%
from suite3d import extension as ext
corr_map = job.load_corr_map_results()['vmap']
corr_map_thresh = ext.thresh_mask_corr_map(corr_map, thresh_window_size_pix = 51, corrmap_thresh_pct=55)
io.show_tif(corr_map_thresh[7], vminmax=(0.02,0.020001))
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x22294db59a0>)

# %%
job.params['max_pix'] = 250
job.params['percentile'] = 99.0         # default
job.params['max_iter'] = 10000          # maximum number of ROIs detected in given patch
job.params["extend_thresh"] = 0.5
job.params["peak_thresh"] = .4
job.params["activity_thresh"] = 20.0    # default
job.params["percentile"] = 99.5           # default

job.segment_rois(vmap = corr_map_thresh)
# Out:
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation
#       Updating self.dirs tag segmentation
#    Saved a copy of params at D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation
#    Updated main params file
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois
#       Updating self.dirs tag rois
#    Saving results to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation and D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois
# dict_keys(['max_img', 'mean_img', 'vmap', 'all_params'])
#    Detecting from patch 1 / 30
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0000
#          Loading 0.14 GB movie to memory, shape: (374, 14, 120, 120)
#          Loaded
#          Loading movie patch to shared memory
#          Loaded
#       Starting extraction with peak_thresh: 0.400 and Th2: 20.000
#       Iter 0000: peak is too small - ending extraction
#    Found 0 cells in 1 iterations
#    Saving cells to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0000\stats.npy
#    Saving iscell.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0000\iscell.npy
#    Detecting from patch 2 / 30
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0001
#          Loading 0.14 GB movie to memory, shape: (374, 14, 120, 120)
#          Loaded
#          Loading movie patch to shared memory
#          Loaded
#       Starting extraction with peak_thresh: 0.400 and Th2: 20.000
#       Iter 0000: peak is too small - ending extraction
#    Found 0 cells in 1 iterations
#    Saving cells to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0001\stats.npy
#    Saving iscell.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0001\iscell.npy
#    Detecting from patch 3 / 30
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0002
#          Loading 0.14 GB movie to memory, shape: (374, 14, 120, 120)
#          Loaded
#          Loading movie patch to shared memory
#          Loaded
#       Starting extraction with peak_thresh: 0.400 and Th2: 20.000
#          Iter 0000: running 01 ROIs in parallel
#          Iter 0001: running 01 ROIs in parallel
#          Iter 0002: running 01 ROIs in parallel
#          Iter 0003: running 01 ROIs in parallel
#          Iter 0004: running 01 ROIs in parallel
#          Iter 0005: running 01 ROIs in parallel
#          Iter 0006: running 01 ROIs in parallel
#          Iter 0007: running 01 ROIs in parallel
#          Iter 0008: running 01 ROIs in parallel
#          Iter 0009: running 01 ROIs in parallel
#          Iter 0010: running 01 ROIs in parallel
#          Iter 0011: running 01 ROIs in parallel
#          Iter 0012: running 01 ROIs in parallel
#          Iter 0013: running 01 ROIs in parallel
#          Iter 0014: running 01 ROIs in parallel
#          Iter 0015: running 01 ROIs in parallel
#          Iter 0016: running 01 ROIs in parallel
#          Iter 0017: running 01 ROIs in parallel
#          Iter 0018: running 01 ROIs in parallel
#          Iter 0019: running 01 ROIs in parallel
#          Iter 0020: running 01 ROIs in parallel
#          Iter 0021: running 01 ROIs in parallel
#          Iter 0022: running 01 ROIs in parallel
#          Iter 0023: running 01 ROIs in parallel
#          Iter 0024: running 01 ROIs in parallel
#          Iter 0025: running 01 ROIs in parallel
#          Iter 0026: running 01 ROIs in parallel
#          Iter 0027: running 01 ROIs in parallel
#          Iter 0028: running 01 ROIs in parallel
#          Iter 0029: running 01 ROIs in parallel
#          Iter 0030: running 01 ROIs in parallel
#          Iter 0031: running 01 ROIs in parallel
#          Iter 0032: running 01 ROIs in parallel
#          Iter 0033: running 01 ROIs in parallel
#          Iter 0034: running 01 ROIs in parallel
#          Iter 0035: running 01 ROIs in parallel
#          Iter 0036: running 01 ROIs in parallel
#          Iter 0037: running 01 ROIs in parallel
#          Iter 0038: running 01 ROIs in parallel
#          Iter 0039: running 01 ROIs in parallel
#          Iter 0040: running 01 ROIs in parallel
#          Iter 0041: running 01 ROIs in parallel
#          Iter 0042: running 01 ROIs in parallel
#          Iter 0043: running 01 ROIs in parallel
#          Iter 0044: running 01 ROIs in parallel
#          Iter 0045: running 01 ROIs in parallel
#          Iter 0046: running 01 ROIs in parallel
#          Iter 0047: running 01 ROIs in parallel
#          Iter 0048: running 01 ROIs in parallel
#          Iter 0049: running 01 ROIs in parallel
#          Iter 0050: running 01 ROIs in parallel
#          Iter 0051: running 01 ROIs in parallel
#          Iter 0052: running 01 ROIs in parallel
#          Iter 0053: running 01 ROIs in parallel
#          Iter 0054: running 01 ROIs in parallel
#          Iter 0055: running 01 ROIs in parallel
#          Iter 0056: running 01 ROIs in parallel
#          Iter 0057: running 01 ROIs in parallel
#          Iter 0058: running 01 ROIs in parallel
#          Iter 0059: running 01 ROIs in parallel
#          Iter 0060: running 01 ROIs in parallel
#          Iter 0061: running 01 ROIs in parallel
#          Iter 0062: running 01 ROIs in parallel
#          Iter 0063: running 01 ROIs in parallel
#          Iter 0064: running 01 ROIs in parallel
#          Iter 0065: running 01 ROIs in parallel
#          Iter 0066: running 01 ROIs in parallel
#          Iter 0067: running 01 ROIs in parallel
#          Iter 0068: running 01 ROIs in parallel
#          Iter 0069: running 01 ROIs in parallel
#          Iter 0070: running 01 ROIs in parallel
#          Iter 0071: running 01 ROIs in parallel
#          Iter 0072: running 01 ROIs in parallel
#          Iter 0073: running 01 ROIs in parallel
#          Iter 0074: running 01 ROIs in parallel
#          Iter 0075: running 01 ROIs in parallel
#          Iter 0076: running 01 ROIs in parallel
#          Iter 0077: running 01 ROIs in parallel
#          Iter 0078: running 01 ROIs in parallel
#          Iter 0079: running 01 ROIs in parallel
#          Iter 0080: running 01 ROIs in parallel
#          Iter 0081: running 01 ROIs in parallel
#          Iter 0082: running 01 ROIs in parallel
#          Iter 0083: running 01 ROIs in parallel
#          Iter 0084: running 01 ROIs in parallel
#          Iter 0085: running 01 ROIs in parallel
#          Iter 0086: running 01 ROIs in parallel
#          Iter 0087: running 01 ROIs in parallel
#          Iter 0088: running 01 ROIs in parallel
#          Iter 0089: running 01 ROIs in parallel
#          Iter 0090: running 01 ROIs in parallel
#          Iter 0091: running 01 ROIs in parallel
#          Iter 0092: running 01 ROIs in parallel
#          Iter 0093: running 01 ROIs in parallel
#          Iter 0094: running 01 ROIs in parallel
#          Iter 0095: running 01 ROIs in parallel
#          Iter 0096: running 01 ROIs in parallel
#          Iter 0097: running 01 ROIs in parallel
#          Iter 0098: running 01 ROIs in parallel
#          Iter 0099: running 01 ROIs in parallel
#          Iter 0100: running 01 ROIs in parallel
#          Iter 0101: running 01 ROIs in parallel
#          Iter 0102: running 01 ROIs in parallel
#          Iter 0103: running 01 ROIs in parallel
#          Iter 0104: running 01 ROIs in parallel
#          Iter 0105: running 01 ROIs in parallel
#          Iter 0106: running 01 ROIs in parallel
#          Iter 0107: running 01 ROIs in parallel
#          Iter 0108: running 01 ROIs in parallel
#          Iter 0109: running 01 ROIs in parallel
#          Iter 0110: running 01 ROIs in parallel
#          Iter 0111: running 01 ROIs in parallel
#          Iter 0112: running 01 ROIs in parallel
#          Iter 0113: running 01 ROIs in parallel
#          Iter 0114: running 01 ROIs in parallel
#          Iter 0115: running 01 ROIs in parallel
#          Iter 0116: running 01 ROIs in parallel
#          Iter 0117: running 01 ROIs in parallel
#          Iter 0118: running 01 ROIs in parallel
#          Iter 0119: running 01 ROIs in parallel
#          Iter 0120: running 01 ROIs in parallel
#          Iter 0121: running 01 ROIs in parallel
#          Iter 0122: running 01 ROIs in parallel
#          Iter 0123: running 01 ROIs in parallel
#          Iter 0124: running 01 ROIs in parallel
#          Iter 0125: running 01 ROIs in parallel
#          Iter 0126: running 01 ROIs in parallel
#          Iter 0127: running 01 ROIs in parallel
#          Iter 0128: running 01 ROIs in parallel
#          Iter 0129: running 01 ROIs in parallel
#          Iter 0130: running 01 ROIs in parallel
#          Iter 0131: running 01 ROIs in parallel
#          Iter 0132: running 01 ROIs in parallel
#          Iter 0133: running 01 ROIs in parallel
#          Iter 0134: running 01 ROIs in parallel
#          Iter 0135: running 01 ROIs in parallel
#          Iter 0136: running 01 ROIs in parallel
#          Iter 0137: running 01 ROIs in parallel
#          Iter 0138: running 01 ROIs in parallel
#          Iter 0139: running 01 ROIs in parallel
#          Iter 0140: running 01 ROIs in parallel
#          Iter 0141: running 01 ROIs in parallel
#          Iter 0142: running 01 ROIs in parallel
#          Iter 0143: running 01 ROIs in parallel
#          Iter 0144: running 01 ROIs in parallel
#          Iter 0145: running 01 ROIs in parallel
#          Iter 0146: running 01 ROIs in parallel
#          Iter 0147: running 01 ROIs in parallel
#          Iter 0148: running 01 ROIs in parallel
#          Iter 0149: running 01 ROIs in parallel
#          Iter 0150: running 01 ROIs in parallel
#          Iter 0151: running 01 ROIs in parallel
#          Iter 0152: running 01 ROIs in parallel
#          Iter 0153: running 01 ROIs in parallel
#          Iter 0154: running 01 ROIs in parallel
#          Iter 0155: running 01 ROIs in parallel
#          Iter 0156: running 01 ROIs in parallel
#          Iter 0157: running 01 ROIs in parallel
#          Iter 0158: running 01 ROIs in parallel
#          Iter 0159: running 01 ROIs in parallel
#          Iter 0160: running 01 ROIs in parallel
#          Iter 0161: running 01 ROIs in parallel
#          Iter 0162: running 01 ROIs in parallel
#          Iter 0163: running 01 ROIs in parallel
#          Iter 0164: running 01 ROIs in parallel
#          Iter 0165: running 01 ROIs in parallel
#          Iter 0166: running 01 ROIs in parallel
#          Iter 0167: running 01 ROIs in parallel
#          Iter 0168: running 01 ROIs in parallel
#          Iter 0169: running 01 ROIs in parallel
#          Iter 0170: running 01 ROIs in parallel
#          Iter 0171: running 01 ROIs in parallel
#          Iter 0172: running 01 ROIs in parallel
#          Iter 0173: running 01 ROIs in parallel
#          Iter 0174: running 01 ROIs in parallel
#          Iter 0175: running 01 ROIs in parallel
#          Iter 0176: running 01 ROIs in parallel
#          Iter 0177: running 01 ROIs in parallel
#          Iter 0178: running 01 ROIs in parallel
#          Iter 0179: running 01 ROIs in parallel
#          Iter 0180: running 01 ROIs in parallel
#          Iter 0181: running 01 ROIs in parallel
#          Iter 0182: running 01 ROIs in parallel
#          Iter 0183: running 01 ROIs in parallel
#          Iter 0184: running 01 ROIs in parallel
#          Iter 0185: running 01 ROIs in parallel
#          Iter 0186: running 01 ROIs in parallel
#          Iter 0187: running 01 ROIs in parallel
#          Iter 0188: running 01 ROIs in parallel
#          Iter 0189: running 01 ROIs in parallel
#          Iter 0190: running 01 ROIs in parallel
#          Iter 0191: running 01 ROIs in parallel
#          Iter 0192: running 01 ROIs in parallel
#          Iter 0193: running 01 ROIs in parallel
#          Iter 0194: running 01 ROIs in parallel
#          Iter 0195: running 01 ROIs in parallel
#          Iter 0196: running 01 ROIs in parallel
#          Iter 0197: running 01 ROIs in parallel
#          Iter 0198: running 01 ROIs in parallel
#          Iter 0199: running 01 ROIs in parallel
#          Iter 0200: running 01 ROIs in parallel
#          Iter 0201: running 01 ROIs in parallel
#          Iter 0202: running 01 ROIs in parallel
#          Iter 0203: running 01 ROIs in parallel
#          Iter 0204: running 01 ROIs in parallel
#          Iter 0205: running 01 ROIs in parallel
#          Iter 0206: running 01 ROIs in parallel
#          Iter 0207: running 01 ROIs in parallel
#          Iter 0208: running 01 ROIs in parallel
#          Iter 0209: running 01 ROIs in parallel
#          Iter 0210: running 01 ROIs in parallel
#          Iter 0211: running 01 ROIs in parallel
#          Iter 0212: running 01 ROIs in parallel
#          Iter 0213: running 01 ROIs in parallel
#          Iter 0214: running 01 ROIs in parallel
#          Iter 0215: running 01 ROIs in parallel
#          Iter 0216: running 01 ROIs in parallel
#          Iter 0217: running 01 ROIs in parallel
#          Iter 0218: running 01 ROIs in parallel
#          Iter 0219: running 01 ROIs in parallel
#          Iter 0220: running 01 ROIs in parallel
#          Iter 0221: running 01 ROIs in parallel
#          Iter 0222: running 01 ROIs in parallel
#          Iter 0223: running 01 ROIs in parallel
#          Iter 0224: running 01 ROIs in parallel
#          Iter 0225: running 01 ROIs in parallel
#          Iter 0226: running 01 ROIs in parallel
#          Iter 0227: running 01 ROIs in parallel
#          Iter 0228: running 01 ROIs in parallel
#          Iter 0229: running 01 ROIs in parallel
#          Iter 0230: running 01 ROIs in parallel
#          Iter 0231: running 01 ROIs in parallel
#          Iter 0232: running 01 ROIs in parallel
#          Iter 0233: running 01 ROIs in parallel
#          Iter 0234: running 01 ROIs in parallel
#          Iter 0235: running 01 ROIs in parallel
#          Iter 0236: running 01 ROIs in parallel
#          Iter 0237: running 01 ROIs in parallel
#          Iter 0238: running 01 ROIs in parallel
#          Iter 0239: running 01 ROIs in parallel
#          Iter 0240: running 01 ROIs in parallel
#          Iter 0241: running 01 ROIs in parallel
#          Iter 0242: running 01 ROIs in parallel
#          Iter 0243: running 01 ROIs in parallel
#          Iter 0244: running 01 ROIs in parallel
#          Iter 0245: running 01 ROIs in parallel
#          Iter 0246: running 01 ROIs in parallel
#          Iter 0247: running 01 ROIs in parallel
#          Iter 0248: running 01 ROIs in parallel
#          Iter 0249: running 01 ROIs in parallel
#          Iter 0250: running 01 ROIs in parallel
#          Iter 0251: running 01 ROIs in parallel
#          Iter 0252: running 01 ROIs in parallel
#          Iter 0253: running 01 ROIs in parallel
#          Iter 0254: running 01 ROIs in parallel
#          Iter 0255: running 01 ROIs in parallel
#          Iter 0256: running 01 ROIs in parallel
#          Iter 0257: running 01 ROIs in parallel
#          Iter 0258: running 01 ROIs in parallel
#          Iter 0259: running 01 ROIs in parallel
#          Iter 0260: running 01 ROIs in parallel
#          Iter 0261: running 01 ROIs in parallel
#          Iter 0262: running 01 ROIs in parallel
#          Iter 0263: running 01 ROIs in parallel
#          Iter 0264: running 01 ROIs in parallel
#          Iter 0265: running 01 ROIs in parallel
#          Iter 0266: running 01 ROIs in parallel
#          Iter 0267: running 01 ROIs in parallel
#          Iter 0268: running 01 ROIs in parallel
#          Iter 0269: running 01 ROIs in parallel
#          Iter 0270: running 01 ROIs in parallel
#          Iter 0271: running 01 ROIs in parallel
#          Iter 0272: running 01 ROIs in parallel
#          Iter 0273: running 01 ROIs in parallel
#          Iter 0274: running 01 ROIs in parallel
#          Iter 0275: running 01 ROIs in parallel
#          Iter 0276: running 01 ROIs in parallel
#          Iter 0277: running 01 ROIs in parallel
#          Iter 0278: running 01 ROIs in parallel
#          Iter 0279: running 01 ROIs in parallel
#          Iter 0280: running 01 ROIs in parallel
#          Iter 0281: running 01 ROIs in parallel
#          Iter 0282: running 01 ROIs in parallel
#          Iter 0283: running 01 ROIs in parallel
#          Iter 0284: running 01 ROIs in parallel
#          Iter 0285: running 01 ROIs in parallel
#          Iter 0286: running 01 ROIs in parallel
#          Iter 0287: running 01 ROIs in parallel
#          Iter 0288: running 01 ROIs in parallel
#          Iter 0289: running 01 ROIs in parallel
#          Iter 0290: running 01 ROIs in parallel
#          Iter 0291: running 01 ROIs in parallel
#          Iter 0292: running 01 ROIs in parallel
#          Iter 0293: running 01 ROIs in parallel
#          Iter 0294: running 01 ROIs in parallel
#          Iter 0295: running 01 ROIs in parallel
#          Iter 0296: running 01 ROIs in parallel
#          Iter 0297: running 01 ROIs in parallel
#          Iter 0298: running 01 ROIs in parallel
#          Iter 0299: running 01 ROIs in parallel
#          Iter 0300: running 01 ROIs in parallel
#          Iter 0301: running 01 ROIs in parallel
#          Iter 0302: running 01 ROIs in parallel
#          Iter 0303: running 01 ROIs in parallel
#          Iter 0304: running 01 ROIs in parallel
#          Iter 0305: running 01 ROIs in parallel
#          Iter 0306: running 01 ROIs in parallel
#          Iter 0307: running 01 ROIs in parallel
#          Iter 0308: running 01 ROIs in parallel
#          Iter 0309: running 01 ROIs in parallel
#          Iter 0310: running 01 ROIs in parallel
#          Iter 0311: running 01 ROIs in parallel
#          Iter 0312: running 01 ROIs in parallel
#          Iter 0313: running 01 ROIs in parallel
#          Iter 0314: running 01 ROIs in parallel
#          Iter 0315: running 01 ROIs in parallel
#          Iter 0316: running 01 ROIs in parallel
#          Iter 0317: running 01 ROIs in parallel
#          Iter 0318: running 01 ROIs in parallel
#          Iter 0319: running 01 ROIs in parallel
#          Iter 0320: running 01 ROIs in parallel
#          Iter 0321: running 01 ROIs in parallel
#          Iter 0322: running 01 ROIs in parallel
#          Iter 0323: running 01 ROIs in parallel
#          Iter 0324: running 01 ROIs in parallel
#          Iter 0325: running 01 ROIs in parallel
#          Iter 0326: running 01 ROIs in parallel
#          Iter 0327: running 01 ROIs in parallel
#          Iter 0328: running 01 ROIs in parallel
#          Iter 0329: running 01 ROIs in parallel
#          Iter 0330: running 01 ROIs in parallel
#          Iter 0331: running 01 ROIs in parallel
#          Iter 0332: running 01 ROIs in parallel
#          Iter 0333: running 01 ROIs in parallel
#          Iter 0334: running 01 ROIs in parallel
#          Iter 0335: running 01 ROIs in parallel
#          Iter 0336: running 01 ROIs in parallel
#          Iter 0337: running 01 ROIs in parallel
#          Iter 0338: running 01 ROIs in parallel
#          Iter 0339: running 01 ROIs in parallel
#          Iter 0340: running 01 ROIs in parallel
#          Iter 0341: running 01 ROIs in parallel
#          Iter 0342: running 01 ROIs in parallel
#          Iter 0343: running 01 ROIs in parallel
#          Iter 0344: running 01 ROIs in parallel
#          Iter 0345: running 01 ROIs in parallel
#          Iter 0346: running 01 ROIs in parallel
#          Iter 0347: running 01 ROIs in parallel
#          Iter 0348: running 01 ROIs in parallel
#          Iter 0349: running 01 ROIs in parallel
#          Iter 0350: running 01 ROIs in parallel
#          Iter 0351: running 01 ROIs in parallel
#          Iter 0352: running 01 ROIs in parallel
#          Iter 0353: running 01 ROIs in parallel
#          Iter 0354: running 01 ROIs in parallel
#          Iter 0355: running 01 ROIs in parallel
#          Iter 0356: running 01 ROIs in parallel
#          Iter 0357: running 01 ROIs in parallel
#          Iter 0358: running 01 ROIs in parallel
#          Iter 0359: running 01 ROIs in parallel
#          Iter 0360: running 01 ROIs in parallel
#          Iter 0361: running 01 ROIs in parallel
#          Iter 0362: running 01 ROIs in parallel
#          Iter 0363: running 01 ROIs in parallel
#          Iter 0364: running 01 ROIs in parallel
#          Iter 0365: running 01 ROIs in parallel
#          Iter 0366: running 01 ROIs in parallel
#          Iter 0367: running 01 ROIs in parallel
#          Iter 0368: running 01 ROIs in parallel
#          Iter 0369: running 01 ROIs in parallel
#          Iter 0370: running 01 ROIs in parallel
#          Iter 0371: running 01 ROIs in parallel
#          Iter 0372: running 01 ROIs in parallel
#          Iter 0373: running 01 ROIs in parallel
#          Iter 0374: running 01 ROIs in parallel
#          Iter 0375: running 01 ROIs in parallel
#          Iter 0376: running 01 ROIs in parallel
#          Iter 0377: running 01 ROIs in parallel
#          Iter 0378: running 01 ROIs in parallel
#          Iter 0379: running 01 ROIs in parallel
#          Iter 0380: running 01 ROIs in parallel
#          Iter 0381: running 01 ROIs in parallel
#          Iter 0382: running 01 ROIs in parallel
#          Iter 0383: running 01 ROIs in parallel
#          Iter 0384: running 01 ROIs in parallel
#          Iter 0385: running 01 ROIs in parallel
#          Iter 0386: running 01 ROIs in parallel
#          Iter 0387: running 01 ROIs in parallel
#          Iter 0388: running 01 ROIs in parallel
#          Iter 0389: running 01 ROIs in parallel
#          Iter 0390: running 01 ROIs in parallel
#          Iter 0391: running 01 ROIs in parallel
#          Iter 0392: running 01 ROIs in parallel
#          Iter 0393: running 01 ROIs in parallel
#          Iter 0394: running 01 ROIs in parallel
#          Iter 0395: running 01 ROIs in parallel
#          Iter 0396: running 01 ROIs in parallel
#          Iter 0397: running 01 ROIs in parallel
#          Iter 0398: running 01 ROIs in parallel
#          Iter 0399: running 01 ROIs in parallel
#          Iter 0400: running 01 ROIs in parallel
#          Iter 0401: running 01 ROIs in parallel
#          Iter 0402: running 01 ROIs in parallel
#          Iter 0403: running 01 ROIs in parallel
#          Iter 0404: running 01 ROIs in parallel
#          Iter 0405: running 01 ROIs in parallel
#          Iter 0406: running 01 ROIs in parallel
#          Iter 0407: running 01 ROIs in parallel
#          Iter 0408: running 01 ROIs in parallel
#          Iter 0409: running 01 ROIs in parallel
#          Iter 0410: running 01 ROIs in parallel
#          Iter 0411: running 01 ROIs in parallel
#          Iter 0412: running 01 ROIs in parallel
#          Iter 0413: running 01 ROIs in parallel
#          Iter 0414: running 01 ROIs in parallel
#          Iter 0415: running 01 ROIs in parallel
#          Iter 0416: running 01 ROIs in parallel
#          Iter 0417: running 01 ROIs in parallel
#          Iter 0418: running 01 ROIs in parallel
#          Iter 0419: running 01 ROIs in parallel
#          Iter 0420: running 01 ROIs in parallel
#          Iter 0421: running 01 ROIs in parallel
#          Iter 0422: running 01 ROIs in parallel
#          Iter 0423: running 01 ROIs in parallel
#          Iter 0424: running 01 ROIs in parallel
#          Iter 0425: running 01 ROIs in parallel
#          Iter 0426: running 01 ROIs in parallel
#          Iter 0427: running 01 ROIs in parallel
#          Iter 0428: running 01 ROIs in parallel
#          Iter 0429: running 01 ROIs in parallel
#          Iter 0430: running 01 ROIs in parallel
#          Iter 0431: running 01 ROIs in parallel
#          Iter 0432: running 01 ROIs in parallel
#          Iter 0433: running 01 ROIs in parallel
#          Iter 0434: running 01 ROIs in parallel
#          Iter 0435: running 01 ROIs in parallel
#          Iter 0436: running 01 ROIs in parallel
#          Iter 0437: running 01 ROIs in parallel
#          Iter 0438: running 01 ROIs in parallel
#          Iter 0439: running 01 ROIs in parallel
#          Iter 0440: running 01 ROIs in parallel
#          Iter 0441: running 01 ROIs in parallel
#          Iter 0442: running 01 ROIs in parallel
#          Iter 0443: running 01 ROIs in parallel
#          Iter 0444: running 01 ROIs in parallel
#          Iter 0445: running 01 ROIs in parallel
#          Iter 0446: running 01 ROIs in parallel
#          Iter 0447: running 01 ROIs in parallel
#          Iter 0448: running 01 ROIs in parallel
#          Iter 0449: running 01 ROIs in parallel
#          Iter 0450: running 01 ROIs in parallel
#          Iter 0451: running 01 ROIs in parallel
#          Iter 0452: running 01 ROIs in parallel
#          Iter 0453: running 01 ROIs in parallel
#          Iter 0454: running 01 ROIs in parallel
#          Iter 0455: running 01 ROIs in parallel
#          Iter 0456: running 01 ROIs in parallel
#          Iter 0457: running 01 ROIs in parallel
#          Iter 0458: running 01 ROIs in parallel
#          Iter 0459: running 01 ROIs in parallel
#          Iter 0460: running 01 ROIs in parallel
#          Iter 0461: running 01 ROIs in parallel
#          Iter 0462: running 01 ROIs in parallel
#          Iter 0463: running 01 ROIs in parallel
#          Iter 0464: running 01 ROIs in parallel
#          Iter 0465: running 01 ROIs in parallel
#          Iter 0466: running 01 ROIs in parallel
#          Iter 0467: running 01 ROIs in parallel
#          Iter 0468: running 01 ROIs in parallel
#          Iter 0469: running 01 ROIs in parallel
#          Iter 0470: running 01 ROIs in parallel
#          Iter 0471: running 01 ROIs in parallel
#          Iter 0472: running 01 ROIs in parallel
#          Iter 0473: running 01 ROIs in parallel
#          Iter 0474: running 01 ROIs in parallel
#          Iter 0475: running 01 ROIs in parallel
#          Iter 0476: running 01 ROIs in parallel
#          Iter 0477: running 01 ROIs in parallel
#          Iter 0478: running 01 ROIs in parallel
#          Iter 0479: running 01 ROIs in parallel
#          Iter 0480: running 01 ROIs in parallel
#          Iter 0481: running 01 ROIs in parallel
#          Iter 0482: running 01 ROIs in parallel
#          Iter 0483: running 01 ROIs in parallel
#          Iter 0484: running 01 ROIs in parallel
#          Iter 0485: running 01 ROIs in parallel
#          Iter 0486: running 01 ROIs in parallel
#          Iter 0487: running 01 ROIs in parallel
#          Iter 0488: running 01 ROIs in parallel
#          Iter 0489: running 01 ROIs in parallel
#          Iter 0490: running 01 ROIs in parallel
#          Iter 0491: running 01 ROIs in parallel
#          Iter 0492: running 01 ROIs in parallel
#          Iter 0493: running 01 ROIs in parallel
#          Iter 0494: running 01 ROIs in parallel
#          Iter 0495: running 01 ROIs in parallel
#          Iter 0496: running 01 ROIs in parallel
#          Iter 0497: running 01 ROIs in parallel
#          Iter 0498: running 01 ROIs in parallel
#          Iter 0499: running 01 ROIs in parallel
#          Iter 0500: running 01 ROIs in parallel
#          Iter 0501: running 01 ROIs in parallel
#          Iter 0502: running 01 ROIs in parallel
#          Iter 0503: running 01 ROIs in parallel
#          Iter 0504: running 01 ROIs in parallel
#          Iter 0505: running 01 ROIs in parallel
#          Iter 0506: running 01 ROIs in parallel
#          Iter 0507: running 01 ROIs in parallel
#          Iter 0508: running 01 ROIs in parallel
#          Iter 0509: running 01 ROIs in parallel
#          Iter 0510: running 01 ROIs in parallel
#          Iter 0511: running 01 ROIs in parallel
#          Iter 0512: running 01 ROIs in parallel
#          Iter 0513: running 01 ROIs in parallel
#          Iter 0514: running 01 ROIs in parallel
#          Iter 0515: running 01 ROIs in parallel
#          Iter 0516: running 01 ROIs in parallel
#          Iter 0517: running 01 ROIs in parallel
#          Iter 0518: running 01 ROIs in parallel
#          Iter 0519: running 01 ROIs in parallel
#          Iter 0520: running 01 ROIs in parallel
#          Iter 0521: running 01 ROIs in parallel
#          Iter 0522: running 01 ROIs in parallel
#          Iter 0523: running 01 ROIs in parallel
#          Iter 0524: running 01 ROIs in parallel
#          Iter 0525: running 01 ROIs in parallel
#          Iter 0526: running 01 ROIs in parallel
#          Iter 0527: running 01 ROIs in parallel
#          Iter 0528: running 01 ROIs in parallel
#          Iter 0529: running 01 ROIs in parallel
#          Iter 0530: running 01 ROIs in parallel
#          Iter 0531: running 01 ROIs in parallel
#          Iter 0532: running 01 ROIs in parallel
#          Iter 0533: running 01 ROIs in parallel
#          Iter 0534: running 01 ROIs in parallel
#          Iter 0535: running 01 ROIs in parallel
#          Iter 0536: running 01 ROIs in parallel
#          Iter 0537: running 01 ROIs in parallel
#          Iter 0538: running 01 ROIs in parallel
#          Iter 0539: running 01 ROIs in parallel
#          Iter 0540: running 01 ROIs in parallel
#          Iter 0541: running 01 ROIs in parallel
#          Iter 0542: running 01 ROIs in parallel
#          Iter 0543: running 01 ROIs in parallel
#          Iter 0544: running 01 ROIs in parallel
#          Iter 0545: running 01 ROIs in parallel
#          Iter 0546: running 01 ROIs in parallel
#          Iter 0547: running 01 ROIs in parallel
#          Iter 0548: running 01 ROIs in parallel
#          Iter 0549: running 01 ROIs in parallel
#          Iter 0550: running 01 ROIs in parallel
#          Iter 0551: running 01 ROIs in parallel
#          Iter 0552: running 01 ROIs in parallel
#          Iter 0553: running 01 ROIs in parallel
#          Iter 0554: running 01 ROIs in parallel
#          Iter 0555: running 01 ROIs in parallel
#          Iter 0556: running 01 ROIs in parallel
#          Iter 0557: running 01 ROIs in parallel
#          Iter 0558: running 01 ROIs in parallel
#          Iter 0559: running 01 ROIs in parallel
#          Iter 0560: running 01 ROIs in parallel
#          Iter 0561: running 01 ROIs in parallel
#          Iter 0562: running 01 ROIs in parallel
#          Iter 0563: running 01 ROIs in parallel
#          Iter 0564: running 01 ROIs in parallel
#          Iter 0565: running 01 ROIs in parallel
#          Iter 0566: running 01 ROIs in parallel
#          Iter 0567: running 01 ROIs in parallel
#          Iter 0568: running 01 ROIs in parallel
#          Iter 0569: running 01 ROIs in parallel
#          Iter 0570: running 01 ROIs in parallel
#          Iter 0571: running 01 ROIs in parallel
#          Iter 0572: running 01 ROIs in parallel
#          Iter 0573: running 01 ROIs in parallel
#          Iter 0574: running 01 ROIs in parallel
#          Iter 0575: running 01 ROIs in parallel
#          Iter 0576: running 01 ROIs in parallel
#          Iter 0577: running 01 ROIs in parallel
#          Iter 0578: running 01 ROIs in parallel
#          Iter 0579: running 01 ROIs in parallel
#          Iter 0580: running 01 ROIs in parallel
#          Iter 0581: running 01 ROIs in parallel
#          Iter 0582: running 01 ROIs in parallel
#          Iter 0583: running 01 ROIs in parallel
#          Iter 0584: running 01 ROIs in parallel
#          Iter 0585: running 01 ROIs in parallel
#          Iter 0586: running 01 ROIs in parallel
#          Iter 0587: running 01 ROIs in parallel
#          Iter 0588: running 01 ROIs in parallel
#          Iter 0589: running 01 ROIs in parallel
#          Iter 0590: running 01 ROIs in parallel
#          Iter 0591: running 01 ROIs in parallel
#          Iter 0592: running 01 ROIs in parallel
#          Iter 0593: running 01 ROIs in parallel
#          Iter 0594: running 01 ROIs in parallel
#          Iter 0595: running 01 ROIs in parallel
#          Iter 0596: running 01 ROIs in parallel
#          Iter 0597: running 01 ROIs in parallel
#          Iter 0598: running 01 ROIs in parallel
#          Iter 0599: running 01 ROIs in parallel
#          Iter 0600: running 01 ROIs in parallel
#          Iter 0601: running 01 ROIs in parallel
#          Iter 0602: running 01 ROIs in parallel
#          Iter 0603: running 01 ROIs in parallel
#          Iter 0604: running 01 ROIs in parallel
#          Iter 0605: running 01 ROIs in parallel
#          Iter 0606: running 01 ROIs in parallel
#          Iter 0607: running 01 ROIs in parallel
#          Iter 0608: running 01 ROIs in parallel
#          Iter 0609: running 01 ROIs in parallel
#          Iter 0610: running 01 ROIs in parallel
#          Iter 0611: running 01 ROIs in parallel
#          Iter 0612: running 01 ROIs in parallel
#          Iter 0613: running 01 ROIs in parallel
#          Iter 0614: running 01 ROIs in parallel
#          Iter 0615: running 01 ROIs in parallel
#          Iter 0616: running 01 ROIs in parallel
#          Iter 0617: running 01 ROIs in parallel
#          Iter 0618: running 01 ROIs in parallel
#          Iter 0619: running 01 ROIs in parallel
#          Iter 0620: running 01 ROIs in parallel
#          Iter 0621: running 01 ROIs in parallel
#          Iter 0622: running 01 ROIs in parallel
#          Iter 0623: running 01 ROIs in parallel
#          Iter 0624: running 01 ROIs in parallel
#    Found 0 cells in 625 iterations
#    Saving cells to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0002\stats.npy
#    Saving iscell.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0002\iscell.npy
#    Detecting from patch 4 / 30
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0003
#          Loading 0.14 GB movie to memory, shape: (374, 14, 120, 120)
#          Loaded
#          Loading movie patch to shared memory
#          Loaded
#       Starting extraction with peak_thresh: 0.400 and Th2: 20.000
#          Iter 0000: running 03 ROIs in parallel
#          Iter 0001: running 03 ROIs in parallel
#          Iter 0002: running 03 ROIs in parallel
#          Iter 0003: running 03 ROIs in parallel
#          Iter 0004: running 03 ROIs in parallel
#          Iter 0005: running 03 ROIs in parallel
#          Iter 0006: running 03 ROIs in parallel
#          Iter 0007: running 03 ROIs in parallel
#          Iter 0008: running 03 ROIs in parallel
#          Iter 0009: running 03 ROIs in parallel
#          Iter 0010: running 03 ROIs in parallel
#          Iter 0011: running 03 ROIs in parallel
#          Iter 0012: running 03 ROIs in parallel
#          Iter 0013: running 03 ROIs in parallel
#          Iter 0014: running 03 ROIs in parallel
#          Iter 0015: running 03 ROIs in parallel
#          Iter 0016: running 03 ROIs in parallel
#          Iter 0017: running 03 ROIs in parallel
#          Iter 0018: running 03 ROIs in parallel
#          Iter 0019: running 03 ROIs in parallel
#          Iter 0020: running 03 ROIs in parallel
#          Iter 0021: running 03 ROIs in parallel
#          Iter 0022: running 03 ROIs in parallel
#          Iter 0023: running 03 ROIs in parallel
#          Iter 0024: running 03 ROIs in parallel
#          Iter 0025: running 03 ROIs in parallel
#          Iter 0026: running 03 ROIs in parallel
#          Iter 0027: running 03 ROIs in parallel
#          Iter 0028: running 03 ROIs in parallel
#          Iter 0029: running 03 ROIs in parallel
#          Iter 0030: running 03 ROIs in parallel
#          Iter 0031: running 03 ROIs in parallel
#          Iter 0032: running 03 ROIs in parallel
#          Iter 0033: running 03 ROIs in parallel
#          Iter 0034: running 03 ROIs in parallel
#          Iter 0035: running 03 ROIs in parallel
#          Iter 0036: running 03 ROIs in parallel
#          Iter 0037: running 03 ROIs in parallel
#          Iter 0038: running 03 ROIs in parallel
#          Iter 0039: running 03 ROIs in parallel
#          Iter 0040: running 03 ROIs in parallel
#          Iter 0041: running 03 ROIs in parallel
#          Iter 0042: running 03 ROIs in parallel
#          Iter 0043: running 03 ROIs in parallel
#          Iter 0044: running 03 ROIs in parallel
#          Iter 0045: running 03 ROIs in parallel
#          Iter 0046: running 03 ROIs in parallel
#          Iter 0047: running 03 ROIs in parallel
#          Iter 0048: running 03 ROIs in parallel
#          Iter 0049: running 03 ROIs in parallel
#          Iter 0050: running 03 ROIs in parallel
#          Iter 0051: running 03 ROIs in parallel
#          Iter 0052: running 03 ROIs in parallel
#          Iter 0053: running 03 ROIs in parallel
#          Iter 0054: running 03 ROIs in parallel
#          Iter 0055: running 03 ROIs in parallel
#          Iter 0056: running 03 ROIs in parallel
#          Iter 0057: running 03 ROIs in parallel
#          Iter 0058: running 03 ROIs in parallel
#          Iter 0059: running 03 ROIs in parallel
#          Iter 0060: running 03 ROIs in parallel
#          Iter 0061: running 03 ROIs in parallel
#          Iter 0062: running 03 ROIs in parallel
#          Iter 0063: running 03 ROIs in parallel
#          Iter 0064: running 03 ROIs in parallel
#          Iter 0065: running 03 ROIs in parallel
#          Iter 0066: running 03 ROIs in parallel
#          Iter 0067: running 03 ROIs in parallel
#          Iter 0068: running 03 ROIs in parallel
#          Iter 0069: running 03 ROIs in parallel
#          Iter 0070: running 03 ROIs in parallel
#          Iter 0071: running 03 ROIs in parallel
#          Iter 0072: running 03 ROIs in parallel
#          Iter 0073: running 03 ROIs in parallel
#          Iter 0074: running 03 ROIs in parallel
#          Iter 0075: running 03 ROIs in parallel
#          Iter 0076: running 03 ROIs in parallel
#          Iter 0077: running 03 ROIs in parallel
#          Iter 0078: running 03 ROIs in parallel
#          Iter 0079: running 03 ROIs in parallel
#          Iter 0080: running 03 ROIs in parallel
#          Iter 0081: running 03 ROIs in parallel
#          Iter 0082: running 03 ROIs in parallel
#          Iter 0083: running 03 ROIs in parallel
#          Iter 0084: running 03 ROIs in parallel
#          Iter 0085: running 03 ROIs in parallel
#          Iter 0086: running 03 ROIs in parallel
#          Iter 0087: running 03 ROIs in parallel
#          Iter 0088: running 03 ROIs in parallel
#          Iter 0089: running 03 ROIs in parallel
#          Iter 0090: running 03 ROIs in parallel
#          Iter 0091: running 03 ROIs in parallel
#          Iter 0092: running 03 ROIs in parallel
#          Iter 0093: running 03 ROIs in parallel
#          Iter 0094: running 03 ROIs in parallel
#          Iter 0095: running 03 ROIs in parallel
#          Iter 0096: running 03 ROIs in parallel
#          Iter 0097: running 03 ROIs in parallel
#          Iter 0098: running 03 ROIs in parallel
#          Iter 0099: running 03 ROIs in parallel
#          Iter 0100: running 03 ROIs in parallel
#          Iter 0101: running 03 ROIs in parallel
#          Iter 0102: running 03 ROIs in parallel
#          Iter 0103: running 03 ROIs in parallel
#          Iter 0104: running 03 ROIs in parallel
#          Iter 0105: running 03 ROIs in parallel
#          Iter 0106: running 03 ROIs in parallel
#          Iter 0107: running 03 ROIs in parallel
#          Iter 0108: running 03 ROIs in parallel
#          Iter 0109: running 03 ROIs in parallel
#          Iter 0110: running 03 ROIs in parallel
#          Iter 0111: running 03 ROIs in parallel
#          Iter 0112: running 03 ROIs in parallel
#          Iter 0113: running 03 ROIs in parallel
#          Iter 0114: running 03 ROIs in parallel
#          Iter 0115: running 03 ROIs in parallel
#          Iter 0116: running 03 ROIs in parallel
#          Iter 0117: running 03 ROIs in parallel
#          Iter 0118: running 03 ROIs in parallel
#          Iter 0119: running 03 ROIs in parallel
#          Iter 0120: running 03 ROIs in parallel
#          Iter 0121: running 03 ROIs in parallel
#          Iter 0122: running 03 ROIs in parallel
#          Iter 0123: running 03 ROIs in parallel
#          Iter 0124: running 03 ROIs in parallel
#          Iter 0125: running 03 ROIs in parallel
#          Iter 0126: running 03 ROIs in parallel
#          Iter 0127: running 03 ROIs in parallel
#          Iter 0128: running 03 ROIs in parallel
#          Iter 0129: running 03 ROIs in parallel
#          Iter 0130: running 03 ROIs in parallel
#          Iter 0131: running 03 ROIs in parallel
#          Iter 0132: running 03 ROIs in parallel
#          Iter 0133: running 03 ROIs in parallel
#          Iter 0134: running 03 ROIs in parallel
#          Iter 0135: running 03 ROIs in parallel
#          Iter 0136: running 03 ROIs in parallel
#          Iter 0137: running 03 ROIs in parallel
#          Iter 0138: running 03 ROIs in parallel
#          Iter 0139: running 03 ROIs in parallel
#          Iter 0140: running 03 ROIs in parallel
#          Iter 0141: running 03 ROIs in parallel
#          Iter 0142: running 03 ROIs in parallel
#          Iter 0143: running 03 ROIs in parallel
#          Iter 0144: running 03 ROIs in parallel
#          Iter 0145: running 03 ROIs in parallel
#          Iter 0146: running 03 ROIs in parallel
#          Iter 0147: running 03 ROIs in parallel
#          Iter 0148: running 03 ROIs in parallel
#          Iter 0149: running 03 ROIs in parallel
#          Iter 0150: running 03 ROIs in parallel
#          Iter 0151: running 03 ROIs in parallel
#          Iter 0152: running 03 ROIs in parallel
#          Iter 0153: running 03 ROIs in parallel
#          Iter 0154: running 03 ROIs in parallel
#          Iter 0155: running 03 ROIs in parallel
#          Iter 0156: running 03 ROIs in parallel
#          Iter 0157: running 03 ROIs in parallel
#          Iter 0158: running 03 ROIs in parallel
#          Iter 0159: running 03 ROIs in parallel
#          Iter 0160: running 03 ROIs in parallel
#          Iter 0161: running 03 ROIs in parallel
#          Iter 0162: running 03 ROIs in parallel
#          Iter 0163: running 03 ROIs in parallel
#          Iter 0164: running 03 ROIs in parallel
#          Iter 0165: running 03 ROIs in parallel
#          Iter 0166: running 03 ROIs in parallel
#          Iter 0167: running 03 ROIs in parallel
#          Iter 0168: running 03 ROIs in parallel
#          Iter 0169: running 03 ROIs in parallel
#          Iter 0170: running 03 ROIs in parallel
#          Iter 0171: running 03 ROIs in parallel
#          Iter 0172: running 03 ROIs in parallel
#          Iter 0173: running 03 ROIs in parallel
#          Iter 0174: running 03 ROIs in parallel
#          Iter 0175: running 03 ROIs in parallel
#          Iter 0176: running 03 ROIs in parallel
#          Iter 0177: running 03 ROIs in parallel
#          Iter 0178: running 03 ROIs in parallel
#          Iter 0179: running 03 ROIs in parallel
#          Iter 0180: running 03 ROIs in parallel
#          Iter 0181: running 03 ROIs in parallel
#          Iter 0182: running 03 ROIs in parallel
#          Iter 0183: running 03 ROIs in parallel
#          Iter 0184: running 03 ROIs in parallel
#          Iter 0185: running 03 ROIs in parallel
#          Iter 0186: running 03 ROIs in parallel
#          Iter 0187: running 03 ROIs in parallel
#          Iter 0188: running 03 ROIs in parallel
#          Iter 0189: running 03 ROIs in parallel
#          Iter 0190: running 03 ROIs in parallel
#          Iter 0191: running 03 ROIs in parallel
#          Iter 0192: running 03 ROIs in parallel
#          Iter 0193: running 03 ROIs in parallel
#          Iter 0194: running 03 ROIs in parallel
#          Iter 0195: running 03 ROIs in parallel
#          Iter 0196: running 03 ROIs in parallel
#          Iter 0197: running 03 ROIs in parallel
#          Iter 0198: running 03 ROIs in parallel
#          Iter 0199: running 03 ROIs in parallel
#          Iter 0200: running 03 ROIs in parallel
#          Iter 0201: running 03 ROIs in parallel
#          Iter 0202: running 03 ROIs in parallel
#          Iter 0203: running 03 ROIs in parallel
#          Iter 0204: running 03 ROIs in parallel
#          Iter 0205: running 03 ROIs in parallel
#          Iter 0206: running 03 ROIs in parallel
#          Iter 0207: running 03 ROIs in parallel
#          Iter 0208: running 03 ROIs in parallel
#          Iter 0209: running 03 ROIs in parallel
#          Iter 0210: running 03 ROIs in parallel
#          Iter 0211: running 03 ROIs in parallel
#          Iter 0212: running 03 ROIs in parallel
#          Iter 0213: running 03 ROIs in parallel
#          Iter 0214: running 03 ROIs in parallel
#          Iter 0215: running 03 ROIs in parallel
#          Iter 0216: running 03 ROIs in parallel
#          Iter 0217: running 03 ROIs in parallel
#          Iter 0218: running 03 ROIs in parallel
#          Iter 0219: running 03 ROIs in parallel
#          Iter 0220: running 03 ROIs in parallel
#          Iter 0221: running 03 ROIs in parallel
#          Iter 0222: running 03 ROIs in parallel
#          Iter 0223: running 03 ROIs in parallel
#          Iter 0224: running 03 ROIs in parallel
#          Iter 0225: running 03 ROIs in parallel
#          Iter 0226: running 03 ROIs in parallel
#          Iter 0227: running 03 ROIs in parallel
#          Iter 0228: running 03 ROIs in parallel
#          Iter 0229: running 03 ROIs in parallel
#          Iter 0230: running 03 ROIs in parallel
#          Iter 0231: running 03 ROIs in parallel
#          Iter 0232: running 03 ROIs in parallel
#          Iter 0233: running 03 ROIs in parallel
#          Iter 0234: running 03 ROIs in parallel
#          Iter 0235: running 03 ROIs in parallel
#          Iter 0236: running 03 ROIs in parallel
#          Iter 0237: running 03 ROIs in parallel
#          Iter 0238: running 03 ROIs in parallel
#          Iter 0239: running 03 ROIs in parallel
#          Iter 0240: running 03 ROIs in parallel
#          Iter 0241: running 03 ROIs in parallel
#          Iter 0242: running 03 ROIs in parallel
#          Iter 0243: running 03 ROIs in parallel
#          Iter 0244: running 03 ROIs in parallel
#          Iter 0245: running 03 ROIs in parallel
#          Iter 0246: running 03 ROIs in parallel
#          Iter 0247: running 03 ROIs in parallel
#          Iter 0248: running 03 ROIs in parallel
#          Iter 0249: running 03 ROIs in parallel
#          Iter 0250: running 03 ROIs in parallel
#          Iter 0251: running 03 ROIs in parallel
#          Iter 0252: running 03 ROIs in parallel
#          Iter 0253: running 03 ROIs in parallel
#          Iter 0254: running 03 ROIs in parallel
#          Iter 0255: running 03 ROIs in parallel
#          Iter 0256: running 03 ROIs in parallel
#          Iter 0257: running 03 ROIs in parallel
#          Iter 0258: running 03 ROIs in parallel
#          Iter 0259: running 03 ROIs in parallel
#          Iter 0260: running 03 ROIs in parallel
#          Iter 0261: running 03 ROIs in parallel
#          Iter 0262: running 03 ROIs in parallel
#          Iter 0263: running 03 ROIs in parallel
#          Iter 0264: running 03 ROIs in parallel
#          Iter 0265: running 03 ROIs in parallel
#          Iter 0266: running 03 ROIs in parallel
#          Iter 0267: running 03 ROIs in parallel
#          Iter 0268: running 03 ROIs in parallel
#          Iter 0269: running 03 ROIs in parallel
#          Iter 0270: running 03 ROIs in parallel
#          Iter 0271: running 03 ROIs in parallel
#          Iter 0272: running 03 ROIs in parallel
#          Iter 0273: running 03 ROIs in parallel
#          Iter 0274: running 03 ROIs in parallel
#          Iter 0275: running 03 ROIs in parallel
#          Iter 0276: running 03 ROIs in parallel
#          Iter 0277: running 03 ROIs in parallel
#          Iter 0278: running 03 ROIs in parallel
#          Iter 0279: running 03 ROIs in parallel
#          Iter 0280: running 03 ROIs in parallel
#          Iter 0281: running 03 ROIs in parallel
#          Iter 0282: running 03 ROIs in parallel
#          Iter 0283: running 03 ROIs in parallel
#          Iter 0284: running 03 ROIs in parallel
#          Iter 0285: running 03 ROIs in parallel
#          Iter 0286: running 03 ROIs in parallel
#          Iter 0287: running 03 ROIs in parallel
#          Iter 0288: running 03 ROIs in parallel
#          Iter 0289: running 03 ROIs in parallel
#          Iter 0290: running 03 ROIs in parallel
#          Iter 0291: running 03 ROIs in parallel
#          Iter 0292: running 03 ROIs in parallel
#          Iter 0293: running 03 ROIs in parallel
#          Iter 0294: running 03 ROIs in parallel
#          Iter 0295: running 03 ROIs in parallel
#          Iter 0296: running 03 ROIs in parallel
#          Iter 0297: running 03 ROIs in parallel
#          Iter 0298: running 03 ROIs in parallel
#          Iter 0299: running 03 ROIs in parallel
#          Iter 0300: running 03 ROIs in parallel
#          Iter 0301: running 03 ROIs in parallel
#          Iter 0302: running 03 ROIs in parallel
#          Iter 0303: running 03 ROIs in parallel
#          Iter 0304: running 03 ROIs in parallel
#          Iter 0305: running 03 ROIs in parallel
#          Iter 0306: running 03 ROIs in parallel
#          Iter 0307: running 03 ROIs in parallel
#          Iter 0308: running 03 ROIs in parallel
#          Iter 0309: running 03 ROIs in parallel
#          Iter 0310: running 03 ROIs in parallel
#          Iter 0311: running 03 ROIs in parallel
#          Iter 0312: running 03 ROIs in parallel
#          Iter 0313: running 03 ROIs in parallel
#          Iter 0314: running 03 ROIs in parallel
#          Iter 0315: running 03 ROIs in parallel
# ...
#          Iter 0460: running 01 ROIs in parallel
#          Iter 0461: running 01 ROIs in parallel
#          Iter 0462: running 01 ROIs in parallel
#          Iter 0463: running 01 ROIs in parallel
#          Iter 0464: running 01 ROIs in parallel
#          Iter 0465: running 01 ROIs in parallel
#          Iter 0466: running 01 ROIs in parallel
#          Iter 0467: running 01 ROIs in parallel
#          Iter 0468: running 01 ROIs in parallel
#          Iter 0469: running 01 ROIs in parallel
#          Iter 0470: running 01 ROIs in parallel
#          Iter 0471: running 01 ROIs in parallel
#          Iter 0472: running 01 ROIs in parallel
#          Iter 0473: running 01 ROIs in parallel
#          Iter 0474: running 01 ROIs in parallel
#          Iter 0475: running 01 ROIs in parallel
#          Iter 0476: running 01 ROIs in parallel
#          Iter 0477: running 01 ROIs in parallel
#          Iter 0478: running 01 ROIs in parallel
#          Iter 0479: running 01 ROIs in parallel
#          Iter 0480: running 01 ROIs in parallel
#          Iter 0481: running 01 ROIs in parallel
#          Iter 0482: running 01 ROIs in parallel
#          Iter 0483: running 01 ROIs in parallel
#          Iter 0484: running 01 ROIs in parallel
#          Iter 0485: running 01 ROIs in parallel
#          Iter 0486: running 01 ROIs in parallel
#          Iter 0487: running 01 ROIs in parallel
#          Iter 0488: running 01 ROIs in parallel
#          Iter 0489: running 01 ROIs in parallel
#          Iter 0490: running 01 ROIs in parallel
#          Iter 0491: running 01 ROIs in parallel
#          Iter 0492: running 01 ROIs in parallel
#          Iter 0493: running 01 ROIs in parallel
#          Iter 0494: running 01 ROIs in parallel
#          Iter 0495: running 01 ROIs in parallel
#          Iter 0496: running 01 ROIs in parallel
#          Iter 0497: running 01 ROIs in parallel
#          Iter 0498: running 01 ROIs in parallel
#          Iter 0499: running 01 ROIs in parallel
#          Iter 0500: running 01 ROIs in parallel
#          Iter 0501: running 01 ROIs in parallel
#          Iter 0502: running 01 ROIs in parallel
#          Iter 0503: running 01 ROIs in parallel
#          Iter 0504: running 01 ROIs in parallel
#          Iter 0505: running 01 ROIs in parallel
#          Iter 0506: running 01 ROIs in parallel
#          Iter 0507: running 01 ROIs in parallel
#          Iter 0508: running 01 ROIs in parallel
#          Iter 0509: running 01 ROIs in parallel
#          Iter 0510: running 01 ROIs in parallel
#          Iter 0511: running 01 ROIs in parallel
#          Iter 0512: running 01 ROIs in parallel
#          Iter 0513: running 01 ROIs in parallel
#          Iter 0514: running 01 ROIs in parallel
#          Iter 0515: running 01 ROIs in parallel
#          Iter 0516: running 01 ROIs in parallel
#          Iter 0517: running 01 ROIs in parallel
#          Iter 0518: running 01 ROIs in parallel
#          Iter 0519: running 01 ROIs in parallel
#          Iter 0520: running 01 ROIs in parallel
#          Iter 0521: running 01 ROIs in parallel
#          Iter 0522: running 01 ROIs in parallel
#          Iter 0523: running 01 ROIs in parallel
#          Iter 0524: running 01 ROIs in parallel
#          Iter 0525: running 01 ROIs in parallel
#          Iter 0526: running 01 ROIs in parallel
#          Iter 0527: running 01 ROIs in parallel
#          Iter 0528: running 01 ROIs in parallel
#          Iter 0529: running 01 ROIs in parallel
#          Iter 0530: running 01 ROIs in parallel
#          Iter 0531: running 01 ROIs in parallel
#          Iter 0532: running 01 ROIs in parallel
#          Iter 0533: running 01 ROIs in parallel
#          Iter 0534: running 01 ROIs in parallel
#          Iter 0535: running 01 ROIs in parallel
#          Iter 0536: running 01 ROIs in parallel
#          Iter 0537: running 01 ROIs in parallel
#          Iter 0538: running 01 ROIs in parallel
#          Iter 0539: running 01 ROIs in parallel
#          Iter 0540: running 01 ROIs in parallel
#          Iter 0541: running 01 ROIs in parallel
#          Iter 0542: running 01 ROIs in parallel
#          Iter 0543: running 01 ROIs in parallel
#          Iter 0544: running 01 ROIs in parallel
#          Iter 0545: running 01 ROIs in parallel
#          Iter 0546: running 01 ROIs in parallel
#          Iter 0547: running 01 ROIs in parallel
#          Iter 0548: running 01 ROIs in parallel
#          Iter 0549: running 01 ROIs in parallel
#          Iter 0550: running 01 ROIs in parallel
#          Iter 0551: running 01 ROIs in parallel
#          Iter 0552: running 01 ROIs in parallel
#          Iter 0553: running 01 ROIs in parallel
#          Iter 0554: running 01 ROIs in parallel
#          Iter 0555: running 01 ROIs in parallel
#          Iter 0556: running 01 ROIs in parallel
#          Iter 0557: running 01 ROIs in parallel
#          Iter 0558: running 01 ROIs in parallel
#          Iter 0559: running 01 ROIs in parallel
#          Iter 0560: running 01 ROIs in parallel
#          Iter 0561: running 01 ROIs in parallel
#          Iter 0562: running 01 ROIs in parallel
#          Iter 0563: running 01 ROIs in parallel
#          Iter 0564: running 01 ROIs in parallel
#          Iter 0565: running 01 ROIs in parallel
#          Iter 0566: running 01 ROIs in parallel
#          Iter 0567: running 01 ROIs in parallel
#          Iter 0568: running 01 ROIs in parallel
#          Iter 0569: running 01 ROIs in parallel
#          Iter 0570: running 01 ROIs in parallel
#          Iter 0571: running 01 ROIs in parallel
#          Iter 0572: running 01 ROIs in parallel
#          Iter 0573: running 01 ROIs in parallel
#          Iter 0574: running 01 ROIs in parallel
#          Iter 0575: running 01 ROIs in parallel
#          Iter 0576: running 01 ROIs in parallel
#          Iter 0577: running 01 ROIs in parallel
#          Iter 0578: running 01 ROIs in parallel
#          Iter 0579: running 01 ROIs in parallel
#          Iter 0580: running 01 ROIs in parallel
#          Iter 0581: running 01 ROIs in parallel
#          Iter 0582: running 01 ROIs in parallel
#          Iter 0583: running 01 ROIs in parallel
#          Iter 0584: running 01 ROIs in parallel
#          Iter 0585: running 01 ROIs in parallel
#          Iter 0586: running 01 ROIs in parallel
#          Iter 0587: running 01 ROIs in parallel
#          Iter 0588: running 01 ROIs in parallel
#          Iter 0589: running 01 ROIs in parallel
#          Iter 0590: running 01 ROIs in parallel
#          Iter 0591: running 01 ROIs in parallel
#          Iter 0592: running 01 ROIs in parallel
#          Iter 0593: running 01 ROIs in parallel
#          Iter 0594: running 01 ROIs in parallel
#          Iter 0595: running 01 ROIs in parallel
#          Iter 0596: running 01 ROIs in parallel
#          Iter 0597: running 01 ROIs in parallel
#          Iter 0598: running 01 ROIs in parallel
#          Iter 0599: running 01 ROIs in parallel
#          Iter 0600: running 01 ROIs in parallel
#          Iter 0601: running 01 ROIs in parallel
#          Iter 0602: running 01 ROIs in parallel
#          Iter 0603: running 01 ROIs in parallel
#          Iter 0604: running 01 ROIs in parallel
#          Iter 0605: running 01 ROIs in parallel
#          Iter 0606: running 01 ROIs in parallel
#          Iter 0607: running 01 ROIs in parallel
#          Iter 0608: running 01 ROIs in parallel
#          Iter 0609: running 01 ROIs in parallel
#          Iter 0610: running 01 ROIs in parallel
#          Iter 0611: running 01 ROIs in parallel
#          Iter 0612: running 01 ROIs in parallel
#          Iter 0613: running 01 ROIs in parallel
#          Iter 0614: running 01 ROIs in parallel
#          Iter 0615: running 01 ROIs in parallel
#          Iter 0616: running 01 ROIs in parallel
#          Iter 0617: running 01 ROIs in parallel
#          Iter 0618: running 01 ROIs in parallel
#          Iter 0619: running 01 ROIs in parallel
#          Iter 0620: running 01 ROIs in parallel
#          Iter 0621: running 01 ROIs in parallel
#          Iter 0622: running 01 ROIs in parallel
#          Iter 0623: running 01 ROIs in parallel
#          Iter 0624: running 01 ROIs in parallel
#    Found 0 cells in 625 iterations
#    Saving cells to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0028\stats.npy
#    Saving iscell.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0028\iscell.npy
#    Detecting from patch 30 / 30
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0029
#          Loading 0.14 GB movie to memory, shape: (374, 14, 120, 120)
#          Loaded
#          Loading movie patch to shared memory
#          Loaded
#       Starting extraction with peak_thresh: 0.400 and Th2: 20.000
#       Iter 0000: peak is too small - ending extraction
#    Found 0 cells in 1 iterations
#    Saving cells to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0029\stats.npy
#    Saving iscell.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0029\iscell.npy
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0000
#       Updating self.dirs tag segmentation-segmentation-patch-0000
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0001
#       Updating self.dirs tag segmentation-segmentation-patch-0001
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0002
#       Updating self.dirs tag segmentation-segmentation-patch-0002
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0003
#       Updating self.dirs tag segmentation-segmentation-patch-0003
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0004
#       Updating self.dirs tag segmentation-segmentation-patch-0004
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0005
#       Updating self.dirs tag segmentation-segmentation-patch-0005
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0006
#       Updating self.dirs tag segmentation-segmentation-patch-0006
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0007
#       Updating self.dirs tag segmentation-segmentation-patch-0007
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0008
#       Updating self.dirs tag segmentation-segmentation-patch-0008
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0009
#       Updating self.dirs tag segmentation-segmentation-patch-0009
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0010
#       Updating self.dirs tag segmentation-segmentation-patch-0010
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0011
#       Updating self.dirs tag segmentation-segmentation-patch-0011
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0012
#       Updating self.dirs tag segmentation-segmentation-patch-0012
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0013
#       Updating self.dirs tag segmentation-segmentation-patch-0013
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0014
#       Updating self.dirs tag segmentation-segmentation-patch-0014
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0015
#       Updating self.dirs tag segmentation-segmentation-patch-0015
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0016
#       Updating self.dirs tag segmentation-segmentation-patch-0016
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0017
#       Updating self.dirs tag segmentation-segmentation-patch-0017
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0018
#       Updating self.dirs tag segmentation-segmentation-patch-0018
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0019
#       Updating self.dirs tag segmentation-segmentation-patch-0019
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0020
#       Updating self.dirs tag segmentation-segmentation-patch-0020
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0021
#       Updating self.dirs tag segmentation-segmentation-patch-0021
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0022
#       Updating self.dirs tag segmentation-segmentation-patch-0022
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0023
#       Updating self.dirs tag segmentation-segmentation-patch-0023
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0024
#       Updating self.dirs tag segmentation-segmentation-patch-0024
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0025
#       Updating self.dirs tag segmentation-segmentation-patch-0025
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0026
#       Updating self.dirs tag segmentation-segmentation-patch-0026
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0027
#       Updating self.dirs tag segmentation-segmentation-patch-0027
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0028
#       Updating self.dirs tag segmentation-segmentation-patch-0028
#       Found dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\segmentation\patch-0029
#       Updating self.dirs tag segmentation-segmentation-patch-0029
#       Deduplicating 0 cells
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[199], line 9
#       6 job.params["activity_thresh"] = 20.0    # default
#       7 job.params["percentile"] = 99.5           # default
# ----> 9 job.segment_rois(vmap = corr_map_thresh)
#
# File c:\Users\RBO\repos\suite3d\suite3d\job.py:996, in Job.segment_rois(self, input_dir_name, output_dir_name, patches_to_segment, ts, vmap)
#     993     patch_counter += 1
#     995 # combine all segmented patches
# --> 996 rois_dir_path = self.combine_patches(
#     997     patches_to_segment,
#     998     rois_dir_path,
#     999     parent_dir_name=segmentation_dir_tag,
#    1000     info_use_idx=None,
#    1001 )
#    1002 return rois_dir_path
#
# File c:\Users\RBO\repos\suite3d\suite3d\job.py:1311, in Job.combine_patches(self, patch_idxs, output_dir_path, info_use_idx, save, deduplicate, extra_stats_keys, parent_dir_name, max_roi_per_patch)
#    1309 self.log("Deduplicating %d cells" % len(stats), 2)
#    1310 tic = time.time()
# -> 1311 stats, duplicate_cells = ext.prune_overlapping_cells(
#    1312     stats,
#    1313     self.params.get("detect_overlap_dist_thresh", 5),
#    1314     self.params.get("detect_overlap_lam_thresh", 0.5),
#    1315 )
#    1316 iscell = iscell[~duplicate_cells]
#    1317 self.log(
#    1318     "Removed %d duplicate cells in %.2fs"
#    1319     % (duplicate_cells.sum(), time.time() - tic),
#    1320     2,
#    1321 )
#
# File c:\Users\RBO\repos\suite3d\suite3d\extension.py:1010, in prune_overlapping_cells(stats, dist_thresh, lam_overlap_thresh)
#    1007 # med_patchs = n.array([s['med_patch'] for s in stats])
#    1008 coords = [n.array(s["coords"]).T for s in stats]
# -> 1010 dm = distance_matrix(meds, meds, threshold=10000)
#    1011 dm[n.tril_indices(dm.shape[0], 1)] = dist_thresh + 1
#    1013 pairs = n.array(n.where((dm < dist_thresh)))
#
# File c:\Users\RBO\miniforge3\envs\suite3d-test\lib\site-packages\scipy\spatial\_kdtree.py:902, in distance_matrix(x, y, p, threshold)
#     870 """Compute the distance matrix.
#     871
#     872 Returns the matrix of all pair-wise distances.
#    (...)
#     898
#     899 """
#     901 x = np.asarray(x)
# --> 902 m, k = x.shape
#     903 y = np.asarray(y)
#     904 n, kk = y.shape
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
import matplotlib.pyplot as plt

npil_filt_xy_um = job.params['npil_filt_xy_um']
npil_filt_type = job.params['npil_filt_type']
cell_filt_xy_um = job.params['cell_filt_xy_um']
cell_filt_type = job.params['cell_filt_type']
cell_filt_z_um = job.params['cell_filt_z_um']
npil_filt_z_um = job.params["npil_filt_z_um"]

params_text = (
    f"npil XY: {npil_filt_xy_um} ({npil_filt_type}) | "
    f"cell XY: {cell_filt_xy_um} ({cell_filt_type}) | "
    f"cell Z: {cell_filt_z_um} | "
    f"npil Z: {npil_filt_z_um}"
)

fig, ax = plt.subplots(figsize=(4, 4), dpi=300)  # Adjust size as needed
ax.imshow(vmap[7], cmap='gray', aspect='auto')

ax.text(0.5, 1.02, params_text, fontsize=6, color='white', weight='bold',
        ha='center', va='bottom', transform=ax.transAxes)

ax.set_xticks([])
ax.set_yticks([])
ax.set_frame_on(False)

plt.subplots_adjust(left=0, right=1, top=0.95, bottom=0)  # Reduce top padding

filename = Path().home().joinpath("repos", "nb_sandbox", f"corrmap_npilXY{npil_filt_xy_um}_{npil_filt_type}_cellXY{cell_filt_xy_um}_{cell_filt_type}_Z{cell_filt_z_um}.png")
plt.savefig(filename, bbox_inches='tight', pad_inches=-0.1, dpi=300)  # Further trim whitespace
plt.close()

print(f"Saved as {filename}")
# Out:
# Saved as C:\Users\RBO\repos\nb_sandbox\corrmap_npilXY5_gaussian_cellXY5_gaussian_Z20.png

# %% [markdown]
# ## Detection
# Now that we have a correlation map, we can segment the cells. The algorithm is similar to suite2p, it does the following:
# 1. Choose the peak value on the correlation map, and set this pixel as your _seed cell_
# 2. Identify the _active frames_ of the candidate cell by taking all frames where the activity of the cell is greater than a threshold (`activity_thresh`) or have activity above a certain percentile (`percentile`)
# 3. Look at the activity of all neighboring pixels of the _seed cell_ during the _active frames_ of the seed cell. If a candidate pixel's activity is similar to the activity of the _seed cell_ (similarity above `extend_thresh`), include the pixel in the _seed cell_.
# 4. Repeat steps 2-3 until you've grown the cell as much as you can
# 5. Remove the cell from the correlation map
# 6. Find the next largest peak of the correlation map, take this as your seed cell and repeat steps 2-6
# 7. Stop when the peak value of the remaining correlation map is below a user-specified threhsold (`peak_thresh`)
# Two main improvements over Suite2p: first, this is done in 3D. Second, it is parallelized to be much faster, as it works on patches of the movie separately!
#
# **The most important variable that you *must* set is `peak_thresh`**. To do this, use the cell below to visualize the correlation map (`vmap` for short) using napari. Use the contrast sliders to find a minimum value where all spots above this value look like they might be cells. I find it useful to set the range to be very small, all pixels above the minimum are basically white. You should try to get rid of most of the obvious noise (e.g. artifacts at edges or around blood vessels, specks of single-pixel white spots, stuff outside the brain). It is not critical to exclude everything, you can be generous here and remove ROIs based on other criteria later. However, if you are too generous, you'll end up with too many pixels above the threhsold and your detection will take forever, with a lot of extra junk cells. I recommend starting a little conservative, and then push the limits.
#
# **Other useful variables**: When you have long enough recordings, 0.2 for `extend_thresh` is OK. However, if you have only a very short recording, or you find many cells that are much larger than they should be (with large, sprinkly footprints that extend way beyond the cell), or you have large cloudy blobs of noise being picked up as cells, increase `extend_thresh`. `activity_thresh` and `percentile` work together, usually it's good enough to just pick one and change it. If you have few frames, or you feel like you have low signal, it's better to set these to be lower, so you include more frames when evaluating a cell. However, if you can afford to, it's good to keep them high (`activity_thresh` around 10, `percentile` around 99.0), because then sparsely-firing cells will be picked up easier. Play around and see!
#
# **To make it faster to try parameters, you can run the detection only on a subset of the patches**. By default the movie is split into ~100 patches (I think), but if you pass `job.patch_and_detect(do_patch_idxs=(10,20,50,80))` then the detection will only run on the specified patches.
#
# **Detection always works better with more frames!** 300 frames is a very small number, so don't expect it to work perfectly on this demo.

# %%
# most important parameter - any value of the corrmap
# above this will be considered a peak for a possible ROI,
# and will be used as a "seed" to grow an ROI around it
# bigger number: fewer ROIs, only bright ones
# smaller number: many ROIs, increasingly worse quality
# job.params['peak_thresh'] = 1.5

# optionally, bin the movie in time to speed up detection
# probably a good idea if you have high framerate (>5 Hz?)
job.params['detection_timebin'] = 6
job.params['segmentation_timebin'] = 1

# when extending an ROI, compare its activity to its neighboring pixels
# in frames where the fluorescence is above this percentile
job.params['percentile'] = 99.5


job.params['extend_thresh'] = 0.01
# params_to_sweep = {
#     'extend_thresh' : (0.01, 0.03, 0.1),
#     'percentile'   : (70.0, 99.5),
#  }

# %% [markdown]
# ### Compute neuropil masks, extract activity and deconvolve
# For each cell, compute a donut around it excluding all other cells to use it to estimate the local neuropil activity. Then, extract the activity of the cell and the neuropil, subtract 0.7\*neuropil activity from the ROI activity, and deconvolve using Oasis. Make sure you have set the `tau` parameter correctly for the deconvolution.

# %%
job.compute_npil_masks(stats_dir = job.dirs['rois'])
# Out:
# 'D:\\W2_DATA\\kbarber\\2025_03_01\\mk301\\results\\s3d-03_25\\rois'

# %%
traces = job.extract_and_deconvolve(stats_dir=job.dirs['rois'])
# Out:
#    Updated main params file
#    Movie shape: (14, 5632, 561, 452)
# 303
#    Extracting 303 valid cells, and saving cell flags to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois\iscell_extracted.npy
#    Extracting activity
#          Will extract in 12 batches of 500
#    Saving intermediate results to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois
#    Deconvolving
#    Saving to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois

# %%
# rpath
res_dir = Path(job.dirs["job_dir"]).joinpath('fix-strips-small-pthresh')

# %%
job.export_results(res_dir, result_dir_name='rois')
# Out:
#    Created dir D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25 to export results
#       Loading from D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois\stats_small.npy
#       Loading from D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois\info.npy
#       Loading from D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois\F.npy
#       Loading from D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois\spks.npy
#       Loading from D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois\Fneu.npy
#       Loading from D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\rois\iscell.npy
#       Saved stats.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25
#       Saved info.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25
#       Saved F.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25
#       Saved spks.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25
#       Saved Fneu.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25
#       Saved iscell.npy to D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25

# %% [markdown]
# # Run the Napari manual curator!
# in any conda terminal with napari installed, you can launch the curator
# this doesn't necessarily need to be on the same computer that you run this
# notebook on, the exported directory contains everything necessary.
#
# ```
# python suite3d/suite3d/curation.py curation --output_dir /mnt/data/demo
# ```

# %% [markdown]
# ## Load outputs and analyze
# This is how you can access the traces for each cell, and the locations for each cell

# %%
out_path
# Out:
# WindowsPath('D:/W2_DATA/kbarber/2025_03_01/mk301/results/s3d-03_25/fix-corrmap-ext_thr_0p02/s3d-results-03_25')

# %%
# %gui qt
out_path = res_dir.joinpath("s3d-results-03_25")
outputs = ui.load_outputs(out_path, load_traces=False)
v,layers = ui.create_ui(outputs)
ui.add_callbacks_to_ui(v,layers,outputs,savedir=out_path)
# Out:
# Cells
# Found old curated + slider-ed iscell with 2114 of 2114 marked as cells
# Saving old iscell_curated to backup path D:\W2_DATA\kbarber\2025_03_01\mk301\results\s3d-03_25\fix-strips-small-pthresh\s3d-results-03_25\iscell_curated_slider_old_27-03-25_17-34-33.npy
# ('vmap_peak', (0.06666971, 0.20809474587440496), 'peak_val', <function add_curation_sliders.<locals>.<lambda> at 0x0000022347F6CE50>)
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1511, 1511 cells valid
# Cells
# 1511, 1511 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1511, 1511 cells valid
# Cells
# 1511, 1511 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1154, 1154 cells valid
# Cells
# 1154, 1154 cells valid
# Cells
# 1, 1 cells valid
# Cells
# 1, 1 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 3, 3 cells valid
# Cells
# 3, 3 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 1154, 1154 cells valid
# Cells
# 1154, 1154 cells valid
# Cells
# 1154, 1154 cells valid
# Cells
# 1154, 1154 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1152, 1152 cells valid
# Cells
# 1152, 1152 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1151, 1151 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1, 1 cells valid
# Cells
# 1, 1 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 2, 2 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1153, 1153 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 1155, 1155 cells valid
# Cells
# 2109, 2109 cells valid
# Cells
# 2109, 2109 cells valid
# Cells

# %%
n_cells, n_t = outputs['F'].shape
frame_times = n.arange(n_t) / outputs['fs']
example_cell = 90
plt.plot(frame_times, outputs['F'][example_cell], label='ROI Fluorescence')
plt.plot(frame_times, outputs['Fneu'][example_cell], label='Neuropil Fluorescence')
plt.plot(frame_times, outputs['spks'][example_cell], label='Deconvolved activity')
plt.legend()
plt.xlabel("Time (s)")
plt.ylabel("Activity")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 n_cells, n_t = outputs['F'].shape
#       2 frame_times = n.arange(n_t) / outputs['fs']
#       3 example_cell = 90
#
# KeyError: 'F'

# %%
# suite2p-style list of all cells
cell_stats = outputs['stats']
print(cell_stats[example_cell].keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 3
#       1 # suite2p-style list of all cells
#       2 cell_stats = outputs['stats']
# ----> 3 print(cell_stats[example_cell].keys())
#
# NameError: name 'example_cell' is not defined

# %%
cell_coords = [stat['coords'] for stat in cell_stats]
cell_centers = n.array([stat['med'] for stat in cell_stats])
vmap_shape = outputs['vmap'].shape

# %%
# make a volume with the footprints of all cells and plot a max-projection of it along z
cell_vol = ui.fill_cells_vol(cell_coords, fill_vals = n.ones(len(cell_coords)), empty=0)
io.show_tif((cell_vol ).mean(axis=0))
# Out:
# (<Figure size 1200x900 with 1 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x18f73755f10>)

# %%
hist,bins = n.histogram(cell_centers[:,0],bins = n.arange(vmap_shape[0]))
bins = bins[:-1]

plt.plot(hist, bins)
plt.xlabel("# of neurons at a given depth")
plt.ylabel("Depth from surface (um)")
plt.yticks(n.arange(bins.max(),0,-bins.max()//6), -15*(bins.max()-n.arange(bins.max(),0,-bins.max()//6)));

# from the plot, seems like the shallowest plane has lots of cells,
# possibly because it's out of the brain and it's mostly noise...
# it might be a good idea to exclude them in the curation
# probably, when you have a longer recording you won't have this issue as much
